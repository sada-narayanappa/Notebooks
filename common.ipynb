# %%
# %%HTML
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#     font-family: Times 'Merriweather', Georgia, serif;
#     font-size: 10pt;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
#
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
#
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     ffont-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
# </style>
#
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>
# <script type="text/javascript" src="http://d3js.org/topojson.v1.min.js"></script>
# <script type="text/javascript" src="http://datamaps.github.io/scripts/0.4.0/datamaps.all.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#   font-family: Times 'Merriweather', Georgia, serif;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
#
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
#
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     ffont-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
# ...

# %%
debug = False;
import os.path

loadDir = "./";
maxDepth = 5;
while (maxDepth > 0):
    cf ="{}Features.py".format(loadDir);
    if (os.path.exists(cf)):
        break;
    loadDir = loadDir + "/../"
    maxDepth = maxDepth -1;
    if (debug): print (loadDir + ":" , maxDepth , cf)
        
cwd=os.getcwd()

if (debug):print ("Load directory is: " , loadDir, "CWD: ",cwd)
os.chdir(loadDir)

# %%
# %run  "DataFrameUtils.py"
# %run  "Features.py"
# %run  "DisplayUtils.py"
# %run  "Classification.py"
# %run  "StatUtils.py"
from datetime import timedelta;
from random import randint
from collections import defaultdict
# %matplotlib inline

# %%
os.chdir(cwd)
if (debug):print ("Load directory is: " , loadDir, "CWD: ",cwd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fe10f5e8b44f> in <module>()
# ----> 1 os.chdir(cwd)
#       2 if (debug):print ("Load directory is: " , loadDir, "CWD: ",cwd)
#
# NameError: name 'cwd' is not defined

# %%
import re;
import json;

# %%
from IPython.display import HTML

js = '''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
//$( document ).ready(code_toggle1);
</script>
<form action="javascript:code_toggle()">
<input type="submit" value="Toggle Code."></form>
''';

# %%
#%%javascript

#MathJax.Hub.Config({
#    TeX: { equationNumbers: { autoNumber: "AMS" } }
#});
#MathJax.Extension['TeX/AMSmath'].startNumber = 0;
#MathJax.Hub.Queue(["Reprocess",MathJax.Hub]);
#
#require("base/js/utils").load_extensions("latex_envs/latex_envs")

# %% [markdown]
# \begin{theorem} \label{theo:dotp}
# Let $u$ and $v$ be two vectors of $\mathbb{R}^n$. The dot product can be expressed as
# \begin{equation}
# \label{eq:dotp}
# u^Tv = |u||v| \cos \theta,
# \end{equation}
# where $\theta$ is the angle between $u$ and $v$ ...
# \end{theorem}

# %% [markdown]
# $$\frac{TR}{TP}$$
