# %%
# Usually you want this file stored someplace and load automatically
# %run "../PyUtils/common.ipynb"
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
# ...

# %%
# %%HTML
#
# <script>
# jj=''
# function test1(){
#     jj=ReturnJSONstring('#myform', 'myForm')
# }
# function test2(){
#     jj=findAndExcecuteCell('#sada', 0)
# }
# function test3(){
#     jj=findAndExcecuteCell('#sada1', 0)
# }
# function test4(){
#     jj=GetFormValue('#id', 't')
# }
# </script>
#
# <div style="background-color:gainsboro; border:solid black; width:100%; padding:10px;">
# <form id="myform">
#     <label>Name:</label>
#     <input type="text" id='name' name="name" value='sada'/>
#     <label>Email</label>
#     <input type="text" name="email"/>
#     <label>Password</label>
#     <input type="password" name="password"/>
#
#     <input type="checkbox" name="cb1" checked="checked">
#     <input type="checkbox" name="cb2" >
#
#     <select name="continent" size="1">
#       <option value="europe">europe</option>
#       <option value="namerica">n. america</option>
#       <option value="samerica">s. america</option>
#       <option value="asia">asia</option>
#       <option value="africa">africa</option>
#       <option value="oz">the other one</option>
#     </select>
# <br/>
# <input type="button" value="test1"  onclick="test1()" />
# <input type="button" value="test2"  onclick="test2()" />
# <input type="button" value="tes3"   onclick="test3()" />
# <input type="button" value="tes4"   onclick="test4()" />
#
# </form>
# </div>
# Out:
# <script>
# jj=''
# function test1(){
#     jj=ReturnJSONstring('#myform', 'myForm')
# }
# function test2(){
#     jj=findAndExcecuteCell('#sada', 0)
# }
# function test3(){
#     jj=findAndExcecuteCell('#sada1', 0)
# }
# function test4(){
#     jj=GetFormValue('#id', 't')
# }
# </script>
#
# <div style="background-color:gainsboro; border:solid black; width:100%; padding:10px;">
# <form id="myform">
#     <label>Name:</label>
#     <input type="text" id='name' name="name" value='sada'/>
#     <label>Email</label>
#     <input type="text" name="email"/>
#     <label>Password</label>
#     <input type="password" name="password"/>
#
#     <input type="checkbox" name="cb1" checked="checked">
#     <input type="checkbox" name="cb2" >
#
#     <select name="continent" size="1">
#       <option value="europe">europe</option>
#       <option value="namerica">n. america</option>
#       <option value="samerica">s. america</option>
#       <option value="asia">asia</option>
# ...

# %%
#sada
from IPython.display import HTML, Javascript

# --> Use this to set a value to a form element
js='''$('#id').val('sadananda Narayanappa')'''

# --> Use this to set a value to a named form element
js='''$('[name="email"]').val('sada@blah')'''

display(Javascript(js))
myForm
# Out:
# '{"name":"sada","email":"sada@blah","password":"test","cb1":"on","continent":"europe"}'

# %%
GetFormValue('name')
# Out:
# ''
