# %%
# %run "../../PyUtils/common.ipynb"
# %run "../../PyUtils/ShowExcel.ipynb"
import pymc3 as pymc3
from pymc3 import *
from numpy import median
from scipy import optimize
file="100MCMC1.xlsx"

from openpyxl.utils import *
wb,ws,js,df2 = openFileAndShow( file, 't1', 0)
df2Orig = df2.copy();

more='''
<script>
function getSelectedCell() {
    console.log($('#CELLADDRESS_t1').text())
}
</script>
<style>
.embtn {
    text-decoration: none; color: #555555; line-height: 1.9em;
    display: inline-block;    padding-left: 10px;    float:left;    padding-right: 10px;    font-family: sans-serif;
    border-top: 0px solid blue;    border-bottom: 1px solid #cccccc;;    border-left: none;    border-right: 1px dotted black;
    background-color: #f0f0f0;
}
.mbtn {
    text-decoration: none; color: #555555; line-height: 1.9em;
    display: inline-block;    padding-left: 10px;     padding-right: 10px;    font-family: sans-serif;
    border-top: 0px solid blue;    border-bottom: 1px solid #cccccc;
    border-left: 1px solid #cccccc;;    border-right: 1px solid #cccccc;
    background-color: #f0f0f0; float:left;
}
.mbtn:hover{     background-color: #cccccc;    border-color:#333;}
.mbtn:focus {    border-color:#333;    background-color: #fefefe;    border-bottom: 2px solid #010101;    outline:0;
}
</style>
<div id=menus style="width:100%; height:2.5em;border: 0px gray dotted;background-color: #ececec; padding-left: 50px;"> 

<input class=mbtn type="button" value="test"   onclick="getSelectedCell()" />
<input class=mbtn type="button" value="test.cgi" onclick="gu.getURL('http://localhost/~snarayan/test.cgi', callBackFunc)" />
<input class=mbtn  type="button" value="loc:8080" onclick="gu.getURL('http://localhost:8888/edit/Sites/test.html',callBackFunc)" />
</div>
'''
display(HTML(more))
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px black solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
# ...

# %%
#df2
