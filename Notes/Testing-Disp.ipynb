# %%
# %run "../Notebooks/PyUtils/common.ipynb"
import base64b
from pandas import ExcelFile
from io import StringIO, BytesIO

import os
import os.path
import sys
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta;
from random import randint
from collections import defaultdict
import matplotlib
import re;
import json;

# %%
# !ls ..

# %%
# %%javascript
# //IPython.notebook.execute_cell_and_select_below()
#
# IPython.keyboard_manager.edit_shortcuts.add_shortcut('alt-enter', {
#     help : "run cell and keep focus", //This is optional
#     handler : function (event) {
#         //console.log("sada")
#         //IPython.notebook.execute_cell_and_select_below();
#         IPython.notebook.execute_cell();
#         IPython.notebook.edit_mode();
#         //IPython.notebook.select_next();
#
#         return false;
#     }}
# );
# IPython.keyboard_manager.edit_shortcuts.add_shortcut('ctrl-enter', {
#     help : "run cell and keep focus", //This is optional
#     handler : function (event) {
#         IPython.notebook.execute_cell();
#         IPython.notebook.edit_mode();
#         return false;
#     }}
# );

# %%
# %%script false
# %%html
# <script src="http://d3js.org/d3.v3.min.js"></script>
# <script>
# //$("#site").css('height', '100%');
# //$("#site").css('padding-top', '80px');
# $("#header").css('display', 'none');
#
# if ($('#sada_head').length < 1) {
#     $('body').prepend('<div id="sada_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
# $('#sada_head').html($('#sada_head_content').val())
# </script>
#
# <textarea rows=5 id=sada_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
#
# </style>
#
# <div style="
#     pposition: fixed;
#     z-index: 50;
#     right: 0;
#     top: 0;
#     align-items: stretch;
#     width:100%">
#
# <div  style=
#     "background-color:#4285f4!important;
#     box-shadow: 2px 1px 1px #888888;
#     height: 54px; left: 0;
#     padding: 14px 12px;
#     z-index: 50;
#     -webkit-backface-visibility: hidden;
#     -webkizt-transform: translateZ(0);
#     -ms-flex-align: center;
#     -webkit-align-items: center;
#     align-items: center;
#     -webkit-flex-direction: row;
#     -ms-flex-direction: row;
#     flex-direction: row;
#     color:white;
#     font-family: 'Roboto','Heebo',Arial,sans-serif;
#     display: block;
#     "
# >
# <img style="display:inline;" align="baseline" width=32 src="ham1.png" />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font style="font-size:1.5em; display:inline;"> Data Science Dash board </font>
#
# <div style="text-align: right;display: block;color:white;float:right;width=50%">
# <a class="bh" style="" href="#" "> &raquo; Help </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; LM Internal Site </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; LM Wisdom </a> &nbsp;
#
# </div>
# </div>
# <div  style=
#     "background-color:#ffffff !important;
#     box-shadow: 2px 1px 1px #888888;
#     border-top: 1px solid #e0e0e0;
#     width: 100%
#     height: 55px;
#     padding: 14px 12px;
#     overflow: hidden;
#     ">
# <a class="bh1" style="" href="#" "> &raquo; Supply Chain Intel </a>
# <a class="bh1" style="" href="#" ">Cash Flow Forecasting</a>
# <a class="bh1" style="" href="#" ">Critical Mission Monitoring System (CMMS - NEC)</a>
# <a class="bh1" style="" href="#" ">Competitive Study</a>
#
# </div>
# </div>
# <ddiv style="height:6px;position:relative;"></ddiv>
#
# </textarea>

# %%
# %%script false
#
# %%html
# <style>
# .mbox2{
#     position: relative;
#     border-right: 1px #eeeeee solid;
#     bbox-shadow: 1px 1px 1px 1px #888888;
#     overflow: hidden;
#     display: inline-block;
#     width:400px;
#     height: 150px;
#     text-align: left;
#     padding-left: 10px;
#     padding-right: 10px;
# }
# </style>
#
# <div  style='position: relative; overflow: hidden; display: width:100%;text-align: center;border-bottom: 1px #eeeeee solid;'>
#     <div class='mbox2'>
#     <h3>Current Trends</h3><br/>
#     </div>
#     <div class='mbox2'>
#     <h3>Key Insights</h3>
#     </div>
#     <div class='mbox2'>
#     <h3>Recommendations:</h3>
# </div>

# %%
# %%html
# <script src="//d3js.org/d3.v3.min.js"></script>
# <style>
# .link {
#     stroke: #ccc;
#     stroke-width: 1px;
# }
#
# .linkOn {
#     stroke: #ccc;
#     stroke-width: 3px;
#
# }
# .node text {
#     stroke: #000000;
#     pointer-events: none;font: 12px sans-serif;
#     stroke-width: .5px;
# }
#
# .node {
#     stroke: firebrick;
#     stroke-width: 0px;
# }
#
# .node.moved {
#   ffill: #f00;
# }
#
# .chart1{
#     position: relative;
#     border-top: 1px gray #eeeeee;
#     box-shadow: 1px 1px 1px 1px #888888;
#     overflow-y: auto;
#     display: inline-block;
#     padding-left: 1px;
#     width:65%;
#     height:310px;
# }
# </style>
#
# <div sstyle="background-color:gainsboro; border:solid black; width:100%; height:310px;padding:01px;">
#
#     <div style="float:left;width:35%; ddisplay:inline;">
#         <textarea rows=15 id=graphtext style="width:100%; height:auto;display:inline-block;">
# idx,id,fixed,comment,x,y,group,sizer,links
# 0,A0,Y,"This is an example A01",0,0,1,10, 1 2
# 1,A1,Y, This is an' example A02,0,0,2,10, 3
# 2,A2,Y,"This is an example A03",0,0,2,10, 1
# 3,A3,Y,"This is an example A04",0,0,1,10, 2
#
# 4,A4,Y,"This is an example A04",0,0,1,10, 5
# 5,A5,Y,"This is an example A04",0,0,1,10, 4 6
# 6,A6,Y,"This is an example A04",0,0,1,10, 4
#
# 7,A4,Y,"This is an example A04",0,0,2,10, 8
# 8,A5,Y,"This is an example A04",0,0,2,10, 7 9
# 9,A6,Y,"This is an example A04",0,0,5,10, 8
#
#         </textarea><br/>
#         <input type="button" value="Redo the Graph"   onclick="findAndExcecuteCell('#create_new_graph', 0)" />
#         <input type="button" value="Show Original Graph"   onclick="d3json(jj2, 'id', 'group', 'r')" />
#         <br/>
#     </div>
#     <div id="chart1" class='chart1' style="">
#
#     </div>
#     <input id="status" style="width:100%;border: 1px solid solid;" value="#status"    />
# </div>
#
# <script>
#
# var gb1;
# var gb2;
#
# var width = $("#chart1").width(), height = 300
#
# var svg  = d3.select("#chart1").append("svg").attr("width", width).attr("height", height);
# var force = d3.layout.force().gravity(0.15).charge(-400).size([width, height]).linkDistance(40);
#
# var drag = force.drag().on("dragstart", mDragstart);
# //node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#
# fill = d3.scale.category20();
#
#
# function d3json(json, displayField, groupColor, radius, charge) {
#
#     if (typeof(json) === "undefined" ||  json == null) {
#         return;
#     }
#     d3.select("svg").selectAll("*").remove();
#
#     force.nodes(json.nodes).links(json.links).start();
#     var link = svg.selectAll(".link").data(json.links).enter().append("line").attr("class", "link");
#     var node = svg.selectAll(".node5").data(json.nodes).enter().append("g").attr("class", "node")
#         //.attr('charge', function(d) { d.r < 10 ?  -13500: 20})
#         .call(force.drag);
#
#
#     node.append("svg:circle")
# //    node.append("rect")
#     .attr("class", "node")
# //    .attr("x", function(d) { return d.x; })
# //    .attr("y", function(d) { return d.y; })
#     .attr("r", function(d) { return radius? d[radius]: 8; })
# //    .attr("width", function(d) { return 120; })
# //    .attr("height", function(d) { return  24; })
#     .on("dblclick", mDblclick)
#     .on('click', function(d) {d3.select(this).style('stroke-width', 6)} )
#     .on("mouseover", function(d) { d3.select(this).style('stroke-width', 6)} )
#     .on("mouseout",  function(d) { d3.select(this).style('stroke-width', 0)} )
#     .style("fill", function(d) { return groupColor? fill(d[groupColor]): fill(0); }
#     )
#
# //    node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#     node.append("text").attr("dx", "0px").attr("dy", "0px").text(function(d) { return displayField? d[displayField] : '' });
#
#     force.on("tick", function() {
#     link.attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; })
#         .on("dblclick", mEDblclick)
#         .on("click", mClick)
#         .on("mouseover", mOver)
#         .on("mouseout",  mOut)
#     ;
#
#     node.attr("transform", function(d) { return "translate(" + d.x + "," + d.y + ")"; });
#     });
# };
#
# function mClick(d) {
#     $('#status').val(" Edge Click: " + this)
#     gb1=d;
#     gb2=this;
#     console.log(d)
#     console.log(this)
# }
#
# function mEDblclick(d) {
#     console.log(this, " Edge Double cliked")
#     $('#status').val(" Edge Double cliked: " + this)
# }
#
# function mDblclick(d) {
#     d3.select(this).classed("moved", d.fixed = false);
#     console.log(this, " Double cliked")
#     $('#status').val(" Node Double cliked: " + this)
# }
#
# function mOver(d) {
# //    d3.select(this).classed("stroke-width", "3px");
#     d3.select(this).style('stroke-width', 6);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOver: " + this)
# }
#
# function mOut(d) {
# //    d3.select(this).classed("stroke-width", 1);
#     d3.select(this).style('stroke-width', 2);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOut: " + this)
# }
#
#
# function mDragstart(d) {
#   d3.select(this).classed("moved", d.fixed = true);
# }
#
# jj2= {'graph': {}, 'directed': true, 'multigraph': true,
#       'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}, {'source': 2, 'target': 3}, {'source': 4, 'target': 3}, {'source': 5, 'target': 9}, {'source': 5, 'target': 24}, {'source': 6, 'target': 3}, {'source': 8, 'target': 3}, {'source': 10, 'target': 19}, {'source': 10, 'target': 9}, {'source': 11, 'target': 17}, {'source': 11, 'target': 9}, {'source': 12, 'target': 3}, {'source': 14, 'target': 7}, {'source': 14, 'target': 17}, {'source': 14, 'target': 18}, {'source': 14, 'target': 19}, {'source': 14, 'target': 13}, {'source': 14, 'target': 16}, {'source': 14, 'target': 5}, {'source': 14, 'target': 24}, {'source': 15, 'target': 3}, {'source': 20, 'target': 18}, {'source': 20, 'target': 9}, {'source': 21, 'target': 5}, {'source': 21, 'target': 9}, {'source': 22, 'target': 13}, {'source': 22, 'target': 9}, {'source': 23, 'target': 16}, {'source': 23, 'target': 9}, {'source': 24, 'target': 3}],
#       'nodes': [{'id': 'B7', 'fixed': false, fx:50, fy:50, 'r': 8, 'group': 13}, {'id': 'C8', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'C2', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J3', 'fixed': true, x: 500, y: 80, 'r': 12, 'group': 16},
#                 {'id': 'C4', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'B3', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C6', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'G3', 'fixed': true, 'r': 12, 'group': 2},
#                 {'id': 'C5', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J2', 'fixed': true, 'r': 12, 'group': 12},
#                 {'id': 'B9', 'fixed': false, 'r': 8, 'group': 15}, {'id': 'B4', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C9', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'E3', 'fixed': true, 'r': 12, 'group': 18},
#                 {'id': 'D2', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'C7', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'F3', 'fixed': true, 'r': 12, 'group': 0}, {'id': 'D3', 'fixed': true, 'r': 12, 'group': 10},
#                 {'id': 'H3', 'fixed': true, 'r': 12, 'group': 4}, {'id': 'I3', 'fixed': true, 'r': 12, 'group': 14},
#                 {'id': 'B8', 'fixed': false, 'r': 8, 'group': 13}, {'id': 'B2', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'B5', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'B6', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C3', 'fixed': false, 'r': 8, 'group': 17}]}
#
# var graph = jj2
# d3json(graph, 'id', 'group', 'r')
#
# function test(gg) {
#     console.log(gg)
# }
#
#
# </script>

# %%
#create_new_graph

prt = '''
<script>

gr1 = {'graph': {}, 'directed': true, 'multigraph': true, 
'nodes' : [NODES],
'links' : [LINKS]
}
d3json(gr1, 'id', 'group', 'r')

</script>
'''

dff = '''
idx,id,fixed,comment,x,y,group, size,links
2,A3,Y,"This is an example A3",0,0,2,10, 1
3,A4,Y,"This is an example A4",0,0,1,10, 2
'''
dff=GetFormValue('#graphtext');

df=LoadDataSet(dff)
assert df is not None, "Could not get Data Frame: " +dff

#'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}], 
#'nodes': [{'id': 'B7', 'fixed': false, 'r': 8, 'group': 13}, {'id': 'C8', 'fixed': false, 'r': 8, 'group': 17} ]
l=[]
n=[]
for (i, r) in df.iterrows():
    it ="{{'id':'{}', 'fixed': false, 'fx':{}, 'fy': {}, 'r':{}, 'group':{}, 'desc':'{}'}}".format(r.id, r.x, r.y, r.sizer, r.group,r.comment.strip())
    
    for j in re.split('\s+', r.links.strip()):
        lk = "{{'source': {}, 'target': {} }}".format(i,j)
        l.append(lk)
    n.append(it)
    #print(it)
    
LINKS= ','.join(l)
NODES= ','.join(n)
g=prt.replace('NODES',NODES).replace('LINKS', LINKS)
display(HTML(g))

# %%
GetFormValue('#graphtext')

# %%
# %%script false
#
# js='''
# <H2> Tableau  Cards </H2>
# <div  style='position: relative; overflow: hidden; display: width:100%;'>
#
#
#
# <div class='tableauPlaceholder' id='viz1503229474559' style='position: relative;width:100%; heightpx: 350px; box-shadow: 1px 1px 1px #888888; overflow: hidden; display: inline-block;'>
# <noscript>
# <a href='#'><img alt='Profit Overview ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ta&#47;TableauExampleDashboard_0&#47;ProfitOverview&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'
# style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
#
#
# <param name='site_root' value='' />
# <param name='name' value='TableauExampleDashboard_0&#47;ProfitOverview' /><param name='tabs' value='no' />
# <param name='toolbar' value='no' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ta&#47;TableauExampleDashboard_0&#47;ProfitOverview&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' />
# </object>
# </div>
# </div>
#
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1503229474559');
# var vizElement = divElement.getElementsByTagName('object')[0];
#
# //vizElement.style.width='1104px';vizElement.style.height='769px';
# vizElement.style.width='1200px';vizElement.style.height='384px';
#
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
#
#
# </div>
# </div>
# '''
# #display(HTML(js))

# %%
# %%script false
#
# '''%%html
# <style>
# .mbox1{
#     position: relative;
#     border-top: 1px gray #eeeeee;
#     box-shadow: 1px 1px 1px 1px #888888;
#     overflow-y: auto;
#     display: inline-block;
#     width:400px;
#     height: 150px;
#     text-align: left;
#     padding-left: 10px;
# }
# </style>
#
# <div  style='position: relative; overflow: hidden ;width:100% !important;text-align: center;'>
#     <div class='mbox1'>
#     <h3>Current Trends</h3><br/>
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     </div>
#     &nbsp;
#     <div class='mbox1'>
#     <h3>Key Insights</h3>
#     </div>
#     &nbsp;
#     <div class='mbox1'>
#     <h3>Recommendations:</h3>
#     </div>
# <div>'''
#
# ;

# %%
# %%html
#
# <style>
# /* Dropdown Button */
# .dropbtn {
#     background-color: #4CAF50;
#     background-color: #4285f4;
#     color: white;
#     padding: 6px;
#     font-size: 12px;
#     font-weight: bold;
#     border: none;
#     cursor: pointer;
# }
# /* Change the background color of the dropdown button when the dropdown content is shown */
# .dropdown:hover .dropbtn {
#     background-color: #4285d4;;
#     text-decoration: none;
# }
#
#
# /* The container <div> - needed to position the dropdown content */
# .dropdown {
#     position: relative;
#     display: inline-block;
# }
#
# /* Dropdown Content (Hidden by Default) */
# .dropdown-content {
#     display: none;
#     position: absolute;
#     bbackground-color: #f9f9f9;
#     min-width: 160px;
#     border: 1px #fefefe solid;
#     box-shadow: 0px 1px 1px 0px rgba(0,0,0,0.2);
#     z-index: 1;
# }
#
# /* Links inside the dropdown */
# .dropdown-content a {
#     color: black;
#     text-decoration: none !important;
#     padding: 5px 16px;
#     display: block;
# }
#
# /* Change color of dropdown links on hover */
# .dropdown-content a:hover{ background-color: #f1f1f1; text-decoration: none; }
#
# /* Show the dropdown menu on hover */
# .dropdown:hover .dropdown-content {
#     display: block;
#     text-decoration: none;
# }
#
#
# </style>
#
# <div class="dropdown">
#   <button class="dropbtn">Drop Down Button</button>
#   <div class="dropdown-content">
#     <a class="" href="#">Link 1</a>
#     <a href="#">Link 2</a>
#     <a href="#">Link 3</a>
#   </div>
# </div>
#
# <br/>
# <br/>
# <br/>
# <br/>
# <br/><br/>
# <br/>
# <br/>
# <br/>
# xml

# %%
xmlDoc= '''<?xml version="1.0"?>
<data>
<elements>
    <branch name="testing" hash="1cdf045c">
        text,source
    </branch>
    
    <country name="Liechtenstein">
        <rank>1</rank>
        <year>2008</year>
        <gdppc>141100</gdppc>
        <neighbor name="Austria" direction="E"/>
        <neighbor name="Switzerland" direction="W"/>
    </country>
    <country name="Singapore">
        <rank>4</rank>
        <year>2011</year>
        <gdppc>59900</gdppc>
        <neighbor name="Malaysia" direction="N"/>
    </country>
    <country name="Panama">
        <rank>68</rank>
        <year>2011</year>
        <gdppc>13600</gdppc>
        <neighbor name="Costa Rica" direction="W"/>
        <neighbor name="Colombia" direction="E"/>
    </country>
</elements>
</data>
'''

import xml.etree.ElementTree as ET
#tree = ET.parse('country_data.xml')
#root = tree.getroot()
root = ET.fromstring(xmlDoc)
root.tag, root.attrib
for i,e in enumerate(root[0]):
    print(i, e.tag, e.attrib )
    for j,e1 in enumerate(e):
        print("\t", j, e1.tag, e1.attrib, e1.text )

# %%
# %%html
# <style>
# #div1, #div2 {
#     float: left;
#     width: 100px;
#     height: 35px;
#     margin: 10px;
#     padding: 10px;
#     border: 1px solid black;
# }
# </style>
# <script>
# function allowDrop(ev) {
#     ev.preventDefault();
# }
#
# function drag(ev) {
#     ev.dataTransfer.setData("text", ev.target.id);
# }
#
# function drop(ev) {
#     ev.preventDefault();
#     var data = ev.dataTransfer.getData("text");
#     ev.target.appendChild(document.getElementById(data));
# }
# </script>
# </head>
# <body>
#
# <div id="div1" ondrop="drop(event)" ondragover="allowDrop(event)">
#   <img src="ham1.png" draggable="true" ondragstart="drag(event)" id="drag1" width="88" height="31">
# </div>
#
# <div id="div2" ondrop="drop(event)" ondragover="allowDrop(event)"></div>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %%
# %%html
# <style>
# #file_drop
# {
#     font-weight: bold;
#     text-align: center;
#     padding: 1em 0;
#     border: 4px dashed #cccccc;
#     width:100%;
#     #float: right;
# }
#
# #file_drop.hover
# {
#     border: 4px dashed firebrick;
#
# }
# </style>
# <div class="fdrop1" id="file_drop" >DROP A File HERE
# <div id="results"> Status</div>
# <textarea rows=2 id=dada style="width:90%;ddisplay:none;">
# </textarea>
# </div>
# <div id="tableresults"> Table</div>
#
# <script>
# function status(msg){
#     m= $('#results');
#     m.html( msg  )
#     //console.log(msg)
# }
# var glt;
# var glt1;
#
# var out = ''
# function SetPythonVariable(buffer, callfunc) {
#     out= buffer;
#     console.log(" >", out.length)
#     var command =  " myBytes = b\'\'\'" + out + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     UpdateExcelSheet()
# //    findAndExcecuteCell('#showExcel')
#     console.log( command.substring(0,300) )
#     return out;
# }
#
# function readFile(files){
#     for (var i=0; i<files.length; i++) {
#         var file = files[i];
#         var reader = new FileReader();
#
#         status($('#results').text() + " Reading FIle :" + file.name)
#
#         fstr = "File: " + file.name + ", type: " + file.type + ", size: " + file.size + ", lastModified: " + file.lastModifiedDate
#
#         reader.onload = function(e) {
#             glt = e.target.result
#             glt1=glt;
#
#             if (file.type.indexOf("image") == 0 ){
#                 status(
#                     fstr + "<br />" +
#                     '<img src="' + glt + '" /></p>'
#                 );
#             }
#             if (file.type.indexOf("text") == 0 ){
#                 $('#dada').val(glt1.substr(0,300))
#                 status(
#                      fstr + ":<br />"
#                 );
#             }
#             if (file.type.indexOf(".sheet") > 0 ){
#                 glt1= btoa(glt);
#                 SetPythonVariable(glt1)
#                 $('#dada').val(glt1.substr(0,100))
#                 status(
#                     fstr + ":<br />"
#                 );
#             }
#         };
#         if (file.type.indexOf("image") == 0 )
#             rf = reader.readAsDataURL(file);
#         if (file.type.indexOf("text") == 0 )
#             rf = reader.readAsBinaryString(file);
#         if (file.type.indexOf(".sheet") > 0 )
#             rf = reader.readAsBinaryString(file);
#             //rf = reader.readAsDataURL(file);
#             //rf = reader.readAsArrayBuffer(file);
#     }
# }
#
# var file_drop = document.getElementById('file_drop');
# function handleDragOver(evt) {
#     evt.stopPropagation()
#     evt.preventDefault()
#     evt.dataTransfer.dropEffect = 'copy'
#     evt.target.className = (evt.type == "dragover" ? "hover" : "");
# }
#
# file_drop.addEventListener('dragover', handleDragOver, false )
# file_drop.addEventListener("dragleave", handleDragOver, false);
#
# var fff;
# file_drop.addEventListener(
#     'drop',
#     function(evt) {
#         evt.stopPropagation()
#         evt.preventDefault()
#         evt.target.className = ("");
#         var files = evt.dataTransfer.files  // FileList object.
#         var file = files[files.length-1]    // File     object.
#         console.log(file)
#         fff=file
#         status(file.name)
#         readFile(files)
#     },
#     false
# )
# status("Hello")
# function UpdateExcelSheet(){
#     console.log('!!');
#     Jupyter.notebook.kernel.execute('ACTION=0' );
#     findAndExcecuteCell('#showExcel')
# }
# </script>
# <input type=button value="Update Excel Sheet" onclick="UpdateExcelSheet()">

# %%
#showExcel
import base64
# %run "../PyUtils/common.ipynb"

if ("ACTION" not in globals()):
    ACTION=0

tableID = "excel"
disprows=5

if ( ACTION==1):
    setTable(dff, tableID, startRow=startRow, maxRows = disprows)


elif (True or ACTION ==0 or srt(ACTION).startswith("DISP")):
    assert 'myBytes' in globals(), "No ready yet"
        
    s=myBytes
    d=base64.decodestring(s)
    excel_data = ExcelFile(BytesIO(d))
    dff = excel_data.parse(excel_data.sheet_names[-1])
    #dff.columns = dff.columns.astype(str)
    dff= dff.fillna('')

    startrow=0
    otr= displayDFs(dff, showIcons=False, editable=True, showTypes=False, search='', maxrows=disprows, startrow=startrow, donotDisplay=True, id=tableID)

    butts = '''
    <script>
    idxs=[]
    vals=[]
    function updateTable(){
        if (idxs.length <=0)
            return;

        var i=0;
        $('#<TABLE_ID> tr').find('th:first').each(function ()
        {
            $(this).text(idxs[i++]);
        });
        i=0
        $('#excel td').each(function ()
        {
            $(this).text(vals[i++]);
        });
        console.log("!!!")

    }

    function myLocal(){
        ret = TableToJSON('#<TABLE_ID>')
        SetPyVarValue(ret,'globalVAR')
        Jupyter.notebook.kernel.execute("dff1=GetDFTable('#<TABLE_ID>', dff, True)")
        
    }

    function myGoto( gg, tab_maxRows, tab_maxDisp ) {
        g = Number.parseInt(gg)
        if (isNaN(g) ){
            return '';
        }
        var kernel = Jupyter.notebook.kernel;    
        command1 = "setTable(dff, '#<TABLE_ID>', startRow="+g+", maxRows = 5) "
        command = "ACTION=1; startRow= " +g
        kernel.execute( command ) ;
        kernel.execute( command1 ) ;
        console.log("Executing Command: " + command1 );
        console.log("Executing Command: " + idxs );
        r=findAndExcecuteCell('#showExcel')
        console.log(r)
        SETT()
        //updateTable()
    }
    var tab_maxRows = NUMROWS;
    var tab_maxDisp = MAXDISP;
    </script>

    <input type=button value='Update DataFrame' onclick="myLocal();">
    <input type=button value=' << ' onclick="myLocal();">
    <input type=button value=' >> ' onclick="myLocal();">
    <input type=button value='GOTO >>' onclick="myGoto( $('#goto').val(), tab_maxRows, tab_maxDisp );">
    <input id='goto' type=text value='0'  size=5 >
    <input type=button value='Search >>' onclick="myLocal();">
    <input type=text value=' ' onclick="myLocal();">
    '''.replace("<TABLE_ID>", tableID).replace('NUMROWS', str(len(dff))).replace('MAXDISP', str(disprows) )

    op = '''<textarea rows=5 id=temp1 style='ddisplay:none;width:100%' >{}</textarea> <script>$('#tableresults').html($('#temp1').text() ) </script>'''.format(otr+butts)

    #display(HTML(otr+butts))
    display(HTML(op))

ACTION
#butts

# %%
#testDisplayDF

# %run "../PyUtils/common.ipynb"
#c = readFile("../PyUtils/ajax.html")
#display(HTML(c))

advertising_DFF=LoadDataSet("../data/Advertising.csv")
tableID = "advertise"
disprows = 10;
startrow = 0
    
#r = getTableRows(DFF_PY_VAR_advertise, startRow=3, maxRows = 5)
#print(r)

butts_common = '''
<script>
jQuery.fn.reverse = [].reverse;

function UpdateTableShowRows( tab_maxRows, tab_maxDisp, tableID, out) {
    if(out.length <=2)
        return
        
    o = JSON.parse(out.slice(1, -1))
    // console.log("==>" + out );
    // console.log("==>VALS\\n " + o.vals );
    // console.log("==>IDXX " + o.idxs + " ++" + tableID);

    if (o.idxs.length <=0)
        return;

    var i=0;
    trs = '<TABLE_ID> tr'.replace('<TABLE_ID>', tableID)
    $(trs).find('th:first').each(function ()
    {
        $(this).text( o.idxs[i++]);
    });
    i=o.vals.length-1;
    tds = '<TABLE_ID> td'.replace('<TABLE_ID>', tableID)
    $(tds).reverse().each(function ()
    {
        $(this).text(o.vals[i--]);
    });
    
}

function TableShowRows( gg, tab_maxRows, tab_maxDisp, tableID, dataframeName ) {
    g = Number.parseInt(gg)
    if (isNaN(g) ){
        alert("hmmmm value: "+ gg + " make no sense" )
        return '';
    }
    var kernel = Jupyter.notebook.kernel;    
    command = "getTableRows({0}, startRow={1}, maxRows={2})".format(dataframeName, g, tab_maxDisp )
    cb = UpdateTableShowRows.bind(null, tab_maxRows, tab_maxDisp, tableID)
    gu.callPython( command, cb) ;
//    console.log("Executing Command: " + command );
}

function PrevPage(tab_maxRows, tab_maxDisp, tableID, dataframeName ){
    last = $(tableID).find('th:last').text()

    g = Number.parseInt(last)
    if (isNaN(g) ){
        alert("hmmmm value: "+ last + " is not Integer - Cannot Navigate!!" )
        return '';
    }
    
    var kernel = Jupyter.notebook.kernel;    
    command = "getTableRows({0}, startRow={1}, maxRows={2})".format(dataframeName, g - 2*tab_maxDisp+2 , tab_maxDisp )
    cb = UpdateTableShowRows.bind(null, tab_maxRows, tab_maxDisp, tableID)
    gu.callPython( command, cb) ;
//    console.log("Executing Command: " + command );
//    console.log("new Indexes are: " + idxs );

}
function NextPage(tab_maxRows, tab_maxDisp, tableID, dataframeName ){
    last = $(tableID).find('th:last').text()

    g = Number.parseInt(last)
    if (isNaN(g) ){
        alert("hmmmm value: "+ last + " is not Integer - Cannot Navigate!!" )
        return '';
    }
    
    var kernel = Jupyter.notebook.kernel;    
    command = "getTableRows({0}, startRow={1}, maxRows={2})".format(dataframeName, g , tab_maxDisp )
    cb = UpdateTableShowRows.bind(null, tab_maxRows, tab_maxDisp, tableID)
    gu.callPython( command, cb) ;
//    console.log("Executing Command: " + command );
//    console.log("new Indexes are: " + idxs );
}

function SaveDataFrameFromHTML(tableID, dataFrameVariable){
    ret = $(tableID).html()
    s = ret.indexOf('</thead>')
    if ( s< 0 ) return;
    s1 = ret.substr(s+10)
    ret = s1.replace(/\\n/g, '');
    //console.log(s, ret)
    //SetPyVarValue(ret,'globalVAR')
    cmd = "GetDFTableFromHTML(r\'\'\'{0}\'\'\', {1})".format(ret,dataFrameVariable);
    gu.callPython(cmd)
}
</script>
''';


butts = '''
<script>
//ret = s1.replace(/\\n/g, '');


function myLocal(){

}
</script>

<input type=button value='GO>>' onclick="TableShowRows( $('#<TABLE_ID>_goto').val(), NUMROWS, MAXDISP, '#<TABLE_ID>', 'DFF_PY_VAR_<TABLE_ID>' );">
<input id='<TABLE_ID>_goto' type=text value='9'  size=4 >
<input type=button value=' << ' onclick="PrevPage( NUMROWS, MAXDISP, '#<TABLE_ID>', 'DFF_PY_VAR_<TABLE_ID>' );">
<input type=button value=' >> ' onclick="NextPage( NUMROWS, MAXDISP, '#<TABLE_ID>', 'DFF_PY_VAR_<TABLE_ID>' );">

<input type=button value='Save' onclick="SaveDataFrameFromHTML('#<TABLE_ID>', 'DFF_PY_VAR_<TABLE_ID>');">
<input type=button value='Search >>' onclick="myLocal();">
<input type=text value=' '">
'''.replace("<TABLE_ID>", tableID).replace('NUMROWS', str(len(advertising_DFF))).replace('MAXDISP', str(disprows) )



globals()['DFF_PY_VAR_'+tableID] = advertising_DFF
otr= displayDFs(advertising_DFF, showIcons=True, editable=True, showTypes=False, search='', maxrows=disprows, startrow=startrow, donotDisplay=True, id=tableID)



op = '''<div id='tableresults1' style='ddisplay:none;width:100%' >{}</div>'''.format(otr+butts_common+butts)

#display(HTML(otr+butts))
display(HTML(op))

# %%
advertising_DFF[9:]

# %%
def getTableRows(dff, startRow=0, maxRows = 5):
    
    startRow = startRow if startRow >=0 else 0;
    e = startRow + maxRows
    
    if (e > len(dff)):
        ddd=dff[-maxRows:]
    else:
        ddd=dff[startRow:e]

    vals = re.findall('<td>(.*?)</td>',  ddd.to_html(), flags=re.DOTALL|re.M|re.MULTILINE|re.IGNORECASE)
    idxs = [""] + (list(ddd.index) )

    
    #ret = '''"vals": {}; "idxs": {}'''.format(json.dumps(vals), json.dumps(idxs))
    ret = '''{{"vals": {}, "idxs": {}}}'''.format(json.dumps(vals), (idxs) )
    
    ret = ret.replace("'", '"')
    
    return ret

def GetDFTableFromHTML(html, dff=None):

    vals = re.findall('<td.*?>(.*?)</td>',  html, flags=re.DOTALL|re.M|re.MULTILINE|re.IGNORECASE)
    idxs = re.findall('<th.*?>(.*?)</th>',  html, flags=re.DOTALL|re.M|re.MULTILINE|re.IGNORECASE)
    rows = re.findall('<tr.*?>(.*?)</tr>',  html, flags=re.DOTALL|re.M|re.MULTILINE|re.IGNORECASE)


    nRows = len(rows)
    nCols = len(vals)/nRows
    vals = np.array(vals).reshape(nRows, nCols)

    #print( vals, len(vals), nCols, nRows)

    dft = pd.DataFrame(vals)
    dft.index = idxs
    if (dff is None ):
        return dft
    
    dft.columns= dff.columns;
    dft.index  = dft.index.astype(dff.index)

    for i,dt in enumerate(dft.dtypes):
        if ( dt != dff.dtypes[i]):
            dft[dft.columns[i]] = dft[dft.columns[i]].astype(dff.dtypes[i])

    for i, r in dft.iterrows():
        dff.loc[i:i,:] = dft.loc[i:i,:]


        
#html='''dff1=test(r <tbody>    <tr>      <th>9</th>      <td contenteditable="">10</td>      <td contenteditable="">199.800</td>      <td contenteditable="">2.600</td>      <td contenteditable="">21.200</td>      <td contenteditable="">10.600</td>    </tr>    <tr>      <th>10</th>      <td contenteditable="">11</td>      <td contenteditable="">66.100</td>      <td contenteditable="">5.800</td>      <td contenteditable="">24.200</td>      <td contenteditable="">8.600</td>    </tr>    <tr>      <th>11</th>      <td contenteditable="">12</td>      <td contenteditable="">214.700</td>      <td contenteditable="">24.000</td>      <td contenteditable="">4.000</td>      <td contenteditable="">17.400</td>    </tr>    <tr>      <th>12</th>      <td contenteditable="">13</td>      <td contenteditable="">23.800</td>      <td contenteditable="">35.100</td>      <td contenteditable="">65.900</td>      <td contenteditable="">9.200</td>    </tr>    <tr>      <th>13</th>      <td contenteditable="">14</td>      <td contenteditable="">97.500</td>      <td contenteditable="">7.600</td>      <td contenteditable="">7.200</td>      <td contenteditable="">9.700</td>    </tr>    <tr>      <th>14</th>      <td contenteditable="">15</td>      <td contenteditable="">204.100</td>      <td contenteditable="">32.900</td>      <td contenteditable="">46.000</td>      <td contenteditable="">19.000</td>    </tr>    <tr>      <th>15</th>      <td contenteditable="">16</td>      <td contenteditable="">195.400</td>      <td contenteditable="">47.700</td>      <td contenteditable="">52.900</td>      <td contenteditable="">22.400</td>    </tr>    <tr>      <th>16</th>      <td contenteditable="">17</td>      <td contenteditable="">67.800</td>      <td contenteditable="">36.600</td>      <td contenteditable="">114.000</td>      <td contenteditable="">12.500</td>    </tr>    <tr>      <th>17</th>      <td contenteditable="">18</td>      <td contenteditable="">281.400</td>      <td contenteditable="">39.600</td>      <td contenteditable="">55.800</td>      <td contenteditable="">24.400</td>    </tr>    <tr>      <th>18</th>      <td contenteditable="">19</td>      <td contenteditable="">69.200</td>      <td contenteditable="">20.500</td>      <td contenteditable="">18.300</td>      <td contenteditable="">11.300</td>    </tr>  </tbody>, DFF_PY_VAR_advertise, True)'''
#GetDFTableFromHTML(html)
