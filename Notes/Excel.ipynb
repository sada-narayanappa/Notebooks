# %%
#Excel Spreadsheets
# %run "../PyUtils/common.ipynb"
# %run "../PyUtils/ShowExcel.ipynb"

from openpyxl.utils import *
wb,ws,js,df2 = openFileAndShow( "international.xlsx", 't1', 0)


def saveHTML(file, js):
    with open (file, "w") as fb:
        fb.write(js);
        fb.write("Sada")
        fb.flush()
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px black solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
# </style>
#
# <!--
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <-->
# <script src="https://ajax.googleapis.com/ajax/libs/angularjs/1.5.7/angular.min.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <div style="background-color:#f7f7f7; border: 1px dotted #cccccc; width:100%; padding:0px; margin: 0px">
# <button onclick="callsave1('#t1', 'df2')">Save to DataFrame</button>
# <label id='STATUS_t1' style="border: 0px solid black">status</label>
# </div>
# <div >
# <table   width=100% style="border: 0px;">
# <tr style="border: 0px;border-left: 0px solid gray;">
#
# <td id='CELLADDRESS_t1' contenteditable style="border: 0px;border-right: 1px dotted gray;width: 90px"> </td>
#
# <td style="border: 0px;text-align:center;" width=80px>
# <font style="font-family: serif; font-weight: 900; font-size: 16px; font-style: ooblique;color:#cccccc; text-align:center">
# &#10005 &nbsp;&nbsp;&nbsp;&#10003&nbsp;&nbsp;&nbsp; <i>f<sub>x</sub> </i>
# </font>
# </td>
#
# <td style="border:0px; border-left: 1px solid gray;width: 1px"></td>
#
# <td id='CELLContents_t1' contenteditable style="border: 0px;border-right: 5px solid gray;">Blah  </td></tr>
#
# </table>
# </div>
# <div><table id='t1' width='100%' border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>G</th>
#       <th>H</th>
#       <th>I</th>
#       <th>J</th>
#       <th>K</th>
#       <th>L</th>
#       <th>M</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td contenteditable >Country</td>
#       <td contenteditable >Y2016</td>
#       <td contenteditable >Share</td>
#       <td contenteditable >Rank</td>
#       <td contenteditable >Y2020</td>
#       <td contenteditable >Rank</td>
#       <td contenteditable >Y2016</td>
#       <td contenteditable >Share</td>
#       <td contenteditable >Rank</td>
#       <td contenteditable >Y2020</td>
#       <td contenteditable >Rank</td>
#       <td contenteditable >PPP/Nom</td>
#       <td contenteditable >Watch</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td contenteditable >Total</td>
#       <td contenteditable ></td>
#       <td contenteditable >63.020</td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td contenteditable >United States of America</td>
#       <td contenteditable >18561.934</td>
#       <td contenteditable >24.700</td>
#       <td contenteditable >1</td>
#       <td contenteditable >21927</td>
#       <td contenteditable >1</td>
#       <td contenteditable >18561.934</td>
#       <td contenteditable >15.600</td>
#       <td contenteditable >2</td>
#       <td contenteditable >21927</td>
#       <td contenteditable >2</td>
#       <td contenteditable >1</td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td contenteditable >China</td>
#       <td contenteditable >11391.619</td>
#       <td contenteditable >15.100</td>
#       <td contenteditable >2</td>
#       <td contenteditable >16458</td>
#       <td contenteditable >2</td>
#       <td contenteditable >21269.017</td>
#       <td contenteditable >17.900</td>
#       <td contenteditable >1</td>
#       <td contenteditable >29348</td>
#       <td contenteditable >1</td>
#       <td contenteditable >1.867</td>
#       <td contenteditable >China</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td contenteditable >Japan</td>
#       <td contenteditable >4730.300</td>
#       <td contenteditable >6.290</td>
#       <td contenteditable >3</td>
#       <td contenteditable >5506</td>
#       <td contenteditable >3</td>
#       <td contenteditable >4931.877</td>
#       <td contenteditable >4.140</td>
#       <td contenteditable >4</td>
#       <td contenteditable >5483</td>
#       <td contenteditable >4</td>
#       <td contenteditable >1.043</td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td contenteditable >Germany</td>
#       <td contenteditable >3494.898</td>
#       <td contenteditable >4.650</td>
#       <td contenteditable >4</td>
#       <td contenteditable >4008</td>
#       <td contenteditable >4</td>
#       <td contenteditable >3979.083</td>
#       <td contenteditable >3.340</td>
#       <td contenteditable >5</td>
#       <td contenteditable >4583</td>
#       <td contenteditable >5</td>
#       <td contenteditable >1.139</td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td contenteditable >United Kingdom</td>
#       <td contenteditable >2649.893</td>
#       <td contenteditable >3.520</td>
#       <td contenteditable >5</td>
#       <td contenteditable >2928</td>
#       <td contenteditable >6</td>
#       <td contenteditable >2787.741</td>
#       <td contenteditable >2.340</td>
#       <td contenteditable >9</td>
#       <td contenteditable >3244</td>
#       <td contenteditable >9</td>
#       <td contenteditable >1.052</td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td contenteditable >France</td>
#       <td contenteditable >2488.284</td>
#       <td contenteditable >3.310</td>
#       <td contenteditable >6</td>
#       <td contenteditable >2851</td>
#       <td contenteditable >7</td>
#       <td contenteditable >2736.717</td>
#       <td contenteditable >2.300</td>
#       <td contenteditable >10</td>
#       <td contenteditable >3185</td>
#       <td contenteditable >10</td>
#       <td contenteditable >1.100</td>
#       <td contenteditable ></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td contenteditable >India</td>
#       <td contenteditable >2250.987</td>
#       <td contenteditable >2.990</td>
#       <td contenteditable >7</td>
#       <td contenteditable >3297</td>
#       <td contenteditable >5</td>
#       <td contenteditable >8720.514</td>
#       <td contenteditable >7.320</td>
#       <td contenteditable >3</td>
#       <td contenteditable >12842</td>
#       <td contenteditable >3</td>
#       <td contenteditable >3.874</td>
#       <td contenteditable >India</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td contenteditable >Italy</td>
#       <td contenteditable >1852.499</td>
#       <td contenteditable >2.460</td>
#       <td contenteditable >8</td>
#       <td contenteditable >2046</td>
#       <td contenteditable >9</td>
#       <td contenteditable >2220.580</td>
#       <td contenteditable >1.860</td>
#       <td contenteditable >12</td>
#       <td contenteditable >2518</td>
#       <td contenteditable >12</td>
#       <td contenteditable >1.199</td>
#       <td contenteditable ></td>
#     </tr>
#   </tbody>
# </table></div><script>var rHeights= [14.0, 14.0, 14.0, 14.0, 16.0, 14.0, 14.0, 14.0, 14.0, 14.0]
# var cWidths = [3, 35.5, 11.1640625, 10.0, 14.83203125, 10.0, 10, 13.1640625, 8.0, 10, 10, 10, 10.6640625, 7.83203125]
# $('#t1 tr:eq(1) td:eq(0)').css('font-weight','bold' )
# $('#t1 tr:eq(1) td:eq(0)').css('background-color','#F9F9F9' )//Country
# $('#t1 tr:eq(1) td:eq(0)').css('text-align','center' )
# $('#t1 tr:eq(1) td:eq(0)').css('font','Times' )
# $('#t1 tr:eq(1) td:eq(0)').css('color','#000000' )
# $('#t1 tr:eq(1) td:eq(0)').css('fontSize','10.0px' )
# $('#t1 tr:eq(1) td:eq(0)').css('border','' )
# $('#t1 tr:eq(1) td:eq(1)').css('font-weight','bold' )
# $('#t1 tr:eq(1) td:eq(1)').css('background-color','#F9F9F9' )//Y2016
# $('#t1 tr:eq(1) td:eq(1)').css('text-align','center' )
# $('#t1 tr:eq(1) td:eq(1)').css('font','Times' )
# $('#t1 tr:eq(1) td:eq(1)').css('color','#000000' )
# $('#t1 tr:eq(1) td:eq(1)').css('fontSize','10.0px' )
# $('#t1 tr:eq(1) td:eq(1)').css('border','' )
# $('#t1 tr:eq(1) td:eq(2)').css('font-weight','bold' )
# $('#t1 tr:eq(1) td:eq(2)').css('b
