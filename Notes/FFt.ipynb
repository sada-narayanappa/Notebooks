# %%
try:       importlib.reload(Jupytils);
except:    import Jupytils
showTopbar("DFFT")
#plt.style.use('style/elegant.mplstyle')
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
# ...

# %%
f = 10  # Frequency, in cycles per second, or Hertz
f_s = 100  # Sampling rate, or number of measurements per second

t = np.linspace(0, 2, 2 * f_s, endpoint=False)
x = np.sin(f * 2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, x)
ax.set_xlabel('Time [s]')
ax.set_ylabel('Signal amplitude');

# %%
from scipy import fftpack

X = fftpack.fft(x)
freqs = fftpack.fftfreq(len(x)) * f_s

fig, ax = plt.subplots()

ax.stem(freqs, np.abs(X))
ax.set_xlabel('Frequency in Hertz [Hz]')
ax.set_ylabel('Frequency Domain (Spectrum) Magnitude')
ax.set_xlim(-f_s / 2, f_s / 2)
ax.set_ylim(-5, 110)
# Out:
# (-5, 110)

# %%
from IPython.display import Audio
Audio('https://www.safaribooksonline.com/library/view/elegant-scipy/9781491922927/data/nightingale.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="https://www.safaribooksonline.com/library/view/elegant-scipy/9781491922927/data/nightingale.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from skimage import util

M = 10
XX= np.arange(100)
slices = util.view_as_windows(XX, window_shape=(M,), step=5)
print('Audio shape: {}, Sliced audio shape: {} '.format(XX.shape, slices.shape))
slices
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-ba91bbd84b0e> in <module>()
# ----> 1 from skimage import util
#       2
#       3 M = 10
#       4 XX= np.arange(100)
#       5 slices = util.view_as_windows(XX, window_shape=(M,), step=5)
#
# ModuleNotFoundError: No module named 'skimage'

# %%
# !python --version
# Out:
# Python 3.5.3 :: Anaconda 4.4.0 (x86_64)

# %%
max(X)
# Out:
# (1.292839333942711e-13+3.3174428936039943e-14j)
