# %%
# %run "../common.ipynb"
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#     font-family: Times 'Merriweather', Georgia, serif;
#     font-size: 10pt;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     ffont-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.prompt {display:none}
#
# </style>
#
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>
# <script type="text/javascript" src="http://d3js.org/topojson.v1.min.js"></script>
# <script type="text/javascript" src="http://datamaps.github.io/scripts/0.4.0/datamaps.all.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import mpld3

mpld3.enable_notebook()

# %%
for i in range(10):
    fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
    ax.grid(color='white', linestyle='solid')
    N = 50
    scatter = ax.scatter(np.random.normal(size=N),
                         np.random.normal(size=N),
                         c=np.random.random(size=N),
                         s = 1000 * np.random.random(size=N),
                         alpha=0.3,
                         cmap=plt.cm.jet)
    display.clear_output(wait=True)
    time.sleep(1.0)
    plt.show()
    break;
    #display.display(pl.gcf())

ax.set_title("D3 Scatter Plot", size=18);

# %%
np.random.random(size=N)
# Out:
# array([ 0.03,  0.24,  0.35,  0.85,  0.11,  0.49,  0.29,  0.52,  0.13,  0.45,  0.71,  0.24,  0.52,  0.98,  0.34,  0.7 ,  1.  ,  0.2 ,  0.47,  0.56,  0.08,  0.21,  0.54,  0.08,  0.06,  0.85,  0.4 ,  0.2 ,  0.41,  0.13,  0.22,  0.3 ,  0.56,  0.2 ,  0.43,  0.56,  0.98,  0.71,  0.39,  0.57,  0.54,  0.39,  0.38,  0.24,  0.48,  0.94,  0.6 ,  0.34,  0.44,  0.01])

# %%
console.error("Sada")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4a886dee9381> in <module>()
# ----> 1 console.error("Sada")
#
# NameError: name 'console' is not defined

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display
for i in range(10):
    pl.plot(pl.randn(100))
    display.clear_output(wait=True)
    time.sleep(1.0)
    pl.show();
    #display.display(pl.gcf())

# %%
def hline(y,x1,x2, c='k', linewidth=6, linestyle="solid", label=None):
    plt.plot([x1,x2], [y,y], c=c, linewidth=linewidth,  linestyle=linestyle, label=label)

def vline(x,y1,y2, c='cyan', linewidth=20, linestyle="dashed", label=None):
    plt.plot([x,x], [y1,y2], c=c, linewidth=linewidth, linestyle=linestyle, label=label)

def rect(x1,y1,w,h,c='y', e='y'):
    r=plt.Rectangle( (x1,y1),w, h, facecolor=c, edgecolor=e,  alpha=0.9)
    plt.gca().add_patch(r)


N=3
M=3
plt.figure(figsize=(10,5))
plt.ylim(0,10)
plt.xlim(0,N*2)

y=7
for i in range(N):
    rect(i*2,y,1,1, c='w', e='k')
    plt.text(i*2+0.5,y +.5, 'S' + str(i), {'ha': 'center', 'va': 'center'}, color='k', size=12)
    vline(i*2+0.5,y, y - 1, linewidth=1, c='k')

A

# %%
from hmmlearn import hmm
from hmmlearn.hmm import GaussianHMM


model = GaussianHMM(3, "full", pi, A)
model.startprob_ = np.array([0.6, 0.3, 0.1])
model.transmat_ = np.array([[0.7, 0.2, 0.1],
                            [0.3, 0.5, 0.2],
                            [0.3, 0.3, 0.4]])
model.means_ = np.array([[0.0, 0.0], [3.0, -3.0], [5.0, 10.0]])
model.covars_ = np.tile(np.identity(2), (3, 1, 1))
model.means_ = means
model.covars_ = covars
X, Z = model.sample(10)
print (X,Z)
# Out:
# [[  0.28   0.06]
#  [  0.4    1.12]
#  [  3.16  -1.35]
#  [ -0.02   0.08]
#  [  0.13  -2.  ]
#  [  5.32   9.91]
#  [  5.94   9.83]
#  [  5.91  11.  ]
#  [  3.19  -1.27]
#  [  3.53  -3.91]] [0 0 1 0 0 2 2 2 1 1]
