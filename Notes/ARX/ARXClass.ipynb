# %%
# %load_ext autoreload
# %autoreload 2

try:    importlib.reload(Jupytils)
except: import Jupytils
import logging as log
import itertools as it
showTopbar('''PYAF Test drive''')

try: importlib.reload(Jupytils.Charts)
except: from Jupytils.Charts import *


from sklearn.linear_model import LinearRegression
from arch.univariate import ARX
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# ddiv.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function setSiteHeight(){
#     tHeight=0
#     $('div.output_subarea').each(function(i,e){
#         //console.log('sada', i, e, $(this).outerHeight() )
#         if ($(this).outerHeight() < 11) {
#             $(this).css('display', 'none')
#             $(this).css('outerHeight', '0px')
#         } else {
#             tHeight += $(this).outerHeight()
#         }
#     })
#     console.log('height', tHeight)
#     $("#site").css('height', tHeight +'px')
# }
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','90%')
#         //setSiteHeight()
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','100%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start=0){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <style>
# .sortdnafter:after { content: "\2193"}
# .sortupafter:after { content: "\2191";}
# .sortdnbefore:before { content: "\2193"}
# .sortupbefore:before { content: "\2191";}
# </style>
#
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
#
# function ExcecuteAllCells(content){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     start = 0;
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( code.startsWith(content)) {
#             console.log("Executing: " + cell);
#             cell.execute()
#         }
#         start += 1
#         cell = Jupyter.notebook.get_cell(start);
#     }
# }
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i > 0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     nRows = $(tableID).find('tr:last').index()+1
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, nRows )
#     cb = UpdateTableShowRows.bind(null, nRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function TableRefresh(tableID) {
#     nRows = $(tableID).find('tr:last').index()+1
#     last = $(tableID).find('th:last').text()
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRo
# <sscript src="http://d3js.org/d3.v3.min.js"></sscript>
#
# <textarea rows=5 id=sada_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
#
# </style>
#
# <div id='HTMLTopBar' style="
#     pposition: fixed;
#     pposition: absolute;
#     z-index: 50;
#     right: 0;
#     top: 0;
#     align-items: stretch;
#     width:100%">
#
#     <div  style=
#         "background-color:#4285f4!important;
#         box-shadow: 2px 1px 1px #888888;
#         height: 50px; left: 0;
#         padding: 14px 12px;
#         z-index: 50;
#         -webkit-backface-visibility: hidden;
#         -webkizt-transform: translateZ(0);
#         -ms-flex-align: center;
#         -webkit-align-items: center;
#         align-items: center;
#         -webkit-flex-direction: row;
#         -ms-flex-direction: row;
#         flex-direction: row;
#         color:white;
#         font-family: 'Roboto','Heebo',Arial,sans-serif;
#         display: block;
#         "
#     >
#     <iimg style="display:inline;" align="baseline" width=32 src="../imgs/ham1.png" />
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#
#
#     <font style="font-size:1.5em; display:inline;">PYAF Test drive</font>
#     <div style="text-align: right;display: block;color:white;float:right;width=50%">
#     <a class="bh" style="" href="#" "> &raquo; Help </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; Home </a> &nbsp;
#
#     </div>
#
#     </div>
# </div>
# </textarea>
#
# <script>
# if ($('#sada_head').length < 1) {
#     $('body').prepend('<div id="sada_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
#
# $('#sada_head').html($('#sada_head_content').val())
#
# $('.nbp-app-bar').toggle()
# </script>
# <script src="https://code.highcharts.com/stock/6.1.1/highstock.js"></script>
# <script src="https://code.highcharts.com/highcharts-more.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/modules/histogram-bellcurve.js"></script>

# %%
df=LoadDataSet("data/test.csv")
dfi=LoadDataSet("data/test.inv.xml", xmlTag="Invariant")
dfi['theta1']= dfi.apply (lambda row: [ float(i.strip()) for i in  row['theta'].split(',') if i.strip()], axis=1)
dfi.n=dfi.n.astype(int)
dfi.m=dfi.m.astype(int)
dfi.k=dfi.k.astype(int)
dfi.fitness=dfi.fitness.astype(float)
dfi.threshold=dfi.threshold.astype(float)

df
# Out:
#            Time      A       B       C      D      E      F      G
# 0         60000 94.502 156.473 148.500 64.516 25.060 50.310 47.876
# 1        120000 94.806 156.706 148.500 64.115 24.957 52.319 47.934
# 2        180000 94.602 156.691 148.500 64.189 24.691 53.450 48.524
# 3        240000 94.670 156.496 148.500 62.643 24.726 53.904 49.280
# ...         ...    ...     ...     ...    ...    ...    ...    ...
# 2497  149880000 94.679 157.041 148.500 61.631 25.016 50.494 48.733
# 2498  149940000 94.594 156.820 148.500 61.752 25.122 51.641 48.855
# 2499  150000000 95.229 156.739 148.500 62.567 25.575 52.215 49.056
# 2500  150060000 94.884 156.338 148.500 63.870 25.444 53.483 49.159
#
# [2501 rows x 8 columns]

# %%
#display(HTML(dfi.to_html()))
dfi.sort_values(['uName', 'yName'], inplace=True)
dfi=dfi.reset_index(drop=True)
displayDFs(dfi, showIcons=False);
# Out:
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>30x13 var: DFF_PY_VAR_tableID_1548312119587<br>
# <div id='tab_tableID_1548312119587' style='ddisplay:none;width:100%' >
#             <table id='tableID_1548312119587' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uName</th>
#       <th>yName</th>
#       <th>fitness</th>
#       <th>correlation</th>
#       <th>validity</th>
#       <th>theta</th>
#       <th>n</th>
#       <th>m</th>
#       <th>k</th>
#       <th>threshold</th>
#       <th>slope</th>
#       <th>intercept</th>
#       <th>theta1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >0.8356905058951782</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.7566798046980097,0.08742089615341801,76.55782422422585</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >4.617520279747</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[0.7566798046980097, 0.08742089615341801, 76.55782422422585]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >D</td>
#       <td style='white-space: nowrap;' contenteditable >0.29655860010845936</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >-0.9630133424708321,0.023043866594117834,0.10041268310120169</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >3.406622459967531</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[-0.9630133424708321, 0.023043866594117834, 0.10041268310120169]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >E</td>
#       <td style='white-space: nowrap;' contenteditable >0.16186693354785164</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.34367147588451813,-0.34042215819690835,24.711512869990965</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2.2843646765284835</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[0.34367147588451813, -0.34042215819690835, 24.711512869990965]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >F</td>
#       <td style='white-space: nowrap;' contenteditable >0.7211136678564295</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >-0.7120381334303367,0.20514306199581256,0.18059555568220276,-21.856425676200672</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >5.69048879407507</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[-0.7120381334303367, 0.20514306199581256, 0.18059555568220276, -21.856425676200672]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >G</td>
#       <td style='white-space: nowrap;' contenteditable >0.1252050411122706</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >-0.5345073561536757,-0.0029261322711296245,-0.044098931439243885,27.32336917086615</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >3.28462926090997</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[-0.5345073561536757, -0.0029261322711296245, -0.044098931439243885, 27.32336917086615]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >0.8428445919493313</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >1.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.5722391154919677,0.5838044266562292,-86.3624790442679</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >4.154889470245979</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >0.0</td>
#       <td style='white-space: nowrap;' contenteditable >[0.5722391154919677, 0.5838044266562292, -86.3624790442679]</td>
#     </tr>
#   </tbody>
# </table>
# <div style="display:block;height:20px">
#
# <input id='tableID_1548312119587_goto' type=text value=''  size=4
# onkeyup = "if (event.keyCode == 13) TableShowRows( $(this).val(), 6, '#tableID_1548312119587')">
#
# <input type=button value='<<' onclick="Page( 1, 6, '#tableID_1548312119587' );">
# <input type=button value='>>' onclick="Page( 0, 6, '#tableID_1548312119587' );">
#
# <input type=button value='Save' onclick="SaveDataFrameFromHTML('#tableID_1548312119587', 'DFF_PY_VAR_tableID_1548312119587');">
# <input type=button value='&#x21bb;' onclick="ResetToOrig('#tableID_1548312119587');">
# <input type=button value='Search>' onclick="SearchDataFrame('DFF_PY_VAR_tableID_1548312119587', '#tableID_1548312119587', 6);">
# <input id='tableID_1548312119587_search' type=text value=''" size=10
#     title="RE search support: ex: ^13$\b to search for 13"
#     onkeyup = "if (event.keyCode == 13) SearchDataFrame('DFF_PY_VAR_tableID_1548312119587', '#tableID_1548312119587', 6);">
# </div>
# <script>
# AddFocus('#tableID_1548312119587', 6);
# SetSort('#tableID_1548312119587');
# AddClickCB('#tableID_1548312119587', null);
# $(

# %%
def Theta(res,n):
    theta=list(res.params[1:n+1].values * -1) +  list(res.params[n+1:-1]) + [res.params[0]]
    return np.array(theta)

def formatRes(res,n):
    theta1=''
    for i,j in res.params[1:n+1].items(): 
        theta1 += "{:7.4f}, ".format(-j)
    for i,j in res.params[n+1:-1].items(): 
        theta1 += "{:7.4f}, ".format(j)

    theta1 += "{:7.4f}, ".format(res.params[0])
    
    return theta1

def formatRes(res,n):
    theta1=''
    for i,j in res.params[1:n+1].items(): 
        theta1 += "{}, ".format(-j)
    for i,j in res.params[n+1:-1].items(): 
        theta1 += "{}, ".format(j)

    theta1 += "{}, ".format(res.params[0])
    
    return theta1

def FitnessAR(y):
    bestFit, bestN, bestRes = (None,None,None)
    for n in range(1,4):
        arx = ARX(y,None, lags=n)
        res = arx.fit()

        th = Theta(res,n);
        ffitc,_,_,thr = FitnessScore(None,y,n,-1,0, th)
        if (bestFit is None or ffitc > bestFit):
            bestFit = ffitc; bestN=n; bestRes = res;

        print ("n", n, ffitc, th, max(abs(res.resid[1:]))*1.05)

    print ("best Fit: {} n: {}".format(bestFit, bestN ) )
    thresh = max(abs(bestRes.resid[bestN:]) ) *1.05
    
    return bestFit, bestN, bestRes, thresh

def ARXModel(y, x, n,m,k):
    if (x is None):
        xx = None
    else:
        xxx=[]
        for i in range(m, -1, -1):
            to = -(m+k-i) if ((m+k-i) > 0) else None
            xxx.append(x[i:to]);
            #print(i, -(m+k-i))

        xx = np.hstack(xxx)
        
    #print ( "===>", len(xx))
    arx = ARX(y[m+k:],xx, lags=n)
    res = arx.fit()
    return res, arx;

def INVXByName(df, yName, uName,n,m,k):
    y= df[yName]
    x= None if uName is None else np.matrix(df[uName]).transpose() 
    ret = ARXModel(y,x,n,m,k)
    return ret;

def INVX(y, x,n,m,k, yName=None, uName=None):
    x= None if x is None else np.matrix(x).transpose() 
    ret = ARXModel(y,x,n,m,k)
    return ret;

def INVG(dfi, r=0):
    dd = dfi.ix[r]
    uName,yName,n,m,k,th,f,trh=dd['uName'], dd['yName'], int(dd['n']), int(dd['m']), int(dd['k']), dd['theta'], float(dd['fitness']),float(dd['threshold'])
    t=''
    for i in  th.split(','):
        if ( not i.strip()): continue;
        t += "{:7.4f}, ".format(float(i.strip()))
    return uName,yName,n,m,k,t,f,trh


def INVRow(dfi, r=0):
    dd = dfi.ix[r]
    ret = dd
    ret.t = [ float(i.strip()) for i in  dd['theta'].split(',') if i.strip()]
    for i in range(ret.n): 
        ret.t[i] = ret.t[i]; 
    return ret


#Theta is a parameter matrix [n-coeffs, m-coffients, constant]
def predict(x, y, n,m,k, theta, t, updateArray=True):
    s = max(n, (m+k))
    if( t < s):
        print("Hmmm Passing an index i:{} resetting to {}".format(i,s))
        t=s
    
    if (x is None):
        p= list(reversed(y[t-n:t] * -1)) + [0] * (1+m)  + [1]
    else:
        p= list(reversed(y[t-n:t] * -1)) + list(reversed(x[t-m-k:t-k+1])) + [1]
    
    yh = (np.array(p).dot(theta))
    rs = (y[t] - yh)
    return yh,rs

# Just faster version of Predict (I think - may be not)
def predict1(x, y, n,m,k, theta, t, log=False):
    yh=0 
    for i in range(n):
        yh += y[t-i-1] * theta[i] * -1.0
        if ( log): print("yh = {} * {} * {}".format(y[t-i-1] , theta[i] , -1.0), end='')
    for i in range(m+1):
        yh += x[t-m-k+i] * theta[n+m-i]
        if ( log): print(" + {} * {} ".format(x[t-m-k+i] , theta[n+m-i]), end='')

    if ( log):  print(" + {} ".format(theta[-1]))

    yh += theta[-1]
    return yh, y[t] - yh

def FitnessScore(x, y, n,m,k,theta, needArrays=True, useSlowPredict=True):
    s=max(n,m+k)
    denom = sum((y[s:]-mean(y[s:]))**2)
    yhat=np.array(y.copy())
    residueFit=[]
    sumResidue = 0;
    for t in range(s,len(y)):  # <= predict all possible candidates
        if (useSlowPredict):
            yyFit,rrFit = predict(x, yhat, n,m,k, theta, t)
        else:
            yyFit,rrFit = predict1(x, yhat, n,m,k, theta, t)
            
        yhat[t] = yyFit
        sumResidue += rrFit ** 2
        
        if (needArrays):
            residueFit.append(rrFit)
   
    fitness = 1-sqrt(sumResidue/denom)
    return fitness,yhat,residueFit;

def findBest(df, y, x, useSlowPredict=True):
    best=Map({});
    for n in range(3):
        for m in range(2):
            for k in range(3):
                res, arx = INVX(y, x,n,m,k)
                theta= Theta(res,n)
                fitscore,yh,rs = FitnessScore(x,y,n,m,k, theta, False,useSlowPredict)
                    
                if (best.res is None or fitscore > best.fitscore ): 
                    best.res = res; best.rs=rs; best.nmk= (n,m,k); best.fitscore = fitscore; 
                    best.n=n; best.m=m; best.k=k;
                    
    best.threshold= max(abs(best.res.resid[best.nmk[0]:]) ) * 1.05
    best.cor = np.corrcoef(x,y)[0,0]
        
    return best;

log.getLogger().setLevel(log.WARN)
def CreateInvariants(df, filename="inv.xml", columns=[]):
    if ( len(df) <= 2 or len(df.columns) <= 1):
        raise Exception("Not enough data in the dataframe")
        
    cols = 'uName,yName,fitness,correlation,validity,theta,n,m,k,threshold,slope,intercept'.split(',')
    dfi = pd.DataFrame(columns=cols);
    newcols=[df.columns[0]]
    
    for c in df.columns[1:]:
        if len(df[c].unique()) > 1:
            newcols.append(c)
    if (len(newcols) < len(df.columns)):
        df = df[newcols]
        
    log.info("Creating invariants using {}".format( df.columns[1:]) )
    for u in df.columns[1:]:
        for v in df.columns[1:]:
            if (u == v):
                continue;
            if ( columns is not None and len(columns) > 0 and (u not in columns) ):
                print("Skipping ....", u, len(columns))
                continue;
                
            x=df[u].values    
            y=df[v].values
            ret = findBest(df, y, x, False);
            #print(f'{u}, {v}, best nmk: {ret.nmk}')
            inv1 = [u,v,ret.fitscore, ret.cor, 1, formatRes(ret.res,ret.n), ret.nmk[0], ret.nmk[1], ret.nmk[2], ret.threshold, 0.0, 0.0]
            ret = findBest(df, x, y, False);
            log.info("{}".format(inv1) )
            dfi.loc[len(dfi)] = inv1
                
    if ( filename is not None):
        dfi.to_csv(filename, index=False)
    
    dfi.sort_values(['uName', 'yName'], inplace=True)
    dfi['theta1']= dfi.apply (lambda row: [ float(i.strip()) for i in  row['theta'].split(',') if i.strip()], axis=1)

    return dfi

#########################################################################################################
def test(r=0):
    uName,yName,n,m,k,fth,fits,trs = INVG(dfi,r =r);
    print(r, "===========>")
    print("=>INV.XML:  {} fit:{:7.6f} thresHold: {:7.5f} nmk: {} ==> u: {} y: {} ".format(fth,  fits, trs, (n,m,k),uName, yName ) )

    y=df[yName].values
    x=df[uName].values
    res,arx = INVX(y, x, n,m,k, yName, uName)
    fitc,th, rs= FitnessScore(x,y,n,m,k,Theta(res,n))
    mthr = max(abs(res.resid[n:]) ) *1.05
    
    #==> Verify
    print("=>COMPUTED: {} fit:{:7.6f} threshold: {:7.5f}".format(formatRes(res,n), fitc, mthr))

    #==> Compute Best FIT for a pair
    ret = findBest(df, y, x, True);
    cor = np.corrcoef(x,y)[0,0]
    print("=>BEST FIT: {} fit:{:7.6f} threshold: {:7.5f} nmk: {}".format(formatRes(ret.res,n), ret.fitscore, ret.threshold, ret.nmk) )

def test1(r=0):
    uName,yName,n,m,k,fth,fits,trs = INVG(dfi,r =r);
    y=df[yName].values
    x=df[uName].values    
    ret = findBest(df, y, x, False);
    if((n,m,k) != ret.nmk or abs(ret.fitscore-fits) > 0.06 or (ret.threshold-trs)>0.05):
        print("{:4d} Expected {} got {}".format(r,(n,m,k), ret.nmk))
        print("=>INV.XML:  {} fit:{:7.6f} thresHold: {:7.5f} nmk: {} ==> u: {} y: {} ".format(fth,  fits, trs, (n,m,k),uName, yName ) )
        print("=>BEST FIT: {} fit:{:7.6f} threshold: {:7.5f} nmk: {}".format(formatRes(ret.res,n), ret.fitscore, ret.threshold, ret.nmk) )

def testall():
    for i in range(0,len(dfi)):
        test1(i)

#test(4)

#%time test1(len(dfi)-12);

# %time invs=CreateInvariants(df)
#anomDF=LoadDataSet("data/test-ab20.csv")
# Out:
# CPU times: user 52.8 s, sys: 21.6 s, total: 1min 14s
# Wall time: 19.8 s

# %%
u,v,f,c,_,t,n,m,k,thr,_,_,etheta=dfi.loc[4]
x=df[u].values    
y=df[v].values
best=findBest(df, y, x, useSlowPredict=True)
print(f'{u, v} {f} === {best.fitscore}, \n{(n,m,k)} === {best.nmk}, \n {thr} === {best.threshold}')
# Out:
# ('A', 'G') 0.1252050411122706 === 0.12520649804987516,
# ('1', '1', '0') === (1, 1, 0),
#  3.28462926090997 === 3.284679883215223

# %%
cols='uName,yName,fitness,n,m,k,threshold'.split(',')
displayDFs([invs[cols], dfi[cols]]);
# Out:
# <table style='vertical-align: top;'><td style='text-align:left;' bgcolor=#ffffff>30x7 var: DFF_PY_VAR_tableID_1536572314508<br>
# <div id='tab_tableID_1536572314508' style='ddisplay:none;width:100%' >
#             <table id='tableID_1536572314508' cellpadding=0 cellspacing=0 border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uName</th>
#       <th>yName</th>
#       <th>fitness</th>
#       <th>n</th>
#       <th>m</th>
#       <th>k</th>
#       <th>threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >0.836</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >4.618</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >D</td>
#       <td style='white-space: nowrap;' contenteditable >0.297</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >3.407</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >E</td>
#       <td style='white-space: nowrap;' contenteditable >0.162</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2.284</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >F</td>
#       <td style='white-space: nowrap;' contenteditable >0.721</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >5.691</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >G</td>
#       <td style='white-space: nowrap;' contenteditable >0.125</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >3.285</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >0.843</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >4.155</td>
#     </tr>
#   </tbody>
# </table>
# <div style="display:block;height:20px">
#
# <input id='tableID_1536572314508_goto' type=text value=''  size=4
# onkeyup = "if (event.keyCode == 13) TableShowRows( $(this).val(), 6, '#tableID_1536572314508')">
#
# <input type=button value='<<' onclick="Page( 1, 6, '#tableID_1536572314508' );">
# <input type=button value='>>' onclick="Page( 0, 6, '#tableID_1536572314508' );">
#
# <input type=button value='Save' onclick="SaveDataFrameFromHTML('#tableID_1536572314508', 'DFF_PY_VAR_tableID_1536572314508');">
# <input type=button value='&#x21bb;' onclick="ResetToOrig('#tableID_1536572314508');">
# <input type=button value='Search>' onclick="SearchDataFrame('DFF_PY_VAR_tableID_1536572314508', '#tableID_1536572314508', 6);">
# <input id='tableID_1536572314508_search' type=text value=''" size=10
#     title="RE search support: ex: ^13$\b to search for 13"
#     onkeyup = "if (event.keyCode == 13) SearchDataFrame('DFF_PY_VAR_tableID_1536572314508', '#tableID_1536572314508', 6);">
# </div>
# <script>
# AddFocus('#tableID_1536572314508', 6);
# SetSort('#tableID_1536572314508');
# AddClickCB('#tableID_1536572314508', null);
# $("#tableID_1536572314508 th").resizable()
#
# </script>
#
#             <div id='tableID_1536572314508_searchResults'></div>
#             </div></td><td>&nbsp;</td><td style='text-align:left;' bgcolor=lightblue>30x7 var: DFF_PY_VAR_tableID_1536572314535<br>
# <div id='tab_tableID_1536572314535' style='ddisplay:none;width:100%' >
#             <table id='tableID_1536572314535' cellpadding=0 cellspacing=0 border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uName</th>
#       <th>yName</th>
#       <th>fitness</th>
#       <th>n</th>
#       <th>m</th>
#       <th>k</th>
#       <th>threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >0.8356905058951782</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >4.617520279747</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >D</td>
#       <td style='white-space: nowrap;' contenteditable >0.29655860010845936</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >3.406622459967531</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >E</td>
#       <td style='white-space: nowrap;' contenteditable >0.16186693354785164</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >2.2843646765284835</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >F</td>
#       <td style='white-space: nowrap;' contenteditable >0.7211136678564295</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >2</td>
#       <td style='white-space: nowrap;' contenteditable >5.69048879407507</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >G</td>
#       <td style='white-space: nowrap;' contenteditable >0.1252050411122706</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >1</td>
#       <td style='white-space: nowrap;' contenteditable >0</td>
#       <td style='white-space: nowrap;' contenteditable >3.28462926090997</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td style='white-space: nowrap;' contenteditable >B</td>
#       <td style='white-space: nowrap;' contenteditable >A</td>
#       <td style='white-space: nowrap;' contenteditable >0.8428445

# %%
def DetectAnomaly(t, invDF, anomDF, sumFitness, edgeCounts, logdetailed=True ):
    ret = Map({})
    ret.t = t;
    ret.anomScore = 0;
    ret.brokenInvs= 0;
    ret.SumSignif = 0;
    ret.brkSignif = 0;
    ret.scores = []
    ret.sumFitness = sumFitness; #sum(invDF.fitness.astype(float));

    ret.brkns = Map({});
    for i in range(len(invDF)):
        r = INVRow(invDF,r = i)
        
        brkn= Map({})
        brkn.brknFitSum =0;
        brkn.r = r
        u=anomDF[r.uName].values
        y=anomDF[r.yName].values
        brkn.uName, brkn.yName, brkn.nmk = r.uName, r.yName, (r.n, r.m, r.k)
        ret.brkns[brkn.uName+":"+brkn.yName] = brkn
        
        thetaArray = invDF.ix[i].theta1;
        #if(r.t != thetaArray): print(r.t , thetaArray )
        
        brkn.yh, brkn.res = predict1(u, y, r.n, r.m, r.k, thetaArray, t, False)
        brkn.sigf  = abs(brkn.res)/r.threshold
        ret.SumSignif += brkn.sigf
        brkn.wsigf     = brkn.sigf * r.fitness
        brkn.broken = " "
        brkn.y = y[t]
        
        if (abs(brkn.res) > r.threshold * 1.1):
            brkn.broken = "*"
            ret.anomScore += r.fitness
            ret.brokenInvs+= 1
            ret.brkSignif += brkn.sigf

    #    break;
    
        #if (logdetailed): 
        #    print("{} {:2d} {} {} fit: {:.4f} Sigf: {:10.4f}({:7.4f}) score: {:6.2f} - {:6.2f} = {:8.2f}, thresh: {:12.6f}".format(brkn.broken,\
        #        i, (brkn.uName, brkn.yName), brkn.nmk, brkn.r.fitness, brkn.sigf, brkn.wsigf, brkn.y, brkn.yh, brkn.res, brkn.r.threshold* 1.1) )

    ret.suspicions, ret.suspicionsCounts = suspicions(ret, edgeCounts, logdetailed);
    print( "Score: {:3d} Anom:{:10.4f} normedAnom: {:6.4f} brk:{:3d}".format(t, ret.anomScore, ret.anomScore/ret.sumFitness , ret.brokenInvs) )
    return ret;
      
def suspicions(ret, edgeCounts, logDetailed=True):
    bvars=defaultdict(int)
    bvarsCount=defaultdict(int)
    bfits=0;
    for i,brkn in sorted(ret.brkns.items()):
        #print(i)
        if (logDetailed):
            print("{} {} {} fit: {:.4f} Sigf: {:10.4f}({:7.4f}) score: {:6.2f} - {:6.2f} = {:8.2f}, thresh: {:12.6f}".format(brkn.broken,\
            i, brkn.nmk, brkn.r.fitness, brkn.sigf, brkn.wsigf, brkn.y, brkn.yh, brkn.res, brkn.r.threshold* 1.1) )
        if ( brkn.broken.strip()):
            bvars[brkn.uName] += brkn.r.fitness
            bvars[brkn.yName] += brkn.r.fitness
            bvarsCount[brkn.uName] += 1
            bvarsCount[brkn.yName] += 1
            #bvars[brkn.uName] += 1
            
    for i, k in sorted(bvars.items()):
        bvars[i] = k/edgeCounts[i]
        if (logDetailed): print(i, bvars[i]), edgeCounts
    return bvars, bvarsCount;
        

def FindResiduals(df, invDF, anomDF, start=None,stop=None, detailedLog=False):
    maxLag = max(max(invDF.n),max(invDF.m+invDF.k))
    start  = maxLag if start is None or start < maxLag else start
    stop   = len(anomDF) if stop is None or stop >= len(anomDF) else stop
    
    allUVs   = list(invDF.uName.values) + list(invDF.yName.values)
    nodes  = unique(allUVs)
    edgeCounts=pd.value_counts(pd.Series(allUVs))
    edges  = unique(list(invDF.uName.values + ":"+ invDF.yName.values))
    sumFit = sum(invDF.fitness.astype(float))
    print("maxLag: {}, Number Nodes: {}, Number of Invariants: {}, sumFit: {}, ".format(maxLag, len(nodes), len(edges), sumFit))

    ret=Map({})
    for t in range(start, stop):
        ret[t]=DetectAnomaly(t, invDF, anomDF, sumFit, edgeCounts, detailedLog)

    return ret, edgeCounts;

anomDF=LoadDataSet("data/test-ab20.csv")
dfi.n=dfi.n.astype(int)
dfi.m=dfi.m.astype(int)
dfi.k=dfi.k.astype(int)
dfi.fitness=dfi.fitness.astype(float)
dfi.threshold=dfi.threshold.astype(float)

#ret, edgeCounts = FindResiduals(df, invs, anomDF, 3,94, False);
ret, edgeCounts = FindResiduals(df, dfi, anomDF, 3,94, False);
#dfi.ix[0].theta1
# Out:
# maxLag: 3, Number Nodes: 6, Number of Invariants: 30, sumFit: 8.820847628339417,
# Score:   3 Anom:    7.0306 normedAnom: 0.7970 brk: 22
# Score:   4 Anom:    7.0306 normedAnom: 0.7970 brk: 22
# Score:   5 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:   6 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:   7 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:   8 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:   9 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  10 Anom:    6.9116 normedAnom: 0.7836 brk: 21
# Score:  11 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  12 Anom:    6.9116 normedAnom: 0.7836 brk: 21
# Score:  13 Anom:    6.9116 normedAnom: 0.7836 brk: 21
# Score:  14 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  15 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  16 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  17 Anom:    7.2129 normedAnom: 0.8177 brk: 22
# Score:  18 Anom:    6.9116 normedAnom: 0.7836 brk: 21

# %%
line=4

#Show Plot for all the anomalies entries
an=[]
for k in sorted(ret.keys()):
    an.append(ret[k].anomScore)
    #print(k, ret[k].anomScore)
plt.plot(sorted(ret.keys()), an);

print("Broken Invariants:")
for k in sorted(ret[line].brkns.keys()):
    print(k, ret[line].brkns[k].broken, ret[3].brkns[k].sigf)

print("\nSuspicious Metrics:")
for k,v in sorted(ret[line].suspicions.items()):
    scount = ret[line].suspicionsCounts[k]
    ecount = edgeCounts[k]
    print(k,v, scount, ecount)
# Out:
# Broken Invariants:
# A:B * 7.004633237877048
# A:D   0.5431066011052574
# A:E * 3.9732740093388794
# A:F * 5.034700278663152
# A:G * 3.1828825502783755
# B:A * 8.743524271866104
# B:D   0.80211875646881
# B:E * 5.0388199679048515
# B:F * 8.099085400427683
# B:G * 4.337632733464636
# D:A * 4.183757978934525
# D:B * 7.72499680511068
# D:E * 10.281475782936894
# D:F   0.026521986807077215
# D:G * 3.891778428169319
# E:A * 1.2088201251615192
# E:B   0.04085505570603878
# E:D * 23.18658394260754
# E:F   0.460401955499192
# E:G * 1.2086614373336613
# F:A * 5.496055946782194
# F:B * 8.88353309675543
# F:D   0.03336362732039968
# F:E * 5.047522922714044
# F:G * 5.104426807393671
# G:A * 7.4491723018466205
# G:B * 9.817688330726867
# G:D   0.3158522855408407
# G:E * 6.549964959563021
# G:F   0.9487893472906072
#
# Suspicious Metrics:
# A 0.38522205163528905 9 10
# B 0.3531061171302491 8 10
# D 0.14651050857775472 5 10
# E 0.12189538924351481 8 10
# F 0.3089650439456717 6 10
# G 0.09041245690606546 8 10

# %%
def timeStamp(strptime="5/4/2016 11:19"):
    dt=pd.to_datetime(strptime, utc=True)
    return int(dt.timestamp()*1000)

def closestRow(pseries, time='6/19/2016'):
    dt1=timeStamp(time)
    r = np.argmin(np.abs(pseries - dt1))
    return r

def isInt(s):
    ret = None;
    try:
        ret = int(s)
    except ValueError:
        pass;
    
    return ret

#test 
tt = ("5/6/2017 10:20")
closestRow(df.ix[:,0], tt)
timeStamp('6/19/2016')

time1 = datetime.datetime.now()
time2 = datetime.datetime.now()

10000/60/60
# Out:
# 2.7777777777777777

# %%
invFile = "/NEC/workingDir/p31/cr12_7.inv.xml"

invDF=LoadDataSet(invFile, xmlTag="Invariant")
invDF = invDF.infer_objects()
invDF = invDF['uName yName fitness theta n m k threshold'.split()]
invDF.fitness  = invDF.fitness.astype(float)
invDF.threshold= invDF.threshold.astype(float)
invDF.n = invDF.n.astype(int)
invDF.m = invDF.m.astype(int)
invDF.k = invDF.k.astype(int)
invDF['theta1']= invDF.apply (lambda row: thetaF(row),axis=1)  # Convert to float array
invDFA = invDF.as_matrix()
invDFC = Map({})
for i, c in enumerate(invDF.columns):
    invDFC[c] = i;

# %%
allUVs   = list(invDF.uName.values) + list(invDF.yName.values)
nodes  = np.unique(allUVs)
nodes
# Out:
# array(['CR2_0002', 'CR2_0006', 'CR2_0011', 'CR2_0015', 'CR2_0016', 'CR2_0017', 'CR2_0018', 'CR2_0019', 'CR2_0020', 'CR2_0025', 'CR2_0026', 'CR2_0045', 'CR2_2719', 'CR2_3518', 'CR2_4228', 'CR2_4229', 'CR2_4231', 'CR2_4276', 'CR2_4277', 'CR2_4278', 'CR2_4279', 'CR2_4280', 'CR2_4281', 'CR2_4282', 'CR2_4283', 'CR2_4287', 'CR2_4288', 'CR2_4289', 'CR2_4290', 'CR2_4292', 'CR2_4293', 'CR2_4294', 'CR2_4295', 'CR2_4296', 'CR2_4297', 'CR2_4298', 'CR2_4299', 'CR2_4300', 'CR2_4301', 'CR2_4302', '