# %%
# %run "../PyUtils/common.ipynb"
import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#     font-family: Times 'Merriweather', Georgia, serif;
#     font-size: 10pt;
# }
#
# body {
#     font: 72.5%/1.7em "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     color: #555;
# }
#
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
# ...

# %%
'''
Install these R Packages:

install.packages('gridExtra')
install.packages("astsa", repos="http://cran.rstudio.com/")
install.packages("ggplot2")
'''
# Out:
# '\nInstall these R Packages:\n\ninstall.packages(\'gridExtra\')\ninstall.packages("astsa", repos="http://cran.rstudio.com/")\ninstall.packages("ggplot2")\n'

# %%
# %%R
# library(ggplot2)
# library(gridExtra)

# %%
# %%R -o pf -w 800 -h 200 -u px  # output variable pf and make image width = 300 and height = 200 units are in PX
# library(astsa)
#
# pf = read.csv('/Users/snarayan/Downloads/eda-course-materials/lesson3/pseudo_facebook.tsv', sep='\t')
#
# p1= qplot(x=friend_count, data=pf)
# p2= qplot(x=log10(friend_count +1), data=pf)
# p3= qplot(x=sqrt(friend_count), data=pf)
#
# grid.arrange(p1, p2, p3, ncol=3)

# %%
# %%R -w 800 -h 200 -u px
#
# ggplot(aes(x = friend_count, y = ..count../sum(..count..)), data = subset(pf, !is.na(gender))) +
#   geom_freqpoly(aes(color = gender), binwidth=10) +
#   scale_x_continuous(limits = c(0, 1000), breaks = seq(0, 1000, 50)) +
#   xlab('Friend Count') +
#   ylab('Percentage of users with that friend count')

# %%
# %%R -w 800 -h 200 -u px
#
# qplot(x=www_likes, data=subset(pf, !is.na(gender)),
#      geom = 'freqpoly', color = gender)  + scale_x_continuous() + scale_x_log10()

# %%
# %%R -w 800 -h 300 -u px
#
# qplot(x=gender, y = friendships_initiated, data=subset(pf, !is.na(gender)), geom='boxplot')  + coord_cartesian(ylim=c(0,200))

# %%
displayDFs(pf)
# Out:
# <table><td bgcolor=#efefef>99003 rows x 15 columns<br><table border="1" class="dataframe">
#   <thead>
#         <tr bgcolor=#e6e6fa>
#       <th bgcolor=#e6e6fa>count</th>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#       <td>99003.000</td>
#     </tr>
#     <tr bgcolor=#e6e6fa>
#       <th bgcolor=#e6e6fa>unique</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>2</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr bgcolor=#e6e6fa>
# ...

# %%
# %run "../PyUtils/common.ipynb"
a = np.matrix([0.55, 0.45])
b = np.matrix([[.7,.3], [.1, .9]])
m1 = A(a, "A")
m2 = A(b, "B")
s =a
m1.M(m1.a);
#m2.d();
#l = m1.l
display (Math("A_{1 \\times 2} \n") )
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#     font-family: Times 'Merriweather', Georgia, serif;
#     font-size: 10pt;
# }
#
# body {
#     ffont: 72.5%/3em "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     color: #555;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# ...

# %%
for i in range(20):
    s = s*b
    #display(s)

# %%
s=m2.pr()
# Out:
# $$B_{2 \times 2} = \begin{bmatrix}
# 0.7 & 0.3\\\\0.1 & 0.9
# \end{bmatrix}$$

# %%
s
# Out:
# 'B_{2 \\times 2} = \\begin{bmatrix}\n0.7 & 0.3\\\\\\\\0.1 & 0.9\n\\end{bmatrix}'
