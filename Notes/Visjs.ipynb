# %% [markdown]
# # Example Charts

# %%
try:       importlib.reload(Jupytils);
except:    import Jupytils
try: importlib.reload(Jupytils.Charts)
except: from Jupytils.Charts import *

showTopbar("Charts")
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# ddiv.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function setSiteHeight(){
#     tHeight=0
#     $('div.output_subarea').each(function(i,e){
#         //console.log('sada', i, e, $(this).outerHeight() )
#         if ($(this).outerHeight() < 11) {
#             $(this).css('display', 'none')
#             $(this).css('outerHeight', '0px')
#         } else {
#             tHeight += $(this).outerHeight()
#         }
#     })
#     console.log('height', tHeight)
#     $("#site").css('height', tHeight +'px')
# }
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','90%')
#         //setSiteHeight()
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','100%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start=0){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <style>
# .sortdnafter:after { content: "\2193"}
# .sortupafter:after { content: "\2191";}
# .sortdnbefore:before { content: "\2193"}
# .sortupbefore:before { content: "\2191";}
# </style>
#
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
#
# function ExcecuteAllCells(content){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     start = 0;
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( code.startsWith(content)) {
#             console.log("Executing: " + cell);
#             cell.execute()
#         }
#         start += 1
#         cell = Jupyter.notebook.get_cell(start);
#     }
# }
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i > 0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     nRows = $(tableID).find('tr:last').index()+1
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, nRows )
#     cb = UpdateTableShowRows.bind(null, nRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function TableRefresh(tableID) {
#     nRows = $(tableID).find('tr:last').index()+1
#     last = $(tableID).find('th:last').text()
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRo
# <script src="https://code.highcharts.com/stock/6.1.1/highstock.js"></script>
# <script src="https://code.highcharts.com/highcharts-more.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/modules/histogram-bellcurve.js"></script>
# <sscript src="http://d3js.org/d3.v3.min.js"></sscript>
#
# <textarea rows=5 id=sada_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
#
# </style>
#
# <div id='HTMLTopBar' style="
#     pposition: fixed;
#     pposition: absolute;
#     z-index: 50;
#     right: 0;
#     top: 0;
#     align-items: stretch;
#     width:100%">
#
#     <div  style=
#         "background-color:#4285f4!important;
#         box-shadow: 2px 1px 1px #888888;
#         height: 50px; left: 0;
#         padding: 14px 12px;
#         z-index: 50;
#         -webkit-backface-visibility: hidden;
#         -webkizt-transform: translateZ(0);
#         -ms-flex-align: center;
#         -webkit-align-items: center;
#         align-items: center;
#         -webkit-flex-direction: row;
#         -ms-flex-direction: row;
#         flex-direction: row;
#         color:white;
#         font-family: 'Roboto','Heebo',Arial,sans-serif;
#         display: block;
#         "
#     >
#     <iimg style="display:inline;" align="baseline" width=32 src="../imgs/ham1.png" />
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#
#
#     <font style="font-size:1.5em; display:inline;">Charts</font>
#     <div style="text-align: right;display: block;color:white;float:right;width=50%">
#     <a class="bh" style="" href="#" "> &raquo; Help </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; Home </a> &nbsp;
#
#     </div>
#
#     </div>
# </div>
# </textarea>
#
# <script>
# if ($('#sada_head').length < 1) {
#     $('body').prepend('<div id="sada_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
#
# $('#sada_head').html($('#sada_head_content').val())
#
# $('.nbp-app-bar').toggle()
# </script>

# %%
html = '''
<link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" rel="stylesheet" type="text/css" />

<script>
if ( typeof vis ==="undefined" ) {
    require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.js"], function(lib) {
        window.vis = jQuery.extend(true, {}, lib);
    });
}
</script>
'''
display(HTML(html))
# Out:
# <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" rel="stylesheet" type="text/css" />
#
# <script>
# if ( typeof vis ==="undefined" ) {
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#     });
# }
# </script>

# %%
def genNW(c):
    nodes=[]
    edges=[]
    for i in range(c):
        n=Map()
        n.id = i
        n.label =  str(i)
        n.group = random.randint(0,4)
        nodes.append(n)
        
        for j in range(random.randint(1,6)):
            e=Map()
            e['from'] = i; 
            e['to'] =  random.randint(0,c)
            edges.append(e)
    
        
    data={'nodes': nodes, 'edges': edges}
    return data

d=genNW(100)
v = "var data =" + json.dumps(d)
#print(v)

# %%
import os, sys
import numpy as np
import pandas as pd
import datetime as dt
import random as rd

from IPython.display import display
from IPython.display import HTML, Javascript

from math import sin, cos, pi, sqrt
html = '''
<style type="text/css">
  #mynetwork { width: 700px; height: 400px; border: 1px solid lightgray; }
</style>

<div id="mynetwork"></div>

<script>

if ( typeof network !== "undefined") {
    network.destroy()
    network=null;
}
// create an array with nodes
  var nodes = new vis.DataSet([
    {id: 1, label: 'Node 1'},
    {id: 2, label: 'Node 2'},
    {id: 3, label: 'Node 3'},
    {id: 4, label: 'Node 4'},
    {id: 5, label: 'Node 5'}
  ]);

  // create an array with edges
  var edges = new vis.DataSet([
    {from: 1, to: 3},
    {from: 1, to: 2},
    {from: 2, to: 4},
    {from: 2, to: 5},
    {from: 3, to: 3}
  ]);

  // create a network
  var data = {
    nodes: nodes,
    edges: edges
  };
  //DATA

    var options = {
      nodes: {
        shape: 'dot',
        scaling: { min: 2, max: 10, label: {   min: 3, max: 10, drawThreshold: 12,  maxVisible: 200 } },
        font: { size: 12, face: 'Tahoma'   }
      },
      edges: { width: 0.15, color: {inherit: 'from'}, smooth: { type: 'continuous' } },
      physics: false,
      interaction: { tooltipDelay: 200, hideEdgesOnDrag: true }
    };
    var options = {
                nodes: {
                    shape: 'dot',
                    size: 16
                },        physics: { 
                stabilization: false },
                layout:{
                    randomSeed:34
                },
                
        };

            var options1 = {
                nodes: {
                    shape: 'dot',
                    size: 6
                },
                physics: {
                    forceAtlas2Based: {
                        gravitationalConstant: -26,
                        centralGravity: 0.005,
                        springLength: 23,
                        springConstant: 0.18
                    },
                    maxVelocity: 146,
                    solver: 'forceAtlas2Based',
                    timestep: 0.35,
                    stabilization: {iterations: 150}
                },
                physics: {
                      enabled: false
                }
            };
            var options2 = {
                nodes: {
                    shape: 'dot',
                    size: 16
                },
                layout:{
                    randomSeed:34
                },
                physics: {
                    forceAtlas2Based: {
                        gravitationalConstant: -26,
                        centralGravity: 0.005,
                        springLength: 230,
                        springConstant: 0.18
                    },
                    maxVelocity: 146,
                    solver: 'forceAtlas2Based',
                    timestep: 0.0,
                    stabilization: {
                        enabled:true,
                        iterations:2000,
                        updateInterval:25
                    }
                }
            };
            
    var network = new vis.Network($('#mynetwork')[0], data, options);
    network.fit()
</script>
'''
d=genNW(400)
v = "var data = JSON.parse('" + json.dumps(d) + "')\n"
js=html.replace("//DATA", v)
display(HTML(js) )
# Out:
# <style type="text/css">
#   #mynetwork { width: 700px; height: 400px; border: 1px solid lightgray; }
# </style>
#
# <div id="mynetwork"></div>
#
# <script>
#
# if ( typeof network !== "undefined") {
#     network.destroy()
#     network=null;
# }
# // create an array with nodes
#   var nodes = new vis.DataSet([
#     {id: 1, label: 'Node 1'},
#     {id: 2, label: 'Node 2'},
#     {id: 3, label: 'Node 3'},
#     {id: 4, label: 'Node 4'},
#     {id: 5, label: 'Node 5'}
#   ]);
#
#   // create an array with edges
#   var edges = new vis.DataSet([
#     {from: 1, to: 3},
#     {from: 1, to: 2},
#     {from: 2, to: 4},
#     {from: 2, to: 5},
#     {from: 3, to: 3}
#   ]);
#
#   // create a network
#   var data = {
#     nodes: nodes,
#     edges: edges
#   };
#   var data = JSON.parse('{"nodes": [{"id": 0, "label": "0", "group": 4}, {"id": 1, "label": "1", "group": 3}, {"id": 2, "label": "2", "group": 4}, {"id": 3, "label": "3", "group": 4}, {"id": 4, "label": "4", "group": 1}, {"id": 5, "label": "5", "group": 0}, {"id": 6, "label": "6", "group": 3}, {"id": 7, "label": "7", "group": 0}, {"id": 8, "label": "8", "group": 1}, {"id": 9, "label": "9", "group": 4}, {"id": 10, "label": "10", "group": 1}, {"id": 11, "label": "11", "group": 1}, {"id": 12, "label": "12", "group": 2}, {"id": 13, "label": "13", "group": 3}, {"id": 14, "label": "14", "group": 4}, {"id": 15, "label": "15", "group": 1}, {"id": 16, "label": "16", "group": 2}, {"id": 17, "label": "17", "group": 0}, {"id": 18, "label": "18", "group": 3}, {"id": 19, "label": "19", "group": 3}, {"id": 20, "label": "20", "group": 4}, {"id": 21, "label": "21", "group": 4}, {"id": 22, "label": "22", "group": 4}, {"id": 23, "label": "23", "group": 0}, {"id": 24, "label": "24", "group": 2}, {"id": 25, "label": "25", "group": 2}, {"id": 26, "label": "26", "group": 1}, {"id": 27, "label": "27", "group": 2}, {"id": 28, "label": "28", "group": 2}, {"id": 29, "label": "29", "group": 2}, {"id": 30, "label": "30", "group": 1}, {"id": 31, "label": "31", "group": 1}, {"id": 32, "label": "32", "group": 3}, {"id": 33, "label": "33", "group": 2}, {"id": 34, "label": "34", "group": 4}, {"id": 35, "label": "35", "group": 4}, {"id": 36, "label": "36", "group": 3}, {"id": 37, "label": "37", "group": 1}, {"id": 38, "label": "38", "group": 0}, {"id": 39, "label": "39", "group": 4}, {"id": 40, "label": "40", "group": 2}, {"id": 41, "label": "41", "group": 3}, {"id": 42, "label": "42", "group": 2}, {"id": 43, "label": "43", "group": 0}, {"id": 44, "label": "44", "group": 0}, {"id": 45, "label": "45", "group": 2}, {"id": 46, "label": "46", "group": 2}, {"id": 47, "label": "47", "group": 0}, {"id": 48, "label": "48", "group": 2}, {"id": 49, "label": "49", "group": 1}, {"id": 50, "label": "50", "group": 4}, {"id": 51, "label": "51", "group": 2}, {"id": 52, "label": "52", "group": 3}, {"id": 53, "label": "53", "group": 1}, {"id": 54, "label": "54", "group": 2}, {"id": 55, "label": "55", "group": 3}, {"id": 56, "label": "56", "group": 2}, {"id": 57, "label": "57", "group": 4}, {"id": 58, "label": "58", "group": 0}, {"id": 59, "label": "59", "group": 4}, {"id": 60, "label": "60", "group": 3}, {"id": 61, "label": "61", "group": 4}, {"id": 62, "label": "62", "group": 3}, {"id": 63, "label": "63", "group": 4}, {"id": 64, "label": "64", "group": 1}, {"id": 65, "label": "65", "group": 0}, {"id": 66, "label": "66", "group": 2}, {"id": 67, "label": "67", "group": 3}, {"id": 68, "label": "68", "group": 4}, {"id": 69, "label": "69", "group": 1}, {"id": 70, "label": "70", "group": 1}, {"id": 71, "label": "71", "group": 4}, {"id": 72, "label": "72", "group": 2}, {"id": 73, "label": "73", "group": 2}, {"id": 74, "label": "74", "group": 1}, {"id": 75, "label": "75", "group": 1}, {"id": 76, "label": "76", "group": 0}, {"id": 77, "label": "77", "group": 0}, {"id": 78, "label": "78", "group": 3}, {"id": 79, "label": "79", "group": 1}, {"id": 80, "label": "80", "group": 1}, {"id": 81, "label": "81", "group": 3}, {"id": 82, "label": "82", "group": 0}, {"id": 83, "label": "83", "group": 4}, {"id": 84, "label": "84", "group": 2}, {"id": 85, "label": "85", "group": 1}, {"id": 86, "label": "86", "group": 2}, {"id": 87, "label": "87", "group": 2}, {"id": 88, "label": "88", "group": 0}, {"id": 89, "label": "89", "group": 0}, {"id": 90, "label": "90", "group": 0}, {"id": 91, "label": "91", "group": 1}, {"id": 92, "label": "92", "group": 0}, {"id": 93, "label": "93", "group": 2}, {"id": 94, "label": "94", "group": 0}, {"id": 95, "label": "95", "group": 0}, {"id": 96, "label": "96", "group": 4}, {"id": 97, "label": "97", "group": 0}, {"id": 98, "label": "98", "group": 3}, {"id": 99, "label": "99", "group": 3}, {"id": 100, "label": "100", "group": 2}, {"id": 101, "label": "101", "group": 4}, {" ...

# %%
# %%html
#
# <script type="text/javascript">
#
# function getScaleFreeNetwork(nodeCount) {
#   var nodes = [];
#   var edges = [];
#   var connectionCount = [];
#
#   // randomly create some nodes and edges
#   for (var i = 0; i < nodeCount; i++) {
#     nodes.push({
#       id: i,
#       label: String(i),
#                   group: Math.floor(Math.random() * 4)
#
#     });
#
#     connectionCount[i] = 0;
#
#     // create edges in a scale-free-network way
#     if (i == 1) {
#       var from = i;
#       var to = Math.floor(Math.random() * nodeCount);
#       edges.push({
#         from: from,
#         to: to,
#       });
#       connectionCount[from]++;
#       connectionCount[to]++;
#     }
#     else if (i > 100) {
#       var conn = edges.length * 2;
#       var rand = Math.floor(Math.random() * conn);
#       var cum = 0;
#       var j = 0;
#       while (j < connectionCount.length && cum < rand) {
#         cum += connectionCount[j];
#         j++;
#       }
#
#
#       var from = i;
#       var to = j;
#       edges.push({
#         from: from,
#         to: to
#       });
#       connectionCount[from]++;
#       connectionCount[to]++;
#     }
#   }
#
#   return {nodes:nodes, edges:edges};
# }
#
#
#
#     var nodes = null;
#     var edges = null;
#     var network = null;
#     var setSmooth = false;
#
#     function destroy() {
#       if (network !== null) {
#         network.destroy();
#         network = null;
#       }
#     }
#
#     function draw() {
#       destroy();
#       var nodeCount = 400
#       // create a network
#       var container = document.getElementById('mynetwork');
#       var data = getScaleFreeNetwork(nodeCount);
#       var options = {
#         physics: { stabilization: false }
#       };
#       network = new vis.Network(container, data, options);
#     }
#
#
# draw()
#   </script>
# Out:
# <script type="text/javascript">
#
# function getScaleFreeNetwork(nodeCount) {
#   var nodes = [];
#   var edges = [];
#   var connectionCount = [];
#
#   // randomly create some nodes and edges
#   for (var i = 0; i < nodeCount; i++) {
#     nodes.push({
#       id: i,
#       label: String(i),
#                   group: Math.floor(Math.random() * 4)
#
#     });
#
#     connectionCount[i] = 0;
#
#     // create edges in a scale-free-network way
#     if (i == 1) {
#       var from = i;
#       var to = Math.floor(Math.random() * nodeCount);
#       edges.push({
#         from: from,
#         to: to,
#       });
#       connectionCount[from]++;
#       connectionCount[to]++;
#     }
#     else if (i > 100) {
#       var conn = edges.length * 2;
#       var rand = Math.floor(Math.random() * conn);
#       var cum = 0;
#       var j = 0;
#       while (j < connectionCount.length && cum < rand) {
#         cum += connectionCount[j];
#         j++;
#       }
#
#
#       var from = i;
#       var to = j;
#       edges.push({
#         from: from,
#         to: to
#       });
#       connectionCount[from]++;
#       connectionCount[to]++;
#     }
#   }
#
#   return {nodes:nodes, edges:edges};
# }
#
#
#
#     var nodes = null;
#     var edges = null;
#     var network = null;
#     var setSmooth = false;
#
#     function destroy() {
#       if (network !== null) {
#         network.destroy();
#         network = null;
#       }
#     }
#
#     function draw() {
#       destroy();
#       var nodeCount = 400
#       // create a network
#       var container = document.getElementById('mynetwork');
#       var data = getScaleFreeNetwork(nodeCount);
#       var options = {
#         physics: { stabilization: false }
#       };
#       network = new vis.Network(container, data, options);
#     }
#
#
# draw()
#   </script>
