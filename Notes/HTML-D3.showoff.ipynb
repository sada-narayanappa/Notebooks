# %%
# %run "../PyUtils/common.ipynb"
import base64
from pandas import ExcelFile
from io import StringIO, BytesIO

import os
import os.path
import sys
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta;
from random import randint
from collections import defaultdict
import matplotlib
import re;
import json;
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
# <!--
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <-->
# <script src="https://ajax.googleapis.com/ajax/libs/angularjs/1.5.7/angular.min.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
#
# <script>
#
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
#
#
# }
#
# code_show=false;
# function ToggleEle(element) {
#
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#     } else {
#         $(element).css('display', 'none');
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function Ntoggle(){
#     ToggleEle('#header')
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '100%');
# }
#
# function assert(condition, message) {
#     if (!condition) {
#         cdonsole.log(message + "Assertion failed")
#         throw message || "Assertion failed";
#     }
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON1(tableName, which) {
#     ret = {}
#     which = which || 'td'
#     var cells = $(tableName).find(which);
#     var i = 0;
#     cells.each(function () {
#         var ct = $(this).text()
#         ret[i++] = ct
#         //console.log(i, ct)
#     });
#     ret1 = JSON.stringify(ret)
#     return ret1;
# }
#
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>

# %%
# %%script false
# %%html
# <script src="http://d3js.org/d3.v3.min.js"></script>
# <script>
# //$("#site").css('height', '100%');
# //$("#site").css('padding-top', '80px');
# $("#header").css('display', 'none');
#
# if ($('#sada_head').length < 1) {
#     $('body').prepend('<div id="sada_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
# $('#sada_head').html($('#sada_head_content').val())
# </script>
#
# <textarea rows=5 id=sada_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
#
# </style>
#
# <div style="
#     pposition: fixed;
#     z-index: 50;
#     right: 0;
#     top: 0;
#     align-items: stretch;
#     width:100%">
#
# <div  style=
#     "background-color:#4285f4!important;
#     box-shadow: 2px 1px 1px #888888;
#     height: 54px; left: 0;
#     padding: 14px 12px;
#     z-index: 50;
#     -webkit-backface-visibility: hidden;
#     -webkizt-transform: translateZ(0);
#     -ms-flex-align: center;
#     -webkit-align-items: center;
#     align-items: center;
#     -webkit-flex-direction: row;
#     -ms-flex-direction: row;
#     flex-direction: row;
#     color:white;
#     font-family: 'Roboto','Heebo',Arial,sans-serif;
#     display: block;
#     "
# >
# <img style="display:inline;" align="baseline" width=32 src="ham1.png" />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <font style="font-size:1.5em; display:inline;"> Data Science Dash board </font>
#
# <div style="text-align: right;display: block;color:white;float:right;width=50%">
# <a class="bh" style="" href="#" "> &raquo; Help </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; LM Internal Site </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; LM Wisdom </a> &nbsp;
#
# </div>
# </div>
# <div  style=
#     "background-color:#ffffff !important;
#     box-shadow: 2px 1px 1px #888888;
#     border-top: 1px solid #e0e0e0;
#     width: 100%
#     height: 55px;
#     padding: 14px 12px;
#     overflow: hidden;
#     ">
# <a class="bh1" style="" href="#" "> &raquo; Supply Chain Intel </a>
# <a class="bh1" style="" href="#" ">Cash Flow Forecasting</a>
# <a class="bh1" style="" href="#" ">Critical Mission Monitoring System (CMMS - NEC)</a>
# <a class="bh1" style="" href="#" ">Competitive Study</a>
#
# </div>
# </div>
# <ddiv style="height:6px;position:relative;"></ddiv>
#
# </textarea>

# %%
# %%script false
#
# %%html
# <style>
# .mbox2{
#     position: relative;
#     border-right: 1px #eeeeee solid;
#     bbox-shadow: 1px 1px 1px 1px #888888;
#     overflow: hidden;
#     display: inline-block;
#     width:400px;
#     height: 150px;
#     text-align: left;
#     padding-left: 10px;
#     padding-right: 10px;
# }
# </style>
#
# <div  style='position: relative; overflow: hidden; display: width:100%;text-align: center;border-bottom: 1px #eeeeee solid;'>
#     <div class='mbox2'>
#     <h3>Current Trends</h3><br/>
#     </div>
#     <div class='mbox2'>
#     <h3>Key Insights</h3>
#     </div>
#     <div class='mbox2'>
#     <h3>Recommendations:</h3>
# </div>

# %%
# %%html
# <script src="//d3js.org/d3.v3.min.js"></script>
# <style>
# .link {
#     stroke: #ccc;
#     stroke-width: 1px;
# }
#
# .linkOn {
#     stroke: #ccc;
#     stroke-width: 3px;
#
# }
# .node text {
#     stroke: #000000;
#     pointer-events: none;font: 12px sans-serif;
#     stroke-width: .5px;
# }
#
# .node {
#     stroke: firebrick;
#     stroke-width: 0px;
# }
#
# .node.moved {
#   ffill: #f00;
# }
#
# .chart1{
#     position: relative;
#     border-top: 1px gray #eeeeee;
#     box-shadow: 1px 1px 1px 1px #888888;
#     overflow-y: auto;
#     display: inline-block;
#     padding-left: 1px;
#     width:65%;
#     height:310px;
# }
# </style>
#
# <div sstyle="background-color:gainsboro; border:solid black; width:100%; height:310px;padding:01px;">
#
#     <div style="float:left;width:35%; ddisplay:inline;">
#         <textarea rows=15 id=graphtext style="width:100%; height:auto;display:inline-block;">
# idx,id,fixed,comment,x,y,group,sizer,links
# 0,A0,Y,"This is an example A01",0,0,1,10, 1 2
# 1,A1,Y, This is an' example A02,0,0,2,10, 3
# 2,A2,Y,"This is an example A03",0,0,2,10, 1
# 3,A3,Y,"This is an example A04",0,0,1,10, 2
#
# 4,A4,Y,"This is an example A04",0,0,1,10, 5
# 5,A5,Y,"This is an example A04",0,0,1,10, 4 6
# 6,A6,Y,"This is an example A04",0,0,1,10, 4
#
# 7,A4,Y,"This is an example A04",0,0,2,10, 8
# 8,A5,Y,"This is an example A04",0,0,2,10, 7 9
# 9,A6,Y,"This is an example A04",0,0,5,10, 8
#
#         </textarea><br/>
#         <input type="button" value="Redo the Graph"   onclick="findAndExcecuteCell('#create_new_graph', 0)" />
#         <input type="button" value="Show Original Graph"   onclick="d3json(jj2, 'id', 'group', 'r')" />
#         <br/>
#     </div>
#     <div id="chart1" class='chart1' style="">
#
#     </div>
#     <input id="status" style="width:100%;border: 1px solid solid;" value="#status"    />
# </div>
#
# <script>
#
# var gb1;
# var gb2;
#
# var width = $("#chart1").width(), height = 300
#
# var svg  = d3.select("#chart1").append("svg").attr("width", width).attr("height", height);
# var force = d3.layout.force().gravity(0.15).charge(-400).size([width, height]).linkDistance(40);
#
# var drag = force.drag().on("dragstart", mDragstart);
# //node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#
# fill = d3.scale.category20();
#
#
# function d3json(json, displayField, groupColor, radius, charge) {
#
#     if (typeof(json) === "undefined" ||  json == null) {
#         return;
#     }
#     d3.select("svg").selectAll("*").remove();
#
#     force.nodes(json.nodes).links(json.links).start();
#     var link = svg.selectAll(".link").data(json.links).enter().append("line").attr("class", "link");
#     var node = svg.selectAll(".node5").data(json.nodes).enter().append("g").attr("class", "node")
#         //.attr('charge', function(d) { d.r < 10 ?  -13500: 20})
#         .call(force.drag);
#
#
#     node.append("svg:circle")
# //    node.append("rect")
#     .attr("class", "node")
# //    .attr("x", function(d) { return d.x; })
# //    .attr("y", function(d) { return d.y; })
#     .attr("r", function(d) { return radius? d[radius]: 8; })
# //    .attr("width", function(d) { return 120; })
# //    .attr("height", function(d) { return  24; })
#     .on("dblclick", mDblclick)
#     .on('click', function(d) {d3.select(this).style('stroke-width', 6)} )
#     .on("mouseover", function(d) { d3.select(this).style('stroke-width', 6)} )
#     .on("mouseout",  function(d) { d3.select(this).style('stroke-width', 0)} )
#     .style("fill", function(d) { return groupColor? fill(d[groupColor]): fill(0); }
#     )
#
# //    node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#     node.append("text").attr("dx", "0px").attr("dy", "0px").text(function(d) { return displayField? d[displayField] : '' });
#
#     force.on("tick", function() {
#     link.attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; })
#         .on("dblclick", mEDblclick)
#         .on("click", mClick)
#         .on("mouseover", mOver)
#         .on("mouseout",  mOut)
#     ;
#
#     node.attr("transform", function(d) { return "translate(" + d.x + "," + d.y + ")"; });
#     });
# };
#
# function mClick(d) {
#     $('#status').val(" Edge Click: " + this)
#     gb1=d;
#     gb2=this;
#     console.log(d)
#     console.log(this)
# }
#
# function mEDblclick(d) {
#     console.log(this, " Edge Double cliked")
#     $('#status').val(" Edge Double cliked: " + this)
# }
#
# function mDblclick(d) {
#     d3.select(this).classed("moved", d.fixed = false);
#     console.log(this, " Double cliked")
#     $('#status').val(" Node Double cliked: " + this)
# }
#
# function mOver(d) {
# //    d3.select(this).classed("stroke-width", "3px");
#     d3.select(this).style('stroke-width', 6);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOver: " + this)
# }
#
# function mOut(d) {
# //    d3.select(this).classed("stroke-width", 1);
#     d3.select(this).style('stroke-width', 2);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOut: " + this)
# }
#
#
# function mDragstart(d) {
#   d3.select(this).classed("moved", d.fixed = true);
# }
#
# jj2= {'graph': {}, 'directed': true, 'multigraph': true,
#       'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}, {'source': 2, 'target': 3}, {'source': 4, 'target': 3}, {'source': 5, 'target': 9}, {'source': 5, 'target': 24}, {'source': 6, 'target': 3}, {'source': 8, 'target': 3}, {'source': 10, 'target': 19}, {'source': 10, 'target': 9}, {'source': 11, 'target': 17}, {'source': 11, 'target': 9}, {'source': 12, 'target': 3}, {'source': 14, 'target': 7}, {'source': 14, 'target': 17}, {'source': 14, 'target': 18}, {'source': 14, 'target': 19}, {'source': 14, 'target': 13}, {'source': 14, 'target': 16}, {'source': 14, 'target': 5}, {'source': 14, 'target': 24}, {'source': 15, 'target': 3}, {'source': 20, 'target': 18}, {'source': 20, 'target': 9}, {'source': 21, 'target': 5}, {'source': 21, 'target': 9}, {'source': 22, 'target': 13}, {'source': 22, 'target': 9}, {'source': 23, 'target': 16}, {'source': 23, 'target': 9}, {'source': 24, 'target': 3}],
#       'nodes': [{'id': 'B7', 'fixed': false, fx:50, fy:50, 'r': 8, 'group': 13}, {'id': 'C8', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'C2', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J3', 'fixed': true, x: 500, y: 80, 'r': 12, 'group': 16},
#                 {'id': 'C4', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'B3', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C6', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'G3', 'fixed': true, 'r': 12, 'group': 2},
#                 {'id': 'C5', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J2', 'fixed': true, 'r': 12, 'group': 12},
#                 {'id': 'B9', 'fixed': false, 'r': 8, 'group': 15}, {'id': 'B4', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C9', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'E3', 'fixed': true, 'r': 12, 'group': 18},
#                 {'id': 'D2', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'C7', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'F3', 'fixed': true, 'r': 12, 'group': 0}, {'id': 'D3', 'fixed': true, 'r': 12, 'group': 10},
#                 {'id': 'H3', 'fixed': true, 'r': 12, 'group': 4}, {'id': 'I3', 'fixed': true, 'r': 12, 'group': 14},
#                 {'id': 'B8', 'fixed': false, 'r': 8, 'group': 13}, {'id': 'B2', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'B5', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'B6', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C3', 'fixed': false, 'r': 8, 'group': 17}]}
#
# var graph = jj2
# d3json(graph, 'id', 'group', 'r')
#
# function test(gg) {
#     console.log(gg)
# }
#
#
# </script>
# Out:
# <script src="//d3js.org/d3.v3.min.js"></script>
# <style>
# .link {
#     stroke: #ccc;
#     stroke-width: 1px;
# }
#
# .linkOn {
#     stroke: #ccc;
#     stroke-width: 3px;
#
# }
# .node text {
#     stroke: #000000;
#     pointer-events: none;font: 12px sans-serif;
#     stroke-width: .5px;
# }
#
# .node {
#     stroke: firebrick;
#     stroke-width: 0px;
# }
#
# .node.moved {
#   ffill: #f00;
# }
#
# .chart1{
#     position: relative;
#     border-top: 1px gray #eeeeee;
#     box-shadow: 1px 1px 1px 1px #888888;
#     overflow-y: auto;
#     display: inline-block;
#     padding-left: 1px;
#     width:65%;
#     height:310px;
# }
# </style>
#
# <div sstyle="background-color:gainsboro; border:solid black; width:100%; height:310px;padding:01px;">
#
#     <div style="float:left;width:35%; ddisplay:inline;">
#         <textarea rows=15 id=graphtext style="width:100%; height:auto;display:inline-block;">
# idx,id,fixed,comment,x,y,group,sizer,links
# 0,A0,Y,"This is an example A01",0,0,1,10, 1 2
# 1,A1,Y, This is an' example A02,0,0,2,10, 3
# 2,A2,Y,"This is an example A03",0,0,2,10, 1
# 3,A3,Y,"This is an example A04",0,0,1,10, 2
#
# 4,A4,Y,"This is an example A04",0,0,1,10, 5
# 5,A5,Y,"This is an example A04",0,0,1,10, 4 6
# 6,A6,Y,"This is an example A04",0,0,1,10, 4
#
# 7,A4,Y,"This is an example A04",0,0,2,10, 8
# 8,A5,Y,"This is an example A04",0,0,2,10, 7 9
# 9,A6,Y,"This is an example A04",0,0,5,10, 8
#
#         </textarea><br/>
#         <input type="button" value="Redo the Graph"   onclick="findAndExcecuteCell('#create_new_graph', 0)" />
#         <input type="button" value="Show Original Graph"   onclick="d3json(jj2, 'id', 'group', 'r')" />
#         <br/>
#     </div>
#     <div id="chart1" class='chart1' style="">
#
#     </div>
#     <input id="status" style="width:100%;border: 1px solid solid;" value="#status"    />
# </div>
#
# <script>
#
# var gb1;
# var gb2;
#
# var width = $("#chart1").width(), height = 300
#
# var svg  = d3.select("#chart1").append("svg").attr("width", width).attr("height", height);
# var force = d3.layout.force().gravity(0.15).charge(-400).size([width, height]).linkDistance(40);
#
# var drag = force.drag().on("dragstart", mDragstart);
# //node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#
# fill = d3.scale.category20();
#
#
# function d3json(json, displayField, groupColor, radius, charge) {
#
#     if (typeof(json) === "undefined" ||  json == null) {
#         return;
#     }
#     d3.select("svg").selectAll("*").remove();
#
#     force.nodes(json.nodes).links(json.links).start();
#     var link = svg.selectAll(".link").data(json.links).enter().append("line").attr("class", "link");
#     var node = svg.selectAll(".node5").data(json.nodes).enter().append("g").attr("class", "node")
#         //.attr('charge', function(d) { d.r < 10 ?  -13500: 20})
#         .call(force.drag);
#
#
#     node.append("svg:circle")
# //    node.append("rect")
#     .attr("class", "node")
# //    .attr("x", function(d) { return d.x; })
# //    .attr("y", function(d) { return d.y; })
#     .attr("r", function(d) { return radius? d[radius]: 8; })
# //    .attr("width", function(d) { return 120; })
# //    .attr("height", function(d) { return  24; })
#     .on("dblclick", mDblclick)
#     .on('click', function(d) {d3.select(this).style('stroke-width', 6)} )
#     .on("mouseover", function(d) { d3.select(this).style('stroke-width', 6)} )
#     .on("mouseout",  function(d) { d3.select(this).style('stroke-width', 0)} )
#     .style("fill", function(d) { return groupColor? fill(d[groupColor]): fill(0); }
#     )
#
# //    node.append("image").attr("xlink:href", "https://github.com/favicon.ico").attr("x", -8).attr("y", -8).attr("width", 16).attr("height", 16);
#     node.append("text").attr("dx", "0px").attr("dy", "0px").text(function(d) { return displayField? d[displayField] : '' });
#
#     force.on("tick", function() {
#     link.attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; })
#         .on("dblclick", mEDblclick)
#         .on("click", mClick)
#         .on("mouseover", mOver)
#         .on("mouseout",  mOut)
#     ;
#
#     node.attr("transform", function(d) { return "translate(" + d.x + "," + d.y + ")"; });
#     });
# };
#
# function mClick(d) {
#     $('#status').val(" Edge Click: " + this)
#     gb1=d;
#     gb2=this;
#     console.log(d)
#     console.log(this)
# }
#
# function mEDblclick(d) {
#     console.log(this, " Edge Double cliked")
#     $('#status').val(" Edge Double cliked: " + this)
# }
#
# function mDblclick(d) {
#     d3.select(this).classed("moved", d.fixed = false);
#     console.log(this, " Double cliked")
#     $('#status').val(" Node Double cliked: " + this)
# }
#
# function mOver(d) {
# //    d3.select(this).classed("stroke-width", "3px");
#     d3.select(this).style('stroke-width', 6);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOver: " + this)
# }
#
# function mOut(d) {
# //    d3.select(this).classed("stroke-width", 1);
#     d3.select(this).style('stroke-width', 2);
#     //console.log(this, " Double cliked")
#     $('#status').val(" mOut: " + this)
# }
#
#
# function mDragstart(d) {
#   d3.select(this).classed("moved", d.fixed = true);
# }
#
# jj2= {'graph': {}, 'directed': true, 'multigraph': true,
#       'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}, {'source': 2, 'target': 3}, {'source': 4, 'target': 3}, {'source': 5, 'target': 9}, {'source': 5, 'target': 24}, {'source': 6, 'target': 3}, {'source': 8, 'target': 3}, {'source': 10, 'target': 19}, {'source': 10, 'target': 9}, {'source': 11, 'target': 17}, {'source': 11, 'target': 9}, {'source': 12, 'target': 3}, {'source': 14, 'target': 7}, {'source': 14, 'target': 17}, {'source': 14, 'target': 18}, {'source': 14, 'target': 19}, {'source': 14, 'target': 13}, {'source': 14, 'target': 16}, {'source': 14, 'target': 5}, {'source': 14, 'target': 24}, {'source': 15, 'target': 3}, {'source': 20, 'target': 18}, {'source': 20, 'target': 9}, {'source': 21, 'target': 5}, {'source': 21, 'target': 9}, {'source': 22, 'target': 13}, {'source': 22, 'target': 9}, {'source': 23, 'target': 16}, {'source': 23, 'target': 9}, {'source': 24, 'target': 3}],
#       'nodes': [{'id': 'B7', 'fixed': false, fx:50, fy:50, 'r': 8, 'group': 13}, {'id': 'C8', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'C2', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J3', 'fixed': true, x: 500, y: 80, 'r': 12, 'group': 16},
#                 {'id': 'C4', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'B3', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C6', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'G3', 'fixed': true, 'r': 12, 'group': 2},
#                 {'id': 'C5', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'J2', 'fixed': true, 'r': 12, 'group': 12},
#                 {'id': 'B9', 'fixed': false, 'r': 8, 'group': 15}, {'id': 'B4', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C9', 'fixed': false, 'r': 8, 'group': 17}, {'id': 'E3', 'fixed': true, 'r': 12, 'group': 18},
#                 {'id': 'D2', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'C7', 'fixed': false, 'r': 8, 'group': 17},
#                 {'id': 'F3', 'fixed': true, 'r': 12, 'group': 0}, {'id': 'D3', 'fixed': true, 'r': 12, 'group': 10},
#                 {'id': 'H3', 'fixed': true, 'r': 12, 'group': 4}, {'id': 'I3', 'fixed': true, 'r': 12, 'group': 14},
#                 {'id': 'B8', 'fixed': false, 'r': 8, 'group': 13}, {'id': 'B2', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'B5', 'fixed': false, 'r': 8, 'group': 19}, {'id': 'B6', 'fixed': false, 'r': 8, 'group': 13},
#                 {'id': 'C3', 'fixed': false, 'r': 8, 'group': 17}]}
#
# var graph = jj2
# d3json(graph, 'id', 'group', 'r')
#
# function test(gg) {
#     console.log(gg)
# }
#
#
# </script>

# %%
#create_new_graph

prt = '''
<script>

gr1 = {'graph': {}, 'directed': true, 'multigraph': true, 
'nodes' : [NODES],
'links' : [LINKS]
}
d3json(gr1, 'id', 'group', 'r')

</script>
'''

dff = '''
idx,id,fixed,comment,x,y,group, size,links
2,A3,Y,"This is an example A3",0,0,2,10, 1
3,A4,Y,"This is an example A4",0,0,1,10, 2
'''
dff=GetFormValue('#graphtext');

df=LoadDataSet(dff)
assert df is not None, "Could not get Data Frame: " +dff

#'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}], 
#'nodes': [{'id': 'B7', 'fixed': false, 'r': 8, 'group': 13}, {'id': 'C8', 'fixed': false, 'r': 8, 'group': 17} ]
l=[]
n=[]
for (i, r) in df.iterrows():
    it ="{{'id':'{}', 'fixed': false, 'fx':{}, 'fy': {}, 'r':{}, 'group':{}, 'desc':'{}'}}".format(r.id, r.x, r.y, r.sizer, r.group,r.comment.strip())
    
    for j in re.split('\s+', r.links.strip()):
        lk = "{{'source': {}, 'target': {} }}".format(i,j)
        l.append(lk)
    n.append(it)
    #print(it)
    
LINKS= ','.join(l)
NODES= ','.join(n)
g=prt.replace('NODES',NODES).replace('LINKS', LINKS)
display(HTML(g))
# Out:
# ERROR: ***  does not exist
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-542e18ee6d88> in <module>()
#      21
#      22 df=LoadDataSet(dff)
# ---> 23 assert df is not None, "Could not get Data Frame: " +dff
#      24
#      25 #'links': [{'source': 0, 'target': 7}, {'source': 0, 'target': 9}, {'source': 1, 'target': 3}],
#
# AssertionError: Could not get Data Frame:

# %%
GetFormValue('#graphtext')

# %%
# %%script false
#
# js='''
# <H2> Tableau  Cards </H2>
# <div  style='position: relative; overflow: hidden; display: width:100%;'>
#
#
#
# <div class='tableauPlaceholder' id='viz1503229474559' style='position: relative;width:100%; heightpx: 350px; box-shadow: 1px 1px 1px #888888; overflow: hidden; display: inline-block;'>
# <noscript>
# <a href='#'><img alt='Profit Overview ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ta&#47;TableauExampleDashboard_0&#47;ProfitOverview&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'
# style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
#
#
# <param name='site_root' value='' />
# <param name='name' value='TableauExampleDashboard_0&#47;ProfitOverview' /><param name='tabs' value='no' />
# <param name='toolbar' value='no' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ta&#47;TableauExampleDashboard_0&#47;ProfitOverview&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' />
# </object>
# </div>
# </div>
#
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1503229474559');
# var vizElement = divElement.getElementsByTagName('object')[0];
#
# //vizElement.style.width='1104px';vizElement.style.height='769px';
# vizElement.style.width='1200px';vizElement.style.height='384px';
#
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
#
#
# </div>
# </div>
# '''
# #display(HTML(js))

# %%
# %%script false
#
# '''%%html
# <style>
# .mbox1{
#     position: relative;
#     border-top: 1px gray #eeeeee;
#     box-shadow: 1px 1px 1px 1px #888888;
#     overflow-y: auto;
#     display: inline-block;
#     width:400px;
#     height: 150px;
#     text-align: left;
#     padding-left: 10px;
# }
# </style>
#
# <div  style='position: relative; overflow: hidden ;width:100% !important;text-align: center;'>
#     <div class='mbox1'>
#     <h3>Current Trends</h3><br/>
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     Balh Blah Blah    Balh Blah Blah    Balh Blah Blah    Balh Blah Blah
#     </div>
#     &nbsp;
#     <div class='mbox1'>
#     <h3>Key Insights</h3>
#     </div>
#     &nbsp;
#     <div class='mbox1'>
#     <h3>Recommendations:</h3>
#     </div>
# <div>'''
#
# ;

# %%
# %%html
#
# <style>
# /* Dropdown Button */
# .dropbtn {
#     background-color: #4CAF50;
#     background-color: #4285f4;
#     color: white;
#     padding: 6px;
#     font-size: 12px;
#     font-weight: bold;
#     border: none;
#     cursor: pointer;
# }
# /* Change the background color of the dropdown button when the dropdown content is shown */
# .dropdown:hover .dropbtn {
#     background-color: #4285d4;;
#     text-decoration: none;
# }
#
#
# /* The container <div> - needed to position the dropdown content */
# .dropdown {
#     position: relative;
#     display: inline-block;
# }
#
# /* Dropdown Content (Hidden by Default) */
# .dropdown-content {
#     display: none;
#     position: absolute;
#     bbackground-color: #f9f9f9;
#     min-width: 160px;
#     border: 1px #fefefe solid;
#     box-shadow: 0px 1px 1px 0px rgba(0,0,0,0.2);
#     z-index: 1;
# }
#
# /* Links inside the dropdown */
# .dropdown-content a {
#     color: black;
#     text-decoration: none !important;
#     padding: 5px 16px;
#     display: block;
# }
#
# /* Change color of dropdown links on hover */
# .dropdown-content a:hover{ background-color: #f1f1f1; text-decoration: none; }
#
# /* Show the dropdown menu on hover */
# .dropdown:hover .dropdown-content {
#     display: block;
#     text-decoration: none;
# }
#
#
# </style>
#
# <div class="dropdown">
#   <button class="dropbtn">Drop Down Button</button>
#   <div class="dropdown-content">
#     <a class="" href="#">Link 1</a>
#     <a href="#">Link 2</a>
#     <a href="#">Link 3</a>
#   </div>
# </div>
#
# <br/>
# <br/>
# <br/>
# <br/>
# <br/><br/>
# <br/>
# <br/>
# <br/>
# xml

# %%
xmlDoc= '''<?xml version="1.0"?>
<data>
<elements>
    <branch name="testing" hash="1cdf045c">
        text,source
    </branch>
    
    <country name="Liechtenstein">
        <rank>1</rank>
        <year>2008</year>
        <gdppc>141100</gdppc>
        <neighbor name="Austria" direction="E"/>
        <neighbor name="Switzerland" direction="W"/>
    </country>
    <country name="Singapore">
        <rank>4</rank>
        <year>2011</year>
        <gdppc>59900</gdppc>
        <neighbor name="Malaysia" direction="N"/>
    </country>
    <country name="Panama">
        <rank>68</rank>
        <year>2011</year>
        <gdppc>13600</gdppc>
        <neighbor name="Costa Rica" direction="W"/>
        <neighbor name="Colombia" direction="E"/>
    </country>
</elements>
</data>
'''

import xml.etree.ElementTree as ET
#tree = ET.parse('country_data.xml')
#root = tree.getroot()
root = ET.fromstring(xmlDoc)
root.tag, root.attrib
for i,e in enumerate(root[0]):
    print(i, e.tag, e.attrib )
    for j,e1 in enumerate(e):
        print("\t", j, e1.tag, e1.attrib, e1.text )

# %%
# %%html
# <style>
# #div1, #div2 {
#     float: left;
#     width: 100px;
#     height: 35px;
#     margin: 10px;
#     padding: 10px;
#     border: 1px solid black;
# }
# </style>
# <script>
# function allowDrop(ev) {
#     ev.preventDefault();
# }
#
# function drag(ev) {
#     ev.dataTransfer.setData("text", ev.target.id);
# }
#
# function drop(ev) {
#     ev.preventDefault();
#     var data = ev.dataTransfer.getData("text");
#     ev.target.appendChild(document.getElementById(data));
# }
# </script>
# </head>
# <body>
#
# <div id="div1" ondrop="drop(event)" ondragover="allowDrop(event)">
#   <img src="ham1.png" draggable="true" ondragstart="drag(event)" id="drag1" width="88" height="31">
# </div>
#
# <div id="div2" ondrop="drop(event)" ondragover="allowDrop(event)"></div>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %%
# %%html
# <style>
# #file_drop
# {
# font-weight: bold;text-align: center;padding: 1em 0;
# border: 4px dashed #cccccc;
# width:100%;float: right;
# }
#
# #file_drop.hover
# {
#     border: 4px dashed firebrick;
#
# }
# </style>
# <div class="fdrop1" id="file_drop" >DROP A File HERE
# <div id="results"> Status</div>
# <textarea rows=5 id=dada style="width:90%;ddisplay:none;">
# </div>
# </textarea>
#
# </div>
#
# <script>
# function status(msg){
#     m= $('#results');
#     m.html( msg  )
#     //console.log(msg)
# }
# var glt;
# var glt1;
#
# var out = ''
# function SetPythonVariable(buffer) {
#     out= buffer;
#     console.log(" >", out.length)
#     var command =  " myBytes = b\'\'\'" + out + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     findAndExcecuteCell('#showExcel')
#     console.log( command.substring(0,300) )
#     return out;
# }
#
# function readFile(files){
#     for (var i=0; i<files.length; i++) {
#         var file = files[i];
#         var reader = new FileReader();
#
#         status($('#results').text() + " Reading FIle :" + file.name)
#
#         fstr = "File: " + file.name + ", type: " + file.type + ", size: " + file.size + ", lastModified: " + file.lastModifiedDate
#
#         reader.onload = function(e) {
#             glt = e.target.result
#             glt1=glt;
#
#             if (file.type.indexOf("image") == 0 ){
#                 status(
#                     fstr + "<br />" +
#                     '<img src="' + glt + '" /></p>'
#                 );
#             }
#             if (file.type.indexOf("text") == 0 ){
#                 $('#dada').val(glt1.substr(0,300))
#                 status(
#                      fstr + ":<br />"
#                 );
#             }
#             if (file.type.indexOf(".sheet") > 0 ){
#                 glt1= btoa(glt);
#                 SetPythonVariable(glt1)
#                 $('#dada').val(glt1.substr(0,100))
#                 status(
#                     fstr + ":<br />"
#                 );
#             }
#         };
#         if (file.type.indexOf("image") == 0 )
#             rf = reader.readAsDataURL(file);
#         if (file.type.indexOf("text") == 0 )
#             rf = reader.readAsBinaryString(file);
#         if (file.type.indexOf(".sheet") > 0 )
#             rf = reader.readAsBinaryString(file);
#             //rf = reader.readAsDataURL(file);
#             //rf = reader.readAsArrayBuffer(file);
#     }
# }
#
# var file_drop = document.getElementById('file_drop');
# function handleDragOver(evt) {
#     evt.stopPropagation()
#     evt.preventDefault()
#     evt.dataTransfer.dropEffect = 'copy'
#     evt.target.className = (evt.type == "dragover" ? "hover" : "");
# }
#
# file_drop.addEventListener('dragover', handleDragOver, false )
# file_drop.addEventListener("dragleave", handleDragOver, false);
#
# var fff;
# file_drop.addEventListener(
#     'drop',
#     function(evt) {
#         evt.stopPropagation()
#         evt.preventDefault()
#         evt.target.className = ("");
#         var files = evt.dataTransfer.files  // FileList object.
#         var file = files[files.length-1]    // File     object.
#         console.log(file)
#         fff=file
#         status(file.name)
#         readFile(files)
#     },
#     false
# )
# status("Hello")
# </script>
# <input type=button value="Update Excel Sheet" onclick="findAndExcecuteCell('#showExcel')">
# Out:
# <style>
# #file_drop
# {
# font-weight: bold;text-align: center;padding: 1em 0;
# border: 4px dashed #cccccc;
# width:100%;float: right;
# }
#
# #file_drop.hover
# {
#     border: 4px dashed firebrick;
#
# }
# </style>
# <div class="fdrop1" id="file_drop" >DROP A File HERE
# <div id="results"> Status</div>
# <textarea rows=5 id=dada style="width:90%;ddisplay:none;">
# </div>
# </textarea>
#
# </div>
#
# <script>
# function status(msg){
#     m= $('#results');
#     m.html( msg  )
#     //console.log(msg)
# }
# var glt;
# var glt1;
#
# var out = ''
# function SetPythonVariable(buffer) {
#     out= buffer;
#     console.log(" >", out.length)
#     var command =  " myBytes = b\'\'\'" + out + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     findAndExcecuteCell('#showExcel')
#     console.log( command.substring(0,300) )
#     return out;
# }
#
# function readFile(files){
#     for (var i=0; i<files.length; i++) {
#         var file = files[i];
#         var reader = new FileReader();
#
#         status($('#results').text() + " Reading FIle :" + file.name)
#
#         fstr = "File: " + file.name + ", type: " + file.type + ", size: " + file.size + ", lastModified: " + file.lastModifiedDate
#
#         reader.onload = function(e) {
#             glt = e.target.result
#             glt1=glt;
#
#             if (file.type.indexOf("image") == 0 ){
#                 status(
#                     fstr + "<br />" +
#                     '<img src="' + glt + '" /></p>'
#                 );
#             }
#             if (file.type.indexOf("text") == 0 ){
#                 $('#dada').val(glt1.substr(0,300))
#                 status(
#                      fstr + ":<br />"
#                 );
#             }
#             if (file.type.indexOf(".sheet") > 0 ){
#                 glt1= btoa(glt);
#                 SetPythonVariable(glt1)
#                 $('#dada').val(glt1.substr(0,100))
#                 status(
#                     fstr + ":<br />"
#                 );
#             }
#         };
#         if (file.type.indexOf("image") == 0 )
#             rf = reader.readAsDataURL(file);
#         if (file.type.indexOf("text") == 0 )
#             rf = reader.readAsBinaryString(file);
#         if (file.type.indexOf(".sheet") > 0 )
#             rf = reader.readAsBinaryString(file);
#             //rf = reader.readAsDataURL(file);
#             //rf = reader.readAsArrayBuffer(file);
#     }
# }
#
# var file_drop = document.getElementById('file_drop');
# function handleDragOver(evt) {
#     evt.stopPropagation()
#     evt.preventDefault()
#     evt.dataTransfer.dropEffect = 'copy'
#     evt.target.className = (evt.type == "dragover" ? "hover" : "");
# }
#
# file_drop.addEventListener('dragover', handleDragOver, false )
# file_drop.addEventListener("dragleave", handleDragOver, false);
#
# var fff;
# file_drop.addEventListener(
#     'drop',
#     function(evt) {
#         evt.stopPropagation()
#         evt.preventDefault()
#         var files = evt.dataTransfer.files  // FileList object.
#         var file = files[files.length-1]    // File     object.
#         console.log(file)
#         fff=file
#         status(file.name)
#         readFile(files)
#     },
#     false
# )
# status("Hello")
# </script>
# <input type=button value="Update Excel Sheet" onclick="findAndExcecuteCell('#showExcel')">

# %%
#showExcel
import base64
# %run "../PyUtils/common.ipynb"
    
s=myBytes
d=base64.decodestring(s)
excel_data = ExcelFile(BytesIO(d))
dff = excel_data.parse(excel_data.sheet_names[-1])
#dff.columns = dff.columns.astype(str)
dff= dff.fillna('')
otr= displayDFs(dff, showIcons=False, editable=True, showTypes=False, search='', maxrows=5, startrow=0, donotDisplay=False, id="excel")
#display(HTML(otr.replace("wwidth", "wwidth")));

butts = '''
<script>
function myLocal(){
    ret = TableToJSON('#excel')
    SetPyVarValue(ret,'globalVAR')
    findAndExcecuteCell('#update1');
}</script>
<input type=button value='Update' onclick="myLocal();">
'''
display(HTML(butts))
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
# <!--
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <-->
# <script src="https://ajax.googleapis.com/ajax/libs/angularjs/1.5.7/angular.min.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
#
# <script>
#
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
#
#
# }
#
# code_show=false;
# function ToggleEle(element) {
#
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#     } else {
#         $(element).css('display', 'none');
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function Ntoggle(){
#     ToggleEle('#header')
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '100%');
# }
#
# function assert(condition, message) {
#     if (!condition) {
#         cdonsole.log(message + "Assertion failed")
#         throw message || "Assertion failed";
#     }
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON1(tableName, which) {
#     ret = {}
#     which = which || 'td'
#     var cells = $(tableName).find(which);
#     var i = 0;
#     cells.each(function () {
#         var ct = $(this).text()
#         ret[i++] = ct
#         //console.log(i, ct)
#     });
#     ret1 = JSON.stringify(ret)
#     return ret1;
# }
#
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <table wwidth=100%><tr><td style='text-align:left;' bgcolor=#efefef>8 rows x 5 columns<br>
# <table cellpadding=0 cellspacing=0 wwidth=100% id='excel' border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TYPE</th>
#       <th>WHO</th>
#       <th>Type</th>
#       <th>Date</th>
#       <th>Num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td contenteditable >HSA</td>
#       <td contenteditable >Paid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017</td>
#       <td contenteditable >Debit</td>
#       <td contenteditable >03/01/2017</td>
#       <td contenteditable >23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td contenteditable >HSA</td>
#       <td contenteditable >Paid Claim #104315537 Vendor/Provider: WALGREENS STORE #05538 HIGHLANDS RAN, CO Date of Service: 02/27/2017</td>
#       <td contenteditable >Debit</td>
#       <td contenteditable >02/27/2017</td>
#       <td contenteditable >24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td contenteditable >HSA</td>
#       <td contenteditable >Paid Claim #104312326 Vendor/Provider: HIGHLAND RANCH SMILES HIGHLANDS RAN, CO Date of Service: 02/27/2017</td>
#       <td contenteditable >Debit</td>
#       <td contenteditable >02/27/2017</td>
#       <td contenteditable >3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td contenteditable >HSA</td>
#       <td contenteditable >Paid Claim #103135518 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 02/15/2017</td>
#       <td contenteditable >Debit</td>
#       <td contenteditable >02/17/2017</td>
#       <td contenteditable >55</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td contenteditable >HSA</td>
#       <td contenteditable >CYC Stand Alone Fee</td>
#       <td contenteditable >Debit</td>
#       <td contenteditable >02/12/2017</td>
#       <td contenteditable >5</td>
#     </tr>
#   </tbody>
# </table></td><tr></table>
# <script>
# function myLocal(){
#     ret = TableToJSON('#excel')
#     SetPyVarValue(ret,'globalVAR')
#     findAndExcecuteCell('#update1');
# }</script>
# <input type=button value='Update' onclick="myLocal();">

# %%
#update1
tJ = GetJValue("TableToJSON('{}')".format('#excel1'))
#UpdateTable(dff,'#edt1')
#import time
#print(tJ, "\n\n", globalVAR)
dfn=GetDFTable('#excel', dff, True)
#display(dfn, dff)
dff
# Out:
# <script>SetPyVarValue(TableToJSON('#excel1'),'globalVAR') </script>
# <script>SetPyVarValue(TableToJSON('#excel'),'globalVAR') </script>
#    TYPE                                                                                                                                                                                                                                                                                                                                                                                                         WHO   Type        Date  Num
# 0   HSA  Paid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017\nPaid Claim #104518191 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 03/01/2017  Debit  03/01/2017   23
# 1  HSA1                                                                                                                                                                                                                                                                                                 Paid Claim #104315537 Vendor/Provider: WALGREENS STORE #05538 HIGHLANDS RAN, CO Date of Service: 02/27/2017  Debit  02/27/2017   24
# 2   HSA                                                                                                                                                                                                                                                                                                  Paid Claim #104312326 Vendor/Provider: HIGHLAND RANCH SMILES HIGHLANDS RAN, CO Date of Service: 02/27/2017  Debit  02/27/2017    3
# 3   HSA                                                                                                                                                                                                                                                                                                           Paid Claim #103135518 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 02/15/2017  Debit  02/17/2017   55
# 4   HSA                                                                                                                                                                                                                                                                                                                                                                                         CYC Stand Alone Fee  Debit  02/12/2017    5
# 5   HSA                                                                                                                                                                                                                                                                                                           Paid Claim #102216399 Vendor/Provider: RELEAF COUNSELIN LITTLETON, CO Date of Service: 02/08/2017  Debit  02/10/2017    2
# 6   HSA                                                                                                                                                                                                                                                                                                 Paid Claim #101771030 Vendor/Provider: WALGREENS STORE #02641 HIGHLANDS RAN, CO Date of Service: 02/02/2017  Debit  02/06/2017    3
# 7   HSA                                                                                                                                                                                                                                                                                                     Paid Claim #101456405 Vendor/Provider: KING SOOPERS #0108 HIGHLANDS RAN, CO Date of Service: 01/31/2017  Debit  02/03/2017    2

# %%
|
