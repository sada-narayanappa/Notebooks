# %% [markdown]
# # SCHASDB Queries

# %%
# %run "../common.ipynb"

#PUT THE QUERY NUMBER BELOW
qn = '1'


fileName="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn="+qn+"&type=html";
dfQN = LoadDataSet(fileName, columns=None, checkForDateTime=False);

displayDFs(dfQN, showStats=False, maxrows=len(dfQN))
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#   font-family: Times 'Merriweather', Georgia, serif;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     ffont-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
# ...

# %%
#CODE FOR BUTTON USER INTERFACE
#response = urllib.request.urlopen('http://www.smartconnectedhealth.org/SCHAS/data/sql/SQL.txt')
#html = response.read().decode("utf-8")
#html  = html.split("\n#--------------------------------------------------------------------------\n")

#qns = []
#for i in range(len(html)):
#    qns.append(html[i].split('\n')[0])

#print(qns)
#response.close()

# %%
#from IPython.html import widgets
#from IPython.display import display

#def func(btn):
#    qn = btn.description
    #print(qn)


#for k in range(len(qns)):
#    btn = widgets.Button(description=qns[k])
#    btn.on_click(func)
#    display(btn)
