# %%
# %run "../../PyUtils/common.ipynb"

folder = "./kuky/";
f1=folder+"KukY_AM_PM_PEF_1.xlsx"
dfAM = LoadDataSet(f1, sheetname=0);
dfPM = LoadDataSet(f1, sheetname=1);

f2=folder+"KukY_2014__AirPollutionData.xlsx"
f2c=folder+"KukY_2014__ClimateData.xlsx"
#poi2=folder+"LeeH_POI_2014_AirPollutionData.xlsx"
#poi2c=folder+"LeeH_POI_2014_ClimateData.xlsx"
df2014Air = LoadDataSet(f2, sheetname=0);
df2014Climate = LoadDataSet(f2c, sheetname=0);
#df2014POIAir = LoadDataSet(poi2,sheetname=0);
#df2014POIClimate = LoadDataSet(poi2c, sheetname=0);

f3=folder+"KukY_2015__AirPollutionData.xlsx"
f3c=folder+"KukY_2015__ClimateData.xlsx"
#poi3=folder+"LeeH_POI_2015_AirPollutionData.xlsx"
#poi3c=folder+"LeeH_POI_2015_ClimateData.xlsx"
df2015Air = LoadDataSet(f3, sheetname=0);
df2015Climate = LoadDataSet(f3c, sheetname=0);
#df2015POIAir = LoadDataSet(poi3,sheetname=0);
#df2015POIClimate = LoadDataSet(poi3c, sheetname=0);

f4=folder+"KukY_2016__AirPollutionData.xlsx"
f4c=folder+"KukY_2016__ClimateData.xlsx"
#poi4=folder+"LeeH_POI_2016_AirPollutionData.xlsx"
#poi4c=folder+"LeeH_POI_2016_ClimateData.xlsx"
df2016Air = LoadDataSet(f4, sheetname=0);
df2016Climate = LoadDataSet(f4c, sheetname=0);
#df2016POIAir = LoadDataSet(poi4,sheetname=0);
#df2016POIClimate = LoadDataSet(poi4c, sheetname=0);
#f1="P1_HanD_Ver1_2015_22112015_AMPEF.xlsx";
#dfOrginal1 = LoadDataSet(f1);
dfAM=dfAM[10:]
print(dfAM)
timeAM=[]
dateAM=dfAM[:]['Unnamed: 7']
pef1AM=[]
pef2AM=[]
pef3AM=[]
pefMaxAM=[]
indexAMPEF=[]
dfPM=dfPM[10:]
print(dfPM)
timePM=[]
datePM=dfPM[:]['Unnamed: 7']
pef1PM=[]
pef2PM=[]
pef3PM=[]
pefMaxPM=[]
indexPMPEF=[]

dateRangeAM = pd.date_range(dateAM.iloc[0],dateAM.iloc[dateAM.size-1])
dateRangePM = pd.date_range(datePM.iloc[0],datePM.iloc[datePM.size-1])


for i in range(0,dateRangeAM.size):   
    found = 0
    for j in dateAM.index:
        if dateRangeAM[i]== dateAM[j]:
            found=1
            timeAM.append(dfAM[:]['Unnamed: 8'][j])
            pef1AM.append(dfAM[:]['Unnamed: 13'][j])
            pef2AM.append(dfAM[:]['Unnamed: 14'][j])
            pef3AM.append(dfAM[:]['Unnamed: 15'][j])
            pefMaxAM.append(dfAM[:]['Unnamed: 16'][j])
            indexAMPEF.append(dfAM[:]['Unnamed: 17'][j])
            break
    if found == 0:
        timeAM.append(dfAM[:]['Unnamed: 8'][10])
        pef1AM.append(None)
        pef2AM.append(None)
        pef3AM.append(None)
        pefMaxAM.append(None)
        indexAMPEF.append(None)
        
for i in range(0,dateRangePM.size):   
    found = 0
    for j in datePM.index:
        if dateRangePM[i]== datePM[j]:
            found=1
            timePM.append(dfPM[:]['Unnamed: 8'][j])
            pef1PM.append(dfPM[:]['Unnamed: 12'][j])
            pef2PM.append(dfPM[:]['Unnamed: 13'][j])
            pef3PM.append(dfPM[:]['Unnamed: 14'][j])
            pefMaxPM.append(dfPM[:]['Unnamed: 15'][j])
            indexPMPEF.append(dfPM[:]['Unnamed: 16'][j])
            break
    if found == 0:
        timePM.append(dfPM[:]['Unnamed: 8'][10])
        pef1PM.append(None)
        pef2PM.append(None)
        pef3PM.append(None)
        pefMaxPM.append(None)
        indexPMPEF.append(None)

dateAM = dateRangeAM
datePM = dateRangePM
print(str(timeAM[0])+"_"+str(pef1AM[0])+"_"+str(pef2AM[0])+"_"+str(pef3AM[0])+"_"+str(pefMaxAM[0])+"_"+str(indexAMPEF[0])+"_"+str(timePM[0])+"_"+str(pef1PM[0])+"_"+str(pef2PM[0])+"_"+str(pef3PM[0])+"_"+str(pefMaxPM[0])+"_"+str(indexPMPEF[0]))
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px black solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
# ...

# %%
import requests

# %%
df2014Air['SO2'].fillna(df2014Air['SO2'].mean(),inplace=True)
df2014Air['CO'].fillna(df2014Air['CO'].mean(),inplace=True)
df2014Air['O3'].fillna(df2014Air['O3'].mean(),inplace=True)
df2014Air['NO2'].fillna(df2014Air['NO2'].mean(),inplace=True)
df2014Air['PM10'].fillna(df2014Air['PM10'].mean(),inplace=True)
df2015Air['SO2'].fillna(df2015Air['SO2'].mean(),inplace=True)
df2015Air['CO'].fillna(df2015Air['CO'].mean(),inplace=True)
df2015Air['O3'].fillna(df2015Air['O3'].mean(),inplace=True)
df2015Air['NO2'].fillna(df2015Air['NO2'].mean(),inplace=True)
df2015Air['PM10'].fillna(df2015Air['PM10'].mean(),inplace=True)
df2016Air['SO2'].fillna(df2016Air['SO2'].mean(),inplace=True)
df2016Air['CO'].fillna(df2016Air['CO'].mean(),inplace=True)
df2016Air['O3'].fillna(df2016Air['O3'].mean(),inplace=True)
df2016Air['NO2'].fillna(df2016Air['NO2'].mean(),inplace=True)
df2016Air['PM10'].fillna(df2016Air['PM10'].mean(),inplace=True)
'''
df2014POIAir['SO2'].fillna(df2014Air['SO2'].mean(),inplace=True)
df2014POIAir['CO'].fillna(df2014Air['CO'].mean(),inplace=True)
df2014POIAir['O3'].fillna(df2014Air['O3'].mean(),inplace=True)
df2014POIAir['NO2'].fillna(df2014Air['NO2'].mean(),inplace=True)
df2014POIAir['PM10'].fillna(df2014Air['PM10'].mean(),inplace=True)
df2015POIAir['SO2'].fillna(df2015POIAir['SO2'].mean(),inplace=True)
df2015POIAir['CO'].fillna(df2015POIAir['CO'].mean(),inplace=True)
df2015POIAir['O3'].fillna(df2015POIAir['O3'].mean(),inplace=True)
df2015POIAir['NO2'].fillna(df2015POIAir['NO2'].mean(),inplace=True)
df2015POIAir['PM10'].fillna(df2015POIAir['PM10'].mean(),inplace=True)
df2016POIAir['SO2'].fillna(df2016POIAir['SO2'].mean(),inplace=True)
df2016POIAir['CO'].fillna(df2016POIAir['CO'].mean(),inplace=True)
df2016POIAir['O3'].fillna(df2016POIAir['O3'].mean(),inplace=True)
df2016POIAir['NO2'].fillna(df2016POIAir['NO2'].mean(),inplace=True)
df2016POIAir['PM10'].fillna(df2016POIAir['PM10'].mean(),inplace=True)
'''
df2015Climate['Temperature(°C)'].fillna(df2015Climate['Temperature(°C)'].mean(),inplace=True)
df2015Climate['Rainfall(mm)'].fillna(df2015Climate['Rainfall(mm)'].mean(),inplace=True)
df2015Climate['wind Speed(m/s)'].fillna(df2015Climate['wind Speed(m/s)'].mean(),inplace=True)
df2015Climate['Wind Direction(16방위)'].fillna(df2015Climate['Wind Direction(16방위)'].mean(),inplace=True)
df2015Climate['Precipitation(%)'].fillna(df2015Climate['Precipitation(%)'].mean(),inplace=True)
df2015Climate['Vapor Pressure(hPa)'].fillna(df2015Climate['Vapor Pressure(hPa)'].mean(),inplace=True)
df2015Climate['Dew point Temperature(°C)'].fillna(df2015Climate['Dew point Temperature(°C)'].mean(),inplace=True)
df2015Climate['Air Pressure(hPa)'].fillna(df2015Climate['Air Pressure(hPa)'].mean(),inplace=True)
df2015Climate['SeaLevelPressure(hPa)'].fillna(df2015Climate['SeaLevelPressure(hPa)'].mean(),inplace=True)
df2015Climate['Ground Temperature(°C)'].fillna(df2015Climate['Ground Temperature(°C)'].mean(),inplace=True)
df2016Climate['Temperature(°C)'].fillna(df2016Climate['Temperature(°C)'].mean(),inplace=True)
df2016Climate['Rainfall(mm)'].fillna(df2016Climate['Rainfall(mm)'].mean(),inplace=True)
df2016Climate['wind Speed(m/s)'].fillna(df2016Climate['wind Speed(m/s)'].mean(),inplace=True)
df2016Climate['Wind Direction(16방위)'].fillna(df2016Climate['Wind Direction(16방위)'].mean(),inplace=True)
df2016Climate['Precipitation(%)'].fillna(df2016Climate['Precipitation(%)'].mean(),inplace=True)
df2016Climate['Vapor Pressure(hPa)'].fillna(df2016Climate['Vapor Pressure(hPa)'].mean(),inplace=True)
df2016Climate['Dew point Temperature(°C)'].fillna(df2016Climate['Dew point Temperature(°C)'].mean(),inplace=True)
df2016Climate['Air Pressure(hPa)'].fillna(df2016Climate['Air Pressure(hPa)'].mean(),inplace=True)
df2016Climate['SeaLevelPressure(hPa)'].fillna(df2016Climate['SeaLevelPressure(hPa)'].mean(),inplace=True)
df2016Climate['Ground Temperature(°C)'].fillna(df2016Climate['Ground Temperature(°C)'].mean(),inplace=True)
'''
df2015POIClimate['Temperature(°C)'].fillna(df2015POIClimate['Temperature(°C)'].mean(),inplace=True)
df2015POIClimate['Rainfall(mm)'].fillna(df2015POIClimate['Rainfall(mm)'].mean(),inplace=True)
df2015POIClimate['wind Speed(m/s)'].fillna(df2015POIClimate['wind Speed(m/s)'].mean(),inplace=True)
df2015POIClimate['Wind Direction(16방위)'].fillna(df2015POIClimate['Wind Direction(16방위)'].mean(),inplace=True)
df2015POIClimate['Precipitation(%)'].fillna(df2015POIClimate['Precipitation(%)'].mean(),inplace=True)
df2015POIClimate['Vapor Pressure(hPa)'].fillna(df2015POIClimate['Vapor Pressure(hPa)'].mean(),inplace=True)
df2015POIClimate['Dew point Temperature(°C)'].fillna(df2015POIClimate['Dew point Temperature(°C)'].mean(),inplace=True)
df2015POIClimate['Air Pressure(hPa)'].fillna(df2015POIClimate['Air Pressure(hPa)'].mean(),inplace=True)
df2015POIClimate['SeaLevelPressure(hPa)'].fillna(df2015POIClimate['SeaLevelPressure(hPa)'].mean(),inplace=True)
df2015POIClimate['Ground Temperature(°C)'].fillna(df2015POIClimate['Ground Temperature(°C)'].mean(),inplace=True)
df2016POIClimate['Temperature(°C)'].fillna(df2016POIClimate['Temperature(°C)'].mean(),inplace=True)
df2016POIClimate['Rainfall(mm)'].fillna(df2016POIClimate['Rainfall(mm)'].mean(),inplace=True)
df2016POIClimate['wind Speed(m/s)'].fillna(df2016POIClimate['wind Speed(m/s)'].mean(),inplace=True)
df2016POIClimate['Wind Direction(16방위)'].fillna(df2016POIClimate['Wind Direction(16방위)'].mean(),inplace=True)
df2016POIClimate['Precipitation(%)'].fillna(df2016POIClimate['Precipitation(%)'].mean(),inplace=True)
df2016POIClimate['Vapor Pressure(hPa)'].fillna(df2016POIClimate['Vapor Pressure(hPa)'].mean(),inplace=True)
df2016POIClimate['Dew point Temperature(°C)'].fillna(df2016POIClimate['Dew point Temperature(°C)'].mean(),inplace=True)
df2016POIClimate['Air Pressure(hPa)'].fillna(df2016POIClimate['Air Pressure(hPa)'].mean(),inplace=True)
df2016POIClimate['SeaLevelPressure(hPa)'].fillna(df2016POIClimate['SeaLevelPressure(hPa)'].mean(),inplace=True)
df2016POIClimate['Ground Temperature(°C)'].fillna(df2016POIClimate['Ground Temperature(°C)'].mean(),inplace=True)
'''
# Out:
# "\ndf2015POIClimate['Temperature(°C)'].fillna(df2015POIClimate['Temperature(°C)'].mean(),inplace=True)\ndf2015POIClimate['Rainfall(mm)'].fillna(df2015POIClimate['Rainfall(mm)'].mean(),inplace=True)\ndf2015POIClimate['wind Speed(m/s)'].fillna(df2015POIClimate['wind Speed(m/s)'].mean(),inplace=True)\ndf2015POIClimate['Wind Direction(16방위)'].fillna(df2015POIClimate['Wind Direction(16방위)'].mean(),inplace=True)\ndf2015POIClimate['Precipitation(%)'].fillna(df2015POIClimate['Precipitation(%)'].mean(),inplace=True)\ndf2015POIClimate['Vapor Pressure(hPa)'].fillna(df2015POIClimate['Vapor Pressure(hPa)'].mean(),inplace=True)\ndf2015POIClimate['Dew point Temperature(°C)'].fillna(df2015POIClimate['Dew point Temperature(°C)'].mean(),inplace=True)\ndf2015POIClimate['Air Pressure(hPa)'].fillna(df2015POIClimate['Air Pressure(hPa)'].mean(),inplace=True)\ndf2015POIClimate['SeaLevelPressure(hPa)'].fillna(df2015POIClimate['SeaLevelPressure(hPa)'].mean(),inplace=True)\ndf2015POIClimate['Ground Temperature
# ...

# %%
print(df2014Air[0:1])
print(df2015Air[0:1])
print(df2016Air[0:1])
# Out:
#                 City지역 Observatory측정소명  Measurement Date측정일시       DATE  TIME   SO2    CO    O3   NO2    PM10             Observatory Address주소
# 0  Kyung-Gi Hwasung Si    Namyang Dong        2014010101.000 2014-01-01 1.000 0.006 0.700 0.022 0.018 184.000  Kyung-Gi Hwasung Si Namyang Dong
#                 City지역 Observatory측정소명  Measurement Date측정일시       DATE  TIME   SO2    CO    O3   NO2   PM10             Observatory Address주소
# 0  Kyung-Gi Hwasung Si    Namyang Dong            2015010101 2015-01-01     1 0.004 0.300 0.023 0.006 41.000  Kyung-Gi Hwasung Si Namyang Dong
#                 City지역 Observatory측정소명  Measurement Date측정일시       DATE  TIME   SO2    CO    O3   NO2   PM10             Observatory Address주소
# 0  Kyung-Gi Hwasung Si    Namyang Dong                   nan 2016-01-01     1 0.002 0.900 0.002 0.028 67.000  Kyung-Gi Hwasung Si Namyang Dong

# %%
date2014a ='DATE'
time2014a ='TIME'
date2015a ='DATE'
time2015a ='TIME'
date2016a ='DATE'
time2016a ='TIME'
#AM air data
SO2AM = []
COAM = []
O3AM = []
NO2AM = []
PM10AM = []
PM25AM = []
SO2MaxAM = []
SO2MaxTimeAM = []
SO2MinAM = []
SO2MinTimeAM = []
COMaxAM = []
COMaxTimeAM = []
COMinAM = []
COMinTimeAM = []
O3MaxAM = []
O3MaxTimeAM = []
O3MinAM = []
O3MinTimeAM = []
NO2MaxAM = []
NO2MaxTimeAM = []
NO2MinAM = []
NO2MinTimeAM = []
PM10MaxAM = []
PM10MaxTimeAM = []
PM10MinAM = []
PM10MinTimeAM = []


for i in range(0,dateRangeAM.size):
    so2sum = 0
    so2maxtemp=-100000
    so2maxtimetemp=-1
    so2mintemp=100000
    so2mintimetemp=-1
    cosum=0
    comaxtemp=-100000
    comaxtimetemp=-1
    comintemp=100000
    comintimetemp=-1
    o3sum=0
    o3maxtemp=-100000
    o3maxtimetemp=-1
    o3mintemp=100000
    o3mintimetemp=-1
    no2sum=0
    no2maxtemp=-100000
    no2maxtimetemp=-1
    no2mintemp=100000
    no2mintimetemp=-1
    pm10sum=0
    pm10maxtemp=-100000
    pm10maxtimetemp=-1
    pm10mintemp=100000
    pm10mintimetemp=-1
    found = 0
    if dateRangeAM[i].year == 2014:
        for j in df2014Air.index:
            if df2014Air['DATE'][j].day == dateRangeAM[i].day and df2014Air['DATE'][j].month == dateRangeAM[i].month and timeAM[i].hour == df2014Air['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2014Air['SO2'][k]
                        cosum=cosum+df2014Air['CO'][k]
                        o3sum=o3sum+df2014Air['O3'][k]
                        no2sum=no2sum+df2014Air['NO2'][k]
                        pm10sum=pm10sum+df2014Air['PM10'][k]
                        if df2014Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2014Air['SO2'][k]  
                            so2maxtimetemp=df2014Air[time2014a][k] 
                        if df2014Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2014Air['SO2'][k]
                            so2mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['CO'][k] > comaxtemp:
                            comaxtemp=df2014Air['CO'][k] 
                            comaxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['CO'][k] < comintemp:
                            comintemp=df2014Air['CO'][k]
                            comintimetemp=df2014Air[time2014a][k]
                        if df2014Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2014Air['O3'][k]
                            o3maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['O3'][k] < o3mintemp:
                            o3mintemp=df2014Air['O3'][k]
                            o3mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2014Air['NO2'][k]
                            no2maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2014Air['NO2'][k]
                            no2mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2014Air['PM10'][k]
                            pm10maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2014Air['PM10'][k]
                            pm10mintimetemp=df2014Air[time2014a][k]
                        
                        
                    
                SO2AM.append(so2sum)
                COAM.append(cosum)
                O3AM.append(o3sum)
                NO2AM.append(no2sum)
                PM10AM.append(pm10sum)
                SO2MaxAM.append(so2maxtemp)
                SO2MaxTimeAM.append(so2maxtimetemp)
                SO2MinAM.append(so2mintemp)
                SO2MinTimeAM.append(so2mintimetemp)
                COMaxAM.append(comaxtemp)
                COMaxTimeAM.append(comaxtimetemp)
                COMinAM.append(comintemp)
                COMinTimeAM.append(comintimetemp)
                O3MaxAM.append(o3maxtemp)
                O3MaxTimeAM.append(o3maxtimetemp)
                O3MinAM.append(o3mintemp)
                O3MinTimeAM.append(o3mintimetemp)
                NO2MaxAM.append(no2maxtemp)
                NO2MaxTimeAM.append(no2maxtimetemp)
                NO2MinAM.append(no2mintemp)
                NO2MinTimeAM.append(no2mintimetemp)
                PM10MaxAM.append(pm10maxtemp)
                PM10MaxTimeAM.append(pm10maxtimetemp)
                PM10MinAM.append(pm10mintemp)
                PM10MinTimeAM.append(pm10mintimetemp)
                found =1
                break
    if dateRangeAM[i].year == 2015:
        for j in df2015Air.index:
            #datetime.datetime.strptime(str(df2015Air[date2015][j]),'%Y%m%d').date().day == dateRangeAM[i].day
            if df2015Air[date2015a][j].date().day == dateRangeAM[i].day and df2015Air[date2015a][j].date().month == dateRangeAM[i].month and timeAM[i].hour == df2015Air[time2015a][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2015Air['SO2'][k]
                        cosum=cosum+df2015Air['CO'][k]
                        o3sum=o3sum+df2015Air['O3'][k]
                        no2sum=no2sum+df2015Air['NO2'][k]
                        pm10sum=pm10sum+df2015Air['PM10'][k]
                        if df2015Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2015Air['SO2'][k]  
                            so2maxtimetemp=df2015Air[time2015a][k] 
                        if df2015Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2015Air['SO2'][k]
                            so2mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['CO'][k] > comaxtemp:
                            comaxtemp=df2015Air['CO'][k] 
                            comaxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['CO'][k] < comintemp:
                            comintemp=df2015Air['CO'][k]
                            comintimetemp=df2015Air[time2015a][k]
                        if df2015Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2015Air['O3'][k]
                            o3maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['O3'][k] < o3mintemp:
                            o3mintemp=df2015Air['O3'][k]
                            o3mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2015Air['NO2'][k]
                            no2maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2015Air['NO2'][k]
                            no2mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2015Air['PM10'][k]
                            pm10maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2015Air['PM10'][k]
                            pm10mintimetemp=df2015Air[time2015a][k]
                    
                SO2AM.append(so2sum)
                COAM.append(cosum)
                O3AM.append(o3sum)
                NO2AM.append(no2sum)
                PM10AM.append(pm10sum)
                SO2MaxAM.append(so2maxtemp)
                SO2MaxTimeAM.append(so2maxtimetemp)
                SO2MinAM.append(so2mintemp)
                SO2MinTimeAM.append(so2mintimetemp)
                COMaxAM.append(comaxtemp)
                COMaxTimeAM.append(comaxtimetemp)
                COMinAM.append(comintemp)
                COMinTimeAM.append(comintimetemp)
                O3MaxAM.append(o3maxtemp)
                O3MaxTimeAM.append(o3maxtimetemp)
                O3MinAM.append(o3mintemp)
                O3MinTimeAM.append(o3mintimetemp)
                NO2MaxAM.append(no2maxtemp)
                NO2MaxTimeAM.append(no2maxtimetemp)
                NO2MinAM.append(no2mintemp)
                NO2MinTimeAM.append(no2mintimetemp)
                PM10MaxAM.append(pm10maxtemp)
                PM10MaxTimeAM.append(pm10maxtimetemp)
                PM10MinAM.append(pm10mintemp)
                PM10MinTimeAM.append(pm10mintimetemp)
                found=1
                break
    if dateRangeAM[i].year == 2016:
        for j in df2016Air.index:
            if df2016Air[date2016a][j].day == dateAM[i].day and df2016Air[date2016a][j].month == dateAM[i].month and timeAM[i].hour == df2016Air[time2016a][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2016Air['SO2'][k]
                        cosum=cosum+df2016Air['CO'][k]
                        o3sum=o3sum+df2016Air['O3'][k]
                        no2sum=no2sum+df2016Air['NO2'][k]
                        pm10sum=pm10sum+df2016Air['PM10'][k]
                        if df2016Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2016Air['SO2'][k]  
                            so2maxtimetemp=df2016Air[time2016a][k] 
                        if df2016Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2016Air['SO2'][k]
                            so2mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['CO'][k] > comaxtemp:
                            comaxtemp=df2016Air['CO'][k] 
                            comaxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['CO'][k] < comintemp:
                            comintemp=df2016Air['CO'][k]
                            comintimetemp=df2016Air[time2016a][k]
                        if df2016Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2016Air['O3'][k]
                            o3maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['O3'][k] < o3mintemp:
                            o3mintemp=df2016Air['O3'][k]
                            o3mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2016Air['NO2'][k]
                            no2maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2016Air['NO2'][k]
                            no2mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2016Air['PM10'][k]
                            pm10maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2016Air['PM10'][k]
                            pm10mintimetemp=df2016Air[time2016a][k]                   
                    
                SO2AM.append(so2sum)
                COAM.append(cosum)
                O3AM.append(o3sum)
                NO2AM.append(no2sum)
                PM10AM.append(pm10sum)
                SO2MaxAM.append(so2maxtemp)
                SO2MaxTimeAM.append(so2maxtimetemp)
                SO2MinAM.append(so2mintemp)
                SO2MinTimeAM.append(so2mintimetemp)
                COMaxAM.append(comaxtemp)
                COMaxTimeAM.append(comaxtimetemp)
                COMinAM.append(comintemp)
                COMinTimeAM.append(comintimetemp)
                O3MaxAM.append(o3maxtemp)
                O3MaxTimeAM.append(o3maxtimetemp)
                O3MinAM.append(o3mintemp)
                O3MinTimeAM.append(o3mintimetemp)
                NO2MaxAM.append(no2maxtemp)
                NO2MaxTimeAM.append(no2maxtimetemp)
                NO2MinAM.append(no2mintemp)
                NO2MinTimeAM.append(no2mintimetemp)
                PM10MaxAM.append(pm10maxtemp)
                PM10MaxTimeAM.append(pm10maxtimetemp)
                PM10MinAM.append(pm10mintemp)
                PM10MinTimeAM.append(pm10mintimetemp)
                found=1
                break
    if found==0:
        SO2AM.append(None)
        COAM.append(None)
        O3AM.append(None)
        NO2AM.append(None)
        PM10AM.append(None)
        SO2MaxAM.append(None)
        SO2MaxTimeAM.append(None)
        SO2MinAM.append(None)
        SO2MinTimeAM.append(None)
        COMaxAM.append(None)
        COMaxTimeAM.append(None)
        COMinAM.append(None)
        COMinTimeAM.append(None)
        O3MaxAM.append(None)
        O3MaxTimeAM.append(None)
        O3MinAM.append(None)
        O3MinTimeAM.append(None)
        NO2MaxAM.append(None)
        NO2MaxTimeAM.append(None)
        NO2MinAM.append(None)
        NO2MinTimeAM.append(None)
        PM10MaxAM.append(None)
        PM10MaxTimeAM.append(None)
        PM10MinAM.append(None)
        PM10MinTimeAM.append(None)

# %%
print(df2014POIAir[0:1])
print(df2015POIAir[0:1])
print(df2016POIAir[0:1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-0214817747b8> in <module>()
# ----> 1 print(df2014POIAir[0:1])
#       2 print(df2015POIAir[0:1])
#       3 print(df2016POIAir[0:1])
#
# NameError: name 'df2014POIAir' is not defined

# %%
date2014apoi ='DATE'
time2014apoi ='TIME'
date2015apoi ='DATE'
time2015apoi ='TIME'
date2016apoi ='DATE'
time2016apoi ='TIME'
#AM air data POI
SO2AMPOI = []
COAMPOI = []
O3AMPOI = []
NO2AMPOI = []
PM10AMPOI = []
PM25AMPOI = []
SO2MaxAMPOI = []
SO2MaxTimeAMPOI = []
SO2MinAMPOI = []
SO2MinTimeAMPOI = []
COMaxAMPOI = []
COMaxTimeAMPOI = []
COMinAMPOI = []
COMinTimeAMPOI = []
O3MaxAMPOI = []
O3MaxTimeAMPOI = []
O3MinAMPOI = []
O3MinTimeAMPOI = []
NO2MaxAMPOI = []
NO2MaxTimeAMPOI = []
NO2MinAMPOI = []
NO2MinTimeAMPOI = []
PM10MaxAMPOI = []
PM10MaxTimeAMPOI = []
PM10MinAMPOI = []
PM10MinTimeAMPOI = []
print(df2016POIAir)
time2014='TIME'
time2015='TIME'
time2016='TIME'
for i in range(0,dateRangeAM.size):
    so2sum = 0
    so2maxtemp=-100000
    so2maxtimetemp=-1
    so2mintemp=100000
    so2mintimetemp=-1
    cosum=0
    comaxtemp=-100000
    comaxtimetemp=-1
    comintemp=100000
    comintimetemp=-1
    o3sum=0
    o3maxtemp=-100000
    o3maxtimetemp=-1
    o3mintemp=100000
    o3mintimetemp=-1
    no2sum=0
    no2maxtemp=-100000
    no2maxtimetemp=-1
    no2mintemp=100000
    no2mintimetemp=-1
    pm10sum=0
    pm10maxtemp=-100000
    pm10maxtimetemp=-1
    pm10mintemp=100000
    pm10mintimetemp=-1
    found = 0
    if dateAM[i].year == 2014:
        for j in df2014POIAir.index:
            if df2014POIAir['DATE'][j].day == dateAM[i].day and df2014POIAir['DATE'][j].month == dateAM[i].month and timeAM[i].hour == df2014POIAir[time2014apoi][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2014POIAir['SO2'][k]
                        cosum=cosum+df2014POIAir['CO'][k]
                        o3sum=o3sum+df2014POIAir['O3'][k]
                        no2sum=no2sum+df2014POIAir['NO2'][k]
                        pm10sum=pm10sum+df2014POIAir['PM10'][k]
                        if df2014POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2014POIAir['SO2'][k]  
                            so2maxtimetemp=df2014POIAir[time2014apoi][k] 
                        if df2014POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2014POIAir['SO2'][k]
                            so2mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2014POIAir['CO'][k] 
                            comaxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['CO'][k] < comintemp:
                            comintemp=df2014POIAir['CO'][k]
                            comintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2014POIAir['O3'][k]
                            o3maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2014Air['O3'][k]
                            o3mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2014POIAir['NO2'][k]
                            no2maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2014POIAir['NO2'][k]
                            no2mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2014POIAir['PM10'][k]
                            pm10maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2014POIAir['PM10'][k]
                            pm10mintimetemp=df2014POIAir[time2014apoi][k]                   
                    
                SO2AMPOI.append(so2sum)
                COAMPOI.append(cosum)
                O3AMPOI.append(o3sum)
                NO2AMPOI.append(no2sum)
                PM10AMPOI.append(pm10sum)
                SO2MaxAMPOI.append(so2maxtemp)
                SO2MaxTimeAMPOI.append(so2maxtimetemp)
                SO2MinAMPOI.append(so2mintemp)
                SO2MinTimeAMPOI.append(so2mintimetemp)
                COMaxAMPOI.append(comaxtemp)
                COMaxTimeAMPOI.append(comaxtimetemp)
                COMinAMPOI.append(comintemp)
                COMinTimeAMPOI.append(comintimetemp)
                O3MaxAMPOI.append(o3maxtemp)
                O3MaxTimeAMPOI.append(o3maxtimetemp)
                O3MinAMPOI.append(o3mintemp)
                O3MinTimeAMPOI.append(o3mintimetemp)
                NO2MaxAMPOI.append(no2maxtemp)
                NO2MaxTimeAMPOI.append(no2maxtimetemp)
                NO2MinAMPOI.append(no2mintemp)
                NO2MinTimeAMPOI.append(no2mintimetemp)
                PM10MaxAMPOI.append(pm10maxtemp)
                PM10MaxTimeAMPOI.append(pm10maxtimetemp)
                PM10MinAMPOI.append(pm10mintemp)
                PM10MinTimeAMPOI.append(pm10mintimetemp)
                found =1
                break
    if dateAM[i].year == 2015:
        for j in df2015POIAir.index:
            if datetime.datetime.strptime(str(df2015POIAir['DATE'][j]),'%Y%m%d').date().day == dateAM[i].day and datetime.datetime.strptime(str(df2015POIAir['DATE'][j]),'%Y%m%d').date().month == dateAM[i].month and timeAM[i].hour == df2015POIAir[time2015apoi][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2015POIAir['SO2'][k]
                        cosum=cosum+df2015POIAir['CO'][k]
                        o3sum=o3sum+df2015POIAir['O3'][k]
                        no2sum=no2sum+df2015POIAir['NO2'][k]
                        pm10sum=pm10sum+df2015POIAir['PM10'][k]
                        if df2015POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2015POIAir['SO2'][k]  
                            so2maxtimetemp=df2015POIAir[time2015apoi][k] 
                        if df2015POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2015POIAir['SO2'][k]
                            so2mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2015POIAir['CO'][k] 
                            comaxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['CO'][k] < comintemp:
                            comintemp=df2015POIAir['CO'][k]
                            comintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2015POIAir['O3'][k]
                            o3maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2015Air['O3'][k]
                            o3mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2015POIAir['NO2'][k]
                            no2maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2015POIAir['NO2'][k]
                            no2mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2015POIAir['PM10'][k]
                            pm10maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2015POIAir['PM10'][k]
                            pm10mintimetemp=df2015POIAir[time2015apoi][k]                        
                    
                SO2AMPOI.append(so2sum)
                COAMPOI.append(cosum)
                O3AMPOI.append(o3sum)
                NO2AMPOI.append(no2sum)
                PM10AMPOI.append(pm10sum)
                SO2MaxAMPOI.append(so2maxtemp)
                SO2MaxTimeAMPOI.append(so2maxtimetemp)
                SO2MinAMPOI.append(so2mintemp)
                SO2MinTimeAMPOI.append(so2mintimetemp)
                COMaxAMPOI.append(comaxtemp)
                COMaxTimeAMPOI.append(comaxtimetemp)
                COMinAMPOI.append(comintemp)
                COMinTimeAMPOI.append(comintimetemp)
                O3MaxAMPOI.append(o3maxtemp)
                O3MaxTimeAMPOI.append(o3maxtimetemp)
                O3MinAMPOI.append(o3mintemp)
                O3MinTimeAMPOI.append(o3mintimetemp)
                NO2MaxAMPOI.append(no2maxtemp)
                NO2MaxTimeAMPOI.append(no2maxtimetemp)
                NO2MinAMPOI.append(no2mintemp)
                NO2MinTimeAMPOI.append(no2mintimetemp)
                PM10MaxAMPOI.append(pm10maxtemp)
                PM10MaxTimeAMPOI.append(pm10maxtimetemp)
                PM10MinAMPOI.append(pm10mintemp)
                PM10MinTimeAMPOI.append(pm10mintimetemp)                
                found=1
                break
    if dateAM[i].year == 2016:
        for j in df2016POIAir.index:
            if df2016POIAir['DATE'][j].day == dateAM[i].day and df2016POIAir['DATE'][j].month == dateAM[i].month and timeAM[i].hour == df2016POIAir[time2016apoi][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2016POIAir['SO2'][k]
                        cosum=cosum+df2016POIAir['CO'][k]
                        o3sum=o3sum+df2016POIAir['O3'][k]
                        no2sum=no2sum+df2016POIAir['NO2'][k]
                        pm10sum=pm10sum+df2016POIAir['PM10'][k]
                        if df2016POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2016POIAir['SO2'][k]  
                            so2maxtimetemp=df2016POIAir[time2016apoi][k] 
                        if df2016POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2016POIAir['SO2'][k]
                            so2mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2016POIAir['CO'][k] 
                            comaxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['CO'][k] < comintemp:
                            comintemp=df2016POIAir['CO'][k]
                            comintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2016POIAir['O3'][k]
                            o3maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2016Air['O3'][k]
                            o3mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2016POIAir['NO2'][k]
                            no2maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2016POIAir['NO2'][k]
                            no2mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2016POIAir['PM10'][k]
                            pm10maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2016POIAir['PM10'][k]
                            pm10mintimetemp=df2016POIAir[time2016apoi][k]                           
                    
                SO2AMPOI.append(so2sum)
                COAMPOI.append(cosum)
                O3AMPOI.append(o3sum)
                NO2AMPOI.append(no2sum)
                PM10AMPOI.append(pm10sum)
                SO2MaxAMPOI.append(so2maxtemp)
                SO2MaxTimeAMPOI.append(so2maxtimetemp)
                SO2MinAMPOI.append(so2mintemp)
                SO2MinTimeAMPOI.append(so2mintimetemp)
                COMaxAMPOI.append(comaxtemp)
                COMaxTimeAMPOI.append(comaxtimetemp)
                COMinAMPOI.append(comintemp)
                COMinTimeAMPOI.append(comintimetemp)
                O3MaxAMPOI.append(o3maxtemp)
                O3MaxTimeAMPOI.append(o3maxtimetemp)
                O3MinAMPOI.append(o3mintemp)
                O3MinTimeAMPOI.append(o3mintimetemp)
                NO2MaxAMPOI.append(no2maxtemp)
                NO2MaxTimeAMPOI.append(no2maxtimetemp)
                NO2MinAMPOI.append(no2mintemp)
                NO2MinTimeAMPOI.append(no2mintimetemp)
                PM10MaxAMPOI.append(pm10maxtemp)
                PM10MaxTimeAMPOI.append(pm10maxtimetemp)
                PM10MinAMPOI.append(pm10mintemp)
                PM10MinTimeAMPOI.append(pm10mintimetemp)                
                found=1
                break
    if found==0:
        SO2AMPOI.append(None)
        COAMPOI.append(None)
        O3AMPOI.append(None)
        NO2AMPOI.append(None)
        PM10AMPOI.append(None)
        SO2MaxAMPOI.append(None)
        SO2MaxTimeAMPOI.append(None)
        SO2MinAMPOI.append(None)
        SO2MinTimeAMPOI.append(None)
        COMaxAMPOI.append(None)
        COMaxTimeAMPOI.append(None)
        COMinAMPOI.append(None)
        COMinTimeAMPOI.append(None)
        O3MaxAMPOI.append(None)
        O3MaxTimeAMPOI.append(None)
        O3MinAMPOI.append(None)
        O3MinTimeAMPOI.append(None)
        NO2MaxAMPOI.append(None)
        NO2MaxTimeAMPOI.append(None)
        NO2MinAMPOI.append(None)
        NO2MinTimeAMPOI.append(None)
        PM10MaxAMPOI.append(None)
        PM10MaxTimeAMPOI.append(None)
        PM10MinAMPOI.append(None)
        PM10MinTimeAMPOI.append(None)
# Out:
#                   City지역 Observatory측정소명  Observatory Code측정소코드  Measurement Date측정일시       DATE  TIME   SO2    CO    O3   NO2    PM10     Obervatory Address주소
# 0     Inchon Bu-Pyung Gu    Bu-Pyung Stn                 823634                   nan 2016-01-01     1 0.008 1.600 0.002 0.064  66.000  Inchon Bu-Pyung Gu 부평3동
# 1     Inchon Bu-Pyung Gu    Bu-Pyung Stn                 823634                   nan 2016-01-01     2 0.008 1.800 0.002 0.062  68.000  Inchon Bu-Pyung Gu 부평3동
# 2     Inchon Bu-Pyung Gu    Bu-Pyung Stn                 823634                   nan 2016-01-01     3 0.007 1.700 0.002 0.059  66.000  Inchon Bu-Pyung Gu 부평3동
# 3     Inchon Bu-Pyung Gu    Bu-Pyung Stn                 823634                   nan 2016-01-01     4 0.007 1.400 0.002 0.055  61.000  Inchon Bu-Pyung Gu 부평3동
# ...                  ...             ...                    ...                   ...        ...   ...   ...   ...   ...   ...     ...                      ...
# ...

# %%
#PM Air data
SO2PM = []
COPM = []
O3PM = []
NO2PM = []
PM10PM = []
PM25PM = []
SO2MaxPM = []
SO2MaxTimePM = []
SO2MinPM = []
SO2MinTimePM = []
COMaxPM = []
COMaxTimePM = []
COMinPM = []
COMinTimePM = []
O3MaxPM = []
O3MaxTimePM = []
O3MinPM = []
O3MinTimePM = []
NO2MaxPM = []
NO2MaxTimePM = []
NO2MinPM = []
NO2MinTimePM = []
PM10MaxPM = []
PM10MaxTimePM = []
PM10MinPM = []
PM10MinTimePM = []
print(df2015Air)
for i in range(0,dateRangePM.size):
    so2sum = 0
    so2maxtemp=-100000
    so2maxtimetemp=-1
    so2mintemp=100000
    so2mintimetemp=-1
    cosum=0
    comaxtemp=-100000
    comaxtimetemp=-1
    comintemp=100000
    comintimetemp=-1
    o3sum=0
    o3maxtemp=-100000
    o3maxtimetemp=-1
    o3mintemp=100000
    o3mintimetemp=-1
    no2sum=0
    no2maxtemp=-100000
    no2maxtimetemp=-1
    no2mintemp=100000
    no2mintimetemp=-1
    pm10sum=0
    pm10maxtemp=-100000
    pm10maxtimetemp=-1
    pm10mintemp=100000
    pm10mintimetemp=-1
    found = 0
    if datePM[i].year == 2014:
        for j in df2014Air.index:
            if df2014Air['DATE'][j].day == datePM[i].day and df2014Air['DATE'][j].month == datePM[i].month and timePM[i].hour == df2014Air['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2014Air['SO2'][k]
                        cosum=cosum+df2014Air['CO'][k]
                        o3sum=o3sum+df2014Air['O3'][k]
                        no2sum=no2sum+df2014Air['NO2'][k]
                        pm10sum=pm10sum+df2014Air['PM10'][k]
                        if df2014Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2014Air['SO2'][k]  
                            so2maxtimetemp=df2014Air[time2014a][k] 
                        if df2014Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2014Air['SO2'][k]
                            so2mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['CO'][k] > comaxtemp:
                            comaxtemp=df2014Air['CO'][k] 
                            comaxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['CO'][k] < comintemp:
                            comintemp=df2014Air['CO'][k]
                            comintimetemp=df2014Air[time2014a][k]
                        if df2014Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2014Air['O3'][k]
                            o3maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['O3'][k] < o3mintemp:
                            o3mintemp=df2014Air['O3'][k]
                            o3mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2014Air['NO2'][k]
                            no2maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2014Air['NO2'][k]
                            no2mintimetemp=df2014Air[time2014a][k]
                        if df2014Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2014Air['PM10'][k]
                            pm10maxtimetemp=df2014Air[time2014a][k]
                        if df2014Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2014Air['PM10'][k]
                            pm10mintimetemp=df2014Air[time2014a][k]                       
                    
                SO2PM.append(so2sum)
                COPM.append(cosum)
                O3PM.append(o3sum)
                NO2PM.append(no2sum)
                PM10PM.append(pm10sum)
                SO2MaxPM.append(so2maxtemp)
                SO2MaxTimePM.append(so2maxtimetemp)
                SO2MinPM.append(so2mintemp)
                SO2MinTimePM.append(so2mintimetemp)
                COMaxPM.append(comaxtemp)
                COMaxTimePM.append(comaxtimetemp)
                COMinPM.append(comintemp)
                COMinTimePM.append(comintimetemp)
                O3MaxPM.append(o3maxtemp)
                O3MaxTimePM.append(o3maxtimetemp)
                O3MinPM.append(o3mintemp)
                O3MinTimePM.append(o3mintimetemp)
                NO2MaxPM.append(no2maxtemp)
                NO2MaxTimePM.append(no2maxtimetemp)
                NO2MinPM.append(no2mintemp)
                NO2MinTimePM.append(no2mintimetemp)
                PM10MaxPM.append(pm10maxtemp)
                PM10MaxTimePM.append(pm10maxtimetemp)
                PM10MinPM.append(pm10mintemp)
                PM10MinTimePM.append(pm10mintimetemp)                
                found =1
                break
    if datePM[i].year == 2015:
        for j in df2015Air.index:
            #datetime.datetime.strptime(str(df2015Air[date2015][j]),'%Y%m%d').date().day == dateRangeAM[i].day
            if df2015Air[date2015a][j].date().day == datePM[i].day and df2015Air[date2015a][j].date().month == datePM[i].month and timePM[i].hour == df2015Air[time2015a][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2015Air['SO2'][k]
                        cosum=cosum+df2015Air['CO'][k]
                        o3sum=o3sum+df2015Air['O3'][k]
                        no2sum=no2sum+df2015Air['NO2'][k]
                        pm10sum=pm10sum+df2015Air['PM10'][k]
                        if df2015Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2015Air['SO2'][k]  
                            so2maxtimetemp=df2015Air[time2015a][k] 
                        if df2015Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2015Air['SO2'][k]
                            so2mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['CO'][k] > comaxtemp:
                            comaxtemp=df2015Air['CO'][k] 
                            comaxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['CO'][k] < comintemp:
                            comintemp=df2015Air['CO'][k]
                            comintimetemp=df2015Air[time2015a][k]
                        if df2015Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2015Air['O3'][k]
                            o3maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['O3'][k] < o3mintemp:
                            o3mintemp=df2015Air['O3'][k]
                            o3mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2015Air['NO2'][k]
                            no2maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2015Air['NO2'][k]
                            no2mintimetemp=df2015Air[time2015a][k]
                        if df2015Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2015Air['PM10'][k]
                            pm10maxtimetemp=df2015Air[time2015a][k]
                        if df2015Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2015Air['PM10'][k]
                            pm10mintimetemp=df2015Air[time2015a][k]                       
                    
                SO2PM.append(so2sum)
                COPM.append(cosum)
                O3PM.append(o3sum)
                NO2PM.append(no2sum)
                PM10PM.append(pm10sum)
                SO2MaxPM.append(so2maxtemp)
                SO2MaxTimePM.append(so2maxtimetemp)
                SO2MinPM.append(so2mintemp)
                SO2MinTimePM.append(so2mintimetemp)
                COMaxPM.append(comaxtemp)
                COMaxTimePM.append(comaxtimetemp)
                COMinPM.append(comintemp)
                COMinTimePM.append(comintimetemp)
                O3MaxPM.append(o3maxtemp)
                O3MaxTimePM.append(o3maxtimetemp)
                O3MinPM.append(o3mintemp)
                O3MinTimePM.append(o3mintimetemp)
                NO2MaxPM.append(no2maxtemp)
                NO2MaxTimePM.append(no2maxtimetemp)
                NO2MinPM.append(no2mintemp)
                NO2MinTimePM.append(no2mintimetemp)
                PM10MaxPM.append(pm10maxtemp)
                PM10MaxTimePM.append(pm10maxtimetemp)
                PM10MinPM.append(pm10mintemp)
                PM10MinTimePM.append(pm10mintimetemp)                 
                found=1
                break
    if datePM[i].year == 2016:
        for j in df2016Air.index:
            if df2016Air[date2016a][j].day == datePM[i].day and df2016Air[date2016a][j].month == datePM[i].month and timePM[i].hour == df2016Air[time2016a][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2016Air['SO2'][k]
                        cosum=cosum+df2016Air['CO'][k]
                        o3sum=o3sum+df2016Air['O3'][k]
                        no2sum=no2sum+df2016Air['NO2'][k]
                        pm10sum=pm10sum+df2016Air['PM10'][k]
                        if df2016Air['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2016Air['SO2'][k]  
                            so2maxtimetemp=df2016Air[time2016a][k] 
                        if df2016Air['SO2'][k] < so2mintemp:
                            so2mintemp=df2016Air['SO2'][k]
                            so2mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['CO'][k] > comaxtemp:
                            comaxtemp=df2016Air['CO'][k] 
                            comaxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['CO'][k] < comintemp:
                            comintemp=df2016Air['CO'][k]
                            comintimetemp=df2016Air[time2016a][k]
                        if df2016Air['O3'][k] > o3maxtemp:
                            o3maxtemp=df2016Air['O3'][k]
                            o3maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['O3'][k] < o3mintemp:
                            o3mintemp=df2016Air['O3'][k]
                            o3mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2016Air['NO2'][k]
                            no2maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['NO2'][k] < no2mintemp:
                            no2mintemp=df2016Air['NO2'][k]
                            no2mintimetemp=df2016Air[time2016a][k]
                        if df2016Air['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2016Air['PM10'][k]
                            pm10maxtimetemp=df2016Air[time2016a][k]
                        if df2016Air['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2016Air['PM10'][k]
                            pm10mintimetemp=df2016Air[time2016a][k]                          
                    
                SO2PM.append(so2sum)
                COPM.append(cosum)
                O3PM.append(o3sum)
                NO2PM.append(no2sum)
                PM10PM.append(pm10sum)
                SO2MaxPM.append(so2maxtemp)
                SO2MaxTimePM.append(so2maxtimetemp)
                SO2MinPM.append(so2mintemp)
                SO2MinTimePM.append(so2mintimetemp)
                COMaxPM.append(comaxtemp)
                COMaxTimePM.append(comaxtimetemp)
                COMinPM.append(comintemp)
                COMinTimePM.append(comintimetemp)
                O3MaxPM.append(o3maxtemp)
                O3MaxTimePM.append(o3maxtimetemp)
                O3MinPM.append(o3mintemp)
                O3MinTimePM.append(o3mintimetemp)
                NO2MaxPM.append(no2maxtemp)
                NO2MaxTimePM.append(no2maxtimetemp)
                NO2MinPM.append(no2mintemp)
                NO2MinTimePM.append(no2mintimetemp)
                PM10MaxPM.append(pm10maxtemp)
                PM10MaxTimePM.append(pm10maxtimetemp)
                PM10MinPM.append(pm10mintemp)
                PM10MinTimePM.append(pm10mintimetemp)                 
                found=1
                break
    if found==0:
        SO2PM.append(None)
        COPM.append(None)
        O3PM.append(None)
        NO2PM.append(None)
        PM10PM.append(None)
        SO2MaxPM.append(None)
        SO2MaxTimePM.append(None)
        SO2MinPM.append(None)
        SO2MinTimePM.append(None)
        COMaxPM.append(None)
        COMaxTimePM.append(None)
        COMinPM.append(None)
        COMinTimePM.append(None)
        O3MaxPM.append(None)
        O3MaxTimePM.append(None)
        O3MinPM.append(None)
        O3MinTimePM.append(None)
        NO2MaxPM.append(None)
        NO2MaxTimePM.append(None)
        NO2MinPM.append(None)
        NO2MinTimePM.append(None)
        PM10MaxPM.append(None)
        PM10MaxTimePM.append(None)
        PM10MinPM.append(None)
        PM10MinTimePM.append(None)
# Out:
#                    City지역 Observatory측정소명  Measurement Date측정일시       DATE  TIME   SO2    CO    O3   NO2    PM10             Observatory Address주소
# 0     Kyung-Gi Hwasung Si    Namyang Dong            2015010101 2015-01-01     1 0.004 0.300 0.023 0.006  41.000  Kyung-Gi Hwasung Si Namyang Dong
# 1     Kyung-Gi Hwasung Si    Namyang Dong            2015010102 2015-01-01     2 0.004 0.300 0.021 0.006  75.000  Kyung-Gi Hwasung Si Namyang Dong
# 2     Kyung-Gi Hwasung Si    Namyang Dong            2015010103 2015-01-01     3 0.004 0.300 0.022 0.005 105.000  Kyung-Gi Hwasung Si Namyang Dong
# 3     Kyung-Gi Hwasung Si    Namyang Dong            2015010104 2015-01-01     4 0.004 0.300 0.021 0.005 117.000  Kyung-Gi Hwasung Si Namyang Dong
# ...                   ...             ...                   ...        ...   ...   ...   ...   ...   ...     ...                               ...
# ...

# %%
#PM air data POI
SO2PMPOI = []
COPMPOI = []
O3PMPOI = []
NO2PMPOI = []
PM10PMPOI = []
PM25PMPOI = []
SO2MaxPMPOI = []
SO2MaxTimePMPOI = []
SO2MinPMPOI = []
SO2MinTimePMPOI = []
COMaxPMPOI = []
COMaxTimePMPOI = []
COMinPMPOI = []
COMinTimePMPOI = []
O3MaxPMPOI = []
O3MaxTimePMPOI = []
O3MinPMPOI = []
O3MinTimePMPOI = []
NO2MaxPMPOI = []
NO2MaxTimePMPOI = []
NO2MinPMPOI = []
NO2MinTimePMPOI = []
PM10MaxPMPOI = []
PM10MaxTimePMPOI = []
PM10MinPMPOI = []
PM10MinTimePMPOI = []
print(df2015POIAir)
for i in range(0,dateRangePM.size):
    so2sum = 0
    so2maxtemp=-100000
    so2maxtimetemp=-1
    so2mintemp=100000
    so2mintimetemp=-1
    cosum=0
    comaxtemp=-100000
    comaxtimetemp=-1
    comintemp=100000
    comintimetemp=-1
    o3sum=0
    o3maxtemp=-100000
    o3maxtimetemp=-1
    o3mintemp=100000
    o3mintimetemp=-1
    no2sum=0
    no2maxtemp=-100000
    no2maxtimetemp=-1
    no2mintemp=100000
    no2mintimetemp=-1
    pm10sum=0
    pm10maxtemp=-100000
    pm10maxtimetemp=-1
    pm10mintemp=100000
    pm10mintimetemp=-1
    found = 0
    if datePM[i].year == 2014:
        for j in df2014POIAir.index:
            if df2014POIAir['DATE'][j].day == datePM[i].day and df2014POIAir['DATE'][j].month == dateAM[i].month and timePM[i].hour == df2014POIAir['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2014POIAir['SO2'][k]
                        cosum=cosum+df2014POIAir['CO'][k]
                        o3sum=o3sum+df2014POIAir['O3'][k]
                        no2sum=no2sum+df2014POIAir['NO2'][k]
                        pm10sum=pm10sum+df2014POIAir['PM10'][k]
                        if df2014POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2014POIAir['SO2'][k]  
                            so2maxtimetemp=df2014POIAir[time2014apoi][k] 
                        if df2014POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2014POIAir['SO2'][k]
                            so2mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2014POIAir['CO'][k] 
                            comaxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['CO'][k] < comintemp:
                            comintemp=df2014POIAir['CO'][k]
                            comintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2014POIAir['O3'][k]
                            o3maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2014Air['O3'][k]
                            o3mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2014POIAir['NO2'][k]
                            no2maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2014POIAir['NO2'][k]
                            no2mintimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2014POIAir['PM10'][k]
                            pm10maxtimetemp=df2014POIAir[time2014apoi][k]
                        if df2014POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2014POIAir['PM10'][k]
                            pm10mintimetemp=df2014POIAir[time2014apoi][k]                          
                    
                SO2PMPOI.append(so2sum)
                COPMPOI.append(cosum)
                O3PMPOI.append(o3sum)
                NO2PMPOI.append(no2sum)
                PM10PMPOI.append(pm10sum)
                SO2MaxPMPOI.append(so2maxtemp)
                SO2MaxTimePMPOI.append(so2maxtimetemp)
                SO2MinPMPOI.append(so2mintemp)
                SO2MinTimePMPOI.append(so2mintimetemp)
                COMaxPMPOI.append(comaxtemp)
                COMaxTimePMPOI.append(comaxtimetemp)
                COMinPMPOI.append(comintemp)
                COMinTimePMPOI.append(comintimetemp)
                O3MaxPMPOI.append(o3maxtemp)
                O3MaxTimePMPOI.append(o3maxtimetemp)
                O3MinPMPOI.append(o3mintemp)
                O3MinTimePMPOI.append(o3mintimetemp)
                NO2MaxPMPOI.append(no2maxtemp)
                NO2MaxTimePMPOI.append(no2maxtimetemp)
                NO2MinPMPOI.append(no2mintemp)
                NO2MinTimePMPOI.append(no2mintimetemp)
                PM10MaxPMPOI.append(pm10maxtemp)
                PM10MaxTimePMPOI.append(pm10maxtimetemp)
                PM10MinPMPOI.append(pm10mintemp)
                PM10MinTimePMPOI.append(pm10mintimetemp)                
                found =1
                break
    if datePM[i].year == 2015:
        for j in df2015POIAir.index:
            if datetime.datetime.strptime(str(df2015POIAir['DATE'][j]),'%Y%m%d').date().day == datePM[i].day and datetime.datetime.strptime(str(df2015POIAir['DATE'][j]),'%Y%m%d').date().month == datePM[i].month and timePM[i].hour == df2015POIAir['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2015POIAir['SO2'][k]
                        cosum=cosum+df2015POIAir['CO'][k]
                        o3sum=o3sum+df2015POIAir['O3'][k]
                        no2sum=no2sum+df2015POIAir['NO2'][k]
                        pm10sum=pm10sum+df2015POIAir['PM10'][k]
                        if df2015POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2015POIAir['SO2'][k]  
                            so2maxtimetemp=df2015POIAir[time2015apoi][k] 
                        if df2015POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2015POIAir['SO2'][k]
                            so2mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2015POIAir['CO'][k] 
                            comaxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['CO'][k] < comintemp:
                            comintemp=df2015POIAir['CO'][k]
                            comintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2015POIAir['O3'][k]
                            o3maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2015Air['O3'][k]
                            o3mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2015POIAir['NO2'][k]
                            no2maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2015POIAir['NO2'][k]
                            no2mintimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2015POIAir['PM10'][k]
                            pm10maxtimetemp=df2015POIAir[time2015apoi][k]
                        if df2015POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2015POIAir['PM10'][k]
                            pm10mintimetemp=df2015POIAir[time2015apoi][k]                         
                    
                SO2PMPOI.append(so2sum)
                COPMPOI.append(cosum)
                O3PMPOI.append(o3sum)
                NO2PMPOI.append(no2sum)
                PM10PMPOI.append(pm10sum)
                SO2MaxPMPOI.append(so2maxtemp)
                SO2MaxTimePMPOI.append(so2maxtimetemp)
                SO2MinPMPOI.append(so2mintemp)
                SO2MinTimePMPOI.append(so2mintimetemp)
                COMaxPMPOI.append(comaxtemp)
                COMaxTimePMPOI.append(comaxtimetemp)
                COMinPMPOI.append(comintemp)
                COMinTimePMPOI.append(comintimetemp)
                O3MaxPMPOI.append(o3maxtemp)
                O3MaxTimePMPOI.append(o3maxtimetemp)
                O3MinPMPOI.append(o3mintemp)
                O3MinTimePMPOI.append(o3mintimetemp)
                NO2MaxPMPOI.append(no2maxtemp)
                NO2MaxTimePMPOI.append(no2maxtimetemp)
                NO2MinPMPOI.append(no2mintemp)
                NO2MinTimePMPOI.append(no2mintimetemp)
                PM10MaxPMPOI.append(pm10maxtemp)
                PM10MaxTimePMPOI.append(pm10maxtimetemp)
                PM10MinPMPOI.append(pm10mintemp)
                PM10MinTimePMPOI.append(pm10mintimetemp)
                found=1
                break
    if datePM[i].year == 2016:
        for j in df2016POIAir.index:
            if df2016POIAir['DATE'][j].day == datePM[i].day and df2016POIAir['DATE'][j].month == datePM[i].month and timePM[i].hour == df2016POIAir[time2016apoi][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                        so2sum = so2sum+df2016POIAir['SO2'][k]
                        cosum=cosum+df2016POIAir['CO'][k]
                        o3sum=o3sum+df2016POIAir['O3'][k]
                        no2sum=no2sum+df2016POIAir['NO2'][k]
                        pm10sum=pm10sum+df2016POIAir['PM10'][k]
                        if df2016POIAir['SO2'][k] > so2maxtemp:
                            so2maxtemp=df2016POIAir['SO2'][k]  
                            so2maxtimetemp=df2016POIAir[time2016apoi][k] 
                        if df2016POIAir['SO2'][k] < so2mintemp:
                            so2mintemp=df2016POIAir['SO2'][k]
                            so2mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['CO'][k] > comaxtemp:
                            comaxtemp=df2016POIAir['CO'][k] 
                            comaxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['CO'][k] < comintemp:
                            comintemp=df2016POIAir['CO'][k]
                            comintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['O3'][k] > o3maxtemp:
                            o3maxtemp=df2016POIAir['O3'][k]
                            o3maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['O3'][k] < o3mintemp:
                            o3mintemp=df2016Air['O3'][k]
                            o3mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['NO2'][k] > no2maxtemp:
                            no2maxtemp=df2016POIAir['NO2'][k]
                            no2maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['NO2'][k] < no2mintemp:
                            no2mintemp=df2016POIAir['NO2'][k]
                            no2mintimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['PM10'][k] > pm10maxtemp:
                            pm10maxtemp=df2016POIAir['PM10'][k]
                            pm10maxtimetemp=df2016POIAir[time2016apoi][k]
                        if df2016POIAir['PM10'][k] < pm10mintemp:
                            pm10mintemp=df2016POIAir['PM10'][k]
                            pm10mintimetemp=df2016POIAir[time2016apoi][k]                        
                    
                SO2PMPOI.append(so2sum)
                COPMPOI.append(cosum)
                O3PMPOI.append(o3sum)
                NO2PMPOI.append(no2sum)
                PM10PMPOI.append(pm10sum)
                SO2MaxPMPOI.append(so2maxtemp)
                SO2MaxTimePMPOI.append(so2maxtimetemp)
                SO2MinPMPOI.append(so2mintemp)
                SO2MinTimePMPOI.append(so2mintimetemp)
                COMaxPMPOI.append(comaxtemp)
                COMaxTimePMPOI.append(comaxtimetemp)
                COMinPMPOI.append(comintemp)
                COMinTimePMPOI.append(comintimetemp)
                O3MaxPMPOI.append(o3maxtemp)
                O3MaxTimePMPOI.append(o3maxtimetemp)
                O3MinPMPOI.append(o3mintemp)
                O3MinTimePMPOI.append(o3mintimetemp)
                NO2MaxPMPOI.append(no2maxtemp)
                NO2MaxTimePMPOI.append(no2maxtimetemp)
                NO2MinPMPOI.append(no2mintemp)
                NO2MinTimePMPOI.append(no2mintimetemp)
                PM10MaxPMPOI.append(pm10maxtemp)
                PM10MaxTimePMPOI.append(pm10maxtimetemp)
                PM10MinPMPOI.append(pm10mintemp)
                PM10MinTimePMPOI.append(pm10mintimetemp)                  
                found=1
                break
    if found==0:
        SO2PMPOI.append(None)
        COPMPOI.append(None)
        O3PMPOI.append(None)
        NO2PMPOI.append(None)
        PM10PMPOI.append(None)
        SO2MaxPMPOI.append(None)
        SO2MaxTimePMPOI.append(None)
        SO2MinPMPOI.append(None)
        SO2MinTimePMPOI.append(None)
        COMaxPMPOI.append(None)
        COMaxTimePMPOI.append(None)
        COMinPMPOI.append(None)
        COMinTimePMPOI.append(None)
        O3MaxPMPOI.append(None)
        O3MaxTimePMPOI.append(None)
        O3MinPMPOI.append(None)
        O3MinTimePMPOI.append(None)
        NO2MaxPMPOI.append(None)
        NO2MaxTimePMPOI.append(None)
        NO2MinPMPOI.append(None)
        NO2MinTimePMPOI.append(None)
        PM10MaxPMPOI.append(None)
        PM10MaxTimePMPOI.append(None)
        PM10MinPMPOI.append(None)
        PM10MinTimePMPOI.append(None)
# Out:
#                   City지역 Observatory측정소명  Observatory Code측정소코드      DATE  TIME   SO2    CO    O3   NO2   PM10  Obervatory Address주소              Unnamed: 11
# 0     Inchon Bu-Pyung Gu    Bu-Pyung Stn             2015010101  20150101     1 0.008 0.400 0.017 0.017 31.000                   nan  Inchon Bu-Pyung Gu 부평3동
# 1     Inchon Bu-Pyung Gu    Bu-Pyung Stn             2015010102  20150101     2 0.009 0.500 0.016 0.015 33.000                   nan  Inchon Bu-Pyung Gu 부평3동
# 2     Inchon Bu-Pyung Gu    Bu-Pyung Stn             2015010103  20150101     3 0.010 0.500 0.017 0.011 42.000                   nan  Inchon Bu-Pyung Gu 부평3동
# 3     Inchon Bu-Pyung Gu    Bu-Pyung Stn             2015010104  20150101     4 0.007 0.400 0.017 0.010 50.000                   nan  Inchon Bu-Pyung Gu 부평3동
# ...                  ...             ...                    ...       ...   ...   ...   ...   ...   ...    ...                   ...                      ...
# ...

# %%
#AM Climate data
TemperatureCAM = []
RainfallMMAM = []
WindSpeedMSAM = []
WindDirectionAM = []
PrecipitationPercentAM = []
VaporPressureHPAAM = []
DewPointTemperatureCAM = []
AirPressureHPAAM = []
SeaLevelPressureHPAAM = []
GroundTemperatureCAM = []
tMaxAM = []
aMaxAM = []
pMaxAM = []
tMinAM = []
aMinAM = []
pMinAM = []
tModeAM = []
aModeAM = []
pModeAM = []
tMaxlesstMinAM = []
aMaxlessaMinAM = []
pMaxlesspMinAM = []

print(df2016Climate)

for i in range(0,dateRangeAM.size):
    found = 0
    tMaxTemp=-1000
    aMaxTemp=-1000
    pMaxTemp=-1000
    tMinTemp=1000
    aMinTemp=1000
    pMinTemp=1000
    tModeTemp=-100
    aModeTemp=-100
    pModeTemp=-100
    tTemp=[]
    aTemp=[]
    pTemp=[]
    if dateAM[i].year == 2014:
        for j in df2014Climate.index:
            if df2014Climate['Date'][j].day == dateAM[i].day and df2014Climate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2014Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2014Climate['Temperature(°C)'][k]  if df2014Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2014Climate['Air Pressure(hPa)'][k]  if df2014Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2014Climate['Precipitation(%)'][k]  if df2014Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2014Climate['Temperature(°C)'][k]  if df2014Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2014Climate['Air Pressure(hPa)'][k]  if df2014Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2014Climate['Precipitation(%)'][k]  if df2014Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2014Climate['Temperature(°C)'][k])
                    aTemp.append(df2014Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2014Climate['Precipitation(%)'][k])
                
                tMaxAM.append(tMaxTemp)
                aMaxAM.append(aMaxTemp)
                pMaxAM.append(pMaxTemp)
                tMinAM.append(tMinTemp)
                aMinAM.append(aMinTemp)
                pMinAM.append(pMinTemp)
                tModeAM.append(max(set(tTemp), key=tTemp.count))
                aModeAM.append(max(set(aTemp), key=aTemp.count))
                pModeAM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAM.append(pMaxTemp-pMinTemp)
                TemperatureCAM.append(df2014Climate['Temperature(°C)'][j])
                RainfallMMAM.append(df2014Climate['Rainfall(mm)'][j])
                WindSpeedMSAM.append(df2014Climate['wind Speed(m/s)'][j])
                WindDirectionAM.append(df2014Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentAM.append(df2014Climate['Precipitation(%)'][j])
                VaporPressureHPAAM.append(df2014Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAM.append(df2014Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAAM.append(df2014Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAM.append(df2014Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAM.append(df2014Climate['Ground Temperature(°C)'][j])
                found =1
                break
    if dateAM[i].year == 2015:
        for j in df2015Climate.index:
            if df2015Climate['Date'][j].day == dateAM[i].day and df2015Climate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2015Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2015Climate['Temperature(°C)'][k]  if df2015Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2015Climate['Air Pressure(hPa)'][k]  if df2015Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2015Climate['Precipitation(%)'][k]  if df2015Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2015Climate['Temperature(°C)'][k]  if df2015Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2015Climate['Air Pressure(hPa)'][k]  if df2015Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2015Climate['Precipitation(%)'][k]  if df2015Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2015Climate['Temperature(°C)'][k])
                    aTemp.append(df2015Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2015Climate['Precipitation(%)'][k])
                
                tMaxAM.append(tMaxTemp)
                aMaxAM.append(aMaxTemp)
                pMaxAM.append(pMaxTemp)
                tMinAM.append(tMinTemp)
                aMinAM.append(aMinTemp)
                pMinAM.append(pMinTemp)
                tModeAM.append(max(set(tTemp), key=tTemp.count))
                aModeAM.append(max(set(aTemp), key=aTemp.count))
                pModeAM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAM.append(pMaxTemp-pMinTemp)
                TemperatureCAM.append(df2015Climate['Temperature(°C)'][j])
                RainfallMMAM.append(df2015Climate['Rainfall(mm)'][j])
                WindSpeedMSAM.append(df2015Climate['wind Speed(m/s)'][j])
                WindDirectionAM.append(df2015Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentAM.append(df2015Climate['Precipitation(%)'][j])
                VaporPressureHPAAM.append(df2015Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAM.append(df2015Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAAM.append(df2015Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAM.append(df2015Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAM.append(df2015Climate['Ground Temperature(°C)'][j])
                found=1
                break
    if dateAM[i].year == 2016:
        for j in df2016Climate.index:
            if df2016Climate['Date'][j].day == dateAM[i].day and df2016Climate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2016Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2016Climate['Temperature(°C)'][k]  if df2016Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2016Climate['Air Pressure(hPa)'][k]  if df2016Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2016Climate['Precipitation(%)'][k]  if df2016Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2016Climate['Temperature(°C)'][k]  if df2016Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2016Climate['Air Pressure(hPa)'][k]  if df2016Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2016Climate['Precipitation(%)'][k]  if df2016Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2016Climate['Temperature(°C)'][k])
                    aTemp.append(df2016Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2016Climate['Precipitation(%)'][k])
                
                tMaxAM.append(tMaxTemp)
                aMaxAM.append(aMaxTemp)
                pMaxAM.append(pMaxTemp)
                tMinAM.append(tMinTemp)
                aMinAM.append(aMinTemp)
                pMinAM.append(pMinTemp)
                tModeAM.append(max(set(tTemp), key=tTemp.count))
                aModeAM.append(max(set(aTemp), key=aTemp.count))
                pModeAM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAM.append(pMaxTemp-pMinTemp)
                TemperatureCAM.append(df2016Climate['Temperature(°C)'][j])
                RainfallMMAM.append(df2016Climate['Rainfall(mm)'][j])
                WindSpeedMSAM.append(df2016Climate['wind Speed(m/s)'][j])
                WindDirectionAM.append(df2016Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentAM.append(df2016Climate['Precipitation(%)'][j])
                VaporPressureHPAAM.append(df2016Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAM.append(df2016Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAAM.append(df2016Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAM.append(df2016Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAM.append(df2016Climate['Ground Temperature(°C)'][j])
                found=1
                break
    if found==0:
        tMaxAM.append(None)
        aMaxAM.append(None)
        pMaxAM.append(None)
        tMinAM.append(None)
        aMinAM.append(None)
        pMinAM.append(None)
        tModeAM.append(None)
        aModeAM.append(None)
        pModeAM.append(None)
        tMaxlesstMinAM.append(None)
        aMaxlessaMinAM.append(None)
        pMaxlesspMinAM.append(None)
        TemperatureCAM.append(None)
        RainfallMMAM.append(None)
        WindSpeedMSAM.append(None)
        WindDirectionAM.append(None)
        PrecipitationPercentAM.append(None)
        VaporPressureHPAAM.append(None)
        DewPointTemperatureCAM.append(None)
        AirPressureHPAAM.append(None)
        SeaLevelPressureHPAAM.append(None)
        GroundTemperatureCAM.append(None)
# Out:
#       Location       Date  TIME  Temperature(°C)  Rainfall(mm)  wind Speed(m/s)  Wind Direction(16방위)  Precipitation(%)  Vapor Pressure(hPa)  Dew point Temperature(°C)  Air Pressure(hPa)  SeaLevelPressure(hPa)  일조(hr)  일사(MJ/m2)  Ground Temperature(°C)  5cm Above Ground Temp(°C)  10cm Above Ground Temp(°C)  20cm Above Ground Temp(°C)  30cm Above Ground Temp(°C)
# 0          119 2016-01-01     1           -3.100         1.485            0.600                   180           100.000                4.900                     -3.100           1028.900               1033.300     nan        nan                  -2.000                        nan                         nan                         nan                         nan
# ...

# %%
#AM Climate data POI
TemperatureCAMPOI = []
RainfallMMAMPOI = []
WindSpeedMSAMPOI = []
WindDirectionAMPOI = []
PrecipitationPercentAMPOI = []
VaporPressureHPAAMPOI = []
DewPointTemperatureCAMPOI = []
AirPressureHPAAMPOI = []
SeaLevelPressureHPAAMPOI = []
GroundTemperatureCAMPOI = []
tMaxAMPOI = []
aMaxAMPOI = []
pMaxAMPOI = []
tMinAMPOI = []
aMinAMPOI = []
pMinAMPOI = []
tModeAMPOI = []
aModeAMPOI = []
pModeAMPOI = []
tMaxlesstMinAMPOI = []
aMaxlessaMinAMPOI = []
pMaxlesspMinAMPOI = []

#print(df2014Climate)

for i in range(0,dateRangeAM.size):
    found = 0
    tMaxTemp=-1000
    aMaxTemp=-1000
    pMaxTemp=-1000
    tMinTemp=1000
    aMinTemp=1000
    pMinTemp=1000
    tModeTemp=-100
    aModeTemp=-100
    pModeTemp=-100
    tTemp=[]
    aTemp=[]
    pTemp=[]    
    if dateAM[i].year == 2014:
        for j in df2014POIClimate.index:
            if df2014POIClimate['Date'][j].day == dateAM[i].day and df2014POIClimate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2014POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2014POIClimate['Temperature(°C)'][k]  if df2014POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2014POIClimate['Air Pressure(hPa)'][k]  if df2014POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2014POIClimate['Precipitation(%)'][k]  if df2014POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2014POIClimate['Temperature(°C)'][k]  if df2014POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2014POIClimate['Air Pressure(hPa)'][k]  if df2014POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2014POIClimate['Precipitation(%)'][k]  if df2014POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2014POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2014POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2014POIClimate['Precipitation(%)'][k])
                
                tMaxAMPOI.append(tMaxTemp)
                aMaxAMPOI.append(aMaxTemp)
                pMaxAMPOI.append(pMaxTemp)
                tMinAMPOI.append(tMinTemp)
                aMinAMPOI.append(aMinTemp)
                pMinAMPOI.append(pMinTemp)
                tModeAMPOI.append(max(set(tTemp), key=tTemp.count))
                aModeAMPOI.append(max(set(aTemp), key=aTemp.count))
                pModeAMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCAMPOI.append(df2014POIClimate['Temperature(°C)'][j])
                RainfallMMAMPOI.append(df2014POIClimate['Rainfall(mm)'][j])
                WindSpeedMSAMPOI.append(df2014POIClimate['wind Speed(m/s)'][j])
                WindDirectionAMPOI.append(df2014POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentAMPOI.append(df2014POIClimate['Precipitation(%)'][j])
                VaporPressureHPAAMPOI.append(df2014POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAMPOI.append(df2014POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAAMPOI.append(df2014POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAMPOI.append(df2014POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAMPOI.append(df2014POIClimate['Ground Temperature(°C)'][j])
                found =1
                break
    if dateAM[i].year == 2015:
        for j in df2015POIClimate.index:
            if df2015POIClimate['Date'][j].day == dateAM[i].day and df2015POIClimate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2015POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2015POIClimate['Temperature(°C)'][k]  if df2015POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2015POIClimate['Air Pressure(hPa)'][k]  if df2015POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2015POIClimate['Precipitation(%)'][k]  if df2015POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2015POIClimate['Temperature(°C)'][k]  if df2015POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2015POIClimate['Air Pressure(hPa)'][k]  if df2015POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2015POIClimate['Precipitation(%)'][k]  if df2015POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2015POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2015POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2015POIClimate['Precipitation(%)'][k])
                
                tMaxAMPOI.append(tMaxTemp)
                aMaxAMPOI.append(aMaxTemp)
                pMaxAMPOI.append(pMaxTemp)
                tMinAMPOI.append(tMinTemp)
                aMinAMPOI.append(aMinTemp)
                pMinAMPOI.append(pMinTemp)
                tModeAMPOI.append(max(set(tTemp), key=tTemp.count))
                aModeAMPOI.append(max(set(aTemp), key=aTemp.count))
                pModeAMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCAMPOI.append(df2015POIClimate['Temperature(°C)'][j])
                RainfallMMAMPOI.append(df2015POIClimate['Rainfall(mm)'][j])
                WindSpeedMSAMPOI.append(df2015POIClimate['wind Speed(m/s)'][j])
                WindDirectionAMPOI.append(df2015POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentAMPOI.append(df2015POIClimate['Precipitation(%)'][j])
                VaporPressureHPAAMPOI.append(df2015POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAMPOI.append(df2015POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAAMPOI.append(df2015POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAMPOI.append(df2015POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAMPOI.append(df2015POIClimate['Ground Temperature(°C)'][j])
                found=1
                break
    if dateAM[i].year == 2016:
        for j in df2016POIClimate.index:
            if df2016POIClimate['Date'][j].day == dateAM[i].day and df2016POIClimate['Date'][j].month == dateAM[i].month and timeAM[i].hour == df2016POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2016POIClimate['Temperature(°C)'][k]  if df2016POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2016POIClimate['Air Pressure(hPa)'][k]  if df2016POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2016POIClimate['Precipitation(%)'][k]  if df2016POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2016POIClimate['Temperature(°C)'][k]  if df2016POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2016POIClimate['Air Pressure(hPa)'][k]  if df2016POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2016POIClimate['Precipitation(%)'][k]  if df2016POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2016POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2016POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2016POIClimate['Precipitation(%)'][k])
                
                tMaxAMPOI.append(tMaxTemp)
                aMaxAMPOI.append(aMaxTemp)
                pMaxAMPOI.append(pMaxTemp)
                tMinAMPOI.append(tMinTemp)
                aMinAMPOI.append(aMinTemp)
                pMinAMPOI.append(pMinTemp)
                tModeAMPOI.append(max(set(tTemp), key=tTemp.count))
                aModeAMPOI.append(max(set(aTemp), key=aTemp.count))
                pModeAMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinAMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinAMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinAMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCAMPOI.append(df2016POIClimate['Temperature(°C)'][j])
                RainfallMMAMPOI.append(df2016POIClimate['Rainfall(mm)'][j])
                WindSpeedMSAMPOI.append(df2016POIClimate['wind Speed(m/s)'][j])
                WindDirectionAMPOI.append(df2016POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentAMPOI.append(df2016POIClimate['Precipitation(%)'][j])
                VaporPressureHPAAMPOI.append(df2016POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCAMPOI.append(df2016POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAAMPOI.append(df2016POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAAMPOI.append(df2016POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCAMPOI.append(df2016POIClimate['Ground Temperature(°C)'][j])
                found=1
                break
    if found==0:
        tMaxAMPOI.append(None)
        aMaxAMPOI.append(None)
        pMaxAMPOI.append(None)
        tMinAMPOI.append(None)
        aMinAMPOI.append(None)
        pMinAMPOI.append(None)
        tModeAMPOI.append(None)
        aModeAMPOI.append(None)
        pModeAMPOI.append(None)
        tMaxlesstMinAMPOI.append(None)
        aMaxlessaMinAMPOI.append(None)
        pMaxlesspMinAMPOI.append(None)        
        TemperatureCAMPOI.append(None)
        RainfallMMAMPOI.append(None)
        WindSpeedMSAMPOI.append(None)
        WindDirectionAMPOI.append(None)
        PrecipitationPercentAMPOI.append(None)
        VaporPressureHPAAMPOI.append(None)
        DewPointTemperatureCAMPOI.append(None)
        AirPressureHPAAMPOI.append(None)
        SeaLevelPressureHPAAMPOI.append(None)
        GroundTemperatureCAMPOI.append(None)

# %%
#PM Climate data
TemperatureCPM = []
RainfallMMPM = []
WindSpeedMSPM = []
WindDirectionPM = []
PrecipitationPercentPM = []
VaporPressureHPAPM = []
DewPointTemperatureCPM = []
AirPressureHPAPM = []
SeaLevelPressureHPAPM = []
GroundTemperatureCPM = []
tMaxPM = []
aMaxPM = []
pMaxPM = []
tMinPM = []
aMinPM = []
pMinPM = []
tModePM = []
aModePM = []
pModePM = []
tMaxlesstMinPM = []
aMaxlessaMinPM = []
pMaxlesspMinPM = []

#print(df2014Climate)

for i in range(0,dateRangePM.size):
    found = 0
    tMaxTemp=-1000
    aMaxTemp=-1000
    pMaxTemp=-1000
    tMinTemp=1000
    aMinTemp=1000
    pMinTemp=1000
    tModeTemp=-100
    aModeTemp=-100
    pModeTemp=-100
    tTemp=[]
    aTemp=[]
    pTemp=[] 
    if datePM[i].year == 2014:
        for j in df2014Climate.index:
            if df2014Climate['Date'][j].day == datePM[i].day and df2014Climate['Date'][j].month == datePM[i].month and timePM[i].hour == df2014Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2014Climate['Temperature(°C)'][k]  if df2014Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2014Climate['Air Pressure(hPa)'][k]  if df2014Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2014Climate['Precipitation(%)'][k]  if df2014Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2014Climate['Temperature(°C)'][k]  if df2014Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2014Climate['Air Pressure(hPa)'][k]  if df2014Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2014Climate['Precipitation(%)'][k]  if df2014Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2014Climate['Temperature(°C)'][k])
                    aTemp.append(df2014Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2014Climate['Precipitation(%)'][k])
                
                tMaxPM.append(tMaxTemp)
                aMaxPM.append(aMaxTemp)
                pMaxPM.append(pMaxTemp)
                tMinPM.append(tMinTemp)
                aMinPM.append(aMinTemp)
                pMinPM.append(pMinTemp)
                tModePM.append(max(set(tTemp), key=tTemp.count))
                aModePM.append(max(set(aTemp), key=aTemp.count))
                pModePM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPM.append(pMaxTemp-pMinTemp)
                TemperatureCPM.append(df2014Climate['Temperature(°C)'][j])
                RainfallMMPM.append(df2014Climate['Rainfall(mm)'][j])
                WindSpeedMSPM.append(df2014Climate['wind Speed(m/s)'][j])
                WindDirectionPM.append(df2014Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentPM.append(df2014Climate['Precipitation(%)'][j])
                VaporPressureHPAPM.append(df2014Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPM.append(df2014Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAPM.append(df2014Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPM.append(df2014Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPM.append(df2014Climate['Ground Temperature(°C)'][j])
                found =1
                break
    if datePM[i].year == 2015:
        for j in df2015Climate.index:
            if df2015Climate['Date'][j].day == datePM[i].day and df2015Climate['Date'][j].month == datePM[i].month and timePM[i].hour == df2015Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2015Climate['Temperature(°C)'][k]  if df2015Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2015Climate['Air Pressure(hPa)'][k]  if df2015Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2015Climate['Precipitation(%)'][k]  if df2015Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2015Climate['Temperature(°C)'][k]  if df2015Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2015Climate['Air Pressure(hPa)'][k]  if df2015Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2015Climate['Precipitation(%)'][k]  if df2015Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2015Climate['Temperature(°C)'][k])
                    aTemp.append(df2015Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2015Climate['Precipitation(%)'][k])
                
                tMaxPM.append(tMaxTemp)
                aMaxPM.append(aMaxTemp)
                pMaxPM.append(pMaxTemp)
                tMinPM.append(tMinTemp)
                aMinPM.append(aMinTemp)
                pMinPM.append(pMinTemp)
                tModePM.append(max(set(tTemp), key=tTemp.count))
                aModePM.append(max(set(aTemp), key=aTemp.count))
                pModePM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPM.append(pMaxTemp-pMinTemp)
                TemperatureCPM.append(df2015Climate['Temperature(°C)'][j])
                RainfallMMPM.append(df2015Climate['Rainfall(mm)'][j])
                WindSpeedMSPM.append(df2015Climate['wind Speed(m/s)'][j])
                WindDirectionPM.append(df2015Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentPM.append(df2015Climate['Precipitation(%)'][j])
                VaporPressureHPAPM.append(df2015Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPM.append(df2015Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAPM.append(df2015Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPM.append(df2015Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPM.append(df2015Climate['Ground Temperature(°C)'][j])
                found=1
                break
    if datePM[i].year == 2016:
        for j in df2016Climate.index:
            if df2016Climate['Date'][j].day == datePM[i].day and df2016Climate['Date'][j].month == datePM[i].month and timePM[i].hour == df2016Climate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2016Climate['Temperature(°C)'][k]  if df2016Climate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2016Climate['Air Pressure(hPa)'][k]  if df2016Climate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2016Climate['Precipitation(%)'][k]  if df2016Climate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2016Climate['Temperature(°C)'][k]  if df2016Climate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2016Climate['Air Pressure(hPa)'][k]  if df2016Climate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2016Climate['Precipitation(%)'][k]  if df2016Climate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2016Climate['Temperature(°C)'][k])
                    aTemp.append(df2016Climate['Air Pressure(hPa)'][k])
                    pTemp.append(df2016Climate['Precipitation(%)'][k])
                
                tMaxPM.append(tMaxTemp)
                aMaxPM.append(aMaxTemp)
                pMaxPM.append(pMaxTemp)
                tMinPM.append(tMinTemp)
                aMinPM.append(aMinTemp)
                pMinPM.append(pMinTemp)
                tModePM.append(max(set(tTemp), key=tTemp.count))
                aModePM.append(max(set(aTemp), key=aTemp.count))
                pModePM.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPM.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPM.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPM.append(pMaxTemp-pMinTemp)
                TemperatureCPM.append(df2016Climate['Temperature(°C)'][j])
                RainfallMMPM.append(df2016Climate['Rainfall(mm)'][j])
                WindSpeedMSPM.append(df2016Climate['wind Speed(m/s)'][j])
                WindDirectionPM.append(df2016Climate['Wind Direction(16방위)'][j])
                PrecipitationPercentPM.append(df2016Climate['Precipitation(%)'][j])
                VaporPressureHPAPM.append(df2016Climate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPM.append(df2016Climate['Dew point Temperature(°C)'][j])
                AirPressureHPAPM.append(df2016Climate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPM.append(df2016Climate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPM.append(df2016Climate['Ground Temperature(°C)'][j])
                found=1
                break
    if found==0:
        print(datePM[i])
        tMaxPM.append(None)
        aMaxPM.append(None)
        pMaxPM.append(None)
        tMinPM.append(None)
        aMinPM.append(None)
        pMinPM.append(None)
        tModePM.append(None)
        aModePM.append(None)
        pModePM.append(None)
        tMaxlesstMinPM.append(None)
        aMaxlessaMinPM.append(None)
        pMaxlesspMinPM.append(None)        
        TemperatureCPM.append(None)
        RainfallMMPM.append(None)
        WindSpeedMSPM.append(None)
        WindDirectionPM.append(None)
        PrecipitationPercentPM.append(None)
        VaporPressureHPAPM.append(None)
        DewPointTemperatureCPM.append(None)
        AirPressureHPAPM.append(None)
        SeaLevelPressureHPAPM.append(None)
        GroundTemperatureCPM.append(None)

# %%
#PM Climate data POI
TemperatureCPMPOI = []
RainfallMMPMPOI = []
WindSpeedMSPMPOI = []
WindDirectionPMPOI = []
PrecipitationPercentPMPOI = []
VaporPressureHPAPMPOI = []
DewPointTemperatureCPMPOI = []
AirPressureHPAPMPOI = []
SeaLevelPressureHPAPMPOI = []
GroundTemperatureCPMPOI = []
tMaxPMPOI = []
aMaxPMPOI = []
pMaxPMPOI = []
tMinPMPOI = []
aMinPMPOI = []
pMinPMPOI = []
tModePMPOI = []
aModePMPOI = []
pModePMPOI = []
tMaxlesstMinPMPOI = []
aMaxlessaMinPMPOI = []
pMaxlesspMinPMPOI = []

#print(df2014Climate)

for i in range(0,dateRangePM.size):
    found = 0
    tMaxTemp=-1000
    aMaxTemp=-1000
    pMaxTemp=-1000
    tMinTemp=1000
    aMinTemp=1000
    pMinTemp=1000
    tModeTemp=-100
    aModeTemp=-100
    pModeTemp=-100
    tTemp=[]
    aTemp=[]
    pTemp=[]     
    if datePM[i].year == 2014:
        for j in df2014POIClimate.index:
            if df2014POIClimate['Date'][j].day == datePM[i].day and df2014POIClimate['Date'][j].month == datePM[i].month and timePM[i].hour == df2014POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2014POIClimate['Temperature(°C)'][k]  if df2014POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2014POIClimate['Air Pressure(hPa)'][k]  if df2014POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2014POIClimate['Precipitation(%)'][k]  if df2014POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2014POIClimate['Temperature(°C)'][k]  if df2014POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2014POIClimate['Air Pressure(hPa)'][k]  if df2014POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2014POIClimate['Precipitation(%)'][k]  if df2014POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2014POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2014POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2014POIClimate['Precipitation(%)'][k])
                
                tMaxPMPOI.append(tMaxTemp)
                aMaxPMPOI.append(aMaxTemp)
                pMaxPMPOI.append(pMaxTemp)
                tMinPMPOI.append(tMinTemp)
                aMinPMPOI.append(aMinTemp)
                pMinPMPOI.append(pMinTemp)
                tModePMPOI.append(max(set(tTemp), key=tTemp.count))
                aModePMPOI.append(max(set(aTemp), key=aTemp.count))
                pModePMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCPMPOI.append(df2014POIClimate['Temperature(°C)'][j])
                RainfallMMPMPOI.append(df2014POIClimate['Rainfall(mm)'][j])
                WindSpeedMSPMPOI.append(df2014POIClimate['wind Speed(m/s)'][j])
                WindDirectionPMPOI.append(df2014POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentPMPOI.append(df2014POIClimate['Precipitation(%)'][j])
                VaporPressureHPAPMPOI.append(df2014POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPMPOI.append(df2014POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAPMPOI.append(df2014POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPMPOI.append(df2014POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPMPOI.append(df2014POIClimate['Ground Temperature(°C)'][j])
                found =1
                break
    if datePM[i].year == 2015:
        for j in df2015POIClimate.index:
            if df2015POIClimate['Date'][j].day == datePM[i].day and df2015POIClimate['Date'][j].month == datePM[i].month and timePM[i].hour == df2015POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2015POIClimate['Temperature(°C)'][k]  if df2015POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2015POIClimate['Air Pressure(hPa)'][k]  if df2015POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2015POIClimate['Precipitation(%)'][k]  if df2015POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2015POIClimate['Temperature(°C)'][k]  if df2015POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2015POIClimate['Air Pressure(hPa)'][k]  if df2015POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2015POIClimate['Precipitation(%)'][k]  if df2015POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2015POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2015POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2015POIClimate['Precipitation(%)'][k])
                
                tMaxPMPOI.append(tMaxTemp)
                aMaxPMPOI.append(aMaxTemp)
                pMaxPMPOI.append(pMaxTemp)
                tMinPMPOI.append(tMinTemp)
                aMinPMPOI.append(aMinTemp)
                pMinPMPOI.append(pMinTemp)
                tModePMPOI.append(max(set(tTemp), key=tTemp.count))
                aModePMPOI.append(max(set(aTemp), key=aTemp.count))
                pModePMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCPMPOI.append(df2015POIClimate['Temperature(°C)'][j])
                RainfallMMPMPOI.append(df2015POIClimate['Rainfall(mm)'][j])
                WindSpeedMSPMPOI.append(df2015POIClimate['wind Speed(m/s)'][j])
                WindDirectionPMPOI.append(df2015POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentPMPOI.append(df2015POIClimate['Precipitation(%)'][j])
                VaporPressureHPAPMPOI.append(df2015POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPMPOI.append(df2015POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAPMPOI.append(df2015POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPMPOI.append(df2015POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPMPOI.append(df2015POIClimate['Ground Temperature(°C)'][j])
                found=1
                break
    if datePM[i].year == 2016:
        for j in df2016POIClimate.index:
            if df2016POIClimate['Date'][j].day == datePM[i].day and df2016POIClimate['Date'][j].month == datePM[i].month and timePM[i].hour == df2016POIClimate['TIME'][j]:
                st = j-24 if j-24>=0 else 0
                for k in range(st, j):
                    tMaxTemp = df2016POIClimate['Temperature(°C)'][k]  if df2016POIClimate['Temperature(°C)'][k] > tMaxTemp else tMaxTemp
                    aMaxTemp = df2016POIClimate['Air Pressure(hPa)'][k]  if df2016POIClimate['Air Pressure(hPa)'][k] > aMaxTemp else aMaxTemp
                    pMaxTemp = df2016POIClimate['Precipitation(%)'][k]  if df2016POIClimate['Precipitation(%)'][k] > pMaxTemp else pMaxTemp
                    tMinTemp = df2016POIClimate['Temperature(°C)'][k]  if df2016POIClimate['Temperature(°C)'][k] < tMinTemp else tMinTemp
                    aMinTemp = df2016POIClimate['Air Pressure(hPa)'][k]  if df2016POIClimate['Air Pressure(hPa)'][k] < aMinTemp else aMinTemp
                    pMinTemp = df2016POIClimate['Precipitation(%)'][k]  if df2016POIClimate['Precipitation(%)'][k] < pMinTemp else pMinTemp
                    tTemp.append(df2016POIClimate['Temperature(°C)'][k])
                    aTemp.append(df2016POIClimate['Air Pressure(hPa)'][k])
                    pTemp.append(df2016POIClimate['Precipitation(%)'][k])
                
                tMaxPMPOI.append(tMaxTemp)
                aMaxPMPOI.append(aMaxTemp)
                pMaxPMPOI.append(pMaxTemp)
                tMinPMPOI.append(tMinTemp)
                aMinPMPOI.append(aMinTemp)
                pMinPMPOI.append(pMinTemp)
                tModePMPOI.append(max(set(tTemp), key=tTemp.count))
                aModePMPOI.append(max(set(aTemp), key=aTemp.count))
                pModePMPOI.append(max(set(pTemp), key=pTemp.count))
                tMaxlesstMinPMPOI.append(tMaxTemp-tMinTemp)
                aMaxlessaMinPMPOI.append(aMaxTemp-aMinTemp)
                pMaxlesspMinPMPOI.append(pMaxTemp-pMinTemp)
                TemperatureCPMPOI.append(df2016POIClimate['Temperature(°C)'][j])
                RainfallMMPMPOI.append(df2016POIClimate['Rainfall(mm)'][j])
                WindSpeedMSPMPOI.append(df2016POIClimate['wind Speed(m/s)'][j])
                WindDirectionPMPOI.append(df2016POIClimate['Wind Direction(16방위)'][j])
                PrecipitationPercentPMPOI.append(df2016POIClimate['Precipitation(%)'][j])
                VaporPressureHPAPMPOI.append(df2016POIClimate['Vapor Pressure(hPa)'][j])
                DewPointTemperatureCPMPOI.append(df2016POIClimate['Dew point Temperature(°C)'][j])
                AirPressureHPAPMPOI.append(df2016POIClimate['Air Pressure(hPa)'][j])
                SeaLevelPressureHPAPMPOI.append(df2016POIClimate['SeaLevelPressure(hPa)'][j])
                GroundTemperatureCPMPOI.append(df2016POIClimate['Ground Temperature(°C)'][j])
                found=1
                break
    if found==0:
        tMaxPMPOI.append(None)
        aMaxPMPOI.append(None)
        pMaxPMPOI.append(None)
        tMinPMPOI.append(None)
        aMinPMPOI.append(None)
        pMinPMPOI.append(None)
        tModePMPOI.append(None)
        aModePMPOI.append(None)
        pModePMPOI.append(None)
        tMaxlesstMinPMPOI.append(None)
        aMaxlessaMinPMPOI.append(None)
        pMaxlesspMinPMPOI.append(None) 
        TemperatureCPMPOI.append(None)
        RainfallMMPMPOI.append(None)
        WindSpeedMSPMPOI.append(None)
        WindDirectionPMPOI.append(None)
        PrecipitationPercentPMPOI.append(None)
        VaporPressureHPAPMPOI.append(None)
        DewPointTemperatureCPMPOI.append(None)
        AirPressureHPAPMPOI.append(None)
        SeaLevelPressureHPAPMPOI.append(None)
        GroundTemperatureCPMPOI.append(None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-565c0df8faff> in <module>()
#      40     pTemp=[]
#      41     if datePM[i].year == 2014:
# ---> 42         for j in df2014POIClimate.index:
#      43             if df2014POIClimate['Date'][j].day == datePM[i].day and df2014POIClimate['Date'][j].month == datePM[i].month and timePM[i].hour == df2014POIClimate['TIME'][j]:
#      44                 st = j-24 if j-24>=0 else 0
#
# NameError: name 'df2014POIClimate' is not defined

# %%
''' print(len(timeAM))
print(len(dateAM))
print(len(pef1AM))
print(len(pef2AM))
print(len(pef3AM))
print(len(pefMaxAM))
print(len(indexAMPEF))
print(len(timePM))
print(len(datePM))
print(len(pef1PM))
print(len(pef2PM))
print(len(pef3PM))
print(len(pefMaxPM))
print(len(indexPMPEF))
print(len(SO2AM))
print(len(COAM))
print(len(O3AM))
print(len(NO2AM))
print(len(PM10AM))
print(len(SO2AMPOI))
print(len(COAMPOI))
print(len(O3AMPOI))
print(len(NO2AMPOI))
print(len(PM10AMPOI))
print(len(SO2PM))
print(len(COPM))
print(len(O3PM))
print(len(NO2PM))
print(len(PM10PM))
print(len(SO2PMPOI))
print(len(COPMPOI))
print(len(O3PMPOI))
print(len(NO2PMPOI))
print(len(PM10PMPOI))
print(len(TemperatureCAM))
print(len(RainfallMMAM))
print(len(WindSpeedMSAM))
print(len(WindDirectionAM))
print(len(PrecipitationPercentAM))
print(len(VaporPressureHPAAM))
print(len(DewPointTemperatureCAM))
print(len(AirPressureHPAAM))
print(len(SeaLevelPressureHPAAM))
print(len(GroundTemperatureCAM))
print(len(TemperatureCAMPOI))
print(len(RainfallMMAMPOI))
print(len(WindSpeedMSAMPOI))
print(len(WindDirectionAMPOI))
print(len(PrecipitationPercentAMPOI))
print(len(VaporPressureHPAAMPOI))
print(len(DewPointTemperatureCAMPOI))
print(len(AirPressureHPAAMPOI))
print(len(SeaLevelPressureHPAAMPOI))
print(len(GroundTemperatureCAMPOI))
print(len(TemperatureCPM))
print(len(RainfallMMPM))
print(len(WindSpeedMSPM))
print(len(WindDirectionPM))
print(len(PrecipitationPercentPM))
print(len(VaporPressureHPAPM))
print(len(DewPointTemperatureCPM))
print(len(AirPressureHPAPM))
print(len(SeaLevelPressureHPAPM))
print(len(GroundTemperatureCPM))
print(len(TemperatureCPMPOI))
print(len(RainfallMMPMPOI))
print(len(WindSpeedMSPMPOI))
print(len(WindDirectionPMPOI))
print(len(PrecipitationPercentPMPOI))
print(len(VaporPressureHPAPMPOI))
print(len(DewPointTemperatureCPMPOI))
print(len(AirPressureHPAPMPOI))
print(len(SeaLevelPressureHPAPMPOI))
print(len(GroundTemperatureCPMPOI)) '''
'''tMaxPMPOI
aMaxPMPOI
pMaxPMPOI
tMinPMPOI
aMinPMPOI
pMinPMPOI
tModePMPOI
aModePMPOI
pModePMPOI
tMaxlesstMinPMPOI
aMaxlessaMinPMPOI
pMaxlesspMinPMPOI
SO2MaxAM = []
SO2MaxTimeAM = []
SO2MinAM = []
SO2MinTimeAM = []
COMaxAM = []
COMaxTimeAM = []
COMinAM = []
COMinTimeAM = []
O3MaxAM = []
O3MaxTimeAM = []
O3MinAM = []
O3MinTimeAM = []
NO2MaxAM = []
NO2MaxTimeAM = []
NO2MinAM = []
NO2MinTimeAM = []
PM10MaxAM = []
PM10MaxTimeAM = []
PM10MinAM = []
PM10MinTimeAM = []'''

'''
#WITH POI
#len(timeAM)
url = "http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q="
for i in range(0,len(timeAM)):
    insertquery = (
                    "INSERT INTO leeh (cname, ampm, timeofday, dateofmeasure, pef1, pef2, pef3, pefmax, indexpef, so2, co, o3, no2, pm10, so2poi, copoi, o3poi, no2poi, pm10poi, "
                    "temperaturec, rainfallmm, windspeedms, winddirection, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, "
                    "temperaturecpoi, rainfallmmpoi, windspeedmspoi, winddirectionpoi, precipitationpercentpoi, vaporpressurehpapoi, dewpointtemperaturecpoi, airpressurehpapoi, sealevelpressurehpapoi, groundtemperaturecpoi, "
                    "tmax, amax, pmax, tmin, amin, pmin, tmode, amode, pmode, tmaxlesstmin, amaxlessamin, pmaxlesspmin, tmaxpoi, amaxpoi, pmaxpoi, tminpoi, aminpoi, pminpoi, tmodepoi, amodepoi, pmodepoi, tmaxlesstminpoi, amaxlessaminpoi, pmaxlesspminpoi, "
                    "so2max, so2maxtime, so2min, so2mintime,comax, comaxtime, comin, comintime,o3max, o3maxtime, o3min, o3mintime,no2max, no2maxtime, no2min, no2mintime,pm10max, pm10maxtime, pm10min, pm10mintime, "
                    "so2maxpoi, so2maxtimepoi, so2minpoi, so2mintimepoi,comaxpoi, comaxtimepoi, cominpoi, comintimepoi,o3maxpoi, o3maxtimepoi, o3minpoi, o3mintimepoi,no2maxpoi, no2maxtimepoi, no2minpoi, no2mintimepoi,pm10maxpoi, pm10maxtimepoi, pm10minpoi, pm10mintimepoi) VALUES "
                    "('leeh','am','"+str(timeAM[i]).replace(":","%3A")+"','"+ str(dateAM[i].date())+"'%3A%3ADATE,"+str(pef1AM[i])+","+ str(pef2AM[i])+","+str(pef3AM[i])+","+ str(pefMaxAM[i])+",'"+ str(indexAMPEF[i])+"',"+str(SO2AM[i])+
                    ","+str(COAM[i])+","+str(O3AM[i])+","+str(NO2AM[i])+","+str(PM10AM[i])+","+str(SO2AMPOI[i])+","+str(COAMPOI[i])+","+str(O3AMPOI[i])+","+str(NO2AMPOI[i])+","+str(PM10AMPOI[i])+","+
                    str(TemperatureCAM[i])+","+str(RainfallMMAM[i])+","+str(WindSpeedMSAM[i])+","+str(WindDirectionAM[i])+","+str(PrecipitationPercentAM[i])+","+str(VaporPressureHPAAM[i])+","+str(DewPointTemperatureCAM[i])+","+
                    str(AirPressureHPAAM[i])+","+str(SeaLevelPressureHPAAM[i])+","+str(GroundTemperatureCAM[i])+","+
                    str(TemperatureCAMPOI[i])+","+str(RainfallMMAMPOI[i])+","+str(WindSpeedMSAMPOI[i])+","+str(WindDirectionAMPOI[i])+","+str(PrecipitationPercentAMPOI[i])+","+str(VaporPressureHPAAMPOI[i])+","+str(DewPointTemperatureCAMPOI[i])+","+
                    str(AirPressureHPAAMPOI[i])+","+str(SeaLevelPressureHPAAMPOI[i])+","+str(GroundTemperatureCAMPOI[i])+","+str(tMaxAM[i])+","+str(aMaxAM[i])+","+str(pMaxAM[i])+","+str(tMinAM[i])+","+str(aMinAM[i])+","+str(pMinAM[i])+","+
                    str(tModeAM[i])+","+str(aModeAM[i])+","+str(pModeAM[i])+","+str(tMaxlesstMinAM[i])+","+str(aMaxlessaMinAM[i])+","+str(pMaxlesspMinAM[i])+","+
                    str(tMaxAMPOI[i])+","+str(aMaxAMPOI[i])+","+str(pMaxAMPOI[i])+","+str(tMinAMPOI[i])+","+str(aMinAMPOI[i])+","+str(pMinAMPOI[i])+","+
                    str(tModeAMPOI[i])+","+str(aModeAMPOI[i])+","+str(pModeAMPOI[i])+","+str(tMaxlesstMinAMPOI[i])+","+str(aMaxlessaMinAMPOI[i])+","+str(pMaxlesspMinAMPOI[i])+","+
                    str(SO2MaxAM[i])+","+str(SO2MaxTimeAM[i])+","+str(SO2MinAM[i])+","+str(SO2MinTimeAM[i])+","+str(COMaxAM[i])+","+str(COMaxTimeAM[i])+","+str(COMinAM[i])+","+str(COMinTimeAM[i])+","+
                    str(O3MaxAM[i])+","+str(O3MaxTimeAM[i])+","+str(O3MinAM[i])+","+str(O3MinTimeAM[i])+","+str(NO2MaxAM[i])+","+str(NO2MaxTimeAM[i])+","+str(NO2MinAM[i])+","+str(NO2MinTimeAM[i])+","+
                    str(PM10MaxAM[i])+","+str(PM10MaxTimeAM[i])+","+str(PM10MinAM[i])+","+str(PM10MinTimeAM[i])+","+
                    str(SO2MaxAMPOI[i])+","+str(SO2MaxTimeAMPOI[i])+","+str(SO2MinAMPOI[i])+","+str(SO2MinTimeAMPOI[i])+","+str(COMaxAMPOI[i])+","+str(COMaxTimeAMPOI[i])+","+str(COMinAMPOI[i])+","+str(COMinTimeAMPOI[i])+","+
                    str(O3MaxAMPOI[i])+","+str(O3MaxTimeAMPOI[i])+","+str(O3MinAMPOI[i])+","+str(O3MinTimeAMPOI[i])+","+str(NO2MaxAMPOI[i])+","+str(NO2MaxTimeAMPOI[i])+","+str(NO2MinAMPOI[i])+","+str(NO2MinTimeAMPOI[i])+","+
                    str(PM10MaxAMPOI[i])+","+str(PM10MaxTimeAMPOI[i])+","+str(PM10MinAMPOI[i])+","+str(PM10MinTimeAMPOI[i])+")")
    insertquery = insertquery.replace("nan","NULL")
    insertquery = insertquery.replace("None","NULL")
    insertquery = insertquery.replace("none","NULL")
    insertquery = insertquery.replace(".","%2E")
    fullurl = str(url)+str(insertquery)
    requests.get(fullurl)
    #print(fullurl)
    
for i in range(0,len(timePM)):
    insertquery = (
                    "INSERT INTO leeh (cname, ampm, timeofday, dateofmeasure, pef1, pef2, pef3, pefmax, indexpef, so2, co, o3, no2, pm10, so2poi, copoi, o3poi, no2poi, pm10poi, "
                    "temperaturec, rainfallmm, windspeedms, winddirection, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, "
                    "temperaturecpoi, rainfallmmpoi, windspeedmspoi, winddirectionpoi, precipitationpercentpoi, vaporpressurehpapoi, dewpointtemperaturecpoi, airpressurehpapoi, sealevelpressurehpapoi, groundtemperaturecpoi, "
                    "tmax, amax, pmax, tmin, amin, pmin, tmode, amode, pmode, tmaxlesstmin, amaxlessamin, pmaxlesspmin, tmaxpoi, amaxpoi, pmaxpoi, tminpoi, aminpoi, pminpoi, tmodepoi, amodepoi, pmodepoi, tmaxlesstminpoi, amaxlessaminpoi, pmaxlesspminpoi, "
                    "so2max, so2maxtime, so2min, so2mintime,comax, comaxtime, comin, comintime,o3max, o3maxtime, o3min, o3mintime,no2max, no2maxtime, no2min, no2mintime,pm10max, pm10maxtime, pm10min, pm10mintime, "
                    "so2maxpoi, so2maxtimepoi, so2minpoi, so2mintimepoi,comaxpoi, comaxtimepoi, cominpoi, comintimepoi,o3maxpoi, o3maxtimepoi, o3minpoi, o3mintimepoi,no2maxpoi, no2maxtimepoi, no2minpoi, no2mintimepoi,pm10maxpoi, pm10maxtimepoi, pm10minpoi, pm10mintimepoi) VALUES "
                    "('leeh','pm','"+str(timePM[i]).replace(":","%3A")+"','"+ str(datePM[i].date())+"'%3A%3ADATE,"+str(pef1PM[i])+","+ str(pef2PM[i])+","+str(pef3PM[i])+","+ str(pefMaxPM[i])+",'"+ str(indexPMPEF[i])+"',"+str(SO2PM[i])+
                    ","+str(COPM[i])+","+str(O3PM[i])+","+str(NO2PM[i])+","+str(PM10PM[i])+","+str(SO2PMPOI[i])+","+str(COPMPOI[i])+","+str(O3PMPOI[i])+","+str(NO2PMPOI[i])+","+str(PM10PMPOI[i])+","+
                    str(TemperatureCPM[i])+","+str(RainfallMMPM[i])+","+str(WindSpeedMSPM[i])+","+str(WindDirectionPM[i])+","+str(PrecipitationPercentPM[i])+","+str(VaporPressureHPAPM[i])+","+str(DewPointTemperatureCPM[i])+","+
                    str(AirPressureHPAPM[i])+","+str(SeaLevelPressureHPAPM[i])+","+str(GroundTemperatureCPM[i])+","+
                    str(TemperatureCPMPOI[i])+","+str(RainfallMMPMPOI[i])+","+str(WindSpeedMSPMPOI[i])+","+str(WindDirectionPMPOI[i])+","+str(PrecipitationPercentPMPOI[i])+","+str(VaporPressureHPAPMPOI[i])+","+str(DewPointTemperatureCPMPOI[i])+","+
                    str(AirPressureHPAPMPOI[i])+","+str(SeaLevelPressureHPAPMPOI[i])+","+str(GroundTemperatureCPMPOI[i])+","+str(tMaxPM[i])+","+str(aMaxPM[i])+","+str(pMaxPM[i])+","+str(tMinPM[i])+","+str(aMinPM[i])+","+str(pMinPM[i])+","+
                    str(tModePM[i])+","+str(aModePM[i])+","+str(pModePM[i])+","+str(tMaxlesstMinPM[i])+","+str(aMaxlessaMinPM[i])+","+str(pMaxlesspMinPM[i])+","+
                    str(tMaxPMPOI[i])+","+str(aMaxPMPOI[i])+","+str(pMaxPMPOI[i])+","+str(tMinPMPOI[i])+","+str(aMinPMPOI[i])+","+str(pMinPMPOI[i])+","+
                    str(tModePMPOI[i])+","+str(aModePMPOI[i])+","+str(pModePMPOI[i])+","+str(tMaxlesstMinPMPOI[i])+","+str(aMaxlessaMinPMPOI[i])+","+str(pMaxlesspMinPMPOI[i])+","+
                    str(SO2MaxPM[i])+","+str(SO2MaxTimePM[i])+","+str(SO2MinPM[i])+","+str(SO2MinTimePM[i])+","+str(COMaxPM[i])+","+str(COMaxTimePM[i])+","+str(COMinPM[i])+","+str(COMinTimePM[i])+","+
                    str(O3MaxPM[i])+","+str(O3MaxTimePM[i])+","+str(O3MinPM[i])+","+str(O3MinTimePM[i])+","+str(NO2MaxPM[i])+","+str(NO2MaxTimePM[i])+","+str(NO2MinPM[i])+","+str(NO2MinTimePM[i])+","+
                    str(PM10MaxPM[i])+","+str(PM10MaxTimePM[i])+","+str(PM10MinPM[i])+","+str(PM10MinTimePM[i])+","+
                    str(SO2MaxPMPOI[i])+","+str(SO2MaxTimePMPOI[i])+","+str(SO2MinPMPOI[i])+","+str(SO2MinTimePMPOI[i])+","+str(COMaxPMPOI[i])+","+str(COMaxTimePMPOI[i])+","+str(COMinPMPOI[i])+","+str(COMinTimePMPOI[i])+","+
                    str(O3MaxPMPOI[i])+","+str(O3MaxTimePMPOI[i])+","+str(O3MinPMPOI[i])+","+str(O3MinTimePMPOI[i])+","+str(NO2MaxPMPOI[i])+","+str(NO2MaxTimePMPOI[i])+","+str(NO2MinPMPOI[i])+","+str(NO2MinTimePMPOI[i])+","+
                    str(PM10MaxPMPOI[i])+","+str(PM10MaxTimePMPOI[i])+","+str(PM10MinPMPOI[i])+","+str(PM10MinTimePMPOI[i])+")")
    insertquery = insertquery.replace("nan","NULL")
    insertquery = insertquery.replace("None","NULL")
    insertquery = insertquery.replace("none","NULL")
    insertquery = insertquery.replace(".","%2E")
    fullurl = str(url)+str(insertquery)
    requests.get(fullurl)
    #print(fullurl)
'''


#WITHOUT POI
url = "http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q="
for i in range(0,len(timeAM)):
    insertquery = (
                    "INSERT INTO kuky (cname, ampm, timeofday, dateofmeasure, pef1, pef2, pef3, pefmax, indexpef, so2, co, o3, no2, pm10, "
                    "temperaturec, rainfallmm, windspeedms, winddirection, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, "
                    "tmax, amax, pmax, tmin, amin, pmin, tmode, amode, pmode, tmaxlesstmin, amaxlessamin, pmaxlesspmin, so2max, so2maxtime, so2min, so2mintime,comax, comaxtime, comin, comintime,o3max, o3maxtime, o3min, o3mintime,no2max, no2maxtime, no2min, no2mintime,pm10max, pm10maxtime, pm10min, pm10mintime) VALUES "
                    "('kuky','am','"+str(timeAM[i]).replace(":","%3A")+"','"+ str(dateAM[i].date())+"'%3A%3ADATE,"+str(pef1AM[i])+","+ str(pef2AM[i])+","+str(pef3AM[i])+","+ str(pefMaxAM[i])+",'"+ str(indexAMPEF[i])+"',"+str(SO2AM[i])+
                    ","+str(COAM[i])+","+str(O3AM[i])+","+str(NO2AM[i])+","+str(PM10AM[i])+","+
                    str(TemperatureCAM[i])+","+str(RainfallMMAM[i])+","+str(WindSpeedMSAM[i])+","+str(WindDirectionAM[i])+","+str(PrecipitationPercentAM[i])+","+str(VaporPressureHPAAM[i])+","+str(DewPointTemperatureCAM[i])+","+
                    str(AirPressureHPAAM[i])+","+str(SeaLevelPressureHPAAM[i])+","+str(GroundTemperatureCAM[i])+","+
                    str(tMaxAM[i])+","+str(aMaxAM[i])+","+str(pMaxAM[i])+","+str(tMinAM[i])+","+str(aMinAM[i])+","+str(pMinAM[i])+","+
                    str(tModeAM[i])+","+str(aModeAM[i])+","+str(pModeAM[i])+","+str(tMaxlesstMinAM[i])+","+str(aMaxlessaMinAM[i])+","+str(pMaxlesspMinAM[i])+","+
                    str(SO2MaxAM[i])+","+str(SO2MaxTimeAM[i])+","+str(SO2MinAM[i])+","+str(SO2MinTimeAM[i])+","+str(COMaxAM[i])+","+str(COMaxTimeAM[i])+","+str(COMinAM[i])+","+str(COMinTimeAM[i])+","+
                    str(O3MaxAM[i])+","+str(O3MaxTimeAM[i])+","+str(O3MinAM[i])+","+str(O3MinTimeAM[i])+","+str(NO2MaxAM[i])+","+str(NO2MaxTimeAM[i])+","+str(NO2MinAM[i])+","+str(NO2MinTimeAM[i])+","+
                    str(PM10MaxAM[i])+","+str(PM10MaxTimeAM[i])+","+str(PM10MinAM[i])+","+str(PM10MinTimeAM[i])+")")
    insertquery = insertquery.replace("nan","NULL")
    insertquery = insertquery.replace("None","NULL")
    insertquery = insertquery.replace("none","NULL")
    insertquery = insertquery.replace(".","%2E")
    fullurl = str(url)+str(insertquery)
    requests.get(fullurl)
    #print(fullurl)
    
for i in range(0,len(timePM)):
    insertquery = (
                    "INSERT INTO kuky (cname, ampm, timeofday, dateofmeasure, pef1, pef2, pef3, pefmax, indexpef, so2, co, o3, no2, pm10, "
                    "temperaturec, rainfallmm, windspeedms, winddirection, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, "
                    "tmax, amax, pmax, tmin, amin, pmin, tmode, amode, pmode, tmaxlesstmin, amaxlessamin, pmaxlesspmin, so2max, so2maxtime, so2min, so2mintime,comax, comaxtime, comin, comintime,o3max, o3maxtime, o3min, o3mintime,no2max, no2maxtime, no2min, no2mintime,pm10max, pm10maxtime, pm10min, pm10mintime) VALUES "
                    "('kuky','pm','"+str(timePM[i]).replace(":","%3A")+"','"+ str(datePM[i].date())+"'%3A%3ADATE,"+str(pef1PM[i])+","+ str(pef2PM[i])+","+str(pef3PM[i])+","+ str(pefMaxPM[i])+",'"+ str(indexPMPEF[i])+"',"+str(SO2PM[i])+
                    ","+str(COPM[i])+","+str(O3PM[i])+","+str(NO2PM[i])+","+str(PM10PM[i])+","+
                    str(TemperatureCPM[i])+","+str(RainfallMMPM[i])+","+str(WindSpeedMSPM[i])+","+str(WindDirectionPM[i])+","+str(PrecipitationPercentPM[i])+","+str(VaporPressureHPAPM[i])+","+str(DewPointTemperatureCPM[i])+","+
                    str(AirPressureHPAPM[i])+","+str(SeaLevelPressureHPAPM[i])+","+str(GroundTemperatureCPM[i])+","+
                    str(tMaxPM[i])+","+str(aMaxPM[i])+","+str(pMaxPM[i])+","+str(tMinPM[i])+","+str(aMinPM[i])+","+str(pMinPM[i])+","+
                    str(tModePM[i])+","+str(aModePM[i])+","+str(pModePM[i])+","+str(tMaxlesstMinPM[i])+","+str(aMaxlessaMinPM[i])+","+str(pMaxlesspMinPM[i])+","+
                    str(SO2MaxPM[i])+","+str(SO2MaxTimePM[i])+","+str(SO2MinPM[i])+","+str(SO2MinTimePM[i])+","+str(COMaxPM[i])+","+str(COMaxTimePM[i])+","+str(COMinPM[i])+","+str(COMinTimePM[i])+","+
                    str(O3MaxPM[i])+","+str(O3MaxTimePM[i])+","+str(O3MinPM[i])+","+str(O3MinTimePM[i])+","+str(NO2MaxPM[i])+","+str(NO2MaxTimePM[i])+","+str(NO2MinPM[i])+","+str(NO2MinTimePM[i])+","+
                    str(PM10MaxPM[i])+","+str(PM10MaxTimePM[i])+","+str(PM10MinPM[i])+","+str(PM10MinTimePM[i])+")")
    insertquery = insertquery.replace("nan","NULL")
    insertquery = insertquery.replace("None","NULL")
    insertquery = insertquery.replace("none","NULL")
    insertquery = insertquery.replace(".","%2E")
    fullurl = str(url)+str(insertquery)
    requests.get(fullurl)
    #print(fullurl)

# %%
# %run "../../PyUtils/common.ipynb"

hand="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20patient_data_table";
kimj="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kimj";
leeh="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20leeh";
sony="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20sony";
kuky="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kuky%20ORDER%20BY%20dateofmeasure";

fileName = kuky;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
dfOriginal
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px black solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
# ...

# %%
#print(datePM[datePM.month==12])
print(SO2PM)
# Out:
# [0.10585147045180451, 0.099000000000000005, 0.085000000000000048, 0.074000000000000024, 0.089000000000000051, 0.082000000000000017, 0.075000000000000025, 0.083851470451804536, 0.074000000000000024, 0.080000000000000016, 0.072000000000000022, 0.075851470451804515, 0.078000000000000028, 0.097000000000000017, 0.097000000000000031, 0.10700000000000004, 0.093000000000000013, 0.10400000000000002, 0.10600000000000004, 0.12600000000000006, 0.12900000000000006, 0.11000000000000003, 0.11400000000000005, 0.12300000000000005, 0.10300000000000004, 0.089000000000000024, 0.097000000000000031, 0.097000000000000045, 0.13685147045180454, 0.11000000000000003, 0.09600000000000003, 0.11400000000000006, 0.094000000000000056, 0.10000000000000002, 0.13800000000000001, 0.12300000000000004, 0.14655441135541353, 0.11400000000000005, 0.11400000000000003, 0.17500000000000002, 0.13000000000000006, 0.10000000000000005, 0.085000000000000048, 0.10400000000000005, 0.12100000000000004, 0.11100000000000007, 0.113000000
# ...
