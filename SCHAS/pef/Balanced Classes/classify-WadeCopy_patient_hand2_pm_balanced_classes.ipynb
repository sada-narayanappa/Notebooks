# %%
# %run "../../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

#Balances the classes in the dataframe at the desired index by duplicating entries for that index at random
#
#@param dataFrame - The dataFrame to add duplicates to
#@param index - The index that contains the class
def BalanceClassesWithDuplicates(dataFrame, index):
    newDF = dataFrame
    classes = dataFrame[index].unique()
    print("classes: [" + ''.join(str(e)+',' for e in classes)+']')
    numberOfClasses = len(dataFrame[index].unique())
    print("Number of Classes:" + str(numberOfClasses))
    
    sizeOfClasses=[]
    
    for aClass in classes:
        sizeOfClasses.append(len(dataFrame.values[dataFrame[index].values == aClass]))
    
    print("Size of Classes: [" + ''.join(str(e)+', ' for e in sizeOfClasses)+']')
    sizeOfLargestClass = max(sizeOfClasses)
    print("Size of Largest Class: " + str(sizeOfLargestClass))
    amountToAddToEachClass = []
    
    for classSize in sizeOfClasses:
        amountToAddToEachClass.append(sizeOfLargestClass - classSize)
        
    print("Amount to Add to Each Class: [" + ''.join(str(e)+', ' for e in amountToAddToEachClass)+']')
    
    k=0
    for amount in amountToAddToEachClass:
        for i in range(0,amount):
           newDF = newDF.append(dataFrame[dataFrame[index].values == classes[k]].sample(n=1, replace=True))
        
        k += 1
    
    
    return newDF;
    
#Balances the classes in the dataframe at the desired index by removing entries at random from the extra 
#represented classes
#
#@param dataFrame - The dataFrame to add duplicates to
#@param index - The index that contains the class
#def BalanceClassesRemoveExtras(dataFrame, index):


patient = "hand2"
ampm = "am"
file = "http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20calculated_jlee%20WHERE%20ampm=%27"+ampm+"%27%20AND%20pname=%27"+patient+"%27%20ORDER%20BY%20date,%20time"

predictQuantile=True
lowerPercent = 0.20
upperPercent = 0.80

fileName = file;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
#displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
dfOriginal
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff
# 0    hand2  2015-01-02   am  06:24:00  279        Y     22.700    0.004   0.700   0.025    0.024   145.000    0.078  12.790   0.428    0.300   990.300    0.003   0.563   0.019    0.013    43.626        -6.800        1.200        340.000                58.000             2.100               -13.600        1020.500             1025.000              -4.800           -3.900         1022.200             63.000           -8.500         1019.600             35.000             4.600             2.600              28.000
# 1    hand2  2015-01-03   am  07:19:00  251        Y     24.917    0.009   0.900   0.026    0.035    54.000    0.125  17.045   0.299    0.584   886.283    0.005   0.684   0.012    0.023    35.570        -9.600        0.600        180.000                71.000             2.100               -13.800        1022.700             1027.200              -6.900           -0.800         1023.400             71.000           -9.600         1019.900             31.000             8.800             3.500              40.000
# 2    hand2  2015-01-04   am  07:46:00  260        Y     24.450    0.013   1.000   0.015    0.039    52.000    0.174  16.975   0.180    0.797   857.550    0.007   0.694   0.007    0.033    35.074         0.700        1.600         70.000                67.000             4.300                -4.700        1013.600             1017.900              -0.700            1.900         1023.400             71.000           -9.600         1013.200             38.000            11.500            10.200              33.000
# 3    hand2  2015-01-05   am  06:08:00  273        Y     22.367    0.009   1.300   0.021    0.065    75.000    0.137  22.300   0.106    1.078  1248.967    0.006   0.997   0.005    0.048    55.841        -2.800        0.000          0.000               100.000             5.000                -2.800        1016.200             1020.600              -2.800            7.600         1017.500            100.000           -2.800         1012.900             59.000            10.400             4.600              41.000
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...
# 653  hand2  2016-10-16   am  07:17:00  260        Y     25.283    0.004   1.100   0.045    0.059   105.000    0.086  19.070   0.332    1.090  1863.967    0.003   0.754   0.013    0.043    73.723        16.700        1.000        110.000                77.000            14.600                12.600        1017.500             1021.600              15.200           26.100         1023.500            100.000           11.200         1017.500             35.000            14.900             6.000              65.000
# 654  hand2  2016-10-17   am  06:11:00  292        Y     22.900    0.004   0.700   0.028    0.037    74.000    0.073  13.440   0.279    0.642  1261.567    0.003   0.587   0.012    0.028    55.090        15.000        0.800        340.000                97.000            16.500                14.500        1013.400             1017.500              15.300           19.400         1017.600            100.000           15.000         1012.600             60.000             4.400             5.000              40.000
# 655  hand2  2016-10-18   am  06:00:00  286        Y     22.817    0.004   0.900   0.055    0.039    72.000    0.066  12.690   0.453    0.625  1205.467    0.003   0.556   0.020    0.027    52.833        11.900        0.600        250.000               100.000            13.800                11.800        1016.100             1020.200              12.900           22.400         1016.200            100.000           11.900         1013.000             55.000            10.500             3.200              45.000
# 656  hand2  2016-10-19   am  06:28:00  311        G     24.467    0.007   1.000   0.032    0.064   104.000    0.118  18.420   0.199    1.045  1752.667    0.005   0.753   0.008    0.043    71.635        11.700        0.000          0.000               100.000            13.700                11.600        1014.900             1019.000              11.900           20.800         1018.100            100.000           11.000         1014.900             61.000             9.800             3.200              39.000
#
# [657 rows x 40 columns]

# %%
#Testing Funcions
classIndex='Class'
d = {'Xvariables': [11, 2, 23, 24, 5, 16, 17, 18], classIndex: [1, 0, 2, 2, 0, 1, 1, 1]}
testDF = pd.DataFrame(data=d)
print(testDF)
testDF = BalanceClassesWithDuplicates(testDF, classIndex)
with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    print(testDF)
# Out:
#    Class  Xvariables
# 0      1          11
# 1      0           2
# 2      2          23
# 3      2          24
# 4      0           5
# 5      1          16
# 6      1          17
# 7      1          18
# classes: [1,0,2,]
# Number of Classes:3
# Size of Classes: [4, 2, 2, ]
# Size of Largest Class: 4
# Amount to Add to Each Class: [0, 2, 2, ]
#    Class  Xvariables
# 0      1          11
# 1      0           2
# 2      2          23
# 3      2          24
# 4      0           5
# 5      1          16
# 6      1          17
# 7      1          18
# 4      0           5
# 4      0           5
# 3      2          24
# 2      2          23

# %%
#Break into groups by percentage

dfOriginal.sort_values(by='pef', ascending=True, inplace=True)
dfOriginal.reset_index(drop=True, inplace=True)
numberOfElements = len(dfOriginal)
upperBoundary = upperPercent*numberOfElements
lowerBoundary = lowerPercent*numberOfElements
dfOriginal['percent_group']=-1

for i in dfOriginal.index:

    if i < lowerBoundary:
        dfOriginal['percent_group'][i] = 0

    elif i > upperBoundary : 
        dfOriginal['percent_group'][i] = 2

    else:
        dfOriginal['percent_group'][i] = 1

print(dfOriginal)
# Out:
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff  percent_group
# 0    hand2  2016-05-01   am  09:00:00  192        Y     24.833    0.008   0.700   0.106    0.033   124.000    0.141  14.083   1.670    0.412  1764.833    0.006   0.567   0.067    0.017    71.067        15.100        0.600        180.000                54.000             9.200                 5.800        1009.700             1013.800              13.700           23.000         1009.700             74.000           11.400         1006.600             36.000            11.600             3.100              38.000              0
# 1    hand2  2016-05-05   am  06:53:00  193        Y     24.800    0.005   0.800   0.051    0.035    72.000    0.090  12.205   0.826    0.444  1340.417    0.004   0.492   0.033    0.018    54.049         8.700        0.100          0.000                96.000            10.700                 8.000        1011.300             1015.500               8.800           21.200         1011.300             97.000            8.500          996.700             26.000            12.700            14.600              71.000              0
# 2    hand2  2016-05-08   am  07:27:00  199        Y     25.450    0.007   0.700   0.048    0.041   173.000    0.108  13.515   0.560    0.662  1978.350    0.004   0.531   0.022    0.026    77.735        14.100        0.700         50.000                82.000            13.100                11.000        1014.300             1018.400              12.800           22.000         1014.300            100.000            9.500         1009.100             37.000            12.500             5.200              63.000              0
# 3    hand2  2016-08-10   am  06:12:00  200        Y     24.000    0.005   0.600   0.081    0.039    76.000    0.089  11.420   1.191    0.533  1165.800    0.004   0.476   0.050    0.022    48.575        25.700        0.200          0.000                98.000            32.200                25.300        1006.500             1010.400              26.100           34.000         1006.500             99.000           25.500         1003.200             59.000             8.500             3.300              40.000              0
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...            ...
# 653  hand2  2015-01-29   am  06:01:00  339        G     24.000    0.007   1.400   0.011    0.056    67.000    0.125  21.702   0.139    0.973  1235.183    0.005   0.904   0.006    0.041    51.466        -2.400        1.400         90.000                62.000             3.200                -8.700        1024.500             1028.900              -1.700            1.600         1026.500             79.000           -7.400         1023.900             38.000             9.000             2.600              41.000              2
# 654  hand2  2016-08-24   am  06:08:00  341        G     23.850    0.010   0.500   0.071    0.038    57.000    0.102  10.468   0.709    0.560   938.117    0.004   0.439   0.030    0.023    39.334        26.400        1.500        160.000                79.000            27.100                22.400        1003.400             1007.300              26.300           33.100         1003.500             94.000           26.000         1000.900             58.000             7.100             2.600              36.000              2
# 655  hand2  2015-01-27   am  10:00:00  341        G     26.867    0.006   1.100   0.030    0.046    79.000    0.116  23.767   0.461    0.752  1431.000    0.004   0.885   0.017    0.028    53.263        -3.300        3.900        320.000                64.000             3.100                -9.100        1020.900             1025.300              -0.700            6.500         1020.900            100.000           -3.600         1014.600             64.000            10.100             6.300              36.000              2
# 656  hand2  2016-04-09   am  06:04:00  355        G     24.000    0.009   0.800   0.063    0.028   179.000    0.137  13.700   0.904    0.484  2114.067    0.006   0.571   0.038    0.020    88.086         8.400        0.000          0.000                99.000            10.900                 8.200        1011.500             1015.700               9.900           20.300         1013.300             99.000            8.000         1010.500             44.000            12.300             2.800              55.000              2
#
# [657 rows x 41 columns]

# %%
df=dfOriginal.copy()

#1. Remove all the rows that does not have any pef values 

df=df.reset_index(drop=True)

#2. Combine 
df=df.fillna(0)
sdttm = df.date + " " + df.time
df.insert(0, 'sdttm', sdttm)
df.sdttm = pd.to_datetime(df.sdttm)

df.sort_values(by='sdttm', ascending=True, inplace=True)
alldrps = "cname, pname, date, time, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, temperature_diff, airpressure_diff, precipitation_diff, tm_window"
if predictQuantile:
    alldrps += ', pef_zone'
else:
    alldrps += ', percent_group'
drps  = alldrps.split(', ')
df=df.drop(drps, axis=1, errors='ignore')
df=df.reset_index(drop=True)

## <== do the following for SAP PA tool
#pef = df.pef;
#df=df.drop(['pef'], axis=1)
#df.insert(1, 'pef1', pef)

#pef[-10:]=0     # Set last 10 to zero for predictions
#df.insert(1, 'pef', pef)
#df.to_csv("HanD/hand1.csv", sep=';')

df1 = df.copy()
df1 = df1.set_index(df1.sdttm)
df1=df1.drop('sdttm', axis=1, errors='ignore')

nq = 5
lnq=list(range(0,nq))
s= pd.qcut(df1.pef, nq, labels=lnq )
df1.insert(1,"pefcat", s)
df1.pefcat = df1.pefcat.astype(str)

pefcol = df1['pef']



columns =  '''so2_max,co_max,o3_max,no2_max,pm10_max,so2_sum,co_sum,o3_sum,no2_sum,pm10_sum,so2_avg,co_avg,o3_avg,no2_avg,pm10_avg,temperaturec,windspeedms,winddirection,precipitationpercent,vaporpressurehpa,dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,
 temperature_max,airpressure_max,precipitation_max,temperature_min,airpressure_min,precipitation_min'''
if predictQuantile:
    columns += ',percent_group'
else:
    columns += ',pef_zone'

#'''pefcat,pef_zone,so2_max,co_max,o3_max,no2_max,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
#dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,temperature_max,airpressure_max,temperature_min'''

 
#amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
cs = [c.strip() for c in columns.split(',')]

df1=df1[cs]
#HTML(df1.to_html())
#displayDFs (df1, maxrows=3 )
df1
# Out:
#                      so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  percent_group
# sdttm
# 2015-01-02 06:24:00    0.004   0.700   0.025    0.024   145.000    0.078  12.790   0.428    0.300   990.300    0.003   0.563   0.019    0.013    43.626        -6.800        1.200        340.000                58.000             2.100               -13.600        1020.500             1025.000              -4.800           -3.900         1022.200             63.000           -8.500         1019.600             35.000              1
# 2015-01-03 07:19:00    0.009   0.900   0.026    0.035    54.000    0.125  17.045   0.299    0.584   886.283    0.005   0.684   0.012    0.023    35.570        -9.600        0.600        180.000                71.000             2.100               -13.800        1022.700             1027.200              -6.900           -0.800         1023.400             71.000           -9.600         1019.900             31.000              1
# 2015-01-04 07:46:00    0.013   1.000   0.015    0.039    52.000    0.174  16.975   0.180    0.797   857.550    0.007   0.694   0.007    0.033    35.074         0.700        1.600         70.000                67.000             4.300                -4.700        1013.600             1017.900              -0.700            1.900         1023.400             71.000           -9.600         1013.200             38.000              1
# 2015-01-05 06:08:00    0.009   1.300   0.021    0.065    75.000    0.137  22.300   0.106    1.078  1248.967    0.006   0.997   0.005    0.048    55.841        -2.800        0.000          0.000               100.000             5.000                -2.800        1016.200             1020.600              -2.800            7.600         1017.500            100.000           -2.800         1012.900             59.000              1
# ...                      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...            ...
# 2016-10-16 07:17:00    0.004   1.100   0.045    0.059   105.000    0.086  19.070   0.332    1.090  1863.967    0.003   0.754   0.013    0.043    73.723        16.700        1.000        110.000                77.000            14.600                12.600        1017.500             1021.600              15.200           26.100         1023.500            100.000           11.200         1017.500             35.000              1
# 2016-10-17 06:11:00    0.004   0.700   0.028    0.037    74.000    0.073  13.440   0.279    0.642  1261.567    0.003   0.587   0.012    0.028    55.090        15.000        0.800        340.000                97.000            16.500                14.500        1013.400             1017.500              15.300           19.400         1017.600            100.000           15.000         1012.600             60.000              1
# 2016-10-18 06:00:00    0.004   0.900   0.055    0.039    72.000    0.066  12.690   0.453    0.625  1205.467    0.003   0.556   0.020    0.027    52.833        11.900        0.600        250.000               100.000            13.800                11.800        1016.100             1020.200              12.900           22.400         1016.200            100.000           11.900         1013.000             55.000              1
# 2016-10-19 06:28:00    0.007   1.000   0.032    0.064   104.000    0.118  18.420   0.199    1.045  1752.667    0.005   0.753   0.008    0.043    71.635        11.700        0.000          0.000               100.000            13.700                11.600        1014.900             1019.000              11.900           20.800         1018.100            100.000           11.000         1014.900             61.000              2
#
# [657 rows x 31 columns]

# %%
# from sklearn.neural_network import MLPClassifier
# nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)

# clf = nn;

# Y_SCALER = None
# #Normalize the input and save the scalar for outcome variable "pefmax" in this case.
# scaler = StandardScaler()
# dp = prepareDF(df1, True)
# for c in dp.columns:
#     if ( c == 'pefcat'):
#         #Y_SCALER = StandardScaler()
#         #dp[c] = Y_SCALER.fit_transform(dp[c])
#         pass;
#     else:
#         dp[c] = scaler.fit_transform(dp[c])
        
# #dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
# dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

# X = dp1.ix[:, dp1.columns != 'pefcat']
# y = dp1.pefcat 
# X = X.as_matrix().astype(np.float)


# kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
# y_pred = y.copy()

# # Iterate through folds\
# i = 0;
# for train_index, test_index in kf.split(X):
#     #print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train = y[train_index]
#     # Initialize a classifier with key word arguments\
#     print ("*",i, end ="");
#     clf.fit(X_train,y_train)
#     y_pred[test_index] = clf.predict(X_test)
#     i = i +1;

# %%
from sklearn.naive_bayes import GaussianNB

predictColumn = "pefcat"
predictColumn = "pef_zone"
if predictQuantile:
    predictColumn = "percent_group"

if ( 'pefcat' in df1.columns ):
    df1.pefcat = df1.pefcat.astype(int)
    df1=df1.drop('pefcat', axis=1)

cls = [# Comment/uncomment out any classfiers according to your need 
       # DO NOT CHANGE
        "DecisionTree Gini" , tree.DecisionTreeClassifier(max_depth=4, criterion="gini"),
        "DecisionTree Entr" , tree.DecisionTreeClassifier(max_depth=4, criterion="entropy"), 
        "SVM"               , sklearn.svm.SVC(kernel="linear"), 
#        "SVM1"              , SVC(kernel="rbf", C=10**3),
        "K-NN"              , sklearn.neighbors.KNeighborsClassifier(),
        "Gradient Boosting" , sklearn.ensemble.RandomForestClassifier(),
        "Logit Regression"  , sklearn.linear_model.LogisticRegression(),
#        "Neural NW"         , MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(25, 10), random_state=1),
        "Naive Bayes"       , GaussianNB()
];

y = df1[predictColumn]
X = df1.drop(predictColumn, axis=1)
a = Classify(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=True)
ik = 0
y_preds=[]
clsNames=[]

for i in cls:
    if type(i) is str:
        clsNames.append(i)
        y_pred = a[4][i]
        y_preds.append(y_pred)
        target_names = ['class 0', 'class 1', 'class 2']
        print(i + ' Metrics')
        y.replace(to_replace="R", value=0, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="Y", value=1, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="G", value=2, inplace=True, limit=None, regex=False, method='pad', axis=None)
        print(classification_report(y, y_pred, target_names=target_names))
# Out:
# Feature space holds 657 observations and 30 features
# Unique target labels: [1 2 0]
# * 0* 1* 2* 3* 4*
#    DecisionTree Gini accuracy: 0.592085
#    DecisionTree Gini r^2 score: -0.110273
# * 0* 1* 2* 3* 4*
#    DecisionTree Entr accuracy: 0.567732
#    DecisionTree Entr r^2 score: -0.136889
# * 0* 1* 2* 3* 4*
#                  SVM accuracy: 0.599696
#                  SVM r^2 score: -0.000006
# * 0* 1* 2* 3* 4*
#                 K-NN accuracy: 0.480974
#                 K-NN r^2 score: -0.547537
# * 0* 1* 2* 3* 4*
#    Gradient Boosting accuracy: 0.538813
#    Gradient Boosting r^2 score: -0.277574
# * 0* 1* 2* 3* 4*
#     Logit Regression accuracy: 0.596651
#     Logit Regression r^2 score: -0.030424
# * 0* 1* 2* 3* 4*
#          Naive Bayes accuracy: 0.432268
#          Naive Bayes r^2 score: -1.079860
# DecisionTree Gini Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.46      0.08      0.14       132
#     class 1       0.61      0.95      0.74       394
#     class 2       0.13      0.02      0.03       131
#
# avg / total       0.48      0.59      0.48       657
#
# DecisionTree Entr Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.31      0.11      0.16       132
#     class 1       0.60      0.89      0.72       394
#     class 2       0.30      0.05      0.09       131
#
# avg / total       0.48      0.57      0.48       657
#
# SVM Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00       132
#     class 1       0.60      1.00      0.75       394
#     class 2       0.00      0.00      0.00       131
#
# avg / total       0.36      0.60      0.45       657
#
# K-NN Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.19      0.17      0.18       132
#     class 1       0.57      0.74      0.65       394
#     class 2       0.08      0.02      0.04       131
#
# avg / total       0.40      0.48      0.43       657
#
# Gradient Boosting Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.31      0.18      0.23       132
#     class 1       0.60      0.81      0.69       394
#     class 2       0.26      0.09      0.14       131
#
# avg / total       0.47      0.54      0.48       657
#
# Logit Regression Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.38      0.04      0.07       132
#     class 1       0.60      0.98      0.75       394
#     class 2       0.40      0.02      0.03       131
#
# avg / total       0.52      0.60      0.47       657
#
# Naive Bayes Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.22      0.31      0.26       132
#     class 1       0.63      0.49      0.55       394
#     class 2       0.29      0.37      0.33       131
#
# avg / total       0.48      0.43      0.45       657

# %%
#(X1,y1,ra,cls) = Classify1(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=False)
DrawDecisionTree(X,y, cls[1])

# %%
import matplotlib.pyplot as plt

#print(size(pefcol.values))
#print(size(y))
#print(y_pred)

plt.plot(pefcol.index[y == 0],pefcol.values[y == 0],'r.',pefcol.index[y == 1],pefcol.values[y == 1],'y.',pefcol.index[y == 2],pefcol.values[y == 2],'g.')

plt.xlabel('date')
plt.ylabel('pef')
plt.title('PEF true')
plt.grid(True)
plt.show()

i=0

for ypredicted in y_preds:
        plt.plot(pefcol.index[ypredicted == 0],pefcol.values[ypredicted == 0],'r.',pefcol.index[ypredicted == 1],pefcol.values[ypredicted == 1],'y.',pefcol.index[ypredicted == 2],pefcol.values[ypredicted == 2],'g.')

        plt.xlabel('date')
        plt.ylabel('pef')
        plt.title('PEF prediction ' + clsNames[i])
        plt.grid(True)
        plt.show()
        i+=1
