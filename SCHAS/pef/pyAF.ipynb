# %%
# %run "../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
#from statsmodels.regression.quantile_regression import QuantReg
#import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
import pyaf.ForecastEngine as autof

han1="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20patient_data_table";
hand="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20hand"
kimj="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kimj";
leeh="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20leeh";
sony="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20sony";
kuky="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kuky";

fileName = hand;

#dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
#displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px black solid;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
# 	position: relative;
# 	float: left;
# 	padding: 0px;
# 	z-index: 3;
# }
#
# .thumbnail:hover {
# 	background-color: #e9e9e2;
# 	color: #335500;
# 	text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
# 	position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
# 	padding: 5px;
# 	border: 1px solid #666;
# 	visibility: hidden;
# 	color: black;
# 	text-decoration: none;
# 	top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
# 	right: 50px;/*position where enlarged image should offset horizontally */
# 	z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
# 	visibility: visible;
# 	width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
# </style>
#
# <!--
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <-->
# <script src="https://ajax.googleapis.com/ajax/libs/angularjs/1.5.7/angular.min.js"></script>
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>

# %%
csvfile_link = "https://raw.githubusercontent.com/antoinecarme/pyaf/master/data/ozone-la-exogenous-2.csv"
exog_dataframe = pd.read_csv(csvfile_link);
exog_dataframe['Date'] = exog_dataframe['Date'].astype(np.datetime64);

#print(exog_dataframe.info())
exog_dataframe
# Out:
#           Date  Exog2  Exog3 Exog4 Exog5
# 0   1955-01-01      2      3     F     M
# 1   1955-02-01      3      5     G     L
# 2   1955-03-01      5      6     G     L
# 3   1955-04-01      6      6     F     M
# ..         ...    ...    ...   ...   ...
# 212 1972-09-01      2      1     B     K
# 213 1972-10-01      1      1     A     K
# 214 1972-11-01      1      0     A     K
# 215 1972-12-01      0      0     A     K
#
# [216 rows x 5 columns]

# %%
encoded_csvfile_link = "https://raw.githubusercontent.com/antoinecarme/pyaf/master/data/ozone_exogenous_encoded.csv"
encoded_ozone_dataframe = pd.read_csv(encoded_csvfile_link);
# print(encoded_ozone_dataframe.columns)
interesting_Columns = ['Date',
                       'Ozone', 'Exog2', 
                       'Exog2',
                       'Exog3', 
                       'Exog4=E', 'Exog4=F', 'Exog4=C', 'Exog4=D', 'Exog4=B',
                       'Exog5=K', 'Exog5=L', 'Exog5=M', 'Exog5=N'];

encoded_ozone_dataframe = encoded_ozone_dataframe[interesting_Columns]
#print(encoded_ozone_dataframe.info())
encoded_ozone_dataframe
# Out:
#            Date  Ozone  Exog2  Exog2  Exog3  Exog4=E  Exog4=F  Exog4=C  Exog4=D  Exog4=B  Exog5=K  Exog5=L  Exog5=M  Exog5=N
# 0    1955-01-01  2.700 -1.035 -1.035 -0.400        0        1        0        0        0        0        0        1        0
# 1    1955-02-01  2.000 -0.391 -0.391  0.891        0        0        0        0        0        0        1        0        0
# 2    1955-03-01  3.600  0.897  0.897  1.537        0        0        0        0        0        0        1        0        0
# 3    1955-04-01  5.000  1.540  1.540  1.537        0        1        0        0        0        0        0        1        0
# ..          ...    ...    ...    ...    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
# 212  1972-09-01  3.100 -1.035 -1.035 -1.692        0        0        0        0        1        1        0        0        0
# 213  1972-10-01  2.100 -1.679 -1.679 -1.692        0        0        0        0        0        1        0        0        0
# 214  1972-11-01  1.600 -1.679 -1.679 -2.338        0        0        0        0        0        1        0        0        0
# 215  1972-12-01  1.300 -2.322 -2.322 -2.338        0        0        0        0        0        1        0        0        0
#
# [216 rows x 14 columns]

# %%
pd.ozone_dataframe,encoded_ozone_dataframe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5a804744df1c> in <module>()
# ----> 1 pd.concat([ozone_dataframe,encoded_ozone_dataframe])
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
#     408             if not self.copy:
#     409                 new_data._consolidate_inplace()
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    4830     blocks = [make_block(
#    4831         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4832         placement=placement) for placement, join_units in concat_plan]
#    4833
#    4834     return BlockManager(blocks, axes)
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    4828          for mgr, indexers in mgrs_indexers], concat_axis)
#    4829
# -> 4830     blocks = [make_block(
#    4831         concatenate_join_units(join_units, concat_axis, copy=copy),
#    4832         placement=placement) for placement, join_units in concat_plan]
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in combine_concat_plans(plans, concat_axis)
#    5065         while num_ended[0] != len(next_items):
#    5066             if num_ended[0] > 0:
# -> 5067                 raise ValueError("Plan shapes are not aligned")
#    5068
#    5069             placements, units = zip(*next_items)
#
# ValueError: Plan shapes are not aligned

# %%
import pyaf.ForecastEngine as autof
lEngine = autof.cForecastEngine()

csvfile_link = "https://raw.githubusercontent.com/antoinecarme/TimeSeriesData/master/ozone-la.csv"
ozone_dataframe = pd.read_csv(csvfile_link);
ozone_dataframe['Date'] = ozone_dataframe['Month'].apply(lambda x : datetime.datetime.strptime(x, "%Y-%m"))

ozone_dataframe.info()

lExogenousData = (exog_dataframe , ['Exog2' , 'Exog3' , 'Exog4',  'Exog5']) 

lEngine.train(ozone_dataframe , 'Date' , 'Ozone', 12 , lExogenousData);
# Out:
# INFO:pyaf.std:START_TRAINING 'Ozone'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 3 columns):
# Month    216 non-null object
# Ozone    216 non-null float64
# Date     216 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.1+ KB
# Process ForkPoolWorker-42:
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py in next(self, timeout)
#     679             try:
# --> 680                 item = self._items.popleft()
#     681             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c71dae0c3743> in <module>()
#      10 lExogenousData = (exog_dataframe , ['Exog2' , 'Exog3' , 'Exog4',  'Exog5'])
#      11
# ---> 12 lEngine.train(ozone_dataframe , 'Date' , 'Ozone', 12 , lExogenousData);
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/ForecastEngine.py in train(self, iInputDS, iTime, iSignal, iHorizon, iExogenousData)
#      23         try:
#      24             self.mSignalDecomposition.mOptions = self.mOptions;
# ---> 25             self.mSignalDecomposition.train(iInputDS, iTime, iSignal, iHorizon, iExogenousData);
#      26         except tsutil.PyAF_Error as error:
#      27             raise error
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/TS/SignalDecomposition.py in train(self, iInputDS, iTime, iSignal, iHorizon, iExogenousData)
#     507
#     508         if(self.mOptions.mParallelMode):
# --> 509             self.train_multiprocessed(iInputDS, iTime, iSignal, iHorizon);
#     510         else:
#     511             self.train_not_threaded(iInputDS, iTime, iSignal, iHorizon);
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/TS/SignalDecomposition.py in train_multiprocessed(self, iInputDS, iTime, iSignal, iHorizon)
#     392             args.append(arg);
#     393
# --> 394         for res in pool.imap(run_transform_thread, args):
#     395             # print("FINISHED_TRAINING" , res.mName);
#     396             self.mSigDecByTransform[res.mTransformation.get_name("")] = res.mSigDec;
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py in next(self, timeout)
#     682                 if self._index == self._length:
#     683                     raise StopIteration
# --> 684                 self._cond.wait(timeout)
#     685                 try:
#     686                     item = self._items.popleft()
#
# /Users/snarayan/anaconda3/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()

# %%
lEngine.getModelInfo()

# %%
lEngine_Without_Exogenous = autof.cForecastEngine()
lEngine_Without_Exogenous.train(ozone_dataframe , 'Date' , 'Ozone', 12);
# Out:
# INFO:pyaf.std:START_TRAINING 'Ozone'
# Process ForkPoolWorker-36:
# KeyboardInterrupt
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-33:
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py in next(self, timeout)
#     679             try:
# --> 680                 item = self._items.popleft()
#     681             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1cccbd433383> in <module>()
#       1 lEngine_Without_Exogenous = autof.cForecastEngine()
# ----> 2 lEngine_Without_Exogenous.train(ozone_dataframe , 'Date' , 'Ozone', 12);
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/ForecastEngine.py in train(self, iInputDS, iTime, iSignal, iHorizon, iExogenousData)
#      23         try:
#      24             self.mSignalDecomposition.mOptions = self.mOptions;
# ---> 25             self.mSignalDecomposition.train(iInputDS, iTime, iSignal, iHorizon, iExogenousData);
#      26         except tsutil.PyAF_Error as error:
#      27             raise error
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/TS/SignalDecomposition.py in train(self, iInputDS, iTime, iSignal, iHorizon, iExogenousData)
#     507
#     508         if(self.mOptions.mParallelMode):
# --> 509             self.train_multiprocessed(iInputDS, iTime, iSignal, iHorizon);
#     510         else:
#     511             self.train_not_threaded(iInputDS, iTime, iSignal, iHorizon);
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/pyaf/TS/SignalDecomposition.py in train_multiprocessed(self, iInputDS, iTime, iSignal, iHorizon)
#     392             args.append(arg);
#     393
# --> 394         for res in pool.imap(run_transform_thread, args):
#     395             # print("FINISHED_TRAINING" , res.mName);
#     396             self.mSigDecByTransform[res.mTransformation.get_name("")] = res.mSigDec;
#
# /Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py in next(self, timeout)
#     682                 if self._index == self._length:
#     683                     raise StopIteration
# --> 684                 self._cond.wait(timeout)
#     685                 try:
#     686                     item = self._items.popleft()
#
# /Users/snarayan/anaconda3/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/snarayan/anaconda3/lib/python3.5/site-packages/multiprocess/pool.py", line 108, in worker
#     task = get()

# %%
lEngine_Without_Exogenous.getModelInfo()

# %%
ozone_forecast_without_exog = lEngine_Without_Exogenous.forecast(ozone_dataframe, 12);
ozone_forecast_with_exog = lEngine.forecast(ozone_dataframe, 12);

# %%
# %matplotlib inline  
ozone_forecast_without_exog.plot.line('Date', ['Ozone' , 'Ozone_Forecast', 
                                             'Ozone_Forecast_Lower_Bound', 
                                             'Ozone_Forecast_Upper_Bound'], grid = True, figsize=(12, 8))
ozone_forecast_with_exog.plot.line('Date', ['Ozone' , 'Ozone_Forecast', 
                                             'Ozone_Forecast_Lower_Bound', 
                                             'Ozone_Forecast_Upper_Bound'], grid = True, figsize=(12, 8))
