# %%
# %run "../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

patient="uhy"
ampm="am"
file="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20calculated_jlee%20WHERE%20ampm=%27"+ampm+"%27%20AND%20pname=%27"+patient+"%27%20ORDER%20BY%20date,%20time"

predictQuantile=True
lowerPercent = 0.20
upperPercent = 0.80

fileName = file;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
#displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
dfOriginal
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
#     pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff
# 0     uhy  2014-01-02   am  09:58:00  368        G     24.450    0.015   1.300   0.026    0.044   108.000    0.254  16.363   0.419    0.630  1948.783    0.010   0.669   0.017    0.026    79.705         0.300        1.900         20.000                48.000             3.000                -9.400        1014.000             1022.600              -0.100            7.200         1014.000             82.000            0.300         1004.600             48.000             6.900             9.400              34.000
# 1     uhy  2014-01-03   am  09:30:00  310        G     23.533    0.011   2.200   0.023    0.077    90.000    0.225  23.727   0.192    1.136  1180.400    0.010   1.008   0.008    0.048    50.159         1.200        0.900        160.000                62.000             4.200                -5.200        1009.000             1017.600               0.300            5.700         1015.100             70.000            0.300         1008.900             37.000             5.400             6.200              33.000
# 2     uhy  2014-01-04   am  09:31:00  326        G     24.017    0.014   2.200   0.015    0.084   117.000    0.215  18.910   0.191    0.952  1306.317    0.009   0.787   0.008    0.040    54.392        -2.700        4.500         20.000                59.000             3.000                -9.600        1011.600             1020.300              -0.800            6.600         1011.600             96.000           -3.000         1006.400             56.000             9.600             5.200              40.000
# 3     uhy  2014-01-05   am  11:01:00  328        G     25.500    0.007   0.800   0.022    0.042    58.000    0.170  15.402   0.281    0.679  1089.650    0.007   0.604   0.011    0.027    42.731        -0.800        2.600        340.000                53.000             3.000                -9.200        1015.600             1024.300               3.700            2.700         1015.600             62.000           -3.500         1009.800             50.000             6.200             5.800              12.000
# ..    ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...
# 685   uhy  2015-11-18   am  09:22:00  307        G     24.000    0.006   1.100   0.048    0.040    50.000    0.115  13.937   0.567    0.690   568.000    0.005   0.581   0.024    0.029    23.667        13.000        4.100        110.000                80.000            11.900                 9.600        1011.300             1019.900              11.200           16.900         1012.200             97.000           11.200         1009.700             66.000             5.700             2.500              31.000
# 686   uhy  2015-11-19   am  10:33:00  295        Y     25.183    0.005   0.600   0.031    0.033    24.000    0.095  10.100   0.443    0.691   220.567    0.004   0.401   0.018    0.027     8.758         9.400        3.700        140.000                84.000             9.900                 6.800        1015.200             1023.900              10.500           13.000         1015.800             98.000            7.500         1010.400             77.000             5.500             5.400              21.000
# 687   uhy  2015-11-20   am  10:32:00  251        Y     23.983    0.008   1.000   0.018    0.032    47.000    0.102  14.153   0.189    0.664   718.267    0.004   0.590   0.008    0.028    29.949         9.900        1.100        360.000                98.000            11.900                 9.500        1015.700             1024.500              11.700           11.300         1015.800             98.000            8.700         1012.400             84.000             2.600             3.400              14.000
# 688   uhy  2015-11-21   am  11:04:00  234        Y     24.533    0.008   1.300   0.019    0.038    89.000    0.126  20.507   0.166    0.705  1316.000    0.005   0.836   0.007    0.029    53.641         9.000        2.100        340.000                68.000             7.700                 3.300        1019.300             1028.100              14.000           13.300         1019.500             98.000            5.800         1014.400             68.000             7.500             5.100              30.000
#
# [689 rows x 40 columns]

# %%
#Break into groups by percentage

dfOriginal.sort_values(by='pef', ascending=True, inplace=True)
dfOriginal.reset_index(drop=True, inplace=True)
numberOfElements = len(dfOriginal)
upperBoundary = upperPercent*numberOfElements
lowerBoundary = lowerPercent*numberOfElements
dfOriginal['percent_group']=-1

for i in dfOriginal.index:

    if i < lowerBoundary:
        dfOriginal['percent_group'][i] = 0

    elif i > upperBoundary : 
        dfOriginal['percent_group'][i] = 2

    else:
        dfOriginal['percent_group'][i] = 1

print(dfOriginal)
# Out:
#     pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff  percent_group
# 0     uhy  2014-12-22   am  09:48:00  158        R     23.850    0.007   1.000   0.018    0.036    44.000    0.119  13.825   0.265    0.379   697.700    0.005   0.580   0.011    0.016    29.254        -6.100        3.800        160.000                99.000             3.800                -6.200        1013.600             1022.900              -1.600           -2.300         1015.300             99.000           -7.900         1012.200             37.000             5.600             3.100              62.000              0
# 1     uhy  2015-07-14   am  09:44:00  184        R     24.000    0.007   0.800   0.049    0.046   115.000    0.090   9.113   0.956    0.742  1363.800    0.004   0.380   0.040    0.031    56.825        23.400        2.900        230.000                99.000            28.400                23.200         995.500             1003.600              28.800           23.600          995.500             99.000           20.500          982.000             99.000             3.100            13.500               0.000              0
# 2     uhy  2015-08-04   am  10:35:00  198        Y     23.800    0.006   0.600   0.030    0.008    35.000    0.079   7.962   0.397    0.110   517.417    0.003   0.335   0.017    0.005    21.740        27.100        7.200        200.000                99.000            35.400                26.900         998.400             1006.400              27.300           28.900         1000.700             99.000           25.200          998.400             99.000             3.700             2.300               0.000              0
# 3     uhy  2015-07-27   am  11:01:00  199        Y     24.350    0.009   0.700   0.024    0.038    29.000    0.106   4.137   0.265    0.702   479.417    0.004   0.170   0.011    0.029    19.689        24.400        2.300        270.000                99.000            30.200                24.200        1001.100             1009.200              25.800           26.900         1001.200             99.000           23.300          999.300             99.000             3.600             1.900               0.000              0
# ..    ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...            ...
# 685   uhy  2014-02-08   am  09:30:00  368        G     24.183    0.008   0.700   0.025    0.041    75.000    0.140  10.728   0.442    0.632   374.750    0.006   0.444   0.018    0.026    15.496         0.000        5.200         90.000                90.000             5.500                -1.400        1008.900             1017.500               0.100            6.400         1014.500             92.000           -1.900         1008.000             48.000             8.300             6.500              44.000              2
# 686   uhy  2014-05-14   am  10:42:00  368        G     25.200    0.016   0.600   0.073    0.052   144.000    0.275  13.980   1.440    0.884  3202.800    0.011   0.555   0.057    0.035   127.095        19.200        2.300        230.000                60.000            13.300                11.200         995.600             1003.800              24.600           20.700         1000.400             94.000           14.900          995.600             60.000             5.800             4.800              34.000              2
# 687   uhy  2014-01-02   am  09:58:00  368        G     24.450    0.015   1.300   0.026    0.044   108.000    0.254  16.363   0.419    0.630  1948.783    0.010   0.669   0.017    0.026    79.705         0.300        1.900         20.000                48.000             3.000                -9.400        1014.000             1022.600              -0.100            7.200         1014.000             82.000            0.300         1004.600             48.000             6.900             9.400              34.000              2
# 688   uhy  2014-04-15   am  10:05:00  371        G     24.333    0.013   0.600   0.051    0.069   124.000    0.180  11.192   0.646    1.103  1869.583    0.007   0.460   0.027    0.045    76.832         8.000        2.200        230.000                99.000            10.600                 7.800        1012.600             1021.400              13.000           18.500         1013.700             99.000            6.400         1010.700             47.000            12.100             3.000              52.000              2
#
# [689 rows x 41 columns]

# %%
df=dfOriginal.copy()

#1. Remove all the rows that does not have any pef values 

df=df.reset_index(drop=True)

#2. Combine 
df=df.fillna(0)
sdttm = df.date + " " + df.time
df.insert(0, 'sdttm', sdttm)
df.sdttm = pd.to_datetime(df.sdttm)

df.sort_values(by='sdttm', ascending=True, inplace=True)
alldrps = "cname, pname, date, time, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, temperature_diff, airpressure_diff, precipitation_diff, tm_window"
if predictQuantile:
    alldrps += ', pef_zone'
else:
    alldrps += ', percent_group'
drps  = alldrps.split(', ')
df=df.drop(drps, axis=1, errors='ignore')
df=df.reset_index(drop=True)

## <== do the following for SAP PA tool
#pef = df.pef;
#df=df.drop(['pef'], axis=1)
#df.insert(1, 'pef1', pef)

#pef[-10:]=0     # Set last 10 to zero for predictions
#df.insert(1, 'pef', pef)
#df.to_csv("HanD/hand1.csv", sep=';')

df1 = df.copy()
df1 = df1.set_index(df1.sdttm)
df1=df1.drop('sdttm', axis=1, errors='ignore')

nq = 5
lnq=list(range(0,nq))
s= pd.qcut(df1.pef, nq, labels=lnq )
df1.insert(1,"pefcat", s)
df1.pefcat = df1.pefcat.astype(str)

pefcol = df1['pef']

columns =  '''so2_max,co_max,o3_max,no2_max,pm10_max,so2_sum,co_sum,o3_sum,no2_sum,pm10_sum,so2_avg,co_avg,o3_avg,no2_avg,pm10_avg,temperaturec,windspeedms,winddirection,precipitationpercent,vaporpressurehpa,dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,
 temperature_max,airpressure_max,precipitation_max,temperature_min,airpressure_min,precipitation_min'''

if predictQuantile:
    columns += ',percent_group'
else:
    columns += ',pef_zone'


#'''pefcat,pef_zone,so2_max,co_max,o3_max,no2_max,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
#dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,temperature_max,airpressure_max,temperature_min'''

 
#amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
cs = [c.strip() for c in columns.split(',')]

df1=df1[cs]
#HTML(df1.to_html())
#displayDFs (df1, maxrows=3 )
df1
# Out:
#                      so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  percent_group
# sdttm
# 2014-01-02 09:58:00    0.015   1.300   0.026    0.044   108.000    0.254  16.363   0.419    0.630  1948.783    0.010   0.669   0.017    0.026    79.705         0.300        1.900         20.000                48.000             3.000                -9.400        1014.000             1022.600              -0.100            7.200         1014.000             82.000            0.300         1004.600             48.000              2
# 2014-01-03 09:30:00    0.011   2.200   0.023    0.077    90.000    0.225  23.727   0.192    1.136  1180.400    0.010   1.008   0.008    0.048    50.159         1.200        0.900        160.000                62.000             4.200                -5.200        1009.000             1017.600               0.300            5.700         1015.100             70.000            0.300         1008.900             37.000              1
# 2014-01-04 09:31:00    0.014   2.200   0.015    0.084   117.000    0.215  18.910   0.191    0.952  1306.317    0.009   0.787   0.008    0.040    54.392        -2.700        4.500         20.000                59.000             3.000                -9.600        1011.600             1020.300              -0.800            6.600         1011.600             96.000           -3.000         1006.400             56.000              2
# 2014-01-05 11:01:00    0.007   0.800   0.022    0.042    58.000    0.170  15.402   0.281    0.679  1089.650    0.007   0.604   0.011    0.027    42.731        -0.800        2.600        340.000                53.000             3.000                -9.200        1015.600             1024.300               3.700            2.700         1015.600             62.000           -3.500         1009.800             50.000              2
# ...                      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...            ...
# 2015-11-18 09:22:00    0.006   1.100   0.048    0.040    50.000    0.115  13.937   0.567    0.690   568.000    0.005   0.581   0.024    0.029    23.667        13.000        4.100        110.000                80.000            11.900                 9.600        1011.300             1019.900              11.200           16.900         1012.200             97.000           11.200         1009.700             66.000              1
# 2015-11-19 10:33:00    0.005   0.600   0.031    0.033    24.000    0.095  10.100   0.443    0.691   220.567    0.004   0.401   0.018    0.027     8.758         9.400        3.700        140.000                84.000             9.900                 6.800        1015.200             1023.900              10.500           13.000         1015.800             98.000            7.500         1010.400             77.000              1
# 2015-11-20 10:32:00    0.008   1.000   0.018    0.032    47.000    0.102  14.153   0.189    0.664   718.267    0.004   0.590   0.008    0.028    29.949         9.900        1.100        360.000                98.000            11.900                 9.500        1015.700             1024.500              11.700           11.300         1015.800             98.000            8.700         1012.400             84.000              0
# 2015-11-21 11:04:00    0.008   1.300   0.019    0.038    89.000    0.126  20.507   0.166    0.705  1316.000    0.005   0.836   0.007    0.029    53.641         9.000        2.100        340.000                68.000             7.700                 3.300        1019.300             1028.100              14.000           13.300         1019.500             98.000            5.800         1014.400             68.000              0
#
# [689 rows x 31 columns]

# %%
# from sklearn.neural_network import MLPClassifier
# nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)

# clf = nn;

# Y_SCALER = None
# #Normalize the input and save the scalar for outcome variable "pefmax" in this case.
# scaler = StandardScaler()
# dp = prepareDF(df1, True)
# for c in dp.columns:
#     if ( c == 'pefcat'):
#         #Y_SCALER = StandardScaler()
#         #dp[c] = Y_SCALER.fit_transform(dp[c])
#         pass;
#     else:
#         dp[c] = scaler.fit_transform(dp[c])
        
# #dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
# dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

# X = dp1.ix[:, dp1.columns != 'pefcat']
# y = dp1.pefcat 
# X = X.as_matrix().astype(np.float)


# kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
# y_pred = y.copy()

# # Iterate through folds\
# i = 0;
# for train_index, test_index in kf.split(X):
#     #print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train = y[train_index]
#     # Initialize a classifier with key word arguments\
#     print ("*",i, end ="");
#     clf.fit(X_train,y_train)
#     y_pred[test_index] = clf.predict(X_test)
#     i = i +1;

# %%
from sklearn.naive_bayes import GaussianNB

predictColumn = "pefcat"
predictColumn = "pef_zone"
if predictQuantile:
    predictColumn = "percent_group"

if ( 'pefcat' in df1.columns ):
    df1.pefcat = df1.pefcat.astype(int)
    df1=df1.drop('pefcat', axis=1)

cls = [# Comment/uncomment out any classfiers according to your need 
       # DO NOT CHANGE
        "DecisionTree Gini" , tree.DecisionTreeClassifier(max_depth=4, criterion="gini"),
        "DecisionTree Entr" , tree.DecisionTreeClassifier(max_depth=4, criterion="entropy"), 
        "SVM"               , sklearn.svm.SVC(kernel="linear"), 
#        "SVM1"              , SVC(kernel="rbf", C=10**3),
#        "Random Forest"     , sklearn.ensemble.RandomForestClassifier(),
#        "K-NN"              , sklearn.neighbors.KNeighborsClassifier(),
        "Gradient Boosting" , sklearn.ensemble.RandomForestClassifier(),
        "Logit Regression"  , sklearn.linear_model.LogisticRegression(),
#        "Neural NW"         , MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(25, 10), random_state=1),
#        "Naive Bayes"       , GaussianNB()
];

y = df1[predictColumn]
X = df1.drop(predictColumn, axis=1)
a = Classify(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=True)
ik = 0
y_preds=[]
clsNames=[]

for i in cls:
    if type(i) is str:
        clsNames.append(i)
        y_pred = a[4][i]
        y_preds.append(y_pred)
        target_names = ['class 0', 'class 1', 'class 2']
        print(i + ' Metrics')
        y.replace(to_replace="R", value=0, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="Y", value=1, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="G", value=2, inplace=True, limit=None, regex=False, method='pad', axis=None)
        print(classification_report(y, y_pred, target_names=target_names))
# Out:
# Feature space holds 689 observations and 30 features
# Unique target labels: [2 1 0]
# * 0* 1* 2* 3* 4*
#    DecisionTree Gini accuracy: 0.580552
#    DecisionTree Gini r^2 score: -0.160006
# * 0* 1* 2* 3* 4*
#    DecisionTree Entr accuracy: 0.582003
#    DecisionTree Entr r^2 score: -0.210915
# * 0* 1* 2* 3* 4*
#                  SVM accuracy: 0.600871
#                  SVM r^2 score: -0.000005
# * 0* 1* 2* 3* 4*
#    Gradient Boosting accuracy: 0.512337
#    Gradient Boosting r^2 score: -0.418189
# * 0* 1* 2* 3* 4*
#     Logit Regression accuracy: 0.590711
#     Logit Regression r^2 score: -0.112733
# DecisionTree Gini Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.21      0.04      0.07       138
#     class 1       0.61      0.92      0.73       414
#     class 2       0.39      0.11      0.17       137
#
# avg / total       0.49      0.58      0.49       689
#
# DecisionTree Entr Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.42      0.04      0.07       138
#     class 1       0.62      0.90      0.73       414
#     class 2       0.31      0.16      0.21       137
#
# avg / total       0.52      0.58      0.50       689
#
# SVM Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00       138
#     class 1       0.60      1.00      0.75       414
#     class 2       0.00      0.00      0.00       137
#
# avg / total       0.36      0.60      0.45       689
#
# Gradient Boosting Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.18      0.10      0.13       138
#     class 1       0.59      0.78      0.67       414
#     class 2       0.26      0.12      0.17       137
#
# avg / total       0.44      0.51      0.46       689
#
# Logit Regression Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.31      0.03      0.05       138
#     class 1       0.61      0.96      0.74       414
#     class 2       0.29      0.05      0.09       137
#
# avg / total       0.48      0.59      0.47       689

# %%
#(X1,y1,ra,cls) = Classify1(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=False)
DrawDecisionTree(X,y, cls[1])

# %%
import matplotlib.pyplot as plt

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (6, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'}

plt.rcParams.update(params)


#print(size(pefcol.values))
#print(size(y))
#print(y_pred)

plt.plot(pefcol.index[y == 0],pefcol.values[y == 0],'r.',pefcol.index[y == 1],pefcol.values[y == 1],'y.',pefcol.index[y == 2],pefcol.values[y == 2],'g.')

plt.xlabel('date')
plt.ylabel('PEF')
#plt.title('PEF true')
plt.grid(True)

plt.savefig('uhy-quan.eps')

plt.show()

i=0

for ypredicted in y_preds:
        plt.plot(pefcol.index[ypredicted == 0],pefcol.values[ypredicted == 0],'r.',pefcol.index[ypredicted == 1],pefcol.values[ypredicted == 1],'y.',pefcol.index[ypredicted == 2],pefcol.values[ypredicted == 2],'g.')

        plt.xlabel('date')
        plt.ylabel('pef')
        plt.title('PEF prediction ' + clsNames[i])
        plt.grid(True)
        plt.show()
        i+=1
