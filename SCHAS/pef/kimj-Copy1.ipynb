# %%
# %run "../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

han1="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20patient_data_table";
hand="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20hand"
kimj="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kimj";
leeh="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20leeh";
sony="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20sony";
kuky="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kuky";

fileName = kimj;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>1222 rows x 103 columns var: DFF_PY_VAR_tableID_1534129209911<br>
# <div id='tab_tableID_1534129209911' style='ddisplay:none;width:100%' >
#             <table id='tableID_1534129209911' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr><td style='text-align: ceter;'></td >
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-cname.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-cname.png' /><br />
#  <table><tr><td>count : 1222 </td><td>unique : 1 </td><td>top : kimj </td><td>freq : 1222 </td></tr></table>
# </span></a></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-ampm.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-ampm.png' /><br />
#  <table><tr><td>count : 1222 </td><td>unique : 2 </td><td>top : pm </td><td>freq : 611 </td></tr></table>
# </span></a></td><td align=center></td><td align=center></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-pef1.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-pef1.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 116.17 </td><td>std : 29.78 </td><td>min : 61.00 </td></tr><tr><td>25% : 98.00 </td><td>50% : 110.00 </td><td>75% : 129.50 </td><td>max : 300.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-pef2.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-pef2.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 114.54 </td><td>std : 28.67 </td><td>min : 60.00 </td></tr><tr><td>25% : 95.00 </td><td>50% : 110.00 </td><td>75% : 128.00 </td><td>max : 300.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-pef3.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-pef3.png' /><br />
#  <table><tr><td>count : 501.00 </td><td>mean : 110.15 </td><td>std : 28.66 </td><td>min : 59.00 </td></tr><tr><td>25% : 92.00 </td><td>50% : 105.00 </td><td>75% : 122.00 </td><td>max : 314.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-pefmax.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-pefmax.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 125.68 </td><td>std : 31.09 </td><td>min : 62.00 </td></tr><tr><td>25% : 106.00 </td><td>50% : 120.00 </td><td>75% : 138.00 </td><td>max : 314.00 </td></tr></table>
# </span></a></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-indexpef.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470-indexpef.png' /><br />
#  <table><tr><td>count : 1222 </td><td>unique : 4 </td><td>top : NULL </td><td>freq : 598 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f179261c470-so2.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f179261c470
png\' border=0 style=\'{margins: 0;}\' width=64 height=64 /> \n<span><img s ...

# %%
df=dfOriginal.copy()

#1. Remove all the rows that does not have any pef values 
df.insert(4, 'npt',0)
df.insert(4, 'pef',0)
df.npt = pd.notnull(df.pef1)*1 + pd.notnull(df.pef2)*1 + pd.notnull(df.pef3)*1
df = df[df.npt > 0]
df=df.reset_index(drop=True)
df.pef = (df.pef1 + df.pef2 + df.pef3)/df.npt

#2. Combine 
df=df.fillna(0)
df.loc[df.timeofday == 'null', 'timeofday'] = "00:00:00"
sdttm = df.dateofmeasure + " " + df.timeofday 
df.insert(0, 'sdttm', sdttm)
df.sdttm = pd.to_datetime(df.sdttm)

df.sort_values(by='sdttm', ascending=True, inplace=True)
drps  = "cname, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, pef, indexpef".split(', ')
df=df.drop(drps, axis=1, errors='ignore')
df=df.reset_index(drop=True)

## <== do the following for SAP PA tool
#pef = df.pef;
#df=df.drop(['pef'], axis=1)
#df.insert(1, 'pef1', pef)

#pef[-10:]=0     # Set last 10 to zero for predictions
#df.insert(1, 'pef', pef)
#df.to_csv("HanD/hand1.csv", sep=';')

df1 = df.copy()
df1 = df1.set_index(df1.sdttm)
df1=df1.drop('sdttm', axis=1, errors='ignore')

columns = '''pefmax,so2,co,o3,no2,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,tmax,amax,tmin'''
#amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
cs = [c.strip() for c in columns.split(',')]

df1=df1[cs]
#HTML(df1.to_html())
displayDFs (df1, maxrows=3 )
# Out:
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>619 rows x 16 columns var: DFF_PY_VAR_tableID_1534129213410<br>
# <div id='tab_tableID_1534129213410' style='ddisplay:none;width:100%' >
#             <table id='tableID_1534129213410' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr><td style='text-align: ceter;'></td >
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-pefmax.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-pefmax.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 125.68 </td><td>std : 31.09 </td><td>min : 62.00 </td></tr><tr><td>25% : 106.00 </td><td>50% : 120.00 </td><td>75% : 138.00 </td><td>max : 314.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-so2.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-so2.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 0.11 </td><td>std : 0.05 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.07 </td><td>50% : 0.10 </td><td>75% : 0.14 </td><td>max : 0.33 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-co.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-co.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 12.93 </td><td>std : 5.06 </td><td>min : 0.00 </td></tr><tr><td>25% : 9.40 </td><td>50% : 11.70 </td><td>75% : 15.35 </td><td>max : 30.35 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-o3.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-o3.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 0.62 </td><td>std : 0.29 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.41 </td><td>50% : 0.60 </td><td>75% : 0.80 </td><td>max : 1.46 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-no2.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-no2.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 0.76 </td><td>std : 0.37 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.46 </td><td>50% : 0.70 </td><td>75% : 0.98 </td><td>max : 2.12 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-temperaturec.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-temperaturec.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 13.09 </td><td>std : 10.78 </td><td>min : -13.30 </td></tr><tr><td>25% : 3.35 </td><td>50% : 14.60 </td><td>75% : 22.55 </td><td>max : 31.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x7f178e0d1cf8-windspeedms.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x7f178e0d1cf8-windspeedms.png' /><br />
#  <table><tr><td>count : 619.00 </td><td>mean : 1.54 </td><td>std : 1.13 </td><td>min : 0.00 </td></tr><tr><td>25% : 0
ined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=5)
        n = c+"_4combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=4)
        n = c+"_3combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=3)
        n = c+"_2combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=2)

    df1=df1[5:]
    df1

# %%
#Outlier analysis

for c in df1.columns:
    print(c, end=', ')

Y_SCALER = None
#Normalize the input and save the scalar for outcome variable "pefmax" in this case.
scaler = StandardScaler()
dp = prepareDF(df1, True)
for c in dp.columns:
    if ( c == 'pefmax'):
        Y_SCALER = StandardScaler()
        dp[c] = Y_SCALER.fit_transform(dp[c])
    else:
        dp[c] = scaler.fit_transform(dp[c])

plt.figure(figsize=(25, 5))
dp.boxplot(rot=45);
plt.show()

REMOVE_OUTLIERS = False
if ( REMOVE_OUTLIERS ):
    dpo= dp.copy()
    #from scipy import stats
    good = dp[(np.abs(stats.zscore(df1)) <= 3).all(axis=1)]
    outl = dp[(np.abs(stats.zscore(df1)) > 3).any(axis=1)]
    #outl
    dp=good
    plt.figure(figsize=(25, 5))
    good.boxplot(rot=45);
    
    print ("OUTLIERS COUNT: {} ", len(dpo) - len(dp));
# Out:
# pefmax, so2, co, o3, no2, temperaturec, windspeedms, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, tmax, amax, tmin, so2_5combined, so2_4combined, so2_3combined, so2_2combined, co_5combined, co_4combined, co_3combined, co_2combined, o3_5combined, o3_4combined, o3_3combined, o3_2combined, no2_5combined, no2_4combined, no2_3combined, no2_2combined,

# %%
plt.figure(figsize=(25, 8))
plt.rc('font', size=14)

#dp = dp[0:90]
#dp = dp["pef,so2,co,o3,no2,pm10,tmax,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec".split(',')]
#dp = dp["pef,so2,co,o3,no2,pm10,temperaturec,rainfallmm,windspeedms,vaporpressurehpa".split(',')]
#dp = dp["pef,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec,rainfallmm,windspeedms,vaporpressurehpa".split(',')]

rolmean = pd.rolling_mean(dp.pefmax, window=14)

plt.plot(dp.index, dp.pefmax, color='b', linewidth=3)
#plt.plot(dp.index, rolmean, color='r', linewidth=2, label='trend')
#plt.plot(dp.index, dp.so2)
plt.plot(dp.index, dp.co)
#plt.plot(dp.index, dp.o3)
plt.plot(dp.index, dp.no2)
#plt.plot(dp.index, dp.pm10)
#plt.plot(dp.index, dp.tmax)
#plt.plot(dp.index, dp.amax)
#plt.plot(dp.index, dp.pmax)

plt.legend()

# %%
PLOT_SCATTER=False
if (PLOT_SCATTER):
    c="r,g,b,c,m,y,k,w".split(",")
    #dpc = dp["pefmax,so2,co,o3,no2,tmax,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec".split(',')]
    dpc=dp;
    axes = scatter_matrix(dpc, alpha=0.2, diagonal='kde', figsize=(13, 10)); # diagonal can be 'hist';

    corr = dpc.corr().as_matrix()
    for i, j in zip(*plt.np.triu_indices_from(axes, k=1)):
        axes[i, j].annotate("%.3f" %corr[i,j], (0.8, 0.8), xycoords='axes fraction', ha='center', va='center')
    #plt.show()

# %%
def run_reg(X,y,reg_class,printDebug = False , reg=None, scaler = None):
    # Construct a kfolds object
    kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
    y_pred = y.copy()

    # Iterate through folds\
    i = 0;
    for train_index, test_index in kf.split(X):
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        # Initialize a classifier with key word arguments
        clf = reg_class(**kwargs) if (reg is None)  else reg;
        if (printDebug): print ("*",i, end ="");
        reg.fit(X_train,y_train)
        y_pred[test_index] = reg.predict(X_test)
        i = i +1;
    if (printDebug): print ("*", end="");
    
    if ( scaler ):
        y1 = scaler.inverse_transform(y)
        y2 = scaler.inverse_transform(y_pred)
    else:
        y1 = y;
        y2 = y_pred;
        
    m = mean_squared_error(y1, y2)
    r  = np.corrcoef(y, y_pred)[0,1]
    r2 = r2_score(y,y_pred)
    
    return y_pred, m, r, r2, clf


import rpy2.robjects.numpy2ri
from rpy2.robjects.packages import importr
rpy2.robjects.numpy2ri.activate()
R = rpy2.robjects.r
DTW = None; #importr('dtw')
def DTW(l1,l2, keep=True):
    alignment = R.dtw(l1, l2, keep=keep)
    d = alignment.rx('distance')[0][0]
    return d

SHOW_DTW_WORKING = False;
if (SHOW_DTW_WORKING):
    from pandas_datareader.data import DataReader
    if ('f' not in globals() ):
        f = DataReader("F",  "yahoo", datetime.datetime(2000,1,1), datetime.datetime(2012,1,1))
    f_2008=f[f.index.year==2008][0:50]
    f_2009=f[f.index.year==2009][0:50]
    f_2010=f[f.index.year==2011][0:50]

    d1 = DTW(f_2008, f_2009)
    d2 = DTW(f_2008, f_2010)
    d3 = DTW(f_2009, f_2010)

    plt.figure(figsize=(25, 5))
    plt.plot(f_2008.Volume.values, marker='o', label="2008")
    plt.plot(f_2009.Volume.values, marker='s', label="2009")
    plt.plot(f_2010.Volume.values, marker='d', label="2010")
    plt.legend()

    print( d1 , '= DTW(f_2008, f_2009)' )
    print( d2 , '= DTW(f_2008, f_2010)' )
    print( d3 , '= DTW(f_2009, f_2010)' )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-552696265cf6> in <module>()
#      32
#      33
# ---> 34 import rpy2.robjects.numpy2ri
#      35 from rpy2.robjects.packages import importr
#      36 rpy2.robjects.numpy2ri.activate()
#
# /home/centos/anaconda3/lib/python3.5/site-packages/rpy2/robjects/__init__.py in <module>()
#      14 import itertools
#      15 from datetime import datetime
# ---> 16 import rpy2.rinterface as rinterface
#      17 import rpy2.rlike.container as rlc
#      18
#
# /home/centos/anaconda3/lib/python3.5/site-packages/rpy2/rinterface/__init__.py in <module>()
#      90 del(os)
#      91
# ---> 92 from rpy2.rinterface._rinterface import (baseenv,
#      93                                          emptyenv,
#      94                                          endr,
#
# ImportError: /home/centos/anaconda3/bin/../lib/libreadline.so.6: undefined symbol: PC

# %%
#POLYMINAL FEATURE PREPARATION
# Prepare data for classification

#dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

X = dp1.ix[:, dp1.columns != 'pefmax']
y = dp1.pefmax
X = X.as_matrix().astype(np.float)

##---- Polynomial features
poly=1
p = PolynomialFeatures(poly)
o = p.fit_transform(X)
X = o

# %%
def score(y_true,y_pred): 
    mse = mean_squared_error(y_true, y_pred)
    r2  = r2_score(y_true, y_pred)
    dtw = DTW(y_true, y_pred)
#    print("MSE: {} R2: {}".format(mse,r2))
    score = mse
    score = r2;
    return score

def myscorer():
    return make_scorer(score, greater_is_better=True) # change for false if using R2
#    return make_scorer(score, greater_is_better=False) # change for false if using MSE


def GridSearch(clf, X,y,param_grid, cv=5, scorer=None):
    clfs = "Grid search on {} ".format(str(clf)[0:20] + "..." + str(clf)[-10]) 
    print ("Grid search on: ", clfs)
    #cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
    grid = GridSearchCV(clf, param_grid=param_grid, cv=cv, scoring=scorer)
    grid.fit(X, y)

    print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))
    return grid


RunGridSearch = False

if ( RunGridSearch ):
#    C_range = np.logspace(-2, 10, 13)
#    gamma_range = np.logspace(-9, 3, 5)
#    param_grid = dict(gamma=gamma_range, C=C_range)
#    GridSearch(SVR(), X,y, param_grid, cv=5)
    
#    param_grid = dict(alpha=np.linspace(0.01, 5000, 100));
#    grid = GridSearch(Ridge(random_state=0), X,y, param_grid, cv=5, scorer= myscorer())
    
    param_grid = dict(alpha=np.linspace(.5, 5, 10), gamma=np.linspace(0.01, 1, 10), degree=[1,2,3,4,5,6,7,8], kernel=['rbf','linear']);
    grid = GridSearch(    KernelRidge(kernel='rbf'), X,y, param_grid, cv=5) #, scorer= myscorer())
    
#    param_grid = dict(max_depth=range(10,50), max_features= ['auto', 'sqrt', 'log2'], n_estimators=[10,20,30,40] );
#    GridSearch(RandomForestRegressor(random_state=10), X,y, param_grid, cv=5)

else:
    prev = '''
Grid search SVR
The best parameters are {'C': 1.0, 'gamma': 1000.0} with a score of -0.19

RIDGE: I did scoring on DTW and alpha=50 seems good 

    Grid search on:  Grid search on Ridge(alpha=1.0, cop...t 
    The best parameters are {'alpha': 50.514949494949491} with a score of -74.02
    
    For MSE and R2, higher alpha is favaoured

'''
    print ('Previous results are:\n', prev)

# %%
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.05, 'loss': 'quantile', 'alpha':.95}
clfs = [
    ensemble.GradientBoostingRegressor(**params),
    ensemble.GradientBoostingRegressor(loss='quantile', alpha=.95,
                                n_estimators=250, max_depth=5,
                                learning_rate=.1, min_samples_leaf=9,
                                min_samples_split=9),
    DecisionTreeRegressor(max_depth=2), 
    DecisionTreeRegressor(max_depth=15),
    linear_model.LinearRegression(),
    RandomForestRegressor(max_depth=50, random_state=0),
#    AdaBoostRegressor(),
    Lasso(alpha=20000, max_iter=1e5),
    Lasso(alpha=0.5, max_iter=1e5),
    Ridge(alpha=50),
    Ridge(alpha=500),

#    GaussianProcess(corr='squared_exponential', theta0=1e-1, thetaL=1e-3, thetaU=1,random_start=100),
#    GaussianProcess( theta0=1e-1, thetaL=1e-3, thetaU=1,random_start=100),

    KernelRidge(kernel='rbf', degree=1,gamma=1.1, alpha=5),
    KernelRidge(kernel='rbf', gamma=0.1),
    KernelRidge(kernel='rbf', gamma=0.1, alpha = 0.1),
    
    SVR(kernel='rbf', C=1, gamma=1000),
    SVR(kernel='linear', C=500),
    SVR(kernel='poly', C=1, degree=2)  ,
]
rclfs={}
dpB= dp.copy()
rclfs

# %%
# This is to experiment with 2,3,4and 5 days of exposure
rclfs={}
dp5= dpB  # <= This has 5 days of exposure
dp4= dp5.select(lambda x: not re.search('.*_5combined', x), axis=1)
dp3= dp4.select(lambda x: not re.search('.*_4combined', x), axis=1)
dp2= dp3.select(lambda x: not re.search('.*_3combined', x), axis=1)
dp0= dp2.select(lambda x: not re.search('.*_2combined', x), axis=1)

dp = dp0 # <== Choose whichever dataset you need here
dp

# %%
rclfs={}
plt.figure(figsize=(25, 8))
h1, h2 =-100, None
#h1, h2 =500, 550
plt.plot(dp.index[h1:h2], y[h1:h2], label='original PEF', linewidth=3)


for i, r in enumerate(clfs):
    d1 = datetime.datetime.now()
    print ("+Run Start {:2} {} : {}".format(i, d1, str(r)[0:25]) , end=' ')
    
    if ( rclfs.get(str(r)) is not None ):
        yp, mse, clf, r, r2, dur = rclfs[str(r)] 
        print ("EXISTS: using MSE: {} ".format(str(r)[0:15]), mse, end=' ')
    else:
        yp, mse,r, r2, clf = run_reg(X,y, None, True, r, Y_SCALER)
        d2 = datetime.datetime.now()
        dur = d2 -d1;
        dur = dur - datetime.timedelta(microseconds=dur.microseconds)
        rclfs[str(clf)]=(yp, mse, (clf), r, r2, dur ) 
    
    l='{} MSE {:07.2f} r: {:3.2f} R^2: {:3.2f} {} '.format( str(clf)[0:5]+'..'+str(clf)[-5], mse, r, r2, str(dur) ) 
    print('-', l)
    
    plt.plot(dp.index[h1:h2], yp[h1:h2], label=l )
    #if ( i > 11):
    #    break;

plt.legend()

# %%
rdf = pd.DataFrame.from_dict(rclfs, orient='index')
rdf.columns = 'y_pred,mse,clf,r,R2,time_to_run'.split(',')
rdf.insert(1,'DTW',0)
rdf.insert(3,'sum',0)
#rdf.clf=rdf.clf.astype(str)
rdf['DTW'] = 0; #rdf.y_pred.apply(lambda x: DTW(x,y))
rdf['sum'] = rdf.y_pred.apply(sum)
rdf= rdf.sort('R2,DTW,mse,sum'.split(','), ascending=[0,1,1,1])
HTML(rdf.to_html())

# %%
#Lets print individual results
h1=-120
h2=None
for i, r in enumerate(rdf.iterrows()):
    clf = str(r[1][4]);
    mse = r[1][2]
    dtw = r[1][1]
    dur = r[1][-1]
    R2  = r[1][6]
    l='[ {} ] : MSE:{:07.2f} DTW:{:07.2f} {} {}'.format( str(clf)[0:17]+'..'+str(clf)[-10], mse, dtw, str(dur), poly)
    l='[ {} ] : R2: {:4.2} MSE:{:7.2f} DTW:{:7.2f}'.format( str(clf)[0:17]+'..'+str(clf)[-10], R2, mse, dtw)
    plt.figure(figsize=(25, 5))
    plt.plot(dp.index[h1:h2], y[h1:h2], label='original PEF', linewidth=3)
    plt.plot(dp.index[h1:h2], r[1][0][h1:h2], linewidth=1, label=l)
    plt.legend()
    
    
    plt.show()

# %%
axes = scatter_matrix(rdf, alpha=0.2, diagonal='hist', figsize=(13, 10)); # diagonal can be 'hist';

# %%
r1 = rdf[rdf.mse <= 1600]

plt.figure(figsize=(6, 6))
plt.scatter(r1.mse, r1.DTW)
plt.grid()
plt.xlabel("MSE")
plt.ylabel("DTW")

# %%
'''
POlynomial degree 1 has the following results

GradientBoostingRegressor  MSE 2470.60 r: 0.19  R^2: -2.22 0:00:03 
GradientBoostingRegressor  MSE 1575.88 r: 0.24  R^2: -1.05 0:00:01 
DecisionTreeRegressor(cri  MSE 0758.55 r: 0.20  R^2: 0.01 0:00:00 
DecisionTreeRegressor(cri  MSE 1241.32 r: 0.22  R^2: -0.62 0:00:00 
LinearRegression(copy_X=T  MSE 0699.95 r: 0.31  R^2: 0.09 0:00:00 
RandomForestRegressor(boo  MSE 0759.59 r: 0.27  R^2: 0.01 0:00:00 
Lasso(alpha=20000, copy_X  MSE 0769.67 r: -0.06 R^2: -0.00 0:00:00 
Lasso(alpha=0.5, copy_X=T  MSE 0770.17 r: -0.07 R^2: -0.00 0:00:00 
Ridge(alpha=50, copy_X=Tr  MSE 0693.19 r: 0.31  R^2: 0.10 0:00:00 
Ridge(alpha=500, copy_X=T  MSE 0712.64 r: 0.28  R^2: 0.07 0:00:00 
KernelRidge(alpha=1, coef  MSE 0685.84 r: 0.34  R^2: 0.11 0:00:00 
SVR(C=1, cache_size=200,   MSE 0777.55 r: -0.12 R^2: -0.01 0:00:00 
SVR(C=500, cache_size=200  MSE 0927.78 r: 0.29  R^2: -0.21 0:00:12 


POLYNOMIAL Degree 2:
GradientBoostingRegressor  MSE 3389.86 r: 0.03  R^2: -3.41 0:00:22 
GradientBoostingRegressor  MSE 1753.38 r: 0.21  R^2: -1.28 0:00:13 
DecisionTreeRegressor(cri  MSE 0785.32 r: 0.13  R^2: -0.02 0:00:00 
DecisionTreeRegressor(cri  MSE 1242.66 r: 0.16  R^2: -0.62 0:00:00 
LinearRegression(copy_X=T  MSE 2300.86 r: 0.14  R^2: -2.00 0:00:00 
RandomForestRegressor(boo  MSE 0759.73 r: 0.26  R^2: 0.01  0:00:01 
Lasso(alpha=20000, copy_X  MSE 0773.09 r: -0.11 R^2: -0.01 0:00:00 
Lasso(alpha=0.5, copy_X=T  MSE 0773.62 r: -0.11 R^2: -0.01 0:00:00 
Ridge(alpha=50, copy_X=Tr  MSE 0719.43 r: 0.29  R^2: 0.06  0:00:00 
Ridge(alpha=500, copy_X=T  MSE 0708.72 r: 0.28  R^2: 0.08  0:00:00 
KernelRidge(alpha=1, coef  MSE 0757.13 r: 0.13  R^2: 0.01  0:00:00 
SVR(C=1, cache_size=200,   MSE 0776.06 r: -0.08 R^2: -0.01 0:00:00 
SVR(C=500, cache_size=200  MSE 3380.81 r: 0.10  R^2: -3.40 0:00:01 

'''


'results of combined sum of exposure for 2,3,4,5 days'

'''
-
'''
