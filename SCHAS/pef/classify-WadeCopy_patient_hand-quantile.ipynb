# %%
# %run "../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB


patient="hand2"
ampm="pm"
file="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20calculated_jlee%20WHERE%20ampm=%27"+ampm+"%27%20AND%20pname=%27"+patient+"%27%20ORDER%20BY%20date,%20time"

predictQuantile=True
lowerPercent = 0.20
upperPercent = 0.20

fileName = file;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
#displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
dfOriginal
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff
# 0    hand2  2015-01-02   pm  17:30:00  263        Y     23.067    0.006   0.900   0.026    0.035    54.000    0.088  13.590   0.388    0.404   647.867    0.004   0.589   0.017    0.018    28.087        -2.500        2.500        290.000                33.000             1.700               -16.600        1021.700             1026.100              -3.000           -0.800         1022.200             68.000           -8.300         1019.900             31.000             7.500             2.300              37.000
# 1    hand2  2015-01-03   pm  18:15:00  265        Y     24.750    0.013   1.000   0.018    0.039    54.000    0.172  19.000   0.222    0.718   949.250    0.007   0.768   0.009    0.029    38.354         1.200        1.500        160.000                60.000             4.000                -5.700        1017.100             1021.400              -1.000            1.900         1023.400             71.000           -9.600         1017.100             33.000            11.500             6.300              38.000
# 2    hand2  2015-01-04   pm  18:05:00  269        Y     23.833    0.009   1.200   0.021    0.055    71.000    0.147  17.317   0.160    0.862   904.750    0.006   0.727   0.007    0.036    37.962         3.400        0.800        270.000                76.000             5.900                -0.400        1014.400             1018.700              -0.100            7.600         1017.100             76.000            0.200         1012.900             59.000             7.400             4.200              17.000
# 3    hand2  2015-01-05   pm  18:09:00  249        Y     24.067    0.015   1.300   0.008    0.069   109.000    0.166  25.268   0.069    1.316  1750.000    0.007   1.050   0.003    0.055    72.715         6.800        0.000          0.000                56.000             5.600                -1.300        1010.400             1014.600               0.100            9.100         1017.500            100.000           -2.800         1010.400             48.000            11.900             7.100              52.000
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...
# 652  hand2  2016-10-15   pm  17:52:00  298        G     23.800    0.005   1.100   0.045    0.065   108.000    0.086  19.393   0.301    1.046  1987.333    0.004   0.815   0.013    0.044    83.501        23.200        0.900         20.000                44.000            12.400                10.200        1019.300             1023.200              19.700           26.100         1023.500            100.000           11.200         1019.300             35.000            14.900             4.200              65.000
# 653  hand2  2016-10-16   pm  19:08:00  298        G     25.267    0.004   1.100   0.028    0.059    78.000    0.093  17.133   0.295    0.942  1527.533    0.004   0.678   0.012    0.037    60.456        16.300        0.700         70.000                98.000            18.100                15.900        1013.100             1017.100              16.700           23.200         1020.100            100.000           16.200         1013.100             44.000             7.000             7.000              56.000
# 654  hand2  2016-10-17   pm  18:21:00  260        Y     23.217    0.004   0.700   0.055    0.037    72.000    0.059  13.430   0.359    0.652  1233.783    0.003   0.578   0.015    0.028    53.142        18.200        2.500        270.000                80.000            16.600                14.600        1013.800             1017.800              17.600           22.400         1014.600            100.000           14.700         1012.600             55.000             7.700             2.000              45.000
# 655  hand2  2016-10-18   pm  18:01:00  281        Y     23.667    0.006   0.900   0.032    0.064    86.000    0.086  13.802   0.315    0.725  1337.400    0.004   0.583   0.013    0.031    56.510        17.000        0.000          0.000                83.000            16.000                14.000        1015.000             1019.000              16.000           20.800         1018.100            100.000           11.000         1013.800             61.000             9.800             4.300              39.000
#
# [656 rows x 40 columns]

# %%
#Break into groups by percentage

dfOriginal.sort_values(by='pef', ascending=True, inplace=True)
dfOriginal.reset_index(drop=True, inplace=True)
numberOfElements = len(dfOriginal)
upperBoundary = upperPercent*numberOfElements
lowerBoundary = lowerPercent*numberOfElements
dfOriginal['percent_group']=-1

for i in dfOriginal.index:

    if i < lowerBoundary:
        dfOriginal['percent_group'][i] = 0

    elif i > upperBoundary : 
        dfOriginal['percent_group'][i] = 2

    else:
        dfOriginal['percent_group'][i] = 1

print(dfOriginal)
# Out:
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff  percent_group
# 0    hand2  2015-03-22   pm  18:11:00  180        R     23.367    0.016   1.100   0.064    0.075   264.000    0.160  18.257   0.625    0.902  3699.850    0.007   0.781   0.027    0.039   158.339         7.900        5.100        270.000                49.000             5.200                -2.100        1017.000             1021.200               6.600           15.000         1017.400            100.000            2.100         1009.800             25.000            12.900             7.600              75.000              0
# 1    hand2  2016-10-03   pm  18:45:00  185        Y     24.500    0.004   0.500   0.042    0.027    28.000    0.067   9.375   0.512    0.336   403.250    0.003   0.383   0.021    0.014    16.459        23.400        2.200        270.000                78.000            22.400                19.300        1006.700             1010.600              22.200           27.700         1007.100            100.000           17.400         1003.200             54.000            10.300             3.900              46.000              0
# 2    hand2  2016-08-10   pm  18:37:00  187        Y     23.450    0.005   0.600   0.072    0.033    98.000    0.094  11.008   1.246    0.485  1409.417    0.004   0.469   0.053    0.021    60.103        31.000        3.400        270.000                58.000            26.000                21.700        1005.200             1009.000              33.500           34.000         1007.000             99.000           25.500         1003.800             47.000             8.500             3.200              52.000              0
# 3    hand2  2016-07-19   pm  20:18:00  191        Y     25.367    0.004   0.600   0.118    0.038    65.000    0.073  12.247   0.911    0.708   962.933    0.003   0.483   0.036    0.028    37.961        28.600        1.600        290.000                68.000            26.600                22.100        1006.500             1010.300              26.600           32.800         1008.200            100.000           20.000         1005.500             50.000            12.800             2.700              50.000              0
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...            ...
# 652  hand2  2015-01-29   pm  18:09:00  344        G     24.033    0.007   1.400   0.008    0.056    83.000    0.127  23.150   0.067    1.131  1250.650    0.005   0.963   0.003    0.047    52.038         1.700        1.700        290.000                56.000             3.900                -6.100        1021.000             1025.300               0.000            3.600         1025.900             79.000           -4.800         1020.600             52.000             8.400             5.300              27.000              2
# 653  hand2  2015-01-24   pm  18:05:00  347        G     18.583    0.011   1.100   0.034    0.050    74.000    0.132  16.158   0.264    0.678   883.917    0.007   0.870   0.014    0.036    47.565         4.400        1.000        270.000                64.000             5.400                -1.800        1022.700             1027.000               0.000            7.600         1022.700             80.000            1.100         1019.400             50.000             6.500             3.300              30.000              2
# 654  hand2  2015-01-30   pm  18:26:00  353        G     24.283    0.008   1.000   0.031    0.048    64.000    0.115  19.797   0.392    0.644  1069.433    0.005   0.815   0.016    0.027    44.040        -1.200        2.400        290.000                44.000             2.500               -11.900        1021.900             1026.300              -0.300            1.700         1022.200             62.000           -2.800         1020.200             36.000             4.500             2.000              26.000              2
# 655  hand2  2015-01-27   pm  18:10:00  356        G     23.917    0.006   1.100   0.030    0.030    79.000    0.117  18.758   0.560    0.463  1283.250    0.005   0.784   0.023    0.019    53.655        -2.200        2.600        320.000                41.000             2.100               -13.700        1020.800             1025.200              -0.400            3.700         1021.800             90.000           -3.600         1016.100             36.000             7.300             5.700              54.000              2
#
# [656 rows x 41 columns]

# %%
df=dfOriginal.copy()

#1. Remove all the rows that does not have any pef values 

df=df.reset_index(drop=True)

#2. Combine 
df=df.fillna(0)
sdttm = df.date + " " + df.time
df.insert(0, 'sdttm', sdttm)
df.sdttm = pd.to_datetime(df.sdttm)

df.sort_values(by='sdttm', ascending=True, inplace=True)
alldrps = "cname, pname, date, time, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, temperature_diff, airpressure_diff, precipitation_diff, tm_window"
if predictQuantile:
    alldrps += ', pef_zone'
else:
    alldrps += ', percent_group'
drps  = alldrps.split(', ')
df=df.drop(drps, axis=1, errors='ignore')
df=df.reset_index(drop=True)

## <== do the following for SAP PA tool
#pef = df.pef;
#df=df.drop(['pef'], axis=1)
#df.insert(1, 'pef1', pef)

#pef[-10:]=0     # Set last 10 to zero for predictions
#df.insert(1, 'pef', pef)
#df.to_csv("HanD/hand1.csv", sep=';')

df1 = df.copy()
df1 = df1.set_index(df1.sdttm)
df1=df1.drop('sdttm', axis=1, errors='ignore')

nq = 5
lnq=list(range(0,nq))
s= pd.qcut(df1.pef, nq, labels=lnq )
df1.insert(1,"pefcat", s)
df1.pefcat = df1.pefcat.astype(str)

pefcol = df1['pef']





columns =  '''so2_max,co_max,o3_max,no2_max,pm10_max,so2_sum,co_sum,o3_sum,no2_sum,pm10_sum,so2_avg,co_avg,o3_avg,no2_avg,pm10_avg,temperaturec,windspeedms,winddirection,precipitationpercent,vaporpressurehpa,dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,
 temperature_max,airpressure_max,precipitation_max,temperature_min,airpressure_min,precipitation_min'''
if predictQuantile:
    columns += ',percent_group'
else:
    columns += ',pef_zone'

#'''pefcat,pef_zone,so2_max,co_max,o3_max,no2_max,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
#dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,temperature_max,airpressure_max,temperature_min'''

 
#amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
cs = [c.strip() for c in columns.split(',')]

df1=df1[cs]
#HTML(df1.to_html())
#displayDFs (df1, maxrows=3 )
df1
# Out:
#                      so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  percent_group
# sdttm
# 2015-01-02 17:30:00    0.006   0.900   0.026    0.035    54.000    0.088  13.590   0.388    0.404   647.867    0.004   0.589   0.017    0.018    28.087        -2.500        2.500        290.000                33.000             1.700               -16.600        1021.700             1026.100              -3.000           -0.800         1022.200             68.000           -8.300         1019.900             31.000              2
# 2015-01-03 18:15:00    0.013   1.000   0.018    0.039    54.000    0.172  19.000   0.222    0.718   949.250    0.007   0.768   0.009    0.029    38.354         1.200        1.500        160.000                60.000             4.000                -5.700        1017.100             1021.400              -1.000            1.900         1023.400             71.000           -9.600         1017.100             33.000              2
# 2015-01-04 18:05:00    0.009   1.200   0.021    0.055    71.000    0.147  17.317   0.160    0.862   904.750    0.006   0.727   0.007    0.036    37.962         3.400        0.800        270.000                76.000             5.900                -0.400        1014.400             1018.700              -0.100            7.600         1017.100             76.000            0.200         1012.900             59.000              2
# 2015-01-05 18:09:00    0.015   1.300   0.008    0.069   109.000    0.166  25.268   0.069    1.316  1750.000    0.007   1.050   0.003    0.055    72.715         6.800        0.000          0.000                56.000             5.600                -1.300        1010.400             1014.600               0.100            9.100         1017.500            100.000           -2.800         1010.400             48.000              2
# ...                      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...            ...
# 2016-10-15 17:52:00    0.005   1.100   0.045    0.065   108.000    0.086  19.393   0.301    1.046  1987.333    0.004   0.815   0.013    0.044    83.501        23.200        0.900         20.000                44.000            12.400                10.200        1019.300             1023.200              19.700           26.100         1023.500            100.000           11.200         1019.300             35.000              2
# 2016-10-16 19:08:00    0.004   1.100   0.028    0.059    78.000    0.093  17.133   0.295    0.942  1527.533    0.004   0.678   0.012    0.037    60.456        16.300        0.700         70.000                98.000            18.100                15.900        1013.100             1017.100              16.700           23.200         1020.100            100.000           16.200         1013.100             44.000              2
# 2016-10-17 18:21:00    0.004   0.700   0.055    0.037    72.000    0.059  13.430   0.359    0.652  1233.783    0.003   0.578   0.015    0.028    53.142        18.200        2.500        270.000                80.000            16.600                14.600        1013.800             1017.800              17.600           22.400         1014.600            100.000           14.700         1012.600             55.000              2
# 2016-10-18 18:01:00    0.006   0.900   0.032    0.064    86.000    0.086  13.802   0.315    0.725  1337.400    0.004   0.583   0.013    0.031    56.510        17.000        0.000          0.000                83.000            16.000                14.000        1015.000             1019.000              16.000           20.800         1018.100            100.000           11.000         1013.800             61.000              2
#
# [656 rows x 31 columns]

# %%
# from sklearn.neural_network import MLPClassifier
# nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)

# clf = nn;

# Y_SCALER = None
# #Normalize the input and save the scalar for outcome variable "pefmax" in this case.
# scaler = StandardScaler()
# dp = prepareDF(df1, True)
# for c in dp.columns:
#     if ( c == 'pefcat'):
#         #Y_SCALER = StandardScaler()
#         #dp[c] = Y_SCALER.fit_transform(dp[c])
#         pass;
#     else:
#         dp[c] = scaler.fit_transform(dp[c])
        
# #dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
# dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

# X = dp1.ix[:, dp1.columns != 'pefcat']
# y = dp1.pefcat 
# X = X.as_matrix().astype(np.float)


# kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
# y_pred = y.copy()

# # Iterate through folds\
# i = 0;
# for train_index, test_index in kf.split(X):
#     #print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train = y[train_index]
#     # Initialize a classifier with key word arguments\
#     print ("*",i, end ="");
#     clf.fit(X_train,y_train)
#     y_pred[test_index] = clf.predict(X_test)
#     i = i +1;

# %%
from sklearn.naive_bayes import GaussianNB

predictColumn = "pefcat"
predictColumn = "pef_zone"
if predictQuantile:
    predictColumn = "percent_group"

if ( 'pefcat' in df1.columns ):
    df1.pefcat = df1.pefcat.astype(int)
    df1=df1.drop('pefcat', axis=1)

cls = [# Comment/uncomment out any classfiers according to your need 
       # DO NOT CHANGE
#        "DecisionTree Gini" , tree.DecisionTreeClassifier(max_depth=4, criterion="gini"),
#       "DecisionTree Entr" , tree.DecisionTreeClassifier(max_depth=4, criterion="entropy"), 
#       "SVM"               , sklearn.svm.SVC(kernel="linear"), 
#        "SVM1"              , SVC(kernel="rbf", C=10**3),
#        "Random Forest"     , sklearn.ensemble.RandomForestClassifier(),
#        "K-NN"              , sklearn.neighbors.KNeighborsClassifier(),
#        "Gradient Boosting" , sklearn.ensemble.RandomForestClassifier(),
        "Logit Regression"  ,  sklearn.linear_model.LogisticRegression(),
#        "Neural NW"         , MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(25, 10), random_state=1),
#        "Naive Bayes"       , GaussianNB()
];

y = df1[predictColumn]
X = df1.drop(predictColumn, axis=1)
a = Classify(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=True)
ik = 0
y_preds=[]
clsNames=[]


for i in cls:
    if type(i) is str:
        clsNames.append(i)
        y_pred = a[4][i]
        y_preds.append(y_pred)
        target_names = ['class 0', 'class 1', 'class 2']
        print(i + ' Metrics')
        y.replace(to_replace="R", value=0, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="Y", value=1, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="G", value=2, inplace=True, limit=None, regex=False, method='pad', axis=None)
        print(classification_report(y, y_pred, target_names=target_names))
# Out:
# Feature space holds 656 observations and 30 features
# Unique target labels: [2 0]
# * 0* 1* 2* 3* 4*
#     Logit Regression accuracy: 0.778963
#     Logit Regression r^2 score: -0.375202
# Logit Regression Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00       132
#     class 1       0.00      0.00      0.00         0
#     class 2       0.00      0.00      0.00       524
#
# avg / total       0.00      0.00      0.00       656

# %%
#(X1,y1,ra,cls) = Classify1(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=False)
DrawDecisionTree(X,y, cls[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-823f96694b09> in <module>()
#       1 #(X1,y1,ra,cls) = Classify1(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=False)
# ----> 2 DrawDecisionTree(X,y, cls[1])
#
# /opt/SCHAS/git/Notebooks/PyUtils/Jupytils/Classification.py in DrawDecisionTree(X, y, cls, class_names)
#     329         visualizeTree(cls, X.columns, class_names=class_names)
#     330     else:
# --> 331         for k in range(int( len(cls)/2) ) :
#     332             dcls = cls[k*2+1];
#     333             if (str(type(dcls)).find('DecisionTreeClassifier') > 0):
#
# TypeError: object of type 'LogisticRegression' has no len()

# %%
import matplotlib.pyplot as plt
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (6, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'}

plt.rcParams.update(params)
#plt.savefig('hand2.eps')


#print(size(pefcol.values))
#print(size(y))
#print(y_pred)

plt.plot(pefcol.index[y == 0],pefcol.values[y == 0],'r.',pefcol.index[y == 1],pefcol.values[y == 1],'y.',pefcol.index[y == 2],pefcol.values[y == 2],'g.')

#plt.xlabel('date', fontsize=12)
#plt.ylabel('PEF', fontsize=12)
#plt.title('PEF real data',fontsize=14)
plt.xlabel('date')
plt.ylabel('PEF')
#plt.title('(a) PEF data of Subject A')
plt.grid(True)


plt.savefig('hand2.eps')

plt.show()

i=0

for ypredicted in y_preds:
        plt.plot(pefcol.index[ypredicted == 0],pefcol.values[ypredicted == 0],'y.',pefcol.index[ypredicted == 1],pefcol.values[ypredicted == 1],'g.')

        plt.xlabel('date')
        plt.ylabel('pef')
        plt.title('PEF prediction ' + clsNames[i])
        plt.grid(True)
        plt.show()
        i+=1
