# %%
# %run "../../PyUtils/common.ipynb"

f1="P1_HanD_Ver1_2015_15122015_PMPEF.xlsx"
df1 = LoadDataSet(f1, sheetname=2);
#f1="P1_HanD_Ver1_2015_22112015_AMPEF.xlsx";
#dfOrginal1 = LoadDataSet(f1);
df1=df1[11:]
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
#
# div#notebook{
#     font-size: 12px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
# ...

# %%
df1[108:]
# Out:
#     Unnamed: 0           Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4           Unnamed: 5           Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31          Unnamed: 32
# 119        109  2015-04-19 00:00:00          0  2015-04-18 00:00:00   18:47:00  2015-04-19 00:00:00  2016-12-14 18:20:00        NaN      0.103     17.300       0.344       1.134         928      19.700    1008.800         100          12     999.800          27      14.600    1007.700         100       7.700           9          73      14.600     999.800         100          nan           1         248           Y  2015-04-19 00:00:00
# ...

# %%
X=np.random.rand(6,3)
y=np.random.rand(6,1)
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train = y[train_index]
    #
    #print (X_train, y_train)
    print (train_index, test_index)
# Out:
# [2 3 4 5] [0 1]
# [0 1 3 4 5] [2]
# [0 1 2 4 5] [3]
# [0 1 2 3 5] [4]
# [0 1 2 3 4] [5]

# %%
kf = sklearn.cross_validation.KFold(len(y),n_folds=5,shuffle=True)
y_pred = y.copy()

# Iterate through folds\
i = 0;
for train_index, test_index in kf:
    X_train, X_test = X[train_index], X[test_index]
    y_train = y[train_index]
    
    print (X_train, y_train)
    #print (train_index, test_index)
# Out:
# [[ 0.26  0.49  0.53]
#  [ 0.11  0.21  0.34]
#  [ 0.47  0.73  0.72]
#  [ 0.28  0.69  0.06]] [[ 0.37]
#  [ 0.63]
#  [ 0.63]
#  [ 0.08]]
# [[ 0.26  0.49  0.53]
#  [ 0.11  0.21  0.34]
#  [ 0.73  0.23  0.45]
#  [ 0.83  0.86  0.93]
#  [ 0.28  0.69  0.06]] [[ 0.37]
#  [ 0.63]
#  [ 0.31]
#  [ 0.9 ]
#  [ 0.08]]
# [[ 0.26  0.49  0.53]
#  [ 0.73  0.23  0.45]
#  [ 0.83  0.86  0.93]
#  [ 0.47  0.73  0.72]
#  [ 0.28  0.69  0.06]] [[ 0.37]
#  [ 0.31]
#  [ 0.9 ]
#  [ 0.63]
#  [ 0.08]]
# [[ 0.26  0.49  0.53]
#  [ 0.11  0.21  0.34]
#  [ 0.73  0.23  0.45]
#  [ 0.83  0.86  0.93]
#  [ 0.47  0.73  0.72]] [[ 0.37]
#  [ 0.63]
#  [ 0.31]
#  [ 0.9 ]
#  [ 0.63]]
# [[ 0.11  0.21  0.34]
#  [ 0.73  0.23  0.45]
#  [ 0.83  0.86  0.93]
#  [ 0.47  0.73  0.72]
#  [ 0.28  0.69  0.06]] [[ 0.63]
#  [ 0.31]
#  [ 0.9 ]
#  [ 0.63]
#  [ 0.08]]
