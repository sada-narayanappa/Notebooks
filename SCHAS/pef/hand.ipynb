# %%
try:       importlib.reload(Jupytils)
except:    import Jupytils
from Jupytils.Charts import *;
showTopbar("Markov Chain Asthma Prediction")

from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
#from statsmodels.regression.quantile_regression import QuantReg
#import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

han1="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20patient_data_table";
hand="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20hand"
kimj="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kimj";
leeh="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20leeh";
sony="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20sony";
kuky="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20kuky";

fileName = hand;

patient="hand2"
hand2="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20calculated_jlee%20WHERE%20pname=%27"+patient+"%27%20ORDER%20BY%20date,%20time"
fileName = hand2;


proxies={'http':None, 'https':None}
dfOriginal = LoadDataSet(fileName, checkForDateTime=False, proxies=proxies);
displayDFs (dfOriginal, maxrows=3 );
#for c in dfOriginal.columns: print (c,  end=', ')
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>
# <script src="http://d3js.org/d3.v3.min.js"></script>
#
# <textarea rows=5 id=sada_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
#
# </style>
#
# <div id='HTMLTopBar' style="
#     pposition: fixed;
#     pposition: absolute;
#     z-index: 50;
#     right: 0;
#     top: 0;
#     align-items: stretch;
#     width:100%">
#
#     <div  style=
#         "background-color:#4285f4!important;
#         box-shadow: 2px 1px 1px #888888;
#         height: 50px; left: 0;
#         padding: 14px 12px;
#         z-index: 50;
#         -webkit-backface-visibility: hidden;
#         -webkizt-transform: translateZ(0);
#         -ms-flex-align: center;
#         -webkit-align-items: center;
#         align-items: center;
#         -webkit-flex-direction: row;
#         -ms-flex-direction: row;
#         flex-direction: row;
#         color:white;
#         font-family: 'Roboto','Heebo',Arial,sans-serif;
#         display: block;
#         "
#     >
#     <iimg style="display:inline;" align="baseline" width=32 src="../imgs/ham1.png" />
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#
#
#     <font style="font-size:1.5em; display:inline;">Markov Chain Asthma Prediction</font>
#     <div style="text-align: right;display: block;color:white;float:right;width=50%">
#     <a class="bh" style="" href="#" "> &raquo; Help </a> &nbsp;
# <a class="bh" style="" href="#" "> &raquo; Home </a> &nbsp;
#
#     </div>
#
#     </div>
# </div>
# </textarea>
#
# <script>
# if ($('#sada_head').length < 1) {
#     $('body').prepend('<div id="sada_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
#
# $('#sada_head').html($('#sada_head_content').val())
#
# </script>
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>1313 rows x 40 columns var: DFF_PY_VAR_tableID_1512711365298<br>
# <div id='tab_tableID_1512711365298' style='ddisplay:none;width:100%' >
#             <table id='tableID_1512711365298' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr><td style='text-align: ceter;'></td >
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-pname.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-pname.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 1 </td><td>top : hand2 </td><td>freq : 1313 </td></tr></table>
# </span></a></td><td align=center></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-ampm.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-ampm.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 2 </td><td>top : am </td><td>freq : 657 </td></tr></table>
# </span></a></td><td align=center></td>
# <td align=center>int64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-pef.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-pef.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 267.06 </td><td>std : 29.50 </td><td>min : 180.00 </td></tr><tr><td>25% : 246.00 </td><td>50% : 268.00 </td><td>75% : 288.00 </td><td>max : 356.00 </td></tr></table>
# </span></a></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-pef_zone.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-pef_zone.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 3 </td><td>top : Y </td><td>freq : 1084 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-tm_window.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-tm_window.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 23.95 </td><td>std : 1.03 </td><td>min : 18.58 </td></tr><tr><td>25% : 23.58 </td><td>50% : 24.00 </td><td>75% : 24.30 </td><td>max : 29.27 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-so2_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-so2_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.01 </td><td>std : 0.00 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.01 </td><td>50% : 0.01 </td><td>75% : 0.01 </td><td>max : 0.04 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-co_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-co_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.80 </td><td>std : 0.27 </td><td>min : 0.30 </td></tr><tr><td>25% : 0.60 </td><td>50% : 0.70 </td><td>75% : 0.90 </td><td>max : 1.90 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-o3_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-o3_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.05 </td><td>std : 0.02 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.03 </td><td>50% : 0.05 </td><td>75% : 0.07 </td><td>max : 0.12 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-no2_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-no2_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.04 </td><td>std : 0.01 </td><td>min : 0.01 </td></tr><tr><td>25% : 0.03 </td><td>50% : 0.04 </td><td>75% : 0.05 </td><td>max : 0.10 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-pm10_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-pm10_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 78.59 </td><td>std : 58.82 </td><td>min : 12.00 </td></tr><tr><td>25% : 51.00 </td><td>50% : 69.00 </td><td>75% : 93.00 </td><td>max : 924.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-so2_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-so2_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.11 </td><td>std : 0.04 </td><td>min : 0.04 </td></tr><tr><td>25% : 0.08 </td><td>50% : 0.10 </td><td>75% : 0.13 </td><td>max : 0.28 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-co_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-co_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 13.76 </td><td>std : 3.87 </td><td>min : 5.49 </td></tr><tr><td>25% : 11.19 </td><td>50% : 13.02 </td><td>75% : 15.31 </td><td>max : 30.16 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-o3_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-o3_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.59 </td><td>std : 0.30 </td><td>min : 0.04 </td></tr><tr><td>25% : 0.36 </td><td>50% : 0.56 </td><td>75% : 0.80 </td><td>max : 1.67 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-no2_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-no2_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.66 </td><td>std : 0.26 </td><td>min : 0.16 </td></tr><tr><td>25% : 0.48 </td><td>50% : 0.61 </td><td>75% : 0.82 </td><td>max : 1.81 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-pm10_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-pm10_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 1175.55 </td><td>std : 831.48 </td><td>min : 155.78 </td></tr><tr><td>25% : 762.10 </td><td>50% : 1047.47 </td><td>75% : 1419.05 </td><td>max : 16907.60 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-so2_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-so2_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.00 </td><td>std : 0.00 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.00 </td><td>50% : 0.00 </td><td>75% : 0.01 </td><td>max : 0.01 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-co_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-co_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.57 </td><td>std : 0.16 </td><td>min : 0.26 </td></tr><tr><td>25% : 0.47 </td><td>50% : 0.54 </td><td>75% : 0.64 </td><td>max : 1.25 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x10e250d30-o3_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x10e250d30-o3_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.02 </td><td>std : 0.01 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.02 </td><td>50% : 0.02 </td><td>75% : 0.03 </td><td>max : 0.07 </td></tr></table>
# </span></a></td>
# <td align=center>float64<

# %%
df=dfOriginal.copy()
df1=df
#1. Remove all the rows that does not have any pef values 
if ( 'pef' not in df.columns):
    df.insert(4, 'npt',0)
    df.insert(4, 'pef',0)
    df.npt = pd.notnull(df.pef1)*1 + pd.notnull(df.pef2)*1 + pd.notnull(df.pef3)*1
    df = df[df.npt > 0]
    df=df.reset_index(drop=True)
    df.pef = (df.pef1 + df.pef2 + df.pef3)/df.npt

    #2. Combine 
    df=df.fillna(0)
    df.loc[df.timeofday == 'null', 'timeofday'] = "00:00:00"
    sdttm = df.dateofmeasure + " " + df.timeofday 
    df.insert(0, 'sdttm', sdttm)
    df.sdttm = pd.to_datetime(df.sdttm)

    df.sort_values(by='sdttm', ascending=True, inplace=True)
    drps  = "cname, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, pef, indexpef".split(', ')
    df=df.drop(drps, axis=1, errors='ignore')
    df=df.reset_index(drop=True)

    ## <== do the following for SAP PA tool
    #pef = df.pef;
    #df=df.drop(['pef'], axis=1)
    #df.insert(1, 'pef1', pef)

    #pef[-10:]=0     # Set last 10 to zero for predictions
    #df.insert(1, 'pef', pef)
    #df.to_csv("HanD/hand1.csv", sep=';')

    df1 = df.copy()
    df1 = df1.set_index(df1.sdttm)
    df1=df1.drop('sdttm', axis=1, errors='ignore')

    s= pd.qcut(df1.pefmax, 10, labels='a1,a2,a3,a4,a5,a6,a7,a8,a9,a10'.split(','))
    df1.insert(1,"pefcat", s)
    df1.pefcat = df1.pefcat.astype(str)

    columns = '''pefmax,so2,co,o3,no2,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
    dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,tmax,amax,tmin'''
    #amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
    cs = [c.strip() for c in columns.split(',')]

    df1=df1[cs]
#HTML(df1.to_html())
displayDFs (df1, maxrows=3 );
# Out:
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>1313 rows x 40 columns var: DFF_PY_VAR_tableID_1512711497441<br>
# <div id='tab_tableID_1512711497441' style='ddisplay:none;width:100%' >
#             <table id='tableID_1512711497441' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr><td style='text-align: ceter;'></td >
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-pname.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-pname.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 1 </td><td>top : hand2 </td><td>freq : 1313 </td></tr></table>
# </span></a></td><td align=center></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-ampm.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-ampm.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 2 </td><td>top : am </td><td>freq : 657 </td></tr></table>
# </span></a></td><td align=center></td>
# <td align=center>int64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-pef.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-pef.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 267.06 </td><td>std : 29.50 </td><td>min : 180.00 </td></tr><tr><td>25% : 246.00 </td><td>50% : 268.00 </td><td>75% : 288.00 </td><td>max : 356.00 </td></tr></table>
# </span></a></td>
# <td align=center>object<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-pef_zone.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-pef_zone.png' /><br />
#  <table><tr><td>count : 1313 </td><td>unique : 3 </td><td>top : Y </td><td>freq : 1084 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-tm_window.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-tm_window.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 23.95 </td><td>std : 1.03 </td><td>min : 18.58 </td></tr><tr><td>25% : 23.58 </td><td>50% : 24.00 </td><td>75% : 24.30 </td><td>max : 29.27 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-so2_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-so2_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.01 </td><td>std : 0.00 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.01 </td><td>50% : 0.01 </td><td>75% : 0.01 </td><td>max : 0.04 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-co_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-co_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.80 </td><td>std : 0.27 </td><td>min : 0.30 </td></tr><tr><td>25% : 0.60 </td><td>50% : 0.70 </td><td>75% : 0.90 </td><td>max : 1.90 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-o3_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-o3_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.05 </td><td>std : 0.02 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.03 </td><td>50% : 0.05 </td><td>75% : 0.07 </td><td>max : 0.12 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-no2_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-no2_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.04 </td><td>std : 0.01 </td><td>min : 0.01 </td></tr><tr><td>25% : 0.03 </td><td>50% : 0.04 </td><td>75% : 0.05 </td><td>max : 0.10 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-pm10_max.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-pm10_max.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 78.59 </td><td>std : 58.82 </td><td>min : 12.00 </td></tr><tr><td>25% : 51.00 </td><td>50% : 69.00 </td><td>75% : 93.00 </td><td>max : 924.00 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-so2_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-so2_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.11 </td><td>std : 0.04 </td><td>min : 0.04 </td></tr><tr><td>25% : 0.08 </td><td>50% : 0.10 </td><td>75% : 0.13 </td><td>max : 0.28 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-co_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-co_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 13.76 </td><td>std : 3.87 </td><td>min : 5.49 </td></tr><tr><td>25% : 11.19 </td><td>50% : 13.02 </td><td>75% : 15.31 </td><td>max : 30.16 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-o3_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-o3_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.59 </td><td>std : 0.30 </td><td>min : 0.04 </td></tr><tr><td>25% : 0.36 </td><td>50% : 0.56 </td><td>75% : 0.80 </td><td>max : 1.67 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-no2_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-no2_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.66 </td><td>std : 0.26 </td><td>min : 0.16 </td></tr><tr><td>25% : 0.48 </td><td>50% : 0.61 </td><td>75% : 0.82 </td><td>max : 1.81 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-pm10_sum.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-pm10_sum.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 1175.55 </td><td>std : 831.48 </td><td>min : 155.78 </td></tr><tr><td>25% : 762.10 </td><td>50% : 1047.47 </td><td>75% : 1419.05 </td><td>max : 16907.60 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-so2_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-so2_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.00 </td><td>std : 0.00 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.00 </td><td>50% : 0.00 </td><td>75% : 0.01 </td><td>max : 0.01 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-co_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-co_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.57 </td><td>std : 0.16 </td><td>min : 0.26 </td></tr><tr><td>25% : 0.47 </td><td>50% : 0.54 </td><td>75% : 0.64 </td><td>max : 1.25 </td></tr></table>
# </span></a></td>
# <td align=center>float64<br/><a class='thumbnail' href='#thumb'>
# <img src='temp/0x111ac0ba8-o3_avg.png' border=0 style='{margins: 0;}' width=64 height=64 />
# <span><img src='temp/0x111ac0ba8-o3_avg.png' /><br />
#  <table><tr><td>count : 1313.00 </td><td>mean : 0.02 </td><td>std : 0.01 </td><td>min : 0.00 </td></tr><tr><td>25% : 0.02 </td><td>50% : 0.02 </td><td>75% : 0.03 </td><td>max : 0.07 </td></tr></table>
# </span></a></td>
# <td align=center>float64<

# %%
CREATE_ROLLING_WINDOW=False

if ( CREATE_ROLLING_WINDOW):
    for c in "so2,co,o3,no2".split(','):
        n = c+"_5combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=5)
        n = c+"_4combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=4)
        n = c+"_3combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=3)
        n = c+"_2combined";
        df1[n] = 0
        df1[n] = pd.rolling_sum(df1[c], window=2)

    df1=df1[5:]
    df1

# %%
#Outlier analysis

for c in df1.columns:
    print(c, end=', ')

Y_SCALER = None
#Normalize the input and save the scalar for outcome variable "pefmax" in this case.
scaler = StandardScaler()
dp = prepareDF(df1, True)
for c in dp.columns:
    if ( c == 'pefmax'):
        Y_SCALER = StandardScaler()
        dp[c] = Y_SCALER.fit_transform(dp[c])
    else:
        dp[c] = scaler.fit_transform(dp[c])

plt.figure(figsize=(25, 5))
dp.boxplot(rot=45);
plt.show()

REMOVE_OUTLIERS = False
if ( REMOVE_OUTLIERS ):
    dpo= dp.copy()
    #from scipy import stats
    good = dp[(np.abs(stats.zscore(df1)) <= 3).all(axis=1)]
    outl = dp[(np.abs(stats.zscore(df1)) > 3).any(axis=1)]
    #outl
    dp=good
    plt.figure(figsize=(25, 5))
    good.boxplot(rot=45);
    
    print ("OUTLIERS COUNT: {} ", len(dpo) - len(dp));
# Out:
# pname, date, ampm, time, pef, pef_zone, tm_window, so2_max, co_max, o3_max, no2_max, pm10_max, so2_sum, co_sum, o3_sum, no2_sum, pm10_sum, so2_avg, co_avg, o3_avg, no2_avg, pm10_avg, temperaturec, windspeedms, winddirection, precipitationpercent, vaporpressurehpa, dewpointtemperaturec, airpressurehpa, sealevelpressurehpa, groundtemperaturec, temperature_max, airpressure_max, precipitation_max, temperature_min, airpressure_min, precipitation_min, temperature_diff, airpressure_diff, precipitation_diff, Dropping in prepareDF -  Index(['date', 'time'], dtype='object')

# %%
plt.figure(figsize=(25, 8))
plt.rc('font', size=14)

#dp = dp[0:90]
#dp = dp["pef,so2,co,o3,no2,pm10,tmax,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec".split(',')]
#dp = dp["pef,so2,co,o3,no2,pm10,temperaturec,rainfallmm,windspeedms,vaporpressurehpa".split(',')]
#dp = dp["pef,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec,rainfallmm,windspeedms,vaporpressurehpa".split(',')]

rolmean = pd.rolling_mean(dp.pef, window=14)

plt.plot(dp.index, dp.pef, color='b', linewidth=3)
#plt.plot(dp.index, rolmean, color='r', linewidth=2, label='trend')
#plt.plot(dp.index, dp.so2)
#plt.plot(dp.index, dp.co)
#plt.plot(dp.index, dp.o3)
#plt.plot(dp.index, dp.no2)
#plt.plot(dp.index, dp.pm10)
#plt.plot(dp.index, dp.tmax)
#plt.plot(dp.index, dp.amax)
#plt.plot(dp.index, dp.pmax)

plt.legend()

# %%
PLOT_SCATTER=False
if (PLOT_SCATTER):
    c="r,g,b,c,m,y,k,w".split(",")
    #dpc = dp["pefmax,so2,co,o3,no2,tmax,so2poi,copoi,o3poi,no2poi,pm10poi,temperaturec".split(',')]
    dpc=dp;
    axes = scatter_matrix(dpc, alpha=0.2, diagonal='kde', figsize=(13, 10)); # diagonal can be 'hist';

    corr = dpc.corr().as_matrix()
    for i, j in zip(*plt.np.triu_indices_from(axes, k=1)):
        axes[i, j].annotate("%.3f" %corr[i,j], (0.8, 0.8), xycoords='axes fraction', ha='center', va='center')
    #plt.show()

# %%
def run_reg(X,y,reg_class,printDebug = False , reg=None, scaler = None):
    # Construct a kfolds object
    kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
    y_pred = y.copy()

    # Iterate through folds\
    i = 0;
    for train_index, test_index in kf.split(X):
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        # Initialize a classifier with key word arguments
        clf = reg_class(**kwargs) if (reg is None)  else reg;
        if (printDebug): print ("*",i, end ="");
        reg.fit(X_train,y_train)
        y_pred[test_index] = reg.predict(X_test)
        i = i +1;
    if (printDebug): print ("*", end="");
    
    if ( scaler ):
        y1 = scaler.inverse_transform(y)
        y2 = scaler.inverse_transform(y_pred)
    else:
        y1 = y;
        y2 = y_pred;
        
    m = mean_squared_error(y1, y2)
    r  = np.corrcoef(y, y_pred)[0,1]
    r2 = r2_score(y,y_pred)
    
    return y_pred, m, r, r2, clf


import rpy2.robjects.numpy2ri
from rpy2.robjects.packages import importr
rpy2.robjects.numpy2ri.activate()
R = rpy2.robjects.r
DTW = None; #importr('dtw')
def DTW(l1,l2, keep=True):
    alignment = R.dtw(l1, l2, keep=keep)
    d = alignment.rx('distance')[0][0]
    return d

SHOW_DTW_WORKING = False;
if (SHOW_DTW_WORKING):
    from pandas_datareader.data import DataReader
    if ('f' not in globals() ):
        f = DataReader("F",  "yahoo", datetime.datetime(2000,1,1), datetime.datetime(2012,1,1))
    f_2008=f[f.index.year==2008][0:50]
    f_2009=f[f.index.year==2009][0:50]
    f_2010=f[f.index.year==2011][0:50]

    d1 = DTW(f_2008, f_2009)
    d2 = DTW(f_2008, f_2010)
    d3 = DTW(f_2009, f_2010)

    plt.figure(figsize=(25, 5))
    plt.plot(f_2008.Volume.values, marker='o', label="2008")
    plt.plot(f_2009.Volume.values, marker='s', label="2009")
    plt.plot(f_2010.Volume.values, marker='d', label="2010")
    plt.legend()

    print( d1 , '= DTW(f_2008, f_2009)' )
    print( d2 , '= DTW(f_2008, f_2010)' )
    print( d3 , '= DTW(f_2009, f_2010)' )

# %%
#POLYMINAL FEATURE PREPARATION
# Prepare data for classification

#dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

X = dp1.ix[:, dp1.columns != 'pef']
y = dp1.pef
X = X.as_matrix().astype(np.float)

##---- Polynomial features
poly=1
p = PolynomialFeatures(poly)
o = p.fit_transform(X)
X = o

# %%
def score(y_true,y_pred): 
    mse = mean_squared_error(y_true, y_pred)
    r2  = r2_score(y_true, y_pred)
    dtw = DTW(y_true, y_pred)
#    print("MSE: {} R2: {}".format(mse,r2))
    score = mse
    score = r2;
    return score

def myscorer():
    return make_scorer(score, greater_is_better=True) # change for false if using R2
#    return make_scorer(score, greater_is_better=False) # change for false if using MSE


def GridSearch(clf, X,y,param_grid, cv=5, scorer=None):
    clfs = "Grid search on {} ".format(str(clf)[0:20] + "..." + str(clf)[-10]) 
    print ("Grid search on: ", clfs)
    #cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
    grid = GridSearchCV(clf, param_grid=param_grid, cv=cv, scoring=scorer)
    grid.fit(X, y)

    print("The best parameters are %s with a score of %0.2f" % (grid.best_params_, grid.best_score_))
    return grid


RunGridSearch = False

if ( RunGridSearch ):
#    C_range = np.logspace(-2, 10, 13)
#    gamma_range = np.logspace(-9, 3, 5)
#    param_grid = dict(gamma=gamma_range, C=C_range)
#    GridSearch(SVR(), X,y, param_grid, cv=5)
    
#    param_grid = dict(alpha=np.linspace(0.01, 5000, 100));
#    grid = GridSearch(Ridge(random_state=0), X,y, param_grid, cv=5, scorer= myscorer())
    
    param_grid = dict(alpha=np.linspace(.5, 5, 10), gamma=np.linspace(0.01, 1, 10), degree=[1,2,3,4,5,6,7,8], kernel=['rbf','linear']);
    grid = GridSearch(    KernelRidge(kernel='rbf'), X,y, param_grid, cv=5) #, scorer= myscorer())
    
#    param_grid = dict(max_depth=range(10,50), max_features= ['auto', 'sqrt', 'log2'], n_estimators=[10,20,30,40] );
#    GridSearch(RandomForestRegressor(random_state=10), X,y, param_grid, cv=5)

else:
    prev = '''
Grid search SVR
The best parameters are {'C': 1.0, 'gamma': 1000.0} with a score of -0.19

RIDGE: I did scoring on DTW and alpha=50 seems good 

    Grid search on:  Grid search on Ridge(alpha=1.0, cop...t 
    The best parameters are {'alpha': 50.514949494949491} with a score of -74.02
    
    For MSE and R2, higher alpha is favaoured

'''
    print ('Previous results are:\n', prev)
# Out:
# Previous results are:
#
# Grid search SVR
# The best parameters are {'C': 1.0, 'gamma': 1000.0} with a score of -0.19
#
# RIDGE: I did scoring on DTW and alpha=50 seems good
#
#     Grid search on:  Grid search on Ridge(alpha=1.0, cop...t
#     The best parameters are {'alpha': 50.514949494949491} with a score of -74.02
#
#     For MSE and R2, higher alpha is favaoured

# %%
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.05, 'loss': 'quantile', 'alpha':.95}
clfs = [
    ensemble.GradientBoostingRegressor(**params),
    ensemble.GradientBoostingRegressor(loss='quantile', alpha=.95,
                                n_estimators=250, max_depth=5,
                                learning_rate=.1, min_samples_leaf=9,
                                min_samples_split=9),
    DecisionTreeRegressor(max_depth=2), 
    DecisionTreeRegressor(max_depth=15),
    linear_model.LinearRegression(),
    RandomForestRegressor(max_depth=50, random_state=0),
#    AdaBoostRegressor(),
    Lasso(alpha=20000, max_iter=1e5),
    Lasso(alpha=0.5, max_iter=1e5),
    Ridge(alpha=50),
    Ridge(alpha=500),

#    GaussianProcess(corr='squared_exponential', theta0=1e-1, thetaL=1e-3, thetaU=1,random_start=100),
#    GaussianProcess( theta0=1e-1, thetaL=1e-3, thetaU=1,random_start=100),

    KernelRidge(kernel='rbf', degree=1,gamma=1.1, alpha=5),
    KernelRidge(kernel='rbf', gamma=0.1, alpha=1),
    KernelRidge(kernel='rbf', gamma=0.1, alpha = 0.1),
    
    SVR(kernel='rbf', C=1, gamma=1000),
#    SVR(kernel='linear', C=500),
    SVR(kernel='poly', C=1, degree=2)  ,
]
rclfs={}
dpB= dp.copy()
rclfs
# Out:
# {}

# %%
# This is to experiment with 2,3,4and 5 days of exposure
rclfs={}
dp5= dpB  # <= This has 5 days of exposure
dp4= dp5.select(lambda x: not re.search('.*_5combined', x), axis=1)
dp3= dp4.select(lambda x: not re.search('.*_4combined', x), axis=1)
dp2= dp3.select(lambda x: not re.search('.*_3combined', x), axis=1)
dp0= dp2.select(lambda x: not re.search('.*_2combined', x), axis=1)

dp = dp0 # <== Choose whichever dataset you need here
dp
# Out:
#       pname   ampm    pef  pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff
# 0     0.000 -0.999  0.405     0.459     -1.206   -0.936  -0.388  -1.040   -1.331     1.129   -0.901  -0.252  -0.539   -1.387    -0.223   -0.784  -0.070  -0.463   -1.333    -0.159        -1.918       -0.447          1.385                -0.602            -1.285                -1.848           1.093                1.121              -1.681           -2.268            1.003             -2.214           -1.762            1.272             -0.532            -1.549            -0.787              -1.209
# 1     0.000  1.001 -0.138     0.459     -0.852   -0.370   0.364  -0.999   -0.569    -0.418   -0.613  -0.045  -0.674   -0.989    -0.635   -0.521   0.093  -0.626   -0.936    -0.612        -1.515        0.579          0.947                -1.769            -1.331                -2.108           1.238                1.251              -1.513           -1.969            1.003             -1.814           -1.743            1.308             -0.774            -0.657            -0.889              -0.632
# 2     0.000 -0.999 -0.545     0.459      0.938    0.480   0.364  -0.999   -0.569    -0.418    0.431   0.850  -0.967   -0.301    -0.348    0.293   0.694  -1.007   -0.390    -0.394        -2.180       -0.921         -0.015                 0.004            -1.285                -1.865           1.358                1.381              -1.876           -1.969            1.150             -1.574           -1.868            1.308             -0.774            -0.257            -0.482              -0.439
# 3     0.000  1.001 -0.070     0.459      0.777    1.613   0.741  -1.330   -0.291    -0.418    1.780   1.356  -1.223    0.210    -0.272    1.627   1.223  -1.247    0.123    -0.312        -1.169       -0.210         -0.190                -0.509            -1.069                -1.165           0.682                0.695              -1.326           -1.708            1.150             -1.574           -1.868            0.969             -0.653             0.573             0.468              -0.567
# ...     ...    ...    ...       ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...
# 1309  0.000  1.001 -0.239     0.459     -0.706   -0.936  -0.388   0.201   -0.430    -0.112   -1.458  -0.086  -0.769   -0.042     0.070   -1.413   0.025  -0.733    0.038     0.119         0.423        0.579          0.772                 0.424             0.367                 0.591           0.284                0.269               0.407            0.272            0.071              0.748            0.454            0.424              0.676            -0.596            -0.991              -0.118
# 1310  0.000 -0.999  0.642     0.459     -1.093   -0.936   0.364   0.201   -0.291    -0.112   -1.255  -0.278  -0.459   -0.146     0.036   -1.170  -0.116  -0.387   -0.026     0.110        -0.167       -0.921          0.597                 1.357             0.048                 0.349           0.562                0.553              -0.031            0.272            0.267              0.748            0.187            0.472              0.676             0.265            -0.584              -0.118
# 1311  0.000  1.001  0.473     0.459     -0.271   -0.370   0.364  -0.751    1.442     0.126   -0.676   0.010  -0.915    0.237     0.195   -0.651   0.055  -0.904    0.273     0.217         0.311       -1.395         -1.590                 0.564             0.298                 0.539           0.429                0.411               0.257            0.118            0.500              0.748            0.101            0.569              1.039             0.050            -0.210              -0.503
# 1312  0.000 -0.999  1.490    -2.180      0.503   -0.086   0.741  -0.751    1.442     0.432    0.226   1.206  -1.298    1.459     0.694    0.155   1.129  -1.312    1.386     0.658        -0.185       -1.395         -1.590                 1.357             0.036                 0.332           0.417                0.411              -0.125            0.118            0.500              0.748            0.101            0.703              1.039             0.050            -0.584              -0.503
#
# [1313 rows x 38 columns]

# %%
rclfs={}
plt.figure(figsize=(25, 8))
h1, h2 =-100, None
#h1, h2 =500, 550
plt.plot(dp.index[h1:h2], y[h1:h2], label='original PEF', linewidth=3)


for i, r in enumerate(clfs):
    d1 = datetime.datetime.now()
    print ("+Run Start {:2} {} : {}".format(i, d1, str(r)[0:25]), end=' ')
    
    if ( rclfs.get(str(r)) is not None ):
        yp, mse, clf, r, r2, dur = rclfs[str(r)] 
        print ("EXISTS: using MSE: {} ".format(str(r)[0:15]), mse, end=' ')
    else:
        yp, mse,r, r2, clf = run_reg(X,y, None, True, r, Y_SCALER)
        d2 = datetime.datetime.now()
        dur = d2 -d1;
        dur = dur - datetime.timedelta(microseconds=dur.microseconds)
        rclfs[str(clf)]=(yp, mse, (clf), r, r2, dur ) 
    
    l='{} MSE {:07.2f} r: {:3.2f} R^2: {:3.2f} {} '.format( str(clf)[0:5]+'..'+str(clf)[-5], mse, r, r2, str(dur) ) 
    print('-', l)
    
    plt.plot(dp.index[h1:h2], yp[h1:h2], label=l )
    #if ( i > 11):
    #    break;

plt.legend()
# Out:
# +Run Start  0 2017-12-07 22:42:02.968677 : GradientBoostingRegressor * 0* 1* 2* 3* 4*- Gradi..a MSE 0001.72 r: 0.65 R^2: -0.72 0:00:05
# +Run Start  1 2017-12-07 22:42:08.583285 : GradientBoostingRegressor * 0* 1* 2* 3* 4*- Gradi..a MSE 0001.46 r: 0.64 R^2: -0.46 0:00:04
# +Run Start  2 2017-12-07 22:42:12.694261 : DecisionTreeRegressor(cri * 0* 1* 2* 3* 4*- Decis..e MSE 0000.57 r: 0.66 R^2: 0.43 0:00:00
# +Run Start  3 2017-12-07 22:42:12.724314 : DecisionTreeRegressor(cri * 0* 1* 2* 3* 4*- Decis..e MSE 0000.93 r: 0.53 R^2: 0.07 0:00:00
# +Run Start  4 2017-12-07 22:42:12.855705 : LinearRegression(copy_X=T * 0* 1* 2* 3* 4*- Linea..a MSE 0000.57 r: 0.66 R^2: 0.43 0:00:00
# +Run Start  5 2017-12-07 22:42:12.880053 : RandomForestRegressor(boo * 0* 1* 2* 3* 4*- Rando..a MSE 0000.58 r: 0.66 R^2: 0.42 0:00:00
# +Run Start  6 2017-12-07 22:42:13.694393 : Lasso(alpha=20000, copy_X * 0* 1* 2* 3* 4*- Lasso..a MSE 0001.00 r: -0.04 R^2: -0.00 0:00:00
# +Run Start  7 2017-12-07 22:42:13.707381 : Lasso(alpha=0.5, copy_X=T * 0* 1* 2* 3* 4*- Lasso..a MSE 0000.83 r: 0.64 R^2: 0.17 0:00:00
# +Run Start  8 2017-12-07 22:42:13.720220 : Ridge(alpha=50, copy_X=Tr * 0* 1* 2* 3* 4*- Ridge... MSE 0000.56 r: 0.67 R^2: 0.44 0:00:00
# +Run Start  9 2017-12-07 22:42:13.733491 : Ridge(alpha=500, copy_X=T * 0* 1* 2* 3* 4*- Ridge... MSE 0000.61 r: 0.65 R^2: 0.39 0:00:00
# +Run Start 10 2017-12-07 22:42:13.746512 : KernelRidge(alpha=5, coef * 0* 1* 2* 3* 4*- Kerne..N MSE 0001.00 r: 0.20 R^2: 0.00 0:00:00
# +Run Start 11 2017-12-07 22:42:13.971234 : KernelRidge(alpha=1, coef * 0* 1* 2* 3* 4*- Kerne..N MSE 0000.63 r: 0.62 R^2: 0.37 0:00:00
# +Run Start 12 2017-12-07 22:42:14.178302 : KernelRidge(alpha=0.1, co * 0* 1* 2* 3* 4*- Kerne..N MSE 0000.63 r: 0.61 R^2: 0.37 0:00:00
# +Run Start 13 2017-12-07 22:42:14.391203 : SVR(C=1, cache_size=200,  * 0* 1* 2* 3* 4*- SVR(C..a MSE 0001.00 r: -0.05 R^2: -0.00 0:00:00
# +Run Start 14 2017-12-07 22:42:14.725357 : SVR(C=1, cache_size=200,  * 0* 1* 2* 3* 4*- SVR(C..a MSE 0000.58 r: 0.65 R^2: 0.42 0:00:00

# %%
rdf = pd.DataFrame.from_dict(rclfs, orient='index')
rdf.columns = 'y_pred,mse,clf,r,R2,time_to_run'.split(',')
rdf.insert(1,'DTW',0)
rdf.insert(3,'sum',0)
#rdf.clf=rdf.clf.astype(str)
rdf['DTW'] = 0; #rdf.y_pred.apply(lambda x: DTW(x,y))
rdf['sum'] = rdf.y_pred.apply(sum)
rdf= rdf.sort_values('R2,DTW,mse,sum'.split(','), ascending=[0,1,1,1])
HTML(rdf.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>y_pred</th>
#       <th>DTW</th>
#       <th>mse</th>
#       <th>sum</th>
#       <th>clf</th>
#       <th>r</th>
#       <th>R2</th>
#       <th>time_to_run</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ridge(alpha=50, copy_X=True, fit_intercept=True, max_iter=None,\n   normalize=False, random_state=None, solver='auto', tol=0.001)</th>
#       <td>0      -0.111
# 1      -0.216
# 2      -0.216
# 3      -0.439
#         ...
# 1309   -0.336
# 1310   -0.153
# 1311   -0.472
# 1312    1.482
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.557</td>
#       <td>-4.893</td>
#       <td>Ridge(alpha=50, copy_X=True, fit_intercept=True, max_iter=None,\n   normalize=False, random_state=None, solver='auto', tol=0.001)</td>
#       <td>0.666</td>
#       <td>0.443</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False, random_state=None,\n           splitter='best')</th>
#       <td>0      -0.249
# 1      -0.250
# 2      -0.269
# 3      -0.271
#         ...
# 1309   -0.271
# 1310   -0.269
# 1311   -0.271
# 1312    1.390
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.568</td>
#       <td>1.364</td>
#       <td>DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False, random_state=None,\n           splitter='best')</td>
#       <td>0.657</td>
#       <td>0.432</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)</th>
#       <td>0      -0.118
# 1      -0.493
# 2      -0.225
# 3      -0.491
#         ...
# 1309   -0.174
# 1310    0.002
# 1311   -0.401
# 1312    1.624
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.571</td>
#       <td>-7.798</td>
#       <td>LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)</td>
#       <td>0.657</td>
#       <td>0.429</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,\n           max_features='auto', max_leaf_nodes=None,\n           min_impurity_split=1e-07, min_samples_leaf=1,\n           min_samples_split=2, min_weight_fraction_leaf=0.0,\n           n_estimators=10, n_jobs=1, oob_score=False, random_state=0,\n           verbose=0, warm_start=False)</th>
#       <td>0      -0.253
# 1       0.042
# 2      -0.114
# 3      -0.161
#         ...
# 1309   -0.589
# 1310   -0.097
# 1311   -0.772
# 1312    1.419
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.576</td>
#       <td>-5.253</td>
#       <td>(DecisionTreeRegressor(criterion='mse', max_depth=50, max_features='auto',\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False,\n           random_state=209652396, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=50, max_features='auto',\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False,\n           random_state=398764591, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=50, max_features='auto',\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False,\n           random_state=924231285, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=50, max_features='auto',\n           max_leaf_nodes=None, min_impurity_split=1e...</td>
#       <td>0.659</td>
#       <td>0.424</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>SVR(C=1, cache_size=200, coef0=0.0, degree=2, epsilon=0.1, gamma='auto',\n  kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)</th>
#       <td>0       0.217
# 1       0.060
# 2      -0.139
# 3      -0.626
#         ...
# 1309   -0.068
# 1310    0.154
# 1311    0.103
# 1312    1.346
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.580</td>
#       <td>85.589</td>
#       <td>SVR(C=1, cache_size=200, coef0=0.0, degree=2, epsilon=0.1, gamma='auto',\n  kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)</td>
#       <td>0.653</td>
#       <td>0.420</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>Ridge(alpha=500, copy_X=True, fit_intercept=True, max_iter=None,\n   normalize=False, random_state=None, solver='auto', tol=0.001)</th>
#       <td>0      -0.137
# 1      -0.156
# 2      -0.095
# 3      -0.201
#         ...
# 1309   -0.215
# 1310   -0.156
# 1311   -0.254
# 1312    1.046
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.608</td>
#       <td>-2.281</td>
#       <td>Ridge(alpha=500, copy_X=True, fit_intercept=True, max_iter=None,\n   normalize=False, random_state=None, solver='auto', tol=0.001)</td>
#       <td>0.652</td>
#       <td>0.392</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>KernelRidge(alpha=0.1, coef0=1, degree=3, gamma=0.1, kernel='rbf',\n      kernel_params=None)</th>
#       <td>0       0.437
# 1       0.050
# 2      -0.529
# 3      -0.086
#         ...
# 1309   -0.243
# 1310    0.392
# 1311   -0.876
# 1312    1.403
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.631</td>
#       <td>-55.546</td>
#       <td>KernelRidge(alpha=0.1, coef0=1, degree=3, gamma=0.1, kernel='rbf',\n      kernel_params=None)</td>
#       <td>0.609</td>
#       <td>0.369</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>KernelRidge(alpha=1, coef0=1, degree=3, gamma=0.1, kernel='rbf',\n      kernel_params=None)</th>
#       <td>0       0.172
# 1      -0.226
# 2      -0.390
# 3      -0.362
#         ...
# 1309   -0.225
# 1310    0.104
# 1311   -0.446
# 1312    0.885
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.633</td>
#       <td>-55.666</td>
#       <td>KernelRidge(alpha=1, coef0=1, degree=3, gamma=0.1, kernel='rbf',\n      kernel_params=None)</td>
#       <td>0.621</td>
#       <td>0.367</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>Lasso(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=100000.0,\n   normalize=False, positive=False, precompute=False, random_state=None,\n   selection='cyclic', tol=0.0001, warm_start=False)</th>
#       <td>0      -0.073
# 1      -0.073
# 2      -0.051
# 3      -0.073
#         ...
# 1309   -0.073
# 1310   -0.077
# 1311   -0.085
# 1312    0.394
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.830</td>
#       <td>-2.115</td>
#       <td>Lasso(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=100000.0,\n   normalize=False, positive=False, precompute=False, random_state=None,\n   selection='cyclic', tol=0.0001, warm_start=False)</td>
#       <td>0.639</td>
#       <td>0.170</td>
#       <td>00:00:00</td>
#     </tr>
#     <tr>
#       <th>DecisionTreeRegressor(criterion='mse', max_depth=15, max_features=None,\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False, random_state=None,\n           splitter='best')</th>
#       <td>0      -0.368
# 1       0.337
# 2      -0.985
# 3      -0.375
#         ...
# 1309    0.613
# 1310    0.744
# 1311    0.328
# 1312    2.169
# Name: pef, Length: 1313, dtype: float64</td>
#       <td>0</td>
#       <td>0.930</td>
#       <td>-25.224</td>
#       <td>DecisionTreeRegressor(criterion='mse', max_depth=15, max_features=None,\n           max_leaf_nodes=None, min_impurity_split=1e-07,\n           min_samples_leaf=1, min_samples_split=2,\n           min_weight_fraction_leaf=0.0, presort=False, random_s

# %%
#Lets print individual results
h1=-120
h2=None
for i, r in enumerate(rdf.iterrows()):
    clf = str(r[1][4]);
    mse = r[1][2]
    dtw = r[1][1]
    dur = r[1][-1]
    l='[ {} ] : MSE:{:07.2f} DTW:{:07.2f} {} {}'.format( str(clf)[0:17]+'..'+str(clf)[-10], mse, dtw, str(dur), poly)
    R2  = r[1][6]
    l='[ {} ] : R2{:4.2} MSE:{:07.2f} DTW:{:07.2f}'.format( str(clf)[0:17]+'..'+str(clf)[-10], R2, mse, dtw)
    plt.figure(figsize=(25, 5))
    plt.plot(dp.index[h1:h2], y[h1:h2], label='original PEF', linewidth=3)
    plt.plot(dp.index[h1:h2], r[1][0][h1:h2], linewidth=1, label=l)
    plt.legend()
    plt.show()

# %%
axes = scatter_matrix(rdf, alpha=0.2, diagonal='kde', figsize=(13, 10)); # diagonal can be 'hist';

# %%
r1 = rdf[rdf.mse <= 1600]

plt.figure(figsize=(6, 6))
plt.scatter(r1.mse, r1.DTW)
plt.grid()
plt.xlabel("MSE")
plt.ylabel("DTW")

# %%
'''
POlynomial degree 1 has the following results

GradientBoostingRegressor  MSE 2470.60 r: 0.19  R^2: -2.22 0:00:03 
GradientBoostingRegressor  MSE 1575.88 r: 0.24  R^2: -1.05 0:00:01 
DecisionTreeRegressor(cri  MSE 0758.55 r: 0.20  R^2: 0.01 0:00:00 
DecisionTreeRegressor(cri  MSE 1241.32 r: 0.22  R^2: -0.62 0:00:00 
LinearRegression(copy_X=T  MSE 0699.95 r: 0.31  R^2: 0.09 0:00:00 
RandomForestRegressor(boo  MSE 0759.59 r: 0.27  R^2: 0.01 0:00:00 
Lasso(alpha=20000, copy_X  MSE 0769.67 r: -0.06 R^2: -0.00 0:00:00 
Lasso(alpha=0.5, copy_X=T  MSE 0770.17 r: -0.07 R^2: -0.00 0:00:00 
Ridge(alpha=50, copy_X=Tr  MSE 0693.19 r: 0.31  R^2: 0.10 0:00:00 
Ridge(alpha=500, copy_X=T  MSE 0712.64 r: 0.28  R^2: 0.07 0:00:00 
KernelRidge(alpha=1, coef  MSE 0685.84 r: 0.34  R^2: 0.11 0:00:00 
SVR(C=1, cache_size=200,   MSE 0777.55 r: -0.12 R^2: -0.01 0:00:00 
SVR(C=500, cache_size=200  MSE 0927.78 r: 0.29  R^2: -0.21 0:00:12 


POLYNOMIAL Degree 2:
GradientBoostingRegressor  MSE 3389.86 r: 0.03  R^2: -3.41 0:00:22 
GradientBoostingRegressor  MSE 1753.38 r: 0.21  R^2: -1.28 0:00:13 
DecisionTreeRegressor(cri  MSE 0785.32 r: 0.13  R^2: -0.02 0:00:00 
DecisionTreeRegressor(cri  MSE 1242.66 r: 0.16  R^2: -0.62 0:00:00 
LinearRegression(copy_X=T  MSE 2300.86 r: 0.14  R^2: -2.00 0:00:00 
RandomForestRegressor(boo  MSE 0759.73 r: 0.26  R^2: 0.01  0:00:01 
Lasso(alpha=20000, copy_X  MSE 0773.09 r: -0.11 R^2: -0.01 0:00:00 
Lasso(alpha=0.5, copy_X=T  MSE 0773.62 r: -0.11 R^2: -0.01 0:00:00 
Ridge(alpha=50, copy_X=Tr  MSE 0719.43 r: 0.29  R^2: 0.06  0:00:00 
Ridge(alpha=500, copy_X=T  MSE 0708.72 r: 0.28  R^2: 0.08  0:00:00 
KernelRidge(alpha=1, coef  MSE 0757.13 r: 0.13  R^2: 0.01  0:00:00 
SVR(C=1, cache_size=200,   MSE 0776.06 r: -0.08 R^2: -0.01 0:00:00 
SVR(C=500, cache_size=200  MSE 3380.81 r: 0.10  R^2: -3.40 0:00:01 

'''


'results of combined sum of exposure for 2,3,4,5 days'

'''
-
'''
