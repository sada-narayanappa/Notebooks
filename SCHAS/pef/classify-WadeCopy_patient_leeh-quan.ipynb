# %%
# %run "../../PyUtils/common.ipynb"
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcess
from sklearn import linear_model
from sklearn import cross_validation 
from sklearn import ensemble
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.formula.api as smf
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB


patient="leeh2"
ampm="pm"
file="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?q=SELECT%20*%20FROM%20calculated_jlee%20WHERE%20ampm=%27"+ampm+"%27%20AND%20pname=%27"+patient+"%27%20ORDER%20BY%20date,%20time"

predictQuantile=True
lowerPercent = 0.20
upperPercent = 0.20

fileName = file;

dfOriginal = LoadDataSet(fileName, checkForDateTime=False);
#displayDFs (dfOriginal, maxrows=3 )
#for c in dfOriginal.columns: print (c,  end=', ')
dfOriginal
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','75%')
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','95%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, tab_maxDisp )
#     cb = UpdateTableShowRows.bind(null, tab_maxDisp, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function Page(back, dispRows, tableID){
#     last = $(tableID).find('th:last').text()
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRowsFromIndex({0},idx='{1}',dispRows={2},goBack={3})".format(dfName, last, dispRows,back )
#     cb = UpdateTableShowRows.bind(null, dispRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function SaveDataFrameFromHTML(tableID, dataFrameVariable){
#     ret = $(tableID).html()
#     s = ret.indexOf('</thead>')
#     if ( s< 0 ) return;
#     s1 = ret.substr(s+10)
#     ret = s1.replace(/\n/g, '');
#     //console.log(s, ret)
#     cmd = "UpdateDataFrameFromHTML(r'''{0}''', {1})".format(ret,dataFrameVariable);
#     gu.callPython(cmd)
# }
#
# function ShowSearchResults(resultsDIV, html){
#     //console.log("===>GOT:" + html)
#     html = html.trim()
#     if ( html.startsWith("'") && html.endsWith("'") ){
#         html =
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff
# 0    leeh2  2015-03-11   pm  21:30:00  251        Y     24.000    0.017   0.900   0.041    0.048   121.000    0.163  12.700   0.677    0.576  1126.000    0.007   0.529   0.028    0.024    46.917         0.200        7.100        340.000                55.000             3.400                -7.700        1011.900             1020.900               0.200            5.500         1016.200             73.000           -2.800         1007.600             50.000             8.300             8.600              23.000
# 1    leeh2  2015-03-12   pm  21:31:00  288        Y     24.017    0.007   0.700   0.040    0.047    63.000    0.108  10.607   0.697    0.564   802.900    0.005   0.442   0.029    0.023    33.431         3.500        3.300        200.000                69.000             5.400                -1.600        1009.500             1018.400               2.000            4.900         1013.000             74.000           -1.400         1009.400             41.000             6.300             3.600              33.000
# 2    leeh2  2015-03-13   pm  21:00:00  265        Y     22.483    0.007   0.800   0.044    0.048    90.000    0.131  11.693   0.672    0.620  1073.600    0.006   0.520   0.030    0.028    47.751         4.000        1.600        270.000                70.000             5.700                -0.900        1011.900             1020.800               0.600            8.700         1011.900             99.000            2.500         1008.100             37.000             6.200             3.800              62.000
# 3    leeh2  2015-03-14   pm  22:00:00  265        Y     24.000    0.012   0.800   0.036    0.050    67.000    0.140  13.600   0.711    0.670  1000.000    0.006   0.567   0.030    0.028    41.667         2.900        1.900        320.000                70.000             5.300                -2.000        1014.800             1023.800               0.100            7.700         1017.100             83.000            0.100         1012.700             36.000             7.600             4.400              47.000
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...
# 586  leeh2  2016-10-17   pm  22:01:00  281        Y     24.000    0.006   0.800   0.048    0.060    95.000    0.101  14.500   0.391    0.834  1694.050    0.004   0.604   0.016    0.035    70.585        17.700        3.600        340.000                98.000            19.700                17.300        1010.700             1019.100              15.200           20.700         1010.700             98.000           15.600         1008.000             76.000             5.100             2.700              22.000
# 587  leeh2  2016-10-18   pm  20:40:00  251        Y     22.650    0.010   0.900   0.030    0.076   116.000    0.098  13.287   0.341    0.908  1634.483    0.004   0.587   0.015    0.040    72.163        17.100        2.300        360.000                73.000            14.200                12.200        1011.000             1019.400              14.200           21.200         1013.400             98.000           12.400         1010.600             67.000             8.800             2.800              31.000
# 588  leeh2  2016-10-19   pm  21:20:00  254        Y     24.667    0.011   1.100   0.061    0.076   121.000    0.137  19.167   0.425    1.369  2240.000    0.006   0.777   0.017    0.056    90.811        16.900        2.300        340.000                90.000            17.300                15.200        1010.100             1018.500              14.100           21.600         1011.500             98.000           15.200         1008.200             71.000             6.400             3.300              27.000
# 589  leeh2  2016-10-20   pm  21:20:00  310        G     24.000    0.006   0.900   0.050    0.075   122.000    0.110  17.800   0.408    1.283  2172.000    0.005   0.742   0.017    0.053    90.500        20.100        4.000        140.000                68.000            16.000                14.000        1010.700             1019.100              15.800           24.200         1012.200             98.000           14.400         1009.000             52.000             9.800             3.200              46.000
#
# [590 rows x 40 columns]

# %%
#Break into groups by percentage

dfOriginal.sort_values(by='pef', ascending=True, inplace=True)
dfOriginal.reset_index(drop=True, inplace=True)
numberOfElements = len(dfOriginal)
upperBoundary = upperPercent*numberOfElements
lowerBoundary = lowerPercent*numberOfElements
dfOriginal['percent_group']=-1

for i in dfOriginal.index:

    if i < lowerBoundary:
        dfOriginal['percent_group'][i] = 0

    elif i > upperBoundary : 
        dfOriginal['percent_group'][i] = 2

    else:
        dfOriginal['percent_group'][i] = 1

print(dfOriginal)
# Out:
#      pname        date ampm      time  pef pef_zone  tm_window  so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  temperature_diff  airpressure_diff  precipitation_diff  percent_group
# 0    leeh2  2015-10-23   pm  21:30:00  185        R     24.083    0.008   0.800   0.041    0.055   103.000    0.126  12.758   0.441    0.777  1474.583    0.005   0.530   0.018    0.032    61.228        16.700        2.500        270.000                86.000            16.300                14.300        1009.900             1018.300              14.800           19.700         1012.200             98.000           14.800         1009.500             71.000             4.900             2.700              27.000              0
# 1    leeh2  2015-11-09   pm  21:30:00  199        Y     23.983    0.008   0.600   0.024    0.030    42.000    0.087   8.993   0.396    0.446   345.783    0.004   0.375   0.017    0.019    14.418        11.000        4.300        340.000                98.000            12.800                10.600        1011.900             1020.600              11.200           12.800         1011.900             98.000            9.600         1007.200             89.000             3.200             4.700               9.000              0
# 2    leeh2  2015-10-19   pm  21:45:00  201        Y     24.533    0.012   1.000   0.072    0.068   165.000    0.147  19.402   0.771    0.891  3245.567    0.006   0.791   0.031    0.036   132.292        17.400        1.600        270.000                98.000            19.400                17.000        1007.900             1016.300              14.200           21.900         1012.000             98.000           13.900         1007.100             64.000             8.000             4.900              34.000              0
# 3    leeh2  2016-01-11   pm  22:01:00  203        Y     24.517    0.007   0.600   0.030    0.036    67.000    0.134  10.608   0.518    0.492  1155.000    0.005   0.433   0.021    0.020    47.111        -4.400        3.600         20.000                54.000             2.400               -12.300        1018.100             1027.400              -1.600           -0.700         1020.000             68.000           -5.300         1016.800             37.000             4.600             3.200              31.000              0
# ..     ...         ...  ...       ...  ...      ...        ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...               ...               ...                 ...            ...
# 586  leeh2  2016-07-13   pm  21:05:00  322        G     24.000    0.010   0.600   0.025    0.033    59.000    0.132  10.725   0.379    0.567   943.667    0.005   0.447   0.016    0.024    39.319        24.100        2.200        250.000                98.000            29.300                23.700         993.900             1001.900              23.800           27.100          994.400             98.000           22.900          992.600             90.000             4.200             1.800               8.000              2
# 587  leeh2  2016-05-17   pm  21:01:00  324        G     24.317    0.013   0.800   0.087    0.091   124.000    0.210  14.863   1.133    0.797  2155.450    0.009   0.611   0.047    0.033    88.641        17.900        1.500        340.000                82.000            16.700                14.700        1008.700             1017.100              16.500           23.500         1008.700             98.000           11.800         1003.200             38.000            11.700             5.500              60.000              2
# 588  leeh2  2016-09-28   pm  21:08:00  326        G     23.917    0.005   0.600   0.025    0.054    59.000    0.098  11.150   0.310    0.687  1011.150    0.004   0.466   0.013    0.029    42.278        18.900        3.100         20.000                98.000            21.300                18.500        1006.800             1015.100              18.800           21.500         1009.300             98.000           18.900         1005.800             96.000             2.600             3.500               2.000              2
# 589  leeh2  2016-08-30   pm  21:06:00  326        G     23.400    0.014   0.400   0.034    0.041    46.000    0.149   7.250   0.589    0.309   679.100    0.006   0.310   0.025    0.013    29.021        20.000        5.100        360.000                84.000            19.600                17.200         983.200              991.300              21.300           23.800          992.000             84.000           20.000          982.600             60.000             3.800             9.400              24.000              2
#
# [590 rows x 41 columns]

# %%
df=dfOriginal.copy()

#1. Remove all the rows that does not have any pef values 

df=df.reset_index(drop=True)

#2. Combine 
df=df.fillna(0)
sdttm = df.date + " " + df.time
df.insert(0, 'sdttm', sdttm)
df.sdttm = pd.to_datetime(df.sdttm)

df.sort_values(by='sdttm', ascending=True, inplace=True)
alldrps = "cname, pname, date, time, ampm, timeofday, dateofmeasure, npt, pef1, pef2, pef3, temperature_diff, airpressure_diff, precipitation_diff, tm_window"
if predictQuantile:
    alldrps += ', pef_zone'
else:
    alldrps += ', percent_group'
drps  = alldrps.split(', ')
df=df.drop(drps, axis=1, errors='ignore')
df=df.reset_index(drop=True)

## <== do the following for SAP PA tool
#pef = df.pef;
#df=df.drop(['pef'], axis=1)
#df.insert(1, 'pef1', pef)

#pef[-10:]=0     # Set last 10 to zero for predictions
#df.insert(1, 'pef', pef)
#df.to_csv("HanD/hand1.csv", sep=';')

df1 = df.copy()
df1 = df1.set_index(df1.sdttm)
df1=df1.drop('sdttm', axis=1, errors='ignore')

nq = 5
lnq=list(range(0,nq))
s= pd.qcut(df1.pef, nq, labels=lnq )
df1.insert(1,"pefcat", s)
df1.pefcat = df1.pefcat.astype(str)


pefcol = df1['pef']


columns =  '''so2_max,co_max,o3_max,no2_max,pm10_max,so2_sum,co_sum,o3_sum,no2_sum,pm10_sum,so2_avg,co_avg,o3_avg,no2_avg,pm10_avg,temperaturec,windspeedms,winddirection,precipitationpercent,vaporpressurehpa,dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,
 temperature_max,airpressure_max,precipitation_max,temperature_min,airpressure_min,precipitation_min'''
if predictQuantile:
    columns += ',percent_group'
else:
    columns += ',pef_zone'

#'''pefcat,pef_zone,so2_max,co_max,o3_max,no2_max,temperaturec,windspeedms,precipitationpercent,vaporpressurehpa,
#dewpointtemperaturec,airpressurehpa,sealevelpressurehpa,groundtemperaturec,temperature_max,airpressure_max,temperature_min'''

 
#amin,pmin,tmaxlesstmin,amaxlessamin,pmaxlesspmin'''
cs = [c.strip() for c in columns.split(',')]

df1=df1[cs]
#HTML(df1.to_html())
#displayDFs (df1, maxrows=3 )
df1
# Out:
#                      so2_max  co_max  o3_max  no2_max  pm10_max  so2_sum  co_sum  o3_sum  no2_sum  pm10_sum  so2_avg  co_avg  o3_avg  no2_avg  pm10_avg  temperaturec  windspeedms  winddirection  precipitationpercent  vaporpressurehpa  dewpointtemperaturec  airpressurehpa  sealevelpressurehpa  groundtemperaturec  temperature_max  airpressure_max  precipitation_max  temperature_min  airpressure_min  precipitation_min  percent_group
# sdttm
# 2015-03-11 21:30:00    0.017   0.900   0.041    0.048   121.000    0.163  12.700   0.677    0.576  1126.000    0.007   0.529   0.028    0.024    46.917         0.200        7.100        340.000                55.000             3.400                -7.700        1011.900             1020.900               0.200            5.500         1016.200             73.000           -2.800         1007.600             50.000              2
# 2015-03-12 21:31:00    0.007   0.700   0.040    0.047    63.000    0.108  10.607   0.697    0.564   802.900    0.005   0.442   0.029    0.023    33.431         3.500        3.300        200.000                69.000             5.400                -1.600        1009.500             1018.400               2.000            4.900         1013.000             74.000           -1.400         1009.400             41.000              2
# 2015-03-13 21:00:00    0.007   0.800   0.044    0.048    90.000    0.131  11.693   0.672    0.620  1073.600    0.006   0.520   0.030    0.028    47.751         4.000        1.600        270.000                70.000             5.700                -0.900        1011.900             1020.800               0.600            8.700         1011.900             99.000            2.500         1008.100             37.000              2
# 2015-03-14 22:00:00    0.012   0.800   0.036    0.050    67.000    0.140  13.600   0.711    0.670  1000.000    0.006   0.567   0.030    0.028    41.667         2.900        1.900        320.000                70.000             5.300                -2.000        1014.800             1023.800               0.100            7.700         1017.100             83.000            0.100         1012.700             36.000              2
# ...                      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...      ...     ...     ...      ...       ...           ...          ...            ...                   ...               ...                   ...             ...                  ...                 ...              ...              ...                ...              ...              ...                ...            ...
# 2016-10-17 22:01:00    0.006   0.800   0.048    0.060    95.000    0.101  14.500   0.391    0.834  1694.050    0.004   0.604   0.016    0.035    70.585        17.700        3.600        340.000                98.000            19.700                17.300        1010.700             1019.100              15.200           20.700         1010.700             98.000           15.600         1008.000             76.000              2
# 2016-10-18 20:40:00    0.010   0.900   0.030    0.076   116.000    0.098  13.287   0.341    0.908  1634.483    0.004   0.587   0.015    0.040    72.163        17.100        2.300        360.000                73.000            14.200                12.200        1011.000             1019.400              14.200           21.200         1013.400             98.000           12.400         1010.600             67.000              2
# 2016-10-19 21:20:00    0.011   1.100   0.061    0.076   121.000    0.137  19.167   0.425    1.369  2240.000    0.006   0.777   0.017    0.056    90.811        16.900        2.300        340.000                90.000            17.300                15.200        1010.100             1018.500              14.100           21.600         1011.500             98.000           15.200         1008.200             71.000              2
# 2016-10-20 21:20:00    0.006   0.900   0.050    0.075   122.000    0.110  17.800   0.408    1.283  2172.000    0.005   0.742   0.017    0.053    90.500        20.100        4.000        140.000                68.000            16.000                14.000        1010.700             1019.100              15.800           24.200         1012.200             98.000           14.400         1009.000             52.000              2
#
# [590 rows x 31 columns]

# %%
# from sklearn.neural_network import MLPClassifier
# nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)

# clf = nn;

# Y_SCALER = None
# #Normalize the input and save the scalar for outcome variable "pefmax" in this case.
# scaler = StandardScaler()
# dp = prepareDF(df1, True)
# for c in dp.columns:
#     if ( c == 'pefcat'):
#         #Y_SCALER = StandardScaler()
#         #dp[c] = Y_SCALER.fit_transform(dp[c])
#         pass;
#     else:
#         dp[c] = scaler.fit_transform(dp[c])
        
# #dp = dp["so2,pef,o3,co,no2,pm10,tmax".split(',')]
# dp1 = dp.set_index(pd.Series(range(0,len(dp)) ) )

# X = dp1.ix[:, dp1.columns != 'pefcat']
# y = dp1.pefcat 
# X = X.as_matrix().astype(np.float)


# kf = sklearn.model_selection.KFold(n_splits=5, shuffle=True)
# y_pred = y.copy()

# # Iterate through folds\
# i = 0;
# for train_index, test_index in kf.split(X):
#     #print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train = y[train_index]
#     # Initialize a classifier with key word arguments\
#     print ("*",i, end ="");
#     clf.fit(X_train,y_train)
#     y_pred[test_index] = clf.predict(X_test)
#     i = i +1;

# %%
from sklearn.naive_bayes import GaussianNB

predictColumn = "pefcat"
predictColumn = "pef_zone"
if predictQuantile:
    predictColumn = "percent_group"

if ( 'pefcat' in df1.columns ):
    df1.pefcat = df1.pefcat.astype(int)
    df1=df1.drop('pefcat', axis=1)

cls = [# Comment/uncomment out any classfiers according to your need 
       # DO NOT CHANGE
        "DecisionTree Gini" , tree.DecisionTreeClassifier(max_depth=4, criterion="gini"),
        "DecisionTree Entr" , tree.DecisionTreeClassifier(max_depth=4, criterion="entropy"), 
        "SVM"               , sklearn.svm.SVC(kernel="linear"), 
#        "SVM1"              , SVC(kernel="rbf", C=10**3),
#        "Random Forest"     , sklearn.ensemble.RandomForestClassifier(),
#        "K-NN"              , sklearn.neighbors.KNeighborsClassifier(),
        "Gradient Boosting" , sklearn.ensemble.RandomForestClassifier(),
        "Logit Regression"  , sklearn.linear_model.LogisticRegression(),
#        "Neural NW"         , MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(25, 10), random_state=1),
#        "Naive Bayes"       , GaussianNB()
];

y = df1[predictColumn]
X = df1.drop(predictColumn, axis=1)
a = Classify(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=True)
ik = 0
y_preds=[]
clsNames=[]

for i in cls:
    if type(i) is str:
        clsNames.append(i)
        y_pred = a[4][i]
        y_preds.append(y_pred)
        target_names = ['class 0', 'class 1', 'class 2']
        print(i + ' Metrics')
        y.replace(to_replace="R", value=0, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="Y", value=1, inplace=True, limit=None, regex=False, method='pad', axis=None)
        y.replace(to_replace="G", value=2, inplace=True, limit=None, regex=False, method='pad', axis=None)
        print(classification_report(y, y_pred, target_names=target_names))
# Out:
# Feature space holds 590 observations and 30 features
# Unique target labels: [2 0 1]
# * 0* 1* 2* 3* 4*
#    DecisionTree Gini accuracy: 0.774576
#    DecisionTree Gini r^2 score: -0.400218
# * 0* 1* 2* 3* 4*
#    DecisionTree Entr accuracy: 0.783051
#    DecisionTree Entr r^2 score: -0.347280
# * 0* 1* 2* 3* 4*
#                  SVM accuracy: 0.794915
#                  SVM r^2 score: -0.257285
# * 0* 1* 2* 3* 4*
#    Gradient Boosting accuracy: 0.766102
#    Gradient Boosting r^2 score: -0.453156
# * 0* 1* 2* 3* 4*
#     Logit Regression accuracy: 0.789831
#     Logit Regression r^2 score: -0.304929
# DecisionTree Gini Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.38      0.19      0.26       118
#     class 1       0.00      0.00      0.00         1
#     class 2       0.82      0.92      0.87       471
#
# avg / total       0.73      0.77      0.74       590
#
# DecisionTree Entr Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.40      0.16      0.23       118
#     class 1       0.00      0.00      0.00         1
#     class 2       0.82      0.94      0.87       471
#
# avg / total       0.73      0.78      0.74       590
#
# SVM Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00       118
#     class 1       0.00      0.00      0.00         1
#     class 2       0.80      1.00      0.89       471
#
# avg / total       0.64      0.79      0.71       590
#
# Gradient Boosting Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.35      0.19      0.24       118
#     class 1       0.00      0.00      0.00         1
#     class 2       0.82      0.91      0.86       471
#
# avg / total       0.72      0.77      0.74       590
#
# Logit Regression Metrics
#              precision    recall  f1-score   support
#
#     class 0       0.40      0.08      0.14       118
#     class 1       0.00      0.00      0.00         1
#     class 2       0.81      0.97      0.88       471
#
# avg / total       0.72      0.79      0.73       590

# %%
#(X1,y1,ra,cls) = Classify1(X,y, True, drawConfusionMatrix=True, classifiers=cls, scale=False)
DrawDecisionTree(X,y, cls[1])

# %%
import matplotlib.pyplot as plt

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (6, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'}

plt.rcParams.update(params)



#print(size(pefcol.values))
#print(size(y))
#print(y_pred)

plt.plot(pefcol.index[y == 0],pefcol.values[y == 0],'r.',pefcol.index[y == 1],pefcol.values[y == 1],'y.',pefcol.index[y == 2],pefcol.values[y == 2],'g.')

plt.xlabel('date')
plt.ylabel('PEF')
#plt.title('PEF true')
plt.grid(True)

plt.savefig('leeh2-quan.eps')
plt.show()

i=0

for ypredicted in y_preds:
        plt.plot(pefcol.index[ypredicted == 0],pefcol.values[ypredicted == 0],'r.',pefcol.index[ypredicted == 1],pefcol.values[ypredicted == 1],'y.',pefcol.index[ypredicted == 2],pefcol.values[ypredicted == 2],'g.')

        plt.xlabel('date')
        plt.ylabel('pef')
        plt.title('PEF prediction ' + clsNames[i])
        plt.grid(True)
        plt.show()
        i+=1
