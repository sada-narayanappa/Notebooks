# %%
# Students do not need to implement this code 
# This is for printing the formula
from IPython.core.display import Image 
#Image(filename='bin.png')

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy.random as rnd

# %%
n = 100
p = 0.8
k = np.arange(0, 101)
binomial = stats.binom.pmf(k, n, p)
binomial
# Out:
# array([  1.26765060e-70,   5.07060240e-68,   1.00397928e-65,
#          1.31186625e-63,   1.27251027e-61,   9.77287884e-60,
#          6.18948993e-58,   3.32464031e-56,   1.54595774e-54,
#          6.32124944e-53,   2.30093479e-51,   7.53033205e-50,
#          2.23399851e-48,   6.04898058e-47,   1.50360374e-45,
#          3.44826459e-44,   7.32756225e-43,   1.44827113e-41,
#          2.67125563e-40,   4.61143078e-39,   7.47051786e-38,
#          1.13836463e-36,   1.63510555e-35,   2.21805623e-34,
#          2.84650549e-33,   3.46135068e-32,   3.99386617e-31,
#          4.37846069e-30,   4.56610901e-29,   4.53461860e-28,
#          4.29277227e-27,   3.87734270e-26,   3.34420808e-25,
#          2.75643817e-24,   2.17272185e-23,   1.63885306e-22,
#          1.18361610e-21,   8.18934380e-21,   5.43082799e-20,
#          3.45344960e-19,   2.10660425e-18,   1.23313420e-17,
#          6.92903977e-17,   3.73845867e-16,   1.93720131e-15,
#          9.64295763e-15,   4.61184930e-14,   2.11948819e-13,
#          9.36107284e-13,   3.97367990e-12,   1.62126140e-11,
#          6.35788784e-11,   2.39643465e-10,   8.68142363e-10,
#          3.02242156e-09,   1.01113739e-08,   3.25008448e-08,
#          1.00353486e-07,   2.97599992e-07,   8.47403368e-07,
#          2.31623587e-06,   6.07537278e-06,   1.52864218e-05,
#          3.68815257e-05,   8.52885281e-05,   1.88946893e-04,
#          4.00796440e-04,   8.13556953e-04,   1.57925761e-03,
#          2.92963731e-03,   5.18964324e-03,   8.77122801e-03,
#          1.41314229e-02,   2.16810872e-02,   3.16426678e-02,
#          4.38778327e-02,   5.77339904e-02,   7.19800400e-02,
#          8.48995343e-02,   9.45716332e-02,   9.93002148e-02,
#          9.80742862e-02,   9.08981189e-02,   7.88513803e-02,
#          6.38320698e-02,   4.80617937e-02,   3.35314840e-02,
#          2.15834839e-02,   1.27538769e-02,   6.87849539e-03,
#          3.36281997e-03,   1.47816262e-03,   5.78411462e-04,
#          1.99023299e-04,   5.92835358e-05,   1.49768932e-05,
#          3.12018609e-06,   5.14669871e-07,   6.30208005e-08,
#          5.09258994e-09,   2.03703598e-10])

# %%
plt.plot(k, binomial, '-o')
plt.title('Binomial: n=%i , p=%.2f' % (n,p), fontsize=15)
plt.xlabel('Numer of successes')
plt.ylabel('Probability of successes', fontsize=15)
plt.show()

# %%
binom_sim = data = stats.binom.rvs(n = 10, p = 0.3, size = 10000)
print ('Mean: %g' % np.mean(binom_sim))
print ('SD: %g' % np.std(binom_sim, ddof=1))
plt.hist(binom_sim, bins = 10, normed = True) #normed
plt.xlabel('x')
plt.ylabel('density')
plt.show()
# Out:
# Mean: 3.0113
# SD: 1.46683

# %%
# Students do not need to implement this code 
# This is for printing the formula
from IPython.core.display import Image 
#Image(filename='geo.png')

# %%
p = 0.35
k = np.arange(0, 21)
geom = stats.geom.pmf(k, p)
geom
# Out:
# array([  0.00000000e+00,   3.50000000e-01,   2.27500000e-01,
#          1.47875000e-01,   9.61187500e-02,   6.24771875e-02,
#          4.06101719e-02,   2.63966117e-02,   1.71577976e-02,
#          1.11525685e-02,   7.24916949e-03,   4.71196017e-03,
#          3.06277411e-03,   1.99080317e-03,   1.29402206e-03,
#          8.41114340e-04,   5.46724321e-04,   3.55370809e-04,
#          2.30991026e-04,   1.50144167e-04,   9.75937083e-05])

# %%
plt.plot(k, geom, '-o')
plt.title('Geometric: $p$ = %i' % p)
plt.xlabel('Numer of trials')
plt.ylabel('Probability of trials', fontsize=15)
plt.show()

# %%
data = stats.geom.rvs(p=0.35, size = 1000)
print('Mean: %g' % np.mean(data))
print('SD: %g' % np.std(data, ddof=1))

plt.figure()
plt.hist(data, bins = 19, normed = True)
plt.xlim(0, 20)
plt.xlabel('Number of trials')
plt.title('Simulating Geometric Random Variables')
plt.show()
# Out:
# Mean: 2.886
# SD: 2.2208

# %%
# Students do not need to implement this code 
# This is for printing the formula
from IPython.core.display import Image 
#Image(filename='poisson.png')

# %%
rate = 2
n = np.arange(0, 10)
y = stats.poisson.pmf(n, rate)

# %%
plt.plot(n, y, 'o-')
plt.title('Poisson: $\lambda$ = %i' % rate)
plt.xlabel('Number of accidents')
plt.ylabel('Probability of numer of accidents')
plt.show()

# %%
data = stats.poisson.rvs(mu = 2, loc = 0, size = 1000)
print('Mean: %g' % np.mean(data))
print('SD: %g' % np.std(data, ddof=1))

plt.figure()
plt.hist(data, bins = 9, normed = True)
plt.xlim(0, 10)
plt.xlabel('Number of accidents')
plt.title('Simulating Poisson Random Variables')
plt.show()
# Out:
# Mean: 2.036
# SD: 1.42995

# %%
# Students do not need to implement this code 
# This is for printing the formula
from IPython.core.display import Image 
#Image(filename='normal.png')

# %%
mu = 0 # mean
sigma = 1 # standard deviation

x = np.arange(-5, 5, 0.1)
y = stats.norm.pdf(x, 0, 1)

plt.plot(x, y)
plt.title('Normal: $\mu$=%.1f, $\sigma^2$=%.1f' % (mu, sigma))
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %%
# Students do not need to implement this code 
# This is for printing the formula
from IPython.core.display import Image 
Image(filename='exp.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-72-7c27f63d2d8b> in <module>()
#       2 # This is for printing the formula
#       3 from IPython.core.display import Image
# ----> 4 Image(filename='exp.png')
#
# /home/centos/anaconda3/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# /home/centos/anaconda3/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# /home/centos/anaconda3/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     777         """Reload the raw data from file or URL."""
#     778         if self.embed:
# --> 779             super(Image,self).reload()
#     780             if self.retina:
#     781                 self._retina_shape()
#
# /home/centos/anaconda3/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     410         """Reload the raw data from file or URL."""
#     411         if self.filename is not None:
# --> 412             with open(self.filename, self._read_flags) as f:
#     413                 self.data = f.read()
#     414         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'exp.png'

# %%
lambd = 0.5
x = np.arange(0, 15, 0.1)
y = lambd * np.exp(-lambd * x)   # could also use stats.expon.pdf

plt.plot(x, y)
plt.title('Exponential: $\lambda$ =%.2f' % lambd)
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %%
data = stats.expon.rvs(scale = 2, size = 1000)

print ('Mean: %g' % np.mean(data))
print ('SD: %g' % np.std(data, ddof=1))

plt.figure()
plt.hist(data, bins = 20, normed = True)
plt.xlim(0, 15)
plt.title('Simulating Exponential Random Variables')
plt.show()
